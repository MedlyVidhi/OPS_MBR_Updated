# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
import datetime as dt
import matplotlib.pyplot as plt
import statistics
import warnings
warnings.filterwarnings('ignore')
import dataframe_image as dfi
import warnings
warnings.filterwarnings("ignore")

plt.rcParams['font.family'] = 'Nunito'
plt.rcParams['font.size'] = 10

# %%
color_code = ['#80ADF7','#EFBA50']
font_name = 'Nunito'
font_size = 10
font_size_title = 12
font_weight = 'bold'
orange_color = '#EFBA50'
blue_color = '#80ADF7'
grey_color = '#B0BCC8'
green_color = '#9EEDE0'
red_color = '#FD7284'
# color_code2 = [blue_color, grey_color]

background_color = "#F1F1F1"
border_color = "#B0BCC8"
text_align = 'center'
border_width ="0.5px"
border_style = 'solid'

body_design = { 'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align}
body_design2 = {'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align,'width':'70px'}
body_design3 = { 'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align,'width':'120px'}

border_design = {'selector': 'th', 'props': [('background-color' , background_color),('border-style' ,border_style),('font-family',font_name),('font-size',font_size),('border-width',border_width),('text-align',text_align),('border-color',border_color)]}
bar_width=0.5

# %%
# %run operations_utils.py

# %%
# %run path_changer_new.py

# %%
data = pd.read_csv(source_file_path+'rx_flow_dec21.csv') #change

# %%
data.head(2)
# Out:
#    Unnamed: 0 pharmacy_location_rxtimelines rxno_rxtimelines  \
# 0           0                         NY-BK        1157987-0
# 1           1                         NJ-SO        1199550-0
#
#   presnpi_rxtimelines ndc_rxtimelines trackrx_status_rxtimelines  \
# 0          1871998476     75987004005                          F
# 1          1417203928     50222030260                          B
#
#    patientno_rxtimelines erxreceived_rxtimelines rx_entered_date_rxtimelines  \
# 0                 620373     2021-12-09 12:31:00         2021-12-09 12:39:00
# 1                  77426     2021-10-15 14:03:00         2021-10-15 17:34:00
#
#   rx_entered_date_verification rx_filledon_date_rxtimelines  \
# 0          2021-12-09 12:39:00          2021-12-31 13:00:00
# 1          2021-10-15 17:34:00          2021-11-30 11:46:08
#
#   rx_pickedup_date_rxtimelines rx_delivered_date_rxtimelines  \
# 0                          NaN                           NaN
# ...

# %%
data.shape
# Out:
# (364689, 224)

# %%
df2 = pd.read_excel("C:/Users/vidhi.mittal/Downloads/columns.xlsx")

# %%
df2 = df2.head(224)
df2.head()
# Out:
#     Old column names  Filter         New_column  Unnamed: 3  \
# 0         Unnamed: 0     NaN                NaN         NaN
# 1  pharmacy_location     1.0  pharmacy_location         NaN
# 2               rxno     1.0               rxno         NaN
# 3            presnpi     1.0            presnpi         NaN
# 4                ndc     1.0                ndc         NaN
#
#         final_names2  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                NaN         NaN         NaN         NaN         NaN
# 1  pharmacy_location         NaN         NaN         NaN         NaN
# 2               rxno         NaN         NaN         NaN         NaN
# 3            presnpi         NaN         NaN         NaN         NaN
# 4                ndc         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN
# ...

# %%
var = list(df2['final_names'].values)

# %%
data.head(1)
# Out:
#    Unnamed: 0 pharmacy_location_rxtimelines rxno_rxtimelines  \
# 0           0                         NY-BK        1157987-0
#
#   presnpi_rxtimelines ndc_rxtimelines trackrx_status_rxtimelines  \
# 0          1871998476     75987004005                          F
#
#    patientno_rxtimelines erxreceived_rxtimelines rx_entered_date_rxtimelines  \
# 0                 620373     2021-12-09 12:31:00         2021-12-09 12:39:00
#
#   rx_entered_date_verification rx_filledon_date_rxtimelines  \
# 0          2021-12-09 12:39:00          2021-12-31 13:00:00
#
#   rx_pickedup_date_rxtimelines rx_delivered_date_rxtimelines  \
# 0                          NaN                           NaN
#
#   rx_labelprint_date_verification rx_drugpick_date_verification  \
# 0             2021-12-14 10:39:55           2021-12-14 10:02:00
#
#   rx_rphpick_date_verification last_run_rxtimelines rx_code_key_location_d  \
# 0          2021-12-14 10:40:08  2022-01-09 01:21:07        NY-BK-1157987-0
#
# ...

# %%
data.columns = var
data.head(2)
# Out:
#    Unnamed: 0 pharmacy_location       rxno     presnpi          ndc  \
# 0           0             NY-BK  1157987-0  1871998476  75987004005
# 1           1             NJ-SO  1199550-0  1417203928  50222030260
#
#   trackrx_status  patientno          erxreceived      rx_entered_date  \
# 0              F     620373  2021-12-09 12:31:00  2021-12-09 12:39:00
# 1              B      77426  2021-10-15 14:03:00  2021-10-15 17:34:00
#
#   rx_entered_date_verification     rx_filledon_date     rx_pickedup_date  \
# 0          2021-12-09 12:39:00  2021-12-31 13:00:00                  NaN
# 1          2021-10-15 17:34:00  2021-11-30 11:46:08  2021-12-02 00:00:00
#
#   rx_delivered_date   rx_labelprint_date     rx_drugpick_date  \
# 0               NaN  2021-12-14 10:39:55  2021-12-14 10:02:00
# 1               NaN  2021-11-30 18:50:21  2021-11-30 18:54:00
#
#        rx_rphpick_date             last_run rx_code_key_location       nabp  \
# ...

# %%
df = data[data['rx_code_key_location'].str.endswith('-0',na=False)]

# %%
def f(row):
        if row['status_tag'] == 'Delivered':
                return False
        elif row.status_tag == 'Pickedup':
                return True
        else:    
            return np.nan

# %%
df['is_pickedup'] = df.apply(f, axis = 1)

# %%
df.rename(columns = {'erxreceived': 'track_erx_received',
 'rx_entered_date': 'track_rx_entered',
 'datef': 'track_rx_filled',
 'rx_filledon_date':'filled_datekey',
 'rx_pickedup_date': 'final_rx_pickedup',
#  'new_delivered_date':'track_rx_delivered',
 'rx_labelprint_date': 'track_label_printed',
 'rx_drugpick_date': 'final_rx_drug_picks',
 'rx_rphpick_date': 'final_rx_rph_picks',
 'first_billed_date': 'first_billed_datetime',
 'last_billed_date': 'end_billed_datetime',
 'processing_start': 'trackrx_processing_date_starttime',
 'patmobileno': 'PATMOBILENO',
 'patphone': 'PATPHONE',
 'totalrxamount': 'TOTALRXAMOUNT',
 'trackrx_last_status_tag': 'trackrx_last_status'}, inplace = True)

# %%
# track_rx_delivered 
# delivery_time

# %%
# df.rename(columns = {'erxreceived': 'track_erx_received',           #'status': 'trackrx_status','status_y': 'status'
#  'rx_entered_date': 'track_rx_entered',
#  'rx_filledon_date': 'track_rx_filled',
#  'datef':'filled_datekey',
# # 'rx_drugpick_date':'rx_drugpick_datetime_mms',                
# #  'rx_drugpick_date': 'track_drug_picks',     
# # 'rx_rphpick_date':'rx_rphverified_datetime_mms',
#  'rx_pickedup_date': 'final_rx_pickedup',
# # 'rx_rphpick_date':'track_rph_picks',
# # 'rx_pickedup_date':'rx_pickup_datetime_mms',
    
# #  'rx_pickedup_date': 'track_rx_pickedup',
#  'new_delivered_date':'track_rx_delivered',
# #  'rx_delivered_date': 'track_rx_delivered',
#  'rx_labelprint_date': 'track_label_printed',
#  'rx_drugpick_date': 'final_rx_drug_picks',
#  'rx_rphpick_date': 'final_rx_rph_picks',
#  'first_billed_date': 'first_billed_datetime',
#  'last_billed_date': 'end_billed_datetime',
#  'processing_start': 'trackrx_processing_date_starttime',
#  'patmobileno': 'PATMOBILENO',
#  'patphone': 'PATPHONE',
#  'totalrxamount': 'TOTALRXAMOUNT',
#  'trackrx_last_status_tag': 'trackrx_last_status'}, inplace = True)

# %%
# df['track_rx_recieved_new'] =  pd.to_datetime(df.track_erx_received, dayfirst = False)
# df['track_rx_entered_new'] =  pd.to_datetime(df.track_rx_entered, dayfirst = False)
# df['max_date'] = df[['track_rx_recieved_new','track_rx_entered_new']].max(axis=1)
# df['max_date_only'] = df['max_date'].dt.date
df['pharmacy_loc'] = df['rx_code_key_location'].astype(str).str[0:5]

# %%
# six_months = date.today() - relativedelta(months=+6)
# six_months = six_months.strftime("%Y-%m")
# six_month_date = str(six_months)+"-01"
# six_month_date

# %%
df['filled_datekey_new'] =  pd.to_datetime(df.filled_datekey, dayfirst = False)

df['mon_key'] = df['filled_datekey_new'].dt.strftime('%m-%y')

df['mon_key_2'] = df['filled_datekey_new'].dt.strftime('%b-%y')

# df = df[df['mon_key_2']!='Jan-21']

# %%
# df = df[df['filled_datekey_new'] > six_month_date]

# %%
df['filled_datekey_new'].max()
# Out:
# Timestamp('2021-12-31 23:25:00')

# %%
mon = ['Jul-21','Aug-21','Sep-21','Oct-21','Nov-21','Dec-21']  #changes
df = df[df['mon_key_2'].isin(mon)]
df['mon_key'].min()
# Out:
# '07-21'

# %%
df['mon_key'].value_counts()
# Out:
# 08-21    37771
# 09-21    37194
# 10-21    35454
# 07-21    34459
# 11-21    33711
# 12-21    33234
# Name: mon_key, dtype: int64

# %%
df['trackrx_last_ibdtag_new'] = df['trackrx_last_ibdtag'].notnull()
df['status_callforins_day01_new'] = df['status_callforins_day01'].notnull()
df['times_processed_ibd_new'] = df['times_processed_ibd'].notnull()
df['status_ibd_2K_new'] = df['status_ibd_2K'].notnull()
df['times_processed_ibd_regular_new'] = df['times_processed_ibd_regular'].notnull()

# %%
df['times_processed_ibd_2K_new'] = df['times_processed_ibd_2K'].notnull()

# %%
df['times_processed_callforins_day01_new'] = df['times_processed_callforins_day01'].notnull()
df['times_processed_callforins_day02_new'] = df['times_processed_callforins_day02'].notnull()
df['times_processed_callforins_day03_new'] = df['times_processed_callforins_day03'].notnull()

# %%
df['final_rx_entered'] = df.apply(lambda r: \
                                                r['trackrx_processing_date_starttime'] if pd.isnull(r['track_rx_entered'])\
                                               else r['track_rx_entered'], axis=1)

# %%
rxjourney_datetimecolumns = ['track_erx_received',
'track_rx_entered',
'track_rx_filled',
'track_label_printed',
# 'track_drug_picks',
# 'track_rph_picks',
# 'track_rx_pickedup',
'new_delivered_date',
'filled_datekey',
# 'rx_pickup_datetime_mms',
# 'rx_drugpick_datetime_mms',
# 'rx_rphverified_datetime_mms',
'final_rx_drug_picks',
'final_rx_rph_picks',
'final_rx_pickedup',
# 'trackrx_status_last_datetime',
'end_billed_datetime',
'first_billed_datetime',
'end_filed_datetime',
'trackrx_processing_date_starttime',
'trackrx_ibd_processing_start',
'trackrx_callins_processing_start',
'ibd_processing_enddatetime',
'workflow_last_change_datetime',
'cxrev_last_datetime',
'delrev_last_datetime',
# 'rx_reversed_last_datetime',
'batch_creation_datetime',
# 'new_delivered_date',
'delivery_date',
'final_rx_entered']

# %%
for cols in rxjourney_datetimecolumns:
    #print(cols)
    df[cols] = pd.to_datetime(df[cols],infer_datetime_format=True)

# %%
delta_columns = ['time_consumed_ibd_regular', 'time_consumed_ibd_2K', 'total_processing_time_ibd']

# %%
for cols in delta_columns:
    df[cols] = pd.to_timedelta(df[cols], errors='coerce')

# %%
df['rx_delta'] = df[['time_consumed_ibd_regular','time_consumed_ibd_2K', 'total_processing_time_ibd']].sum(axis=1)
#modf['rx_delta'].replace(pd.to_timedelta('0 days 00:00:00'), pd.NaT, inplace = True)
df[['rx_delta_day','rx_delta_days_str','rx_delta_time2']] = df['rx_delta'].astype(str).str.split(" ", n = 3, expand = True)

# %%
df['rx_delta_day'] = df['rx_delta_day'].astype(str).astype(int)
df['rx_delta_day'] = pd.to_timedelta(df['rx_delta_day'],'d')
df['trackrx_ibd_processing_start'] = pd.to_datetime(df['trackrx_ibd_processing_start'])
df['rx_delta_time2'] = pd.to_timedelta(df['rx_delta_time2'])

# %%
df['ibd_processing_end_rx_final'] = df['trackrx_ibd_processing_start'] + df['rx_delta_day'] + df['rx_delta_time2']

# %%
df['received_to_entered_time'] = df.apply(lambda r: pd.to_timedelta(r['final_rx_entered']-r['track_erx_received'])\
                                                                              if r['is_eRx']==True else 'NA',axis=1)

df['entered_to_first_billed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['first_billed_datetime']-r['final_rx_entered']),axis=1)

df['first_billed_to_last_billed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['end_billed_datetime']-r['first_billed_datetime']),axis=1)

df['entered_to_last_billed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['end_billed_datetime']-r['final_rx_entered']),axis=1)

df['entered_to_label_printed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['track_label_printed']-r['final_rx_entered']),axis=1)

df['last_billed_to_label_printed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['track_label_printed']-r['end_billed_datetime']),axis=1)

df['label_printed_to_drug_picked'] = df\
                            .apply(lambda r: pd.to_timedelta(r['final_rx_drug_picks']-r['track_label_printed']),axis=1)

df['drug_picked_to_rph_verified'] = df\
                            .apply(lambda r: pd.to_timedelta(r['final_rx_rph_picks']-r['final_rx_drug_picks']),axis=1)

df['rph_verified_to_pharmacy_pickedup'] = df\
                            .apply(lambda r: pd.to_timedelta(r['final_rx_pickedup']-r['final_rx_rph_picks'])\
                                   if (r['is_pickedup']==True) else 'NA',axis=1)

"""
df['rph_verified_to_delivery_pickedup'] = df\
                            .apply(lambda r: pd.to_timedelta(r['final_rx_pickedup']-r['final_rx_rph_picks'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)

df['delivery_pickedup_to_delivered'] = df\
                            .apply(lambda r: pd.to_timedelta(r['new_delivered_date']-r['final_rx_pickedup'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)
"""

df['rph_verified_to_batch_creation'] = df\
                            .apply(lambda r: pd.to_timedelta(r['batch_creation_datetime']-r['final_rx_rph_picks'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)

df['batch_creation_to_delivered'] = df\
                            .apply(lambda r: pd.to_timedelta(r['new_delivered_date']-r['batch_creation_datetime'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)



df['rph_verified_to_delivered'] = df\
                            .apply(lambda r: pd.to_timedelta(r['new_delivered_date']-r['final_rx_rph_picks'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)



df['ibd_processing_start_to_end'] = df\
                            .apply(lambda r: pd.to_timedelta(r['trackrx_ibd_processing_start']-r['ibd_processing_enddatetime']),axis=1)

# df['ibd_processing_end_to_first_billed'] = df\
#                             .apply(lambda r: pd.to_timedelta(r['trackrx_ibd_processing_start']-r['first_billed_datetime']),axis=1)




df['time_to_identify_pa_is_required'] = df\
                            .apply(lambda r: pd.to_timedelta(r['trackrx_ibd_processing_start']-r['track_rx_entered']), axis = 1)

df['waiting_time_for_ibd_processing'] = df\
                            .apply(lambda r: pd.to_timedelta(r['ibd_processing_enddatetime']-r['trackrx_ibd_processing_start']), axis = 1)

# df['time_taken_by_rx_to_be_picked_up_by_IBD_team'] = df\
#                             .apply(lambda r: pd.to_timedelta(r['time_consumed_ibd_regular'] + r['time_consumed_ibd_2K']), axis = 1)

df['ibd_processing_end_to_label_printed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['track_label_printed']-r['ibd_processing_enddatetime']), axis = 1)

df['rx_entered_to_callins_processing_start'] = df\
                            .apply(lambda r: pd.to_timedelta(r['trackrx_callins_processing_start']-r['track_rx_entered']), axis = 1)


df['ibd_processing_end_to_first_billed'] = df\
                            .apply(lambda r: pd.to_timedelta(r['first_billed_datetime'] - r['ibd_processing_end_rx_final']), axis = 1)

# df['ibd_processing_end_to_first_billed'] = df\
#                                 .apply(lambda r: pd.to_timedelta(r['first_billed_datetime'] - r['ibd_processing_enddatetime']), axis=1)

                    
                                                                  

df['rph_verified_to_delivery_pickedup'] = df\
                            .apply(lambda r: pd.to_timedelta(r['final_rx_pickedup']-r['final_rx_rph_picks'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)

df['delivery_pickedup_to_delivered'] = df\
                            .apply(lambda r: pd.to_timedelta(r['new_delivered_date']-r['final_rx_pickedup'])\
                                   if (r['is_pickedup']==False) else 'NA',axis=1)

# df['final_received_to_delivered'] = df\
#                             .apply(lambda r: pd.to_timedelta(r['track_erx_received']-r['final_rx_entered']),axis=1)

# %%
df['final_received'] = df.apply(lambda r: r['final_rx_entered'] if pd.isnull(r['track_erx_received']) else r['track_erx_received'], axis=1)

# %%
# final_received = track_erx_received 
# else:
#    final_received = final_rx_entered

# %%
df['final_received_to_delivered'] = df\
                            .apply(lambda r: pd.to_timedelta(r['new_delivered_date']-r['final_received']),axis=1)

# %%
df['rec_to_rphv'] = df.apply(lambda r: r['track_rx_entered'] if pd.isnull(r['track_erx_received']) else r['track_erx_received'], axis=1)
df['received_to_rph_verified'] = df.apply(lambda r: pd.to_timedelta(r['final_rx_rph_picks']-r['rec_to_rphv']), axis = 1)
df.drop(columns=['rec_to_rphv'],axis=1,inplace=True)

# %%
df['time_taken_by_rx_to_be_picked_up_by_IBD_team'] = df\
                            .apply(lambda r: pd.to_timedelta(r['time_consumed_ibd_regular'] + r['time_consumed_ibd_2K']), axis = 1)

# %%
df['time_taken_by_IBD_team_to_process_rx'] = df['total_processing_time_ibd']

# %%
#now apply all on scenario
df['c1'] = pd.to_timedelta(df['time_consumed_callforins_day01'], errors='coerce')
df['c2'] = pd.to_timedelta(df['time_consumed_callforins_day02'], errors='coerce')
df['c3'] = pd.to_timedelta(df['time_consumed_callforins_day03'], errors='coerce')

df['total_call'] = df[['c1','c2','c3']].sum(axis=1)

# %%
df['time_taken_for_call_for_insurance_process'] = df['total_call']

# %%
def get_time_value(x):
    return x > 0

# %%
df['total_call_2'] = df['total_call'].dt.total_seconds()

# %%
df['is_call'] = df['total_call_2'].apply(lambda x: get_time_value(x))

# %%
df['pharmacy_loc'].unique()
# Out:
# array(['NY-BK', 'NJ-SO', 'PA-PH', 'MD-BA', 'TX-SA', 'FL-MI', 'NY-MA',
#        'TX-DA', 'NC-RA', 'GA-AT', 'CT-CT', 'CT-NH', 'NY-UC'], dtype=object)

# %%
# df = df[(df['pharmacy_loc'] != 'TX-DA') & (df['pharmacy_loc'] != 'TX-SA') & (df['pharmacy_loc'] != 'GA-AT')]
# df.pharmacy_loc.unique()

# %%
pharmacy_loc_list = ['FL-MI', 'MD-BA', 'NC-RA', 'NJ-SO', 'NY-BK', 'NY-MA', 'PA-PH']
df = df[df['pharmacy_loc'].isin(pharmacy_loc_list)]
df.pharmacy_loc.unique()
# Out:
# array(['NY-BK', 'NJ-SO', 'PA-PH', 'MD-BA', 'FL-MI', 'NY-MA', 'NC-RA'],
#       dtype=object)

# %%
df['total_processing_time_ibd_new'] = df['total_processing_time_ibd'].notnull()

# %%
main_odf_new = df

# %%
# %store main_odf_new
# Out:
# Stored 'main_odf_new' (DataFrame)

# %% [markdown]
# # Scenario 1

# %%
scenario_1_df = df[(df['trackrx_last_ibdtag_new'] == False) & (df['status_callforins_day01_new'] == False)] #times_processed_ibd_regular_new

# scenario_2_df = df[(df['trackrx_last_ibdtag_new'] == True) & (df['status_callforins_day01_new'] == False)]

# scenario_3_df = df[(df['trackrx_last_ibdtag_new'] == True) & (df['status_callforins_day01_new'] == True)]

# scenario_4_df = df[(df['trackrx_last_ibdtag_new'] == False) & (df['status_callforins_day01_new'] == True)]

# %%
#scenario_1_df.to_csv('scenario_1_df.csv', index=False)

# %%
def get_mean_timedelta_stats(df,timecolumn):
    try:
        df = df[df[timecolumn]!='NA']
        df = df[pd.notnull(df[timecolumn])]
        df = df[df[timecolumn]>=dt.timedelta(0)] # add = 

        df['timevalue'] = pd.to_timedelta(df[timecolumn])

        timemean = statistics.mean(df['timevalue'].dt.total_seconds().tolist())
        tc = len(df)

        return pd.to_timedelta(round(timemean,2),'s')
    except:
        pass

# %%
def get_median_timedelta(df,timecolumn):
    try:
        df = df[df[timecolumn]!='NA']
        df = df[pd.notnull(df[timecolumn])]
        df = df[df[timecolumn]>=dt.timedelta(0)] # add = 

        meantimedelta =  statistics.median(df[timecolumn].values.tolist())

        return pd.to_timedelta(meantimedelta)
    except:
        pass

# %%
scenario_1_df.to_csv(output_file_path+'scenario_1_df.csv', index=False)

# %%
#scenario 1 city mean

# %%
 mean_columns_list = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

list_mean_time_received_to_entered_time = []
list_mean_time_entered_to_first_billed = []
list_mean_time_first_billed_to_last_billed = []
list_mean_time_entered_to_last_billed = []
list_mean_time_entered_to_label_printed = []

list_mean_time_last_billed_to_label_printed = []
list_mean_time_label_printed_to_drug_picked = []
list_mean_time_drug_picked_to_rph_verified = []
list_mean_time_rph_verified_to_pharmacy_pickedup = []
list_mean_time_rph_verified_to_batch_creation = []
list_mean_time_batch_creation_to_delivered = []
list_mean_time_rph_verified_to_delivered = []
list_mean_time_ibd_processing_start_to_end = []
list_mean_time_ibd_processing_end_to_first_billed = []
list_mean_time_rph_verified_to_delivery_pickedup = []
list_mean_time_delivery_pickedup_to_delivered = []
list_mean_time_final_received_to_delivered = []

list_mean_time_time_to_identify_pa_is_required = []
list_mean_time_waiting_time_for_ibd_processing = []
list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team = []
list_mean_time_ibd_processing_end_to_label_printed = []
list_mean_time_rx_entered_to_callins_processing_start = []

list_mean_time_time_taken_by_IBD_team_to_process_rx = []
list_mean_time_time_taken_for_call_for_insurance_process = []

pharmacy_loc = []
month_key = []

for i in np.unique(scenario_1_df.pharmacy_loc):
    loc = i
    pharmacy_loc.append(i)
    x = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_mean_time_received_to_entered_time.append(x)
    y = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_mean_time_entered_to_first_billed.append(y)
    z = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_mean_time_first_billed_to_last_billed.append(z)
    a = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_mean_time_entered_to_last_billed.append(a)
    b = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_mean_time_entered_to_label_printed.append(b)
    
    
    r = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_mean_time_last_billed_to_label_printed.append(r)
    e = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_mean_time_label_printed_to_drug_picked.append(e)
    f = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_mean_time_drug_picked_to_rph_verified.append(f)
    g = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_mean_time_rph_verified_to_pharmacy_pickedup.append(g)
    h = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_mean_time_rph_verified_to_batch_creation.append(h)
    j = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_mean_time_batch_creation_to_delivered.append(j)
    l = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_mean_time_rph_verified_to_delivered.append(l)
    m = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_mean_time_ibd_processing_start_to_end.append(m)
    n = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_mean_time_ibd_processing_end_to_first_billed.append(n)
    o = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_mean_time_rph_verified_to_delivery_pickedup.append(o)
    p = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_mean_time_delivery_pickedup_to_delivered.append(p)
    q = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_mean_time_final_received_to_delivered.append(q)


    
    t = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_mean_time_time_to_identify_pa_is_required.append(t)
    
    u = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_mean_time_waiting_time_for_ibd_processing.append(u)
    
    v = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team.append(v)
    
    w = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_mean_time_ibd_processing_end_to_label_printed.append(w)
    
    c = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_mean_time_rx_entered_to_callins_processing_start.append(c)
    
    
    ff = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_mean_time_time_taken_by_IBD_team_to_process_rx.append(ff)
    
    cc = get_mean_timedelta_stats(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_mean_time_time_taken_for_call_for_insurance_process.append(cc)

    
s1_output_df_mean = pd.DataFrame()
s1_output_df_mean['pharmacy_loc'] = pharmacy_loc
s1_output_df_mean['mean_time_received_to_entered_time'] = list_mean_time_received_to_entered_time
s1_output_df_mean['mean_time_received_to_entered_time_hr'] = round(s1_output_df_mean['mean_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s1_output_df_mean['mean_time_entered_to_first_billed'] = list_mean_time_entered_to_first_billed
s1_output_df_mean['mean_time_entered_to_first_billed_hr'] = round(s1_output_df_mean['mean_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s1_output_df_mean['mean_time_first_billed_to_last_billed'] = list_mean_time_first_billed_to_last_billed
s1_output_df_mean['mean_time_first_billed_to_last_billed_hr'] = round(s1_output_df_mean['mean_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s1_output_df_mean['mean_time_entered_to_last_billed'] = list_mean_time_entered_to_last_billed
s1_output_df_mean['mean_time_entered_to_last_billed_hr'] = round(s1_output_df_mean['mean_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s1_output_df_mean['mean_time_entered_to_label_printed'] = list_mean_time_entered_to_label_printed
s1_output_df_mean['mean_time_entered_to_label_printed_hr'] = round(s1_output_df_mean['mean_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s1_output_df_mean['mean_time_last_billed_to_label_printed'] = list_mean_time_last_billed_to_label_printed
s1_output_df_mean['mean_time_last_billed_to_label_printed_hr'] = round(s1_output_df_mean['mean_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_label_printed_to_drug_picked'] = list_mean_time_label_printed_to_drug_picked
s1_output_df_mean['mean_time_label_printed_to_drug_picked_hr'] = round(s1_output_df_mean['mean_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_drug_picked_to_rph_verified'] = list_mean_time_drug_picked_to_rph_verified
s1_output_df_mean['mean_time_drug_picked_to_rph_verified_hr'] = round(s1_output_df_mean['mean_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'] = list_mean_time_rph_verified_to_pharmacy_pickedup
s1_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s1_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_rph_verified_to_batch_creation'] = list_mean_time_rph_verified_to_batch_creation
s1_output_df_mean['mean_time_rph_verified_to_batch_creation_hr'] = round(s1_output_df_mean['mean_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_batch_creation_to_delivered'] = list_mean_time_batch_creation_to_delivered
s1_output_df_mean['mean_time_batch_creation_to_delivered_hr'] = round(s1_output_df_mean['mean_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_rph_verified_to_delivered'] = list_mean_time_rph_verified_to_delivered
s1_output_df_mean['mean_time_rph_verified_to_delivered_hr'] = round(s1_output_df_mean['mean_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_ibd_processing_start_to_end'] = list_mean_time_ibd_processing_start_to_end
#s1_output_df_mean['mean_time_ibd_processing_start_to_end'].replace('NA', pd.NaT, inplace=True)
#s1_output_df_mean['mean_time_ibd_processing_start_to_end_hr'] = round(s1_output_df_mean['mean_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_ibd_processing_end_to_first_billed'] = list_mean_time_ibd_processing_end_to_first_billed
#s1_output_df_mean['mean_time_ibd_processing_end_to_first_billed_hr'] = round(s1_output_df_mean['mean_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'] = list_mean_time_rph_verified_to_delivery_pickedup
s1_output_df_mean['mean_time_rph_verified_to_delivery_pickedup_hr'] = round(s1_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_delivery_pickedup_to_delivered'] = list_mean_time_delivery_pickedup_to_delivered
s1_output_df_mean['mean_time_delivery_pickedup_to_delivered_hr'] = round(s1_output_df_mean['mean_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_final_received_to_delivered'] = list_mean_time_final_received_to_delivered
s1_output_df_mean['mean_time_final_received_to_delivered_hr'] = round(s1_output_df_mean['mean_time_final_received_to_delivered'].dt.total_seconds()/3600,2)


s1_output_df_mean['mean_time_time_to_identify_pa_is_required'] = list_mean_time_time_to_identify_pa_is_required
#s1_output_df_mean['mean_time_time_to_identify_pa_is_required_hr'] = round(s1_output_df_mean['mean_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_waiting_time_for_ibd_processing'] = list_mean_time_waiting_time_for_ibd_processing
#s1_output_df_mean['mean_time_waiting_time_for_ibd_processing_hr'] = round(s1_output_df_mean['mean_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team
#s1_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s1_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_ibd_processing_end_to_label_printed'] = list_mean_time_ibd_processing_end_to_label_printed
#s1_output_df_mean['mean_time_ibd_processing_end_to_label_printed_hr'] = round(s1_output_df_mean['mean_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_rx_entered_to_callins_processing_start'] = list_mean_time_rx_entered_to_callins_processing_start
#s1_output_df_mean['mean_time_rx_entered_to_callins_processing_start_hr'] = round(s1_output_df_mean['mean_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)



s1_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'] = list_mean_time_time_taken_by_IBD_team_to_process_rx
#s1_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s1_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s1_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'] = list_mean_time_time_taken_for_call_for_insurance_process
#s1_output_df_mean['mean_time_time_taken_for_call_for_insurance_process_hr'] = round(s1_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
city_wise_rx = pd.pivot_table(scenario_1_df, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
# city_wise_rx

# %%
s1_output_df_mean_final = pd.merge(s1_output_df_mean, city_wise_rx, on = 'pharmacy_loc', how = 'left')

# %%
s1_output_df_mean_final.append(s1_output_df_mean_final.mean(axis=0), ignore_index = True).to_clipboard(index=False)

# %%
writer = pd.ExcelWriter(output_file_path+'Scenario-1_city-wise_mean_median.xlsx', engine='xlsxwriter')
mean_df_scenario_1 = s1_output_df_mean_final.append(s1_output_df_mean_final.mean(axis=0), ignore_index = True)
mean_df_scenario_1 = mean_df_scenario_1.astype(str)
mean_df_scenario_1.to_excel(writer,sheet_name='City mean',index=False)

# %%
# scenario 1 city median

# %%
median_columns_list = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']


    
list_median_time_received_to_entered_time = []
list_median_time_entered_to_first_billed = []
list_median_time_first_billed_to_last_billed = []
list_median_time_entered_to_last_billed = []
list_median_time_entered_to_label_printed = []

list_median_time_last_billed_to_label_printed = []
list_median_time_label_printed_to_drug_picked = []
list_median_time_drug_picked_to_rph_verified = []
list_median_time_rph_verified_to_pharmacy_pickedup = []
list_median_time_rph_verified_to_batch_creation = []
list_median_time_batch_creation_to_delivered = []
list_median_time_rph_verified_to_delivered = []
list_median_time_ibd_processing_start_to_end = []
list_median_time_ibd_processing_end_to_first_billed = []
list_median_time_rph_verified_to_delivery_pickedup = []
list_median_time_delivery_pickedup_to_delivered = []
list_median_time_final_received_to_delivered = []

list_median_time_time_to_identify_pa_is_required = []
list_median_time_waiting_time_for_ibd_processing = []
list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team = []
list_median_time_ibd_processing_end_to_label_printed = []
list_median_time_rx_entered_to_callins_processing_start = []

list_median_time_time_taken_by_IBD_team_to_process_rx = []
list_median_time_time_taken_for_call_for_insurance_process = []


pharmacy_loc = []
month_key = []

for i in np.unique(scenario_1_df.pharmacy_loc):
    loc = i
    pharmacy_loc.append(i)
    x = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_median_time_received_to_entered_time.append(x)
    y = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_median_time_entered_to_first_billed.append(y)
    z = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_median_time_first_billed_to_last_billed.append(z)
    a = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_median_time_entered_to_last_billed.append(a)
    b = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_median_time_entered_to_label_printed.append(b)
    
    
    r = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_median_time_last_billed_to_label_printed.append(r)
    e = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_median_time_label_printed_to_drug_picked.append(e)
    f = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_median_time_drug_picked_to_rph_verified.append(f)
    g = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_median_time_rph_verified_to_pharmacy_pickedup.append(g)
    h = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_median_time_rph_verified_to_batch_creation.append(h)
    j = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_median_time_batch_creation_to_delivered.append(j)
    l = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_median_time_rph_verified_to_delivered.append(l)
    m = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_median_time_ibd_processing_start_to_end.append(m)
    n = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_median_time_ibd_processing_end_to_first_billed.append(n)
    o = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_median_time_rph_verified_to_delivery_pickedup.append(o)
    p = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_median_time_delivery_pickedup_to_delivered.append(p)
    q = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_median_time_final_received_to_delivered.append(q)
    

    t = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_median_time_time_to_identify_pa_is_required.append(t)
    
    u = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_median_time_waiting_time_for_ibd_processing.append(u)
    
    v = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team.append(v)
    
    w = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_median_time_ibd_processing_end_to_label_printed.append(w)
    
    c = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_median_time_rx_entered_to_callins_processing_start.append(c)
    
    ff = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_median_time_time_taken_by_IBD_team_to_process_rx.append(ff)
    
    cc = get_median_timedelta(scenario_1_df[scenario_1_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_median_time_time_taken_for_call_for_insurance_process.append(cc)

# 'time_to_identify_pa_is_required'
# 'waiting_time_for_ibd_processing'
# 'time_taken_by_rx_to_be_picked_up_by_IBD_team'
# 'ibd_processing_end_to_label_printed'
# 'rx_entered_to_callins_processing_start'
    
    
    
s1_output_df_median = pd.DataFrame()
s1_output_df_median['pharmacy_loc'] = pharmacy_loc
s1_output_df_median['median_time_received_to_entered_time'] = list_median_time_received_to_entered_time
s1_output_df_median['median_time_received_to_entered_time_hr'] = round(s1_output_df_median['median_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s1_output_df_median['median_time_entered_to_first_billed'] = list_median_time_entered_to_first_billed
s1_output_df_median['median_time_entered_to_first_billed_hr'] = round(s1_output_df_median['median_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s1_output_df_median['median_time_first_billed_to_last_billed'] = list_median_time_first_billed_to_last_billed
s1_output_df_median['median_time_first_billed_to_last_billed_hr'] = round(s1_output_df_median['median_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s1_output_df_median['median_time_entered_to_last_billed'] = list_median_time_entered_to_last_billed
s1_output_df_median['median_time_entered_to_last_billed_hr'] = round(s1_output_df_median['median_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s1_output_df_median['median_time_entered_to_label_printed'] = list_median_time_entered_to_label_printed
s1_output_df_median['median_time_entered_to_label_printed_hr'] = round(s1_output_df_median['median_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s1_output_df_median['median_time_last_billed_to_label_printed'] = list_median_time_last_billed_to_label_printed
s1_output_df_median['median_time_last_billed_to_label_printed_hr'] = round(s1_output_df_median['median_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_label_printed_to_drug_picked'] = list_median_time_label_printed_to_drug_picked
s1_output_df_median['median_time_label_printed_to_drug_picked_hr'] = round(s1_output_df_median['median_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_drug_picked_to_rph_verified'] = list_median_time_drug_picked_to_rph_verified
s1_output_df_median['median_time_drug_picked_to_rph_verified_hr'] = round(s1_output_df_median['median_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'] = list_median_time_rph_verified_to_pharmacy_pickedup
s1_output_df_median['median_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s1_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_rph_verified_to_batch_creation'] = list_median_time_rph_verified_to_batch_creation
s1_output_df_median['median_time_rph_verified_to_batch_creation_hr'] = round(s1_output_df_median['median_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_batch_creation_to_delivered'] = list_median_time_batch_creation_to_delivered
s1_output_df_median['median_time_batch_creation_to_delivered_hr'] = round(s1_output_df_median['median_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_rph_verified_to_delivered'] = list_median_time_rph_verified_to_delivered
s1_output_df_median['median_time_rph_verified_to_delivered_hr'] = round(s1_output_df_median['median_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_ibd_processing_start_to_end'] = list_median_time_ibd_processing_start_to_end
#s1_output_df_median['median_time_ibd_processing_start_to_end_hr'] = round(s1_output_df_median['median_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_ibd_processing_end_to_first_billed'] = list_median_time_ibd_processing_end_to_first_billed
#s1_output_df_median['median_time_ibd_processing_end_to_first_billed_hr'] = round(s1_output_df_median['median_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_rph_verified_to_delivery_pickedup'] = list_median_time_rph_verified_to_delivery_pickedup
#s1_output_df_median['median_time_rph_verified_to_delivery_pickedup_hr'] = round(s1_output_df_median['median_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_delivery_pickedup_to_delivered'] = list_median_time_delivery_pickedup_to_delivered
#s1_output_df_median['median_time_delivery_pickedup_to_delivered_hr'] = round(s1_output_df_median['median_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_final_received_to_delivered'] = list_median_time_final_received_to_delivered
#s1_output_df_median['median_time_final_received_to_delivered_hr'] = round(s1_output_df_median['median_time_final_received_to_delivered'].dt.total_seconds()/3600,2)


s1_output_df_median['median_time_time_to_identify_pa_is_required'] = list_median_time_time_to_identify_pa_is_required
#s1_output_df_median['median_time_time_to_identify_pa_is_required_hr'] = round(s1_output_df_median['median_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_waiting_time_for_ibd_processing'] = list_median_time_waiting_time_for_ibd_processing
#s1_output_df_median['median_time_waiting_time_for_ibd_processing_hr'] = round(s1_output_df_median['median_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team
#s1_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s1_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_ibd_processing_end_to_label_printed'] = list_median_time_ibd_processing_end_to_label_printed
#s1_output_df_median['median_time_ibd_processing_end_to_label_printed_hr'] = round(s1_output_df_median['median_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_rx_entered_to_callins_processing_start'] = list_median_time_rx_entered_to_callins_processing_start
#s1_output_df_median['median_time_rx_entered_to_callins_processing_start_hr'] = round(s1_output_df_median['median_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)


s1_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'] = list_median_time_time_taken_by_IBD_team_to_process_rx
#s1_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s1_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s1_output_df_median['median_time_time_taken_for_call_for_insurance_process'] = list_median_time_time_taken_for_call_for_insurance_process
#s1_output_df_median['median_time_time_taken_for_call_for_insurance_process_hr'] = round(s1_output_df_median['median_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
s1_output_df_median_final = pd.merge(s1_output_df_median, city_wise_rx, on = 'pharmacy_loc', how = 'left')
s1_output_df_median_final = s1_output_df_median_final.append(s1_output_df_median_final.median(axis=0), ignore_index = True)#.reset_index()
s1_output_df_median_final.to_clipboard(index=False)
median_df_scenario_1 = s1_output_df_median_final 
median_df_scenario_1 = median_df_scenario_1.astype(str)
median_df_scenario_1.to_excel(writer,sheet_name='City median',index=False)

# %%
#s1_output_df_median_final.append(s1_output_df_median_final.median(axis=0), ignore_index = True).to_clipboard(index=False)

# %%
colnames = s1_output_df_median_final.columns[~s1_output_df_median_final.columns.str.contains(pat = '_hr')]
#len(colnames)

# %%
scenario_1_df_time = s1_output_df_median_final[['pharmacy_loc', 'median_time_received_to_entered_time',
       'median_time_entered_to_first_billed',
       'median_time_first_billed_to_last_billed',
       'median_time_entered_to_last_billed',
       'median_time_entered_to_label_printed',
       'median_time_last_billed_to_label_printed',
       'median_time_label_printed_to_drug_picked',
       'median_time_drug_picked_to_rph_verified',
       'median_time_rph_verified_to_pharmacy_pickedup',
       'median_time_rph_verified_to_batch_creation',
       'median_time_batch_creation_to_delivered',
       'median_time_rph_verified_to_delivered',
       'median_time_ibd_processing_start_to_end',
       'median_time_ibd_processing_end_to_first_billed',
       'median_time_rph_verified_to_delivery_pickedup',
       'median_time_delivery_pickedup_to_delivered',
       'median_time_final_received_to_delivered',
       'median_time_time_to_identify_pa_is_required',
       'median_time_waiting_time_for_ibd_processing',
       'median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team',
       'median_time_ibd_processing_end_to_label_printed',
       'median_time_rx_entered_to_callins_processing_start']]

# %%
scenario_1_df_time = scenario_1_df_time[['pharmacy_loc','median_time_received_to_entered_time',
'median_time_entered_to_first_billed',
'median_time_first_billed_to_last_billed',
'median_time_last_billed_to_label_printed',
'median_time_label_printed_to_drug_picked',
'median_time_drug_picked_to_rph_verified',
'median_time_rph_verified_to_pharmacy_pickedup',
'median_time_rph_verified_to_delivered',
'median_time_final_received_to_delivered']]

# %%
scenario_1_df_time['pharmacy_loc'] = scenario_1_df_time['pharmacy_loc'].fillna('Overall')

# %%
scenario_1_df_time = scenario_1_df_time.set_index('pharmacy_loc')
#scenario_1_df_time

# %%
for i in scenario_1_df_time.columns:
    scenario_1_df_time[i] = scenario_1_df_time[i].astype(str).str[0:15]
    scenario_1_df_time[i] = pd.to_timedelta(scenario_1_df_time[i])

# %%
my_string  = scenario_1_df_time.columns.str[12:]
new_column_names = []
for i in my_string:
    nn = i.replace("_", " ")
    new_column_names.append(nn)

scenario_1_df_time.columns = new_column_names

# %%
split_scenario_1_df_1 = scenario_1_df_time[scenario_1_df_time.columns[0:6]]
split_scenario_1_df_2 = scenario_1_df_time[scenario_1_df_time.columns[6:]]

#scenario_1_df_time

# %%
df_style1 = split_scenario_1_df_1.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style1.set_properties(subset=df_style1.columns, **{'width': '120px'})
df_style1.set_table_styles([border_design])
df_style2 = split_scenario_1_df_2.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style2.set_properties(subset=df_style2.columns, **{'width': '120px'})
df_style2.set_table_styles([border_design])
# Out:
# <style  type="text/css" >
#     #T_85de1_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_85de1_row0_col0,#T_85de1_row0_col1,#T_85de1_row2_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #006837;
#             color:  #f1f1f1;
#             width:  120px;
#         }#T_85de1_row0_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
# ...

# %%
dfi.export(df_style1, output_distribution_sce_1+'split_scenario_1_df_1_new.png')
dfi.export(df_style2, output_distribution_sce_1+'split_scenario_1_df_2_new.png')

# %%
scenario_1_min_df = scenario_1_df_time.iloc[:-1,:]
#scenario_1_min_df

# %%
scenario_1_df_min_values = pd.DataFrame(columns=['min value','pharmacy loc'],index=range(0,len(scenario_1_min_df.columns)))
scenario_1_df_min_values['min value'] = scenario_1_min_df.min(axis=0).values
scenario_1_df_min_values['pharmacy loc'] = scenario_1_min_df.idxmin().values
scenario_1_df_min_values['deltatime'] = scenario_1_min_df.columns

scenario_1_df_min_values['text'] = scenario_1_df_min_values['pharmacy loc']+' - '+scenario_1_df_min_values['min value'].astype(str)

# %%
# %store l scenario_1_df_min_values
# Out:
# Stored 'l' (Timedelta)
# Stored 'scenario_1_df_min_values' (DataFrame)

# %%
writer.save()

# %%
scenario_1_df_ny_bk = scenario_1_df[scenario_1_df['pharmacy_loc'] == 'NY-BK']
scenario_1_df_ny_bk_df = scenario_1_df_ny_bk[['rx_code_key_location', 'entered_to_first_billed']]
scenario_1_df_ny_bk_df['Secs'] = pd.to_timedelta(scenario_1_df_ny_bk_df['entered_to_first_billed']).dt.total_seconds()
scenario_1_df_ny_bk_df.to_clipboard(index = False)

# %% [markdown]
# # Scenario 2 median file generation

# %%
scenario_2_df = df[(df['trackrx_last_ibdtag_new'] == True) & (df['status_callforins_day01_new'] == False)]
Rx_with_IBD_2d = df[(df['trackrx_last_ibdtag_new'] == True) & (df['times_processed_ibd_regular_new'] == False) & (df['times_processed_ibd_2K_new'] == False) & (df['total_processing_time_ibd_new'] == False)]
rx_list =  Rx_with_IBD_2d['rx_code_key_location'].to_list()
# Rx_with_IBD2 = Rx_with_IBD[~Rx_with_IBD['rx_code_key_location'].isin(rx_list)]
scenario_2_df = scenario_2_df[~scenario_2_df['rx_code_key_location'].isin(rx_list)]

# %%
# scenario_2_df = df[(df['trackrx_last_ibdtag_new'] == True) & (df['status_callforins_day01_new'] == False)]

scenario_2_df.to_csv(output_file_path+'scenario_2_df.csv', index=False)

# %%
# scenario 2 city mean

# %%
mean_columns_list_2 = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

list_mean_time_received_to_entered_time_2 = []
list_mean_time_entered_to_first_billed_2 = []
list_mean_time_first_billed_to_last_billed_2 = []
list_mean_time_entered_to_last_billed_2 = []
list_mean_time_entered_to_label_printed_2 = []

list_mean_time_last_billed_to_label_printed_2 = []
list_mean_time_label_printed_to_drug_picked_2 = []
list_mean_time_drug_picked_to_rph_verified_2 = []
list_mean_time_rph_verified_to_pharmacy_pickedup_2 = []
list_mean_time_rph_verified_to_batch_creation_2 = []
list_mean_time_batch_creation_to_delivered_2 = []
list_mean_time_rph_verified_to_delivered_2 = []
list_mean_time_ibd_processing_start_to_end_2 = []
list_mean_time_ibd_processing_end_to_first_billed_2 = []
list_mean_time_rph_verified_to_delivery_pickedup_2 = []
list_mean_time_delivery_pickedup_to_delivered_2 = []
list_mean_time_final_received_to_delivered_2 = []

list_mean_time_time_to_identify_pa_is_required_2 = []
list_mean_time_waiting_time_for_ibd_processing_2 = []
list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_2 = []
list_mean_time_ibd_processing_end_to_label_printed_2 = []
list_mean_time_rx_entered_to_callins_processing_start_2 = []

list_mean_time_time_taken_by_IBD_team_to_process_rx_2 = []
list_mean_time_time_taken_for_call_for_insurance_process_2 = []

pharmacy_loc_2 = []
month_key_2 = []

for i in np.unique(scenario_2_df.pharmacy_loc):
    loc_2 = i
    pharmacy_loc_2.append(i)
    x_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_mean_time_received_to_entered_time_2.append(x_2)
    y_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_mean_time_entered_to_first_billed_2.append(y_2)
    z_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_mean_time_first_billed_to_last_billed_2.append(z_2)
    a_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_mean_time_entered_to_last_billed_2.append(a_2)
    b_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_mean_time_entered_to_label_printed_2.append(b_2)
    
    
    r_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_mean_time_last_billed_to_label_printed_2.append(r_2)
    e_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_mean_time_label_printed_to_drug_picked_2.append(e_2)
    f_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_mean_time_drug_picked_to_rph_verified_2.append(f_2)
    g_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_mean_time_rph_verified_to_pharmacy_pickedup_2.append(g_2)
    h_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_mean_time_rph_verified_to_batch_creation_2.append(h_2)
    j_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_mean_time_batch_creation_to_delivered_2.append(j_2)
    l_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_mean_time_rph_verified_to_delivered_2.append(l_2)
    m_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_mean_time_ibd_processing_start_to_end_2.append(m_2)
    n_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_mean_time_ibd_processing_end_to_first_billed_2.append(n_2)
    o_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_mean_time_rph_verified_to_delivery_pickedup_2.append(o_2)
    p_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_mean_time_delivery_pickedup_to_delivered_2.append(p_2)
    q_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_mean_time_final_received_to_delivered_2.append(q_2)


    
    t_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_mean_time_time_to_identify_pa_is_required_2.append(t_2)
    
    u_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_mean_time_waiting_time_for_ibd_processing_2.append(u_2)
    
    v_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_2.append(v_2)
    
    w_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_mean_time_ibd_processing_end_to_label_printed_2.append(w_2)
    
    c_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_mean_time_rx_entered_to_callins_processing_start_2.append(c_2)
    
    
    ff_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_mean_time_time_taken_by_IBD_team_to_process_rx_2.append(ff_2)
    
    cc_2 = get_mean_timedelta_stats(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_mean_time_time_taken_for_call_for_insurance_process_2.append(cc_2)

    
s2_output_df_mean = pd.DataFrame()
s2_output_df_mean['pharmacy_loc'] = pharmacy_loc_2
s2_output_df_mean['mean_time_received_to_entered_time'] = list_mean_time_received_to_entered_time_2
s2_output_df_mean['mean_time_received_to_entered_time_hr'] = round(s2_output_df_mean['mean_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s2_output_df_mean['mean_time_entered_to_first_billed'] = list_mean_time_entered_to_first_billed_2
s2_output_df_mean['mean_time_entered_to_first_billed_hr'] = round(s2_output_df_mean['mean_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s2_output_df_mean['mean_time_first_billed_to_last_billed'] = list_mean_time_first_billed_to_last_billed_2
s2_output_df_mean['mean_time_first_billed_to_last_billed_hr'] = round(s2_output_df_mean['mean_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s2_output_df_mean['mean_time_entered_to_last_billed'] = list_mean_time_entered_to_last_billed_2
s2_output_df_mean['mean_time_entered_to_last_billed_hr'] = round(s2_output_df_mean['mean_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s2_output_df_mean['mean_time_entered_to_label_printed'] = list_mean_time_entered_to_label_printed_2
s2_output_df_mean['mean_time_entered_to_label_printed_hr'] = round(s2_output_df_mean['mean_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s2_output_df_mean['mean_time_last_billed_to_label_printed'] = list_mean_time_last_billed_to_label_printed_2
s2_output_df_mean['mean_time_last_billed_to_label_printed_hr'] = round(s2_output_df_mean['mean_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_label_printed_to_drug_picked'] = list_mean_time_label_printed_to_drug_picked_2
s2_output_df_mean['mean_time_label_printed_to_drug_picked_hr'] = round(s2_output_df_mean['mean_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_drug_picked_to_rph_verified'] = list_mean_time_drug_picked_to_rph_verified_2
s2_output_df_mean['mean_time_drug_picked_to_rph_verified_hr'] = round(s2_output_df_mean['mean_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'] = list_mean_time_rph_verified_to_pharmacy_pickedup_2
s2_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s2_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_rph_verified_to_batch_creation'] = list_mean_time_rph_verified_to_batch_creation_2
s2_output_df_mean['mean_time_rph_verified_to_batch_creation_hr'] = round(s2_output_df_mean['mean_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_batch_creation_to_delivered'] = list_mean_time_batch_creation_to_delivered_2
s2_output_df_mean['mean_time_batch_creation_to_delivered_hr'] = round(s2_output_df_mean['mean_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_rph_verified_to_delivered'] = list_mean_time_rph_verified_to_delivered_2
s2_output_df_mean['mean_time_rph_verified_to_delivered_hr'] = round(s2_output_df_mean['mean_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_ibd_processing_start_to_end'] = list_mean_time_ibd_processing_start_to_end_2
s2_output_df_mean['mean_time_ibd_processing_start_to_end'].replace(np.nan, pd.to_timedelta(0), inplace=True)
print(s2_output_df_mean['mean_time_ibd_processing_start_to_end'])
s2_output_df_mean['mean_time_ibd_processing_start_to_end_hr'] = round(s2_output_df_mean['mean_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_ibd_processing_end_to_first_billed'] = list_mean_time_ibd_processing_end_to_first_billed_2
s2_output_df_mean['mean_time_ibd_processing_end_to_first_billed_hr'] = round(s2_output_df_mean['mean_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'] = list_mean_time_rph_verified_to_delivery_pickedup_2
s2_output_df_mean['mean_time_rph_verified_to_delivery_pickedup_hr'] = round(s2_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_delivery_pickedup_to_delivered'] = list_mean_time_delivery_pickedup_to_delivered_2
s2_output_df_mean['mean_time_delivery_pickedup_to_delivered_hr'] = round(s2_output_df_mean['mean_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_final_received_to_delivered'] = list_mean_time_final_received_to_delivered_2
s2_output_df_mean['mean_time_final_received_to_delivered_hr'] = round(s2_output_df_mean['mean_time_final_received_to_delivered'].dt.total_seconds()/3600,2)


s2_output_df_mean['mean_time_time_to_identify_pa_is_required'] = list_mean_time_time_to_identify_pa_is_required_2
s2_output_df_mean['mean_time_time_to_identify_pa_is_required_hr'] = round(s2_output_df_mean['mean_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_waiting_time_for_ibd_processing'] = list_mean_time_waiting_time_for_ibd_processing_2
s2_output_df_mean['mean_time_waiting_time_for_ibd_processing_hr'] = round(s2_output_df_mean['mean_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_2
s2_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s2_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_ibd_processing_end_to_label_printed'] = list_mean_time_ibd_processing_end_to_label_printed_2
s2_output_df_mean['mean_time_ibd_processing_end_to_label_printed_hr'] = round(s2_output_df_mean['mean_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_rx_entered_to_callins_processing_start'] = list_mean_time_rx_entered_to_callins_processing_start_2
# s2_output_df_mean['mean_time_rx_entered_to_callins_processing_start_hr'] = round(s2_output_df_mean['mean_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)



s2_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'] = list_mean_time_time_taken_by_IBD_team_to_process_rx_2
s2_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s2_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s2_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'] = list_mean_time_time_taken_for_call_for_insurance_process_2
#s2_output_df_mean['mean_time_time_taken_for_call_for_insurance_process_hr'] = round(s2_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)
# Out:
# 0   0 days
# 1   0 days
# 2   0 days
# 3   0 days
# 4   0 days
# 5   0 days
# 6   0 days
# Name: mean_time_ibd_processing_start_to_end, dtype: timedelta64[ns]

# %%
s2_output_df_mean
# Out:
#   pharmacy_loc mean_time_received_to_entered_time  \
# 0        FL-MI             0 days 10:02:55.160000
# 1        MD-BA             0 days 06:03:08.200000
# 2        NC-RA             0 days 08:43:07.330000
# 3        NJ-SO             0 days 06:41:04.690000
# 4        NY-BK             0 days 01:37:56.640000
# 5        NY-MA             0 days 03:12:41.060000
# 6        PA-PH             0 days 04:03:49.670000
#
#    mean_time_received_to_entered_time_hr mean_time_entered_to_first_billed  \
# 0                                  10.05           14 days 14:34:17.240000
# 1                                   6.05           17 days 15:46:17.240000
# 2                                   8.72           12 days 19:40:58.010000
# 3                                   6.68           14 days 19:07:49.780000
# 4                                   1.63           17 days 11:26:41.560000
# 5                                   3.21           29 days 04:12:47.100000
# ...

# %%
city_wise_rx_2 = pd.pivot_table(scenario_2_df, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()

# %%
s2_output_df_mean_final = pd.merge(s2_output_df_mean, city_wise_rx, on = 'pharmacy_loc', how = 'left')
s2_output_df_mean_final
# Out:
#   pharmacy_loc mean_time_received_to_entered_time  \
# 0        FL-MI             0 days 10:02:55.160000
# 1        MD-BA             0 days 06:03:08.200000
# 2        NC-RA             0 days 08:43:07.330000
# 3        NJ-SO             0 days 06:41:04.690000
# 4        NY-BK             0 days 01:37:56.640000
# 5        NY-MA             0 days 03:12:41.060000
# 6        PA-PH             0 days 04:03:49.670000
#
#    mean_time_received_to_entered_time_hr mean_time_entered_to_first_billed  \
# 0                                  10.05           14 days 14:34:17.240000
# 1                                   6.05           17 days 15:46:17.240000
# 2                                   8.72           12 days 19:40:58.010000
# 3                                   6.68           14 days 19:07:49.780000
# 4                                   1.63           17 days 11:26:41.560000
# 5                                   3.21           29 days 04:12:47.100000
# ...

# %%
writer = pd.ExcelWriter(output_file_path+'Scenario-2_city-wise_mean_median.xlsx', engine='xlsxwriter')
mean_df_scenario_2 = s2_output_df_mean_final.append(s2_output_df_mean_final.mean(axis=0), ignore_index = True)
mean_df_scenario_2 = mean_df_scenario_2.astype(str)
mean_df_scenario_2.to_excel(writer,sheet_name='City mean',index=False)

# %%
# scenario 2 city median

# %%
median_columns_list_2 = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

    
list_median_time_received_to_entered_time_2 = []
list_median_time_entered_to_first_billed_2 = []
list_median_time_first_billed_to_last_billed_2 = []
list_median_time_entered_to_last_billed_2 = []
list_median_time_entered_to_label_printed_2 = []

list_median_time_last_billed_to_label_printed_2 = []
list_median_time_label_printed_to_drug_picked_2 = []
list_median_time_drug_picked_to_rph_verified_2 = []
list_median_time_rph_verified_to_pharmacy_pickedup_2 = []
list_median_time_rph_verified_to_batch_creation_2 = []
list_median_time_batch_creation_to_delivered_2 = []
list_median_time_rph_verified_to_delivered_2 = []
list_median_time_ibd_processing_start_to_end_2 = []
list_median_time_ibd_processing_end_to_first_billed_2 = []
list_median_time_rph_verified_to_delivery_pickedup_2 = []
list_median_time_delivery_pickedup_to_delivered_2 = []
list_median_time_final_received_to_delivered_2 = []

list_median_time_time_to_identify_pa_is_required_2 = []
list_median_time_waiting_time_for_ibd_processing_2 = []
list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_2 = []
list_median_time_ibd_processing_end_to_label_printed_2 = []
list_median_time_rx_entered_to_callins_processing_start_2 = []

list_median_time_time_taken_by_IBD_team_to_process_rx_2 = []
list_median_time_time_taken_for_call_for_insurance_process_2 = []


pharmacy_loc_2 = []
month_key_2 = []

for i in np.unique(scenario_2_df.pharmacy_loc):
    loc_2 = i
    pharmacy_loc_2.append(i)
    x_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_median_time_received_to_entered_time_2.append(x_2)
    y_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_median_time_entered_to_first_billed_2.append(y_2)
    z_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_median_time_first_billed_to_last_billed_2.append(z_2)
    a_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_median_time_entered_to_last_billed_2.append(a_2)
    b_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_median_time_entered_to_label_printed_2.append(b_2)
    
    
    r_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_median_time_last_billed_to_label_printed_2.append(r_2)
    e_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_median_time_label_printed_to_drug_picked_2.append(e_2)
    f_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_median_time_drug_picked_to_rph_verified_2.append(f_2)
    g_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_median_time_rph_verified_to_pharmacy_pickedup_2.append(g_2)
    h_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_median_time_rph_verified_to_batch_creation_2.append(h_2)
    j_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_median_time_batch_creation_to_delivered_2.append(j_2)
    l_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_median_time_rph_verified_to_delivered_2.append(l_2)
    m_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_median_time_ibd_processing_start_to_end_2.append(m_2)
    n_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_median_time_ibd_processing_end_to_first_billed_2.append(n_2)
    o_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_median_time_rph_verified_to_delivery_pickedup_2.append(o_2)
    p_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_median_time_delivery_pickedup_to_delivered_2.append(p_2)
    q_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_median_time_final_received_to_delivered_2.append(q_2)


    t_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_median_time_time_to_identify_pa_is_required_2.append(t_2)
    
    u_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_median_time_waiting_time_for_ibd_processing_2.append(u_2)
    
    v_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_2.append(v_2)
    
    w_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_median_time_ibd_processing_end_to_label_printed_2.append(w_2)
    
    c_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_median_time_rx_entered_to_callins_processing_start_2.append(c_2)
    
    ff_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_median_time_time_taken_by_IBD_team_to_process_rx_2.append(ff_2)
    
    cc_2 = get_median_timedelta(scenario_2_df[scenario_2_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_median_time_time_taken_for_call_for_insurance_process_2.append(cc_2)

    
    
    
s2_output_df_median = pd.DataFrame()
s2_output_df_median['pharmacy_loc'] = pharmacy_loc_2
s2_output_df_median['median_time_received_to_entered_time'] = list_median_time_received_to_entered_time_2
s2_output_df_median['median_time_received_to_entered_time_hr'] = round(s2_output_df_median['median_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s2_output_df_median['median_time_entered_to_first_billed'] = list_median_time_entered_to_first_billed_2
s2_output_df_median['median_time_entered_to_first_billed_hr'] = round(s2_output_df_median['median_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s2_output_df_median['median_time_first_billed_to_last_billed'] = list_median_time_first_billed_to_last_billed_2
s2_output_df_median['median_time_first_billed_to_last_billed_hr'] = round(s2_output_df_median['median_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s2_output_df_median['median_time_entered_to_last_billed'] = list_median_time_entered_to_last_billed_2
s2_output_df_median['median_time_entered_to_last_billed_hr'] = round(s2_output_df_median['median_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s2_output_df_median['median_time_entered_to_label_printed'] = list_median_time_entered_to_label_printed_2
s2_output_df_median['median_time_entered_to_label_printed_hr'] = round(s2_output_df_median['median_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s2_output_df_median['median_time_last_billed_to_label_printed'] = list_median_time_last_billed_to_label_printed_2
s2_output_df_median['median_time_last_billed_to_label_printed_hr'] = round(s2_output_df_median['median_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_label_printed_to_drug_picked'] = list_median_time_label_printed_to_drug_picked_2
s2_output_df_median['median_time_label_printed_to_drug_picked_hr'] = round(s2_output_df_median['median_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_drug_picked_to_rph_verified'] = list_median_time_drug_picked_to_rph_verified_2
s2_output_df_median['median_time_drug_picked_to_rph_verified_hr'] = round(s2_output_df_median['median_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'] = list_median_time_rph_verified_to_pharmacy_pickedup_2
s2_output_df_median['median_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s2_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_rph_verified_to_batch_creation'] = list_median_time_rph_verified_to_batch_creation_2
s2_output_df_median['median_time_rph_verified_to_batch_creation_hr'] = round(s2_output_df_median['median_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_batch_creation_to_delivered'] = list_median_time_batch_creation_to_delivered_2
s2_output_df_median['median_time_batch_creation_to_delivered_hr'] = round(s2_output_df_median['median_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_rph_verified_to_delivered'] = list_median_time_rph_verified_to_delivered_2
s2_output_df_median['median_time_rph_verified_to_delivered_hr'] = round(s2_output_df_median['median_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_ibd_processing_start_to_end'] = list_median_time_ibd_processing_start_to_end_2
s2_output_df_median['median_time_ibd_processing_start_to_end'] = s2_output_df_median['median_time_ibd_processing_start_to_end'].replace(np.nan,pd.to_timedelta(0))
s2_output_df_median['median_time_ibd_processing_start_to_end_hr'] = round(s2_output_df_median['median_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_ibd_processing_end_to_first_billed'] = list_median_time_ibd_processing_end_to_first_billed_2
s2_output_df_median['median_time_ibd_processing_end_to_first_billed_hr'] = round(s2_output_df_median['median_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_rph_verified_to_delivery_pickedup'] = list_median_time_rph_verified_to_delivery_pickedup_2
s2_output_df_median['median_time_rph_verified_to_delivery_pickedup_hr'] = round(s2_output_df_median['median_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_delivery_pickedup_to_delivered'] = list_median_time_delivery_pickedup_to_delivered_2
s2_output_df_median['median_time_delivery_pickedup_to_delivered_hr'] = round(s2_output_df_median['median_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_final_received_to_delivered'] = list_median_time_final_received_to_delivered_2
s2_output_df_median['median_time_final_received_to_delivered_hr'] = round(s2_output_df_median['median_time_final_received_to_delivered'].dt.total_seconds()/3600,2)


s2_output_df_median['median_time_time_to_identify_pa_is_required'] = list_median_time_time_to_identify_pa_is_required_2
s2_output_df_median['median_time_time_to_identify_pa_is_required_hr'] = round(s2_output_df_median['median_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_waiting_time_for_ibd_processing'] = list_median_time_waiting_time_for_ibd_processing_2
s2_output_df_median['median_time_waiting_time_for_ibd_processing_hr'] = round(s2_output_df_median['median_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_2
s2_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s2_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_ibd_processing_end_to_label_printed'] = list_median_time_ibd_processing_end_to_label_printed_2
s2_output_df_median['median_time_ibd_processing_end_to_label_printed_hr'] = round(s2_output_df_median['median_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_rx_entered_to_callins_processing_start'] = list_median_time_rx_entered_to_callins_processing_start_2
#s2_output_df_median['median_time_rx_entered_to_callins_processing_start_hr'] = round(s2_output_df_median['median_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)


s2_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'] = list_median_time_time_taken_by_IBD_team_to_process_rx_2
s2_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s2_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s2_output_df_median['median_time_time_taken_for_call_for_insurance_process'] = list_median_time_time_taken_for_call_for_insurance_process_2
#s2_output_df_median['median_time_time_taken_for_call_for_insurance_process_hr'] = round(s2_output_df_median['median_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
s2_output_df_median_final = pd.merge(s2_output_df_median, city_wise_rx_2, on = 'pharmacy_loc', how = 'left')
s2_output_df_median_final = s2_output_df_median_final.append(s2_output_df_median_final.median(axis=0), ignore_index = True)
s2_output_df_median_final.to_clipboard(index=False)

median_df_scenario_2 = s2_output_df_median_final
median_df_scenario_2 = median_df_scenario_2.astype(str)
median_df_scenario_2.to_excel(writer,sheet_name='City median',index=False)

# %%
colnames_2 = s2_output_df_median_final.columns[~s2_output_df_median_final.columns.str.contains(pat = '_hr')]
#colnames_2

# %%
scenario_2_df_time = s2_output_df_median_final[['pharmacy_loc', 'median_time_received_to_entered_time',
       'median_time_entered_to_first_billed',
       'median_time_first_billed_to_last_billed',
       'median_time_entered_to_last_billed',
       'median_time_entered_to_label_printed',
       'median_time_last_billed_to_label_printed',
       'median_time_label_printed_to_drug_picked',
       'median_time_drug_picked_to_rph_verified',
       'median_time_rph_verified_to_pharmacy_pickedup',
       'median_time_rph_verified_to_batch_creation',
       'median_time_batch_creation_to_delivered',
       'median_time_rph_verified_to_delivered',
       'median_time_ibd_processing_start_to_end',
       'median_time_ibd_processing_end_to_first_billed',
       'median_time_rph_verified_to_delivery_pickedup',
       'median_time_delivery_pickedup_to_delivered',
       'median_time_final_received_to_delivered',
       'median_time_time_to_identify_pa_is_required',
       'median_time_waiting_time_for_ibd_processing',
       'median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team',
       'median_time_ibd_processing_end_to_label_printed',
       'median_time_rx_entered_to_callins_processing_start',
       'median_time_time_taken_by_IBD_team_to_process_rx',
       'median_time_time_taken_for_call_for_insurance_process',
       'rx_code_key_location']]

# %%
scenario_2_df_time = scenario_2_df_time[['pharmacy_loc','median_time_received_to_entered_time',
'median_time_time_to_identify_pa_is_required',
'median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team',
'median_time_time_taken_by_IBD_team_to_process_rx',
'median_time_ibd_processing_end_to_first_billed',
'median_time_first_billed_to_last_billed',
'median_time_last_billed_to_label_printed',
'median_time_label_printed_to_drug_picked',
'median_time_drug_picked_to_rph_verified',
'median_time_rph_verified_to_pharmacy_pickedup',
'median_time_rph_verified_to_delivered',
'median_time_final_received_to_delivered']]

# %%
scenario_2_df_time['pharmacy_loc'] = scenario_2_df_time['pharmacy_loc'].fillna('Overall')

# %%
scenario_2_df_time = scenario_2_df_time.set_index('pharmacy_loc')
scenario_2_df_time
# Out:
#              median_time_received_to_entered_time  \
# pharmacy_loc
# FL-MI                             0 days 02:40:00
# MD-BA                             0 days 01:20:00
# NC-RA                             0 days 01:59:00
# NJ-SO                             0 days 02:04:00
# NY-BK                             0 days 00:37:00
# NY-MA                             0 days 01:13:00
# PA-PH                             0 days 00:50:00
# Overall                           0 days 01:20:00
#
#              median_time_time_to_identify_pa_is_required  \
# pharmacy_loc
# FL-MI                                    0 days 02:17:53
# MD-BA                                    0 days 00:21:06
# NC-RA                                    0 days 00:01:43
# NJ-SO                                    0 days 03:56:07
# NY-BK                                    0 days 00:25:32
# NY-MA                             0 days 19:40:22.500000
# PA-PH                                    0 days 01:36:40
# ...

# %%
for i in scenario_2_df_time.columns:
    #scenario_2_df_time[i] = scenario_2_df_time[i].astype(str).str[0:15]
    scenario_2_df_time[i] = pd.to_timedelta(scenario_2_df_time[i]).dt.round('s')#pd.to_timedelta(scenario_2_df_time[i])
    #df.dt.round('5s')

# pandas.to_datetime(your_datetime_item).round('1s')

# %%
my_string  = scenario_2_df_time.columns.str[12:]
new_column_names = []
for i in my_string:
    nn = i.replace("_", " ")
    new_column_names.append(nn)

# %%
scenario_2_df_time.columns = new_column_names

# %%
split_scenario_2_df1 = scenario_2_df_time[scenario_2_df_time.columns[0:6]]
split_scenario_2_df2 = scenario_2_df_time[scenario_2_df_time.columns[6:]]

# %%
df_style1 = split_scenario_2_df1.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style1.set_table_styles([border_design])
df_style1.set_properties(subset=df_style1.columns, **{'width': '120px'})

df_style2 = split_scenario_2_df2.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style2.set_table_styles([border_design])
df_style2.set_properties(subset=df_style2.columns, **{'width': '120px'})
# Out:
# <style  type="text/css" >
#     #T_ac899_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_ac899_row0_col0{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#             width:  120px;
#         }#T_ac899_row0_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
# ...

# %%
dfi.export(df_style1, output_distribution_sce_2+'split_scenario_2_df1_new.png')
dfi.export(df_style2, output_distribution_sce_2+'split_scenario_2_df2_new.png')

# %%
scenario_2_min_df = scenario_2_df_time.iloc[:-1,:]
scenario_2_min_df
# Out:
#              received to entered time time to identify pa is required  \
# pharmacy_loc
# FL-MI                 0 days 02:40:00                 0 days 02:17:53
# MD-BA                 0 days 01:20:00                 0 days 00:21:06
# NC-RA                 0 days 01:59:00                 0 days 00:01:43
# NJ-SO                 0 days 02:04:00                 0 days 03:56:07
# NY-BK                 0 days 00:37:00                 0 days 00:25:32
# NY-MA                 0 days 01:13:00                 0 days 19:40:22
# PA-PH                 0 days 00:50:00                 0 days 01:36:40
#
#              time taken by rx to be picked up by IBD team  \
# pharmacy_loc
# FL-MI                                                 NaT
# MD-BA                                     0 days 07:04:30
# NC-RA                                     0 days 21:20:47
# NJ-SO                                     0 days 17:18:00
# NY-BK                                     0 days 23:09:27
# ...

# %%
scenario_2_df_min_values = pd.DataFrame(columns=['min value','pharmacy loc'],index=range(0,len(scenario_2_min_df.columns)))
scenario_2_df_min_values['min value'] = scenario_2_min_df.min(axis=0).values
scenario_2_df_min_values['pharmacy loc'] = scenario_2_min_df.idxmin().values
scenario_2_df_min_values['deltatime'] = scenario_2_min_df.columns

scenario_2_df_min_values['text'] = scenario_2_df_min_values['pharmacy loc']+' - '+scenario_2_df_min_values['min value'].astype(str)

# %%
# %store l scenario_2_df_min_values
# Out:
# Stored 'l' (Timedelta)
# Stored 'scenario_2_df_min_values' (DataFrame)

# %%
writer.save()

# %% [markdown]
# # Scenario 3

# %%
scenario_3_df = df[(df['trackrx_last_ibdtag_new'] == True) & ((df['status_callforins_day01'] == 'completed') | (df['status_callforins_day02'] == 'completed') | (df['status_callforins_day03'] == 'completed'))]
# df['trackrx_last_ibdtag_new'] == True -> remove columns with blank times_processed_ibd_regular, times_processed_ibd_2K, total_processing_time_ibd
# df['status_callforins_day01_new'] == True replace it with -> status_callforins_day01 - completed OR status_callforins_day02 - completed OR status_callforins_day03 - completed
rx_to_exclude = df[(df['trackrx_last_ibdtag_new'] == True) & (df['times_processed_ibd_regular_new'] == False) & (df['times_processed_ibd_2K_new'] == False) & (df['total_processing_time_ibd_new'] == False)]
len(rx_to_exclude)
rx_list =  rx_to_exclude['rx_code_key_location'].to_list()
# Rx_with_IBD2 = Rx_with_IBD[~Rx_with_IBD['rx_code_key_location'].isin(rx_list)]
scenario_3_df = scenario_3_df[~scenario_3_df['rx_code_key_location'].isin(rx_list)]

# %%
scenario_3_df.to_csv(output_file_path+'scenario_3_df.csv', index=False)

# %%
mean_columns_list_3 = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

list_mean_time_received_to_entered_time_3 = []
list_mean_time_entered_to_first_billed_3 = []
list_mean_time_first_billed_to_last_billed_3 = []
list_mean_time_entered_to_last_billed_3 = []
list_mean_time_entered_to_label_printed_3 = []

list_mean_time_last_billed_to_label_printed_3 = []
list_mean_time_label_printed_to_drug_picked_3 = []
list_mean_time_drug_picked_to_rph_verified_3 = []
list_mean_time_rph_verified_to_pharmacy_pickedup_3 = []
list_mean_time_rph_verified_to_batch_creation_3 = []
list_mean_time_batch_creation_to_delivered_3 = []
list_mean_time_rph_verified_to_delivered_3 = []
list_mean_time_ibd_processing_start_to_end_3 = []
list_mean_time_ibd_processing_end_to_first_billed_3 = []
list_mean_time_rph_verified_to_delivery_pickedup_3 = []
list_mean_time_delivery_pickedup_to_delivered_3 = []
list_mean_time_final_received_to_delivered_3 = []

list_mean_time_time_to_identify_pa_is_required_3 = []
list_mean_time_waiting_time_for_ibd_processing_3 = []
list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_3 = []
list_mean_time_ibd_processing_end_to_label_printed_3 = []
list_mean_time_rx_entered_to_callins_processing_start_3 = []

list_mean_time_time_taken_by_IBD_team_to_process_rx_3 = []
list_mean_time_time_taken_for_call_for_insurance_process_3 = []

pharmacy_loc_3 = []
month_key_3 = []

for i in np.unique(scenario_3_df.pharmacy_loc):
    loc_3 = i
    pharmacy_loc_3.append(i)
    x_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_mean_time_received_to_entered_time_3.append(x_3)
    y_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_mean_time_entered_to_first_billed_3.append(y_3)
    z_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_mean_time_first_billed_to_last_billed_3.append(z_3)
    a_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_mean_time_entered_to_last_billed_3.append(a_3)
    b_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_mean_time_entered_to_label_printed_3.append(b_3)
    
    
    r_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_mean_time_last_billed_to_label_printed_3.append(r_3)
    e_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_mean_time_label_printed_to_drug_picked_3.append(e_3)
    f_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_mean_time_drug_picked_to_rph_verified_3.append(f_3)
    g_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_mean_time_rph_verified_to_pharmacy_pickedup_3.append(g_3)
    h_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_mean_time_rph_verified_to_batch_creation_3.append(h_3)
    j_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_mean_time_batch_creation_to_delivered_3.append(j_3)
    l_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_mean_time_rph_verified_to_delivered_3.append(l_3)
    m_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_mean_time_ibd_processing_start_to_end_3.append(m_3)
    n_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_mean_time_ibd_processing_end_to_first_billed_3.append(n_3)
    o_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_mean_time_rph_verified_to_delivery_pickedup_3.append(o_3)
    p_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_mean_time_delivery_pickedup_to_delivered_3.append(p_3)
    q_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_mean_time_final_received_to_delivered_3.append(q_3)


    
    t_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_mean_time_time_to_identify_pa_is_required_3.append(t_3)
    
    u_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_mean_time_waiting_time_for_ibd_processing_3.append(u_3)
    
    v_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_3.append(v_3)
    
    w_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_mean_time_ibd_processing_end_to_label_printed_3.append(w_3)
    
    c_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_mean_time_rx_entered_to_callins_processing_start_3.append(c_3)
    
    
    ff_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_mean_time_time_taken_by_IBD_team_to_process_rx_3.append(ff_3)
    
    cc_3 = get_mean_timedelta_stats(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_mean_time_time_taken_for_call_for_insurance_process_3.append(cc_3)

    
s3_output_df_mean = pd.DataFrame()
s3_output_df_mean['pharmacy_loc'] = pharmacy_loc_3
s3_output_df_mean['mean_time_received_to_entered_time'] = list_mean_time_received_to_entered_time_3
s3_output_df_mean['mean_time_received_to_entered_time_hr'] = round(s3_output_df_mean['mean_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s3_output_df_mean['mean_time_entered_to_first_billed'] = list_mean_time_entered_to_first_billed_3
s3_output_df_mean['mean_time_entered_to_first_billed_hr'] = round(s3_output_df_mean['mean_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s3_output_df_mean['mean_time_first_billed_to_last_billed'] = list_mean_time_first_billed_to_last_billed_3
s3_output_df_mean['mean_time_first_billed_to_last_billed_hr'] = round(s3_output_df_mean['mean_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s3_output_df_mean['mean_time_entered_to_last_billed'] = list_mean_time_entered_to_last_billed_3
s3_output_df_mean['mean_time_entered_to_last_billed_hr'] = round(s3_output_df_mean['mean_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s3_output_df_mean['mean_time_entered_to_label_printed'] = list_mean_time_entered_to_label_printed_3
s3_output_df_mean['mean_time_entered_to_label_printed_hr'] = round(s3_output_df_mean['mean_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s3_output_df_mean['mean_time_last_billed_to_label_printed'] = list_mean_time_last_billed_to_label_printed_3
s3_output_df_mean['mean_time_last_billed_to_label_printed_hr'] = round(s3_output_df_mean['mean_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_label_printed_to_drug_picked'] = list_mean_time_label_printed_to_drug_picked_3
s3_output_df_mean['mean_time_label_printed_to_drug_picked_hr'] = round(s3_output_df_mean['mean_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_drug_picked_to_rph_verified'] = list_mean_time_drug_picked_to_rph_verified_3
s3_output_df_mean['mean_time_drug_picked_to_rph_verified_hr'] = round(s3_output_df_mean['mean_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'] = list_mean_time_rph_verified_to_pharmacy_pickedup_3
s3_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s3_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_rph_verified_to_batch_creation'] = list_mean_time_rph_verified_to_batch_creation_3
s3_output_df_mean['mean_time_rph_verified_to_batch_creation_hr'] = round(s3_output_df_mean['mean_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_batch_creation_to_delivered'] = list_mean_time_batch_creation_to_delivered_3
s3_output_df_mean['mean_time_batch_creation_to_delivered_hr'] = round(s3_output_df_mean['mean_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_rph_verified_to_delivered'] = list_mean_time_rph_verified_to_delivered_3
s3_output_df_mean['mean_time_rph_verified_to_delivered_hr'] = round(s3_output_df_mean['mean_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_ibd_processing_start_to_end'] = list_mean_time_ibd_processing_start_to_end_3
# s3_output_df_mean['mean_time_ibd_processing_start_to_end'].replace('NA', pd.NaT, inplace=True)
# s3_output_df_mean['mean_time_ibd_processing_start_to_end_hr'] = round(s3_output_df_mean['mean_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_ibd_processing_end_to_first_billed'] = list_mean_time_ibd_processing_end_to_first_billed_3
# s3_output_df_mean['mean_time_ibd_processing_end_to_first_billed_hr'] = round(s3_output_df_mean['mean_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'] = list_mean_time_rph_verified_to_delivery_pickedup_3
# s3_output_df_mean['mean_time_rph_verified_to_delivery_pickedup_hr'] = round(s3_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_delivery_pickedup_to_delivered'] = list_mean_time_delivery_pickedup_to_delivered_3
# s3_output_df_mean['mean_time_delivery_pickedup_to_delivered_hr'] = round(s3_output_df_mean['mean_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_final_received_to_delivered'] = list_mean_time_final_received_to_delivered_3
# s3_output_df_mean['mean_time_final_received_to_delivered_hr'] = round(s3_output_df_mean['mean_time_final_received_to_delivered'].dt.total_seconds()/3600,2)


s3_output_df_mean['mean_time_time_to_identify_pa_is_required'] = list_mean_time_time_to_identify_pa_is_required_3
# s3_output_df_mean['mean_time_time_to_identify_pa_is_required_hr'] = round(s3_output_df_mean['mean_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_waiting_time_for_ibd_processing'] = list_mean_time_waiting_time_for_ibd_processing_3
# s3_output_df_mean['mean_time_waiting_time_for_ibd_processing_hr'] = round(s3_output_df_mean['mean_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_3
# s3_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s3_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_ibd_processing_end_to_label_printed'] = list_mean_time_ibd_processing_end_to_label_printed_3
# s3_output_df_mean['mean_time_ibd_processing_end_to_label_printed_hr'] = round(s3_output_df_mean['mean_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_rx_entered_to_callins_processing_start'] = list_mean_time_rx_entered_to_callins_processing_start_3
# s3_output_df_mean['mean_time_rx_entered_to_callins_processing_start_hr'] = round(s3_output_df_mean['mean_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)



s3_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'] = list_mean_time_time_taken_by_IBD_team_to_process_rx_3
# s3_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s3_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s3_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'] = list_mean_time_time_taken_for_call_for_insurance_process_3
#s3_output_df_mean['mean_time_time_taken_for_call_for_insurance_process_hr'] = round(s3_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
city_wise_rx_3 = pd.pivot_table(scenario_3_df, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()

s3_output_df_mean_final = pd.merge(s3_output_df_mean, city_wise_rx, on = 'pharmacy_loc', how = 'left')
s3_output_df_mean_final

writer = pd.ExcelWriter(output_file_path+'Scenario-3_city-wise_mean_median.xlsx', engine='xlsxwriter')
mean_df_scenario_3 = s3_output_df_mean_final.append(s3_output_df_mean_final.mean(axis=0), ignore_index = True)
mean_df_scenario_3 = mean_df_scenario_3.astype(str)
mean_df_scenario_3.to_excel(writer,sheet_name='City mean',index=False)

# %%
# scenario 3 city median

# %%
median_columns_list_3 = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

    
list_median_time_received_to_entered_time_3 = []
list_median_time_entered_to_first_billed_3 = []
list_median_time_first_billed_to_last_billed_3 = []
list_median_time_entered_to_last_billed_3 = []
list_median_time_entered_to_label_printed_3 = []

list_median_time_last_billed_to_label_printed_3 = []
list_median_time_label_printed_to_drug_picked_3 = []
list_median_time_drug_picked_to_rph_verified_3 = []
list_median_time_rph_verified_to_pharmacy_pickedup_3 = []
list_median_time_rph_verified_to_batch_creation_3 = []
list_median_time_batch_creation_to_delivered_3 = []
list_median_time_rph_verified_to_delivered_3 = []
list_median_time_ibd_processing_start_to_end_3 = []
list_median_time_ibd_processing_end_to_first_billed_3 = []
list_median_time_rph_verified_to_delivery_pickedup_3 = []
list_median_time_delivery_pickedup_to_delivered_3 = []
list_median_time_final_received_to_delivered_3 = []

list_median_time_time_to_identify_pa_is_required_3 = []
list_median_time_waiting_time_for_ibd_processing_3 = []
list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_3 = []
list_median_time_ibd_processing_end_to_label_printed_3 = []
list_median_time_rx_entered_to_callins_processing_start_3 = []

list_median_time_time_taken_by_IBD_team_to_process_rx_3 = []
list_median_time_time_taken_for_call_for_insurance_process_3 = []


pharmacy_loc_3 = []
month_key_3 = []

for i in np.unique(scenario_3_df.pharmacy_loc):
    loc_3 = i
    pharmacy_loc_3.append(i)
    x_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_median_time_received_to_entered_time_3.append(x_3)
    y_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_median_time_entered_to_first_billed_3.append(y_3)
    z_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_median_time_first_billed_to_last_billed_3.append(z_3)
    a_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_median_time_entered_to_last_billed_3.append(a_3)
    b_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_median_time_entered_to_label_printed_3.append(b_3)
    
    
    r_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_median_time_last_billed_to_label_printed_3.append(r_3)
    e_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_median_time_label_printed_to_drug_picked_3.append(e_3)
    f_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_median_time_drug_picked_to_rph_verified_3.append(f_3)
    g_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_median_time_rph_verified_to_pharmacy_pickedup_3.append(g_3)
    h_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_median_time_rph_verified_to_batch_creation_3.append(h_3)
    j_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_median_time_batch_creation_to_delivered_3.append(j_3)
    l_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_median_time_rph_verified_to_delivered_3.append(l_3)
    m_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_median_time_ibd_processing_start_to_end_3.append(m_3)
    n_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_median_time_ibd_processing_end_to_first_billed_3.append(n_3)
    o_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_median_time_rph_verified_to_delivery_pickedup_3.append(o_3)
    p_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_median_time_delivery_pickedup_to_delivered_3.append(p_3)
    q_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_median_time_final_received_to_delivered_3.append(q_3)


    t_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_median_time_time_to_identify_pa_is_required_3.append(t_3)
    
    u_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_median_time_waiting_time_for_ibd_processing_3.append(u_3)
    
    v_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_3.append(v_3)
    
    w_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_median_time_ibd_processing_end_to_label_printed_3.append(w_3)
    
    c_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_median_time_rx_entered_to_callins_processing_start_3.append(c_3)
    
    ff_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_median_time_time_taken_by_IBD_team_to_process_rx_3.append(ff_3)
    
    cc_3 = get_median_timedelta(scenario_3_df[scenario_3_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_median_time_time_taken_for_call_for_insurance_process_3.append(cc_3)

    
    
    
s3_output_df_median = pd.DataFrame()
s3_output_df_median['pharmacy_loc'] = pharmacy_loc_3
s3_output_df_median['median_time_received_to_entered_time'] = list_median_time_received_to_entered_time_3
s3_output_df_median['median_time_received_to_entered_time_hr'] = round(s3_output_df_median['median_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s3_output_df_median['median_time_entered_to_first_billed'] = list_median_time_entered_to_first_billed_3
s3_output_df_median['median_time_entered_to_first_billed_hr'] = round(s3_output_df_median['median_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s3_output_df_median['median_time_first_billed_to_last_billed'] = list_median_time_first_billed_to_last_billed_3
s3_output_df_median['median_time_first_billed_to_last_billed_hr'] = round(s3_output_df_median['median_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s3_output_df_median['median_time_entered_to_last_billed'] = list_median_time_entered_to_last_billed_3
s3_output_df_median['median_time_entered_to_last_billed_hr'] = round(s3_output_df_median['median_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s3_output_df_median['median_time_entered_to_label_printed'] = list_median_time_entered_to_label_printed_3
s3_output_df_median['median_time_entered_to_label_printed_hr'] = round(s3_output_df_median['median_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s3_output_df_median['median_time_last_billed_to_label_printed'] = list_median_time_last_billed_to_label_printed_3
s3_output_df_median['median_time_last_billed_to_label_printed_hr'] = round(s3_output_df_median['median_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_label_printed_to_drug_picked'] = list_median_time_label_printed_to_drug_picked_3
s3_output_df_median['median_time_label_printed_to_drug_picked_hr'] = round(s3_output_df_median['median_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_drug_picked_to_rph_verified'] = list_median_time_drug_picked_to_rph_verified_3
s3_output_df_median['median_time_drug_picked_to_rph_verified_hr'] = round(s3_output_df_median['median_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'] = list_median_time_rph_verified_to_pharmacy_pickedup_3
s3_output_df_median['median_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s3_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_rph_verified_to_batch_creation'] = list_median_time_rph_verified_to_batch_creation_3
s3_output_df_median['median_time_rph_verified_to_batch_creation_hr'] = round(s3_output_df_median['median_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_batch_creation_to_delivered'] = list_median_time_batch_creation_to_delivered_3
s3_output_df_median['median_time_batch_creation_to_delivered_hr'] = round(s3_output_df_median['median_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_rph_verified_to_delivered'] = list_median_time_rph_verified_to_delivered_3
s3_output_df_median['median_time_rph_verified_to_delivered_hr'] = round(s3_output_df_median['median_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_ibd_processing_start_to_end'] = list_median_time_ibd_processing_start_to_end_3
#s3_output_df_median['median_time_ibd_processing_start_to_end_hr'] = round(s3_output_df_median['median_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_ibd_processing_end_to_first_billed'] = list_median_time_ibd_processing_end_to_first_billed_3
# s3_output_df_median['median_time_ibd_processing_end_to_first_billed_hr'] = round(s3_output_df_median['median_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_rph_verified_to_delivery_pickedup'] = list_median_time_rph_verified_to_delivery_pickedup_3
# s3_output_df_median['median_time_rph_verified_to_delivery_pickedup_hr'] = round(s3_output_df_median['median_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_delivery_pickedup_to_delivered'] = list_median_time_delivery_pickedup_to_delivered_3
# s3_output_df_median['median_time_delivery_pickedup_to_delivered_hr'] = round(s3_output_df_median['median_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_final_received_to_delivered'] = list_median_time_final_received_to_delivered_3
# s3_output_df_median['median_time_final_received_to_delivered_hr'] = round(s3_output_df_median['median_time_final_received_to_delivered'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_time_to_identify_pa_is_required'] = list_median_time_time_to_identify_pa_is_required_3
# s3_output_df_median['median_time_time_to_identify_pa_is_required_hr'] = round(s3_output_df_median['median_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_waiting_time_for_ibd_processing'] = list_median_time_waiting_time_for_ibd_processing_3
# s3_output_df_median['median_time_waiting_time_for_ibd_processing_hr'] = round(s3_output_df_median['median_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_3
# s3_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s3_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_ibd_processing_end_to_label_printed'] = list_median_time_ibd_processing_end_to_label_printed_3
# s3_output_df_median['median_time_ibd_processing_end_to_label_printed_hr'] = round(s3_output_df_median['median_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_rx_entered_to_callins_processing_start'] = list_median_time_rx_entered_to_callins_processing_start_3
#s3_output_df_median['median_time_rx_entered_to_callins_processing_start_hr'] = round(s3_output_df_median['median_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)


s3_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'] = list_median_time_time_taken_by_IBD_team_to_process_rx_3
# s3_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s3_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s3_output_df_median['median_time_time_taken_for_call_for_insurance_process'] = list_median_time_time_taken_for_call_for_insurance_process_3
#s3_output_df_median['median_time_time_taken_for_call_for_insurance_process_hr'] = round(s3_output_df_median['median_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
s3_output_df_median_final = pd.merge(s3_output_df_median, city_wise_rx_3, on = 'pharmacy_loc', how = 'left')
s3_output_df_median_final = s3_output_df_median_final.append(s3_output_df_median_final.median(axis=0), ignore_index = True)
s3_output_df_median_final.to_clipboard(index=False)

median_df_scenario_3 = s3_output_df_median_final
median_df_scenario_3 = median_df_scenario_3.astype(str)
median_df_scenario_3.to_excel(writer,sheet_name='City median',index=False)

# %%
colnames_3 = s3_output_df_median_final.columns[~s3_output_df_median_final.columns.str.contains(pat = '_hr')]
#colnames_3

# %%
scenario_3_df_time = s3_output_df_median_final[['pharmacy_loc', 'median_time_received_to_entered_time',
       'median_time_entered_to_first_billed',
       'median_time_first_billed_to_last_billed',
       'median_time_entered_to_last_billed',
       'median_time_entered_to_label_printed',
       'median_time_last_billed_to_label_printed',
       'median_time_label_printed_to_drug_picked',
       'median_time_drug_picked_to_rph_verified',
       'median_time_rph_verified_to_pharmacy_pickedup',
       'median_time_rph_verified_to_batch_creation',
       'median_time_batch_creation_to_delivered',
       'median_time_rph_verified_to_delivered',
       'median_time_ibd_processing_start_to_end',
       'median_time_ibd_processing_end_to_first_billed',
       'median_time_rph_verified_to_delivery_pickedup',
       'median_time_delivery_pickedup_to_delivered',
       'median_time_final_received_to_delivered',
       'median_time_time_to_identify_pa_is_required',
       'median_time_waiting_time_for_ibd_processing',
       'median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team',
       'median_time_ibd_processing_end_to_label_printed',
       'median_time_rx_entered_to_callins_processing_start',
       'median_time_time_taken_by_IBD_team_to_process_rx',
       'median_time_time_taken_for_call_for_insurance_process',
       'rx_code_key_location']]

# %%
scenario_3_df_time = scenario_3_df_time[['pharmacy_loc',
'median_time_received_to_entered_time',
'median_time_rx_entered_to_callins_processing_start',
'median_time_time_taken_for_call_for_insurance_process',
'median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team',
'median_time_time_taken_by_IBD_team_to_process_rx',
'median_time_ibd_processing_end_to_first_billed',
'median_time_first_billed_to_last_billed',
'median_time_last_billed_to_label_printed',
'median_time_label_printed_to_drug_picked',
'median_time_drug_picked_to_rph_verified',
'median_time_rph_verified_to_pharmacy_pickedup',
'median_time_rph_verified_to_delivered',
'median_time_final_received_to_delivered']]

# %%
scenario_3_df_time['pharmacy_loc'] = scenario_3_df_time['pharmacy_loc'].fillna('Overall')

# %%
scenario_3_df_time = scenario_3_df_time.set_index('pharmacy_loc')
scenario_3_df_time
# Out:
#              median_time_received_to_entered_time  \
# pharmacy_loc
# FL-MI                             0 days 02:37:30
# MD-BA                             0 days 01:21:30
# NC-RA                             0 days 01:35:00
# NJ-SO                             0 days 02:06:00
# NY-BK                             0 days 00:39:00
# NY-MA                             0 days 01:00:00
# PA-PH                             0 days 00:54:00
# Overall                           0 days 01:21:30
#
#              median_time_rx_entered_to_callins_processing_start  \
# pharmacy_loc
# FL-MI                                           0 days 05:44:53
# MD-BA                                           0 days 00:46:24
# NC-RA                                           0 days 00:07:17
# NJ-SO                                           0 days 03:49:33
# NY-BK                                           0 days 00:18:31
# NY-MA                                    0 days 20:38:14.500000
# ...

# %%
for i in scenario_3_df_time.columns:
    #scenario_3_df_time[i] = scenario_3_df_time[i].astype(str).str[0:15]
    scenario_3_df_time[i] = pd.to_timedelta(scenario_3_df_time[i]).dt.round('s')

# %%
my_string  = scenario_3_df_time.columns.str[12:]
new_column_names = []
for i in my_string:
    nn = i.replace("_", " ")
    new_column_names.append(nn)

scenario_3_df_time.columns = new_column_names

# cols = scenario_3_df_time.columns.str[12:]
# scenario_3_df_time.columns = cols

# %%
split_scenario_3_df1 = scenario_3_df_time[scenario_3_df_time.columns[0:7]]
split_scenario_3_df2 = scenario_3_df_time[scenario_3_df_time.columns[7:]]

# %%
df_style1 = split_scenario_3_df1.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style1.set_properties(subset=df_style1.columns, **{'width': '120px'})
df_style1.set_table_styles([border_design])

df_style2 = split_scenario_3_df2.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style2.set_properties(subset=df_style2.columns, **{'width': '120px'})

df_style2.set_table_styles([border_design])
# Out:
# <style  type="text/css" >
#     #T_53f31_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_53f31_row0_col0,#T_53f31_row7_col0{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #15904c;
#             color:  #000000;
#             width:  120px;
#         }#T_53f31_row0_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
# ...

# %%
dfi.export(df_style1, output_distribution_sce_3+'split_scenario_3_df1_new.png')
dfi.export(df_style2, output_distribution_sce_3+'split_scenario_3_df2_new.png')

# %%
scenario_3_min_df = scenario_3_df_time.iloc[:-1,:]
scenario_3_min_df
# Out:
#              received to entered time rx entered to callins processing start  \
# pharmacy_loc
# FL-MI                 0 days 02:37:30                        0 days 05:44:53
# MD-BA                 0 days 01:21:30                        0 days 00:46:24
# NC-RA                 0 days 01:35:00                        0 days 00:07:17
# NJ-SO                 0 days 02:06:00                        0 days 03:49:33
# NY-BK                 0 days 00:39:00                        0 days 00:18:31
# NY-MA                 0 days 01:00:00                        0 days 20:38:14
# PA-PH                 0 days 00:54:00                        0 days 00:18:12
#
#              time taken for call for insurance process  \
# pharmacy_loc
# FL-MI                                  1 days 19:32:15
# MD-BA                                  2 days 02:12:23
# NC-RA                                  1 days 15:24:46
# NJ-SO                                  1 days 04:08:33
# ...

# %%
scenario_3_df_min_values = pd.DataFrame(columns=['min value','pharmacy loc'],index=range(0,len(scenario_3_min_df.columns)))
scenario_3_df_min_values['min value'] = scenario_3_min_df.min(axis=0).values
scenario_3_df_min_values['pharmacy loc'] = scenario_3_min_df.idxmin().values
scenario_3_df_min_values['deltatime'] = scenario_3_min_df.columns

scenario_3_df_min_values['text'] = scenario_3_df_min_values['pharmacy loc']+' - '+scenario_3_df_min_values['min value'].astype(str)

# %%
# %store l scenario_3_df_min_values
# Out:
# Stored 'l' (Timedelta)
# Stored 'scenario_3_df_min_values' (DataFrame)

# %%
writer.save()

# %% [markdown]
# # Scenario 4

# %%
scenario_4_df = df[(df['trackrx_last_ibdtag_new'] == False) & ((df['status_callforins_day01'] == 'completed') | (df['status_callforins_day02'] == 'completed') | (df['status_callforins_day03'] == 'completed'))]
scenario_4_df.to_csv(output_file_path+'scenario_4_df.csv', index=False)

# %%
mean_columns_list_4 = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

list_mean_time_received_to_entered_time_4 = []
list_mean_time_entered_to_first_billed_4 = []
list_mean_time_first_billed_to_last_billed_4 = []
list_mean_time_entered_to_last_billed_4 = []
list_mean_time_entered_to_label_printed_4 = []

list_mean_time_last_billed_to_label_printed_4 = []
list_mean_time_label_printed_to_drug_picked_4 = []
list_mean_time_drug_picked_to_rph_verified_4 = []
list_mean_time_rph_verified_to_pharmacy_pickedup_4 = []
list_mean_time_rph_verified_to_batch_creation_4 = []
list_mean_time_batch_creation_to_delivered_4 = []
list_mean_time_rph_verified_to_delivered_4 = []
list_mean_time_ibd_processing_start_to_end_4 = []
list_mean_time_ibd_processing_end_to_first_billed_4 = []
list_mean_time_rph_verified_to_delivery_pickedup_4 = []
list_mean_time_delivery_pickedup_to_delivered_4 = []
list_mean_time_final_received_to_delivered_4 = []

list_mean_time_time_to_identify_pa_is_required_4 = []
list_mean_time_waiting_time_for_ibd_processing_4 = []
list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_4 = []
list_mean_time_ibd_processing_end_to_label_printed_4 = []
list_mean_time_rx_entered_to_callins_processing_start_4 = []

list_mean_time_time_taken_by_IBD_team_to_process_rx_4 = []
list_mean_time_time_taken_for_call_for_insurance_process_4 = []

pharmacy_loc_4 = []
month_key_4 = []

for i in np.unique(scenario_4_df.pharmacy_loc):
    loc_4 = i
    pharmacy_loc_4.append(i)
    x_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_mean_time_received_to_entered_time_4.append(x_4)
    y_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_mean_time_entered_to_first_billed_4.append(y_4)
    z_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_mean_time_first_billed_to_last_billed_4.append(z_4)
    a_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_mean_time_entered_to_last_billed_4.append(a_4)
    b_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_mean_time_entered_to_label_printed_4.append(b_4)
    
    
    r_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_mean_time_last_billed_to_label_printed_4.append(r_4)
    e_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_mean_time_label_printed_to_drug_picked_4.append(e_4)
    f_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_mean_time_drug_picked_to_rph_verified_4.append(f_4)
    g_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_mean_time_rph_verified_to_pharmacy_pickedup_4.append(g_4)
    h_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_mean_time_rph_verified_to_batch_creation_4.append(h_4)
    j_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_mean_time_batch_creation_to_delivered_4.append(j_4)
    l_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_mean_time_rph_verified_to_delivered_4.append(l_4)
    m_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_mean_time_ibd_processing_start_to_end_4.append(m_4)
    n_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_mean_time_ibd_processing_end_to_first_billed_4.append(n_4)
    o_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_mean_time_rph_verified_to_delivery_pickedup_4.append(o_4)
    p_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_mean_time_delivery_pickedup_to_delivered_4.append(p_4)
    q_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_mean_time_final_received_to_delivered_4.append(q_4)


    
    t_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_mean_time_time_to_identify_pa_is_required_4.append(t_4)
    
    u_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_mean_time_waiting_time_for_ibd_processing_4.append(u_4)
    
    v_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_4.append(v_4)
    
    w_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_mean_time_ibd_processing_end_to_label_printed_4.append(w_4)
    
    c_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_mean_time_rx_entered_to_callins_processing_start_4.append(c_4)
    
    
    ff_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_mean_time_time_taken_by_IBD_team_to_process_rx_4.append(ff_4)
    
    cc_4 = get_mean_timedelta_stats(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_mean_time_time_taken_for_call_for_insurance_process_4.append(cc_4)

    
s4_output_df_mean = pd.DataFrame()
s4_output_df_mean['pharmacy_loc'] = pharmacy_loc_4
s4_output_df_mean['mean_time_received_to_entered_time'] = list_mean_time_received_to_entered_time_4
s4_output_df_mean['mean_time_received_to_entered_time_hr'] = round(s4_output_df_mean['mean_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s4_output_df_mean['mean_time_entered_to_first_billed'] = list_mean_time_entered_to_first_billed_4
s4_output_df_mean['mean_time_entered_to_first_billed_hr'] = round(s4_output_df_mean['mean_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s4_output_df_mean['mean_time_first_billed_to_last_billed'] = list_mean_time_first_billed_to_last_billed_4
s4_output_df_mean['mean_time_first_billed_to_last_billed_hr'] = round(s4_output_df_mean['mean_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s4_output_df_mean['mean_time_entered_to_last_billed'] = list_mean_time_entered_to_last_billed_4
s4_output_df_mean['mean_time_entered_to_last_billed_hr'] = round(s4_output_df_mean['mean_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s4_output_df_mean['mean_time_entered_to_label_printed'] = list_mean_time_entered_to_label_printed_4
s4_output_df_mean['mean_time_entered_to_label_printed_hr'] = round(s4_output_df_mean['mean_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s4_output_df_mean['mean_time_last_billed_to_label_printed'] = list_mean_time_last_billed_to_label_printed_4
s4_output_df_mean['mean_time_last_billed_to_label_printed_hr'] = round(s4_output_df_mean['mean_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_label_printed_to_drug_picked'] = list_mean_time_label_printed_to_drug_picked_4
s4_output_df_mean['mean_time_label_printed_to_drug_picked_hr'] = round(s4_output_df_mean['mean_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_drug_picked_to_rph_verified'] = list_mean_time_drug_picked_to_rph_verified_4
s4_output_df_mean['mean_time_drug_picked_to_rph_verified_hr'] = round(s4_output_df_mean['mean_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'] = list_mean_time_rph_verified_to_pharmacy_pickedup_4
s4_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s4_output_df_mean['mean_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_rph_verified_to_batch_creation'] = list_mean_time_rph_verified_to_batch_creation_4
s4_output_df_mean['mean_time_rph_verified_to_batch_creation_hr'] = round(s4_output_df_mean['mean_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_batch_creation_to_delivered'] = list_mean_time_batch_creation_to_delivered_4
s4_output_df_mean['mean_time_batch_creation_to_delivered_hr'] = round(s4_output_df_mean['mean_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_rph_verified_to_delivered'] = list_mean_time_rph_verified_to_delivered_4
s4_output_df_mean['mean_time_rph_verified_to_delivered_hr'] = round(s4_output_df_mean['mean_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_ibd_processing_start_to_end'] = list_mean_time_ibd_processing_start_to_end_4
# s4_output_df_mean['mean_time_ibd_processing_start_to_end'].replace('NA', pd.NaT, inplace=True)
# s4_output_df_mean['mean_time_ibd_processing_start_to_end_hr'] = round(s4_output_df_mean['mean_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_ibd_processing_end_to_first_billed'] = list_mean_time_ibd_processing_end_to_first_billed_4
# s4_output_df_mean['mean_time_ibd_processing_end_to_first_billed_hr'] = round(s4_output_df_mean['mean_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'] = list_mean_time_rph_verified_to_delivery_pickedup_4
# s4_output_df_mean['mean_time_rph_verified_to_delivery_pickedup_hr'] = round(s4_output_df_mean['mean_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_delivery_pickedup_to_delivered'] = list_mean_time_delivery_pickedup_to_delivered_4
# s4_output_df_mean['mean_time_delivery_pickedup_to_delivered_hr'] = round(s4_output_df_mean['mean_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_final_received_to_delivered'] = list_mean_time_final_received_to_delivered_4
# s4_output_df_mean['mean_time_final_received_to_delivered_hr'] = round(s4_output_df_mean['mean_time_final_received_to_delivered'].dt.total_seconds()/3600,2)


s4_output_df_mean['mean_time_time_to_identify_pa_is_required'] = list_mean_time_time_to_identify_pa_is_required_4
# s4_output_df_mean['mean_time_time_to_identify_pa_is_required_hr'] = round(s4_output_df_mean['mean_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_waiting_time_for_ibd_processing'] = list_mean_time_waiting_time_for_ibd_processing_4
# s4_output_df_mean['mean_time_waiting_time_for_ibd_processing_hr'] = round(s4_output_df_mean['mean_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_4
# s4_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s4_output_df_mean['mean_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_ibd_processing_end_to_label_printed'] = list_mean_time_ibd_processing_end_to_label_printed_4
# s4_output_df_mean['mean_time_ibd_processing_end_to_label_printed_hr'] = round(s4_output_df_mean['mean_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_rx_entered_to_callins_processing_start'] = list_mean_time_rx_entered_to_callins_processing_start_4
# s4_output_df_mean['mean_time_rx_entered_to_callins_processing_start_hr'] = round(s4_output_df_mean['mean_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)



s4_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'] = list_mean_time_time_taken_by_IBD_team_to_process_rx_4
# s4_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s4_output_df_mean['mean_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s4_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'] = list_mean_time_time_taken_for_call_for_insurance_process_4
#s4_output_df_mean['mean_time_time_taken_for_call_for_insurance_process_hr'] = round(s4_output_df_mean['mean_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
city_wise_rx_4 = pd.pivot_table(scenario_4_df, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
city_wise_rx_4
# Out:
#   pharmacy_loc  rx_code_key_location
# 0        FL-MI                   311
# 1        MD-BA                   445
# 2        NC-RA                   495
# 3        NJ-SO                  2634
# 4        NY-BK                  3454
# 5        NY-MA                   293
# 6        PA-PH                  2346

# %%
s4_output_df_mean_final = pd.merge(s4_output_df_mean, city_wise_rx_4, on = 'pharmacy_loc', how = 'left')
s4_output_df_mean_final
# Out:
#   pharmacy_loc mean_time_received_to_entered_time  \
# 0        FL-MI             0 days 10:12:59.950000
# 1        MD-BA             0 days 06:01:45.510000
# 2        NC-RA             0 days 03:08:33.780000
# 3        NJ-SO             0 days 03:53:06.120000
# 4        NY-BK             0 days 01:54:16.430000
# 5        NY-MA             0 days 05:09:10.570000
# 6        PA-PH             0 days 03:19:26.530000
#
#    mean_time_received_to_entered_time_hr mean_time_entered_to_first_billed  \
# 0                                  10.22           12 days 20:37:15.330000
# 1                                   6.03            8 days 21:35:03.700000
# 2                                   3.14            5 days 19:24:33.610000
# 3                                   3.89            8 days 02:19:42.790000
# 4                                   1.90           13 days 04:20:41.210000
# 5                                   5.15           18 days 11:44:26.280000
# ...

# %%
writer = pd.ExcelWriter(output_file_path+'Scenario-4_city-wise_mean_median.xlsx', engine='xlsxwriter')
mean_df_scenario_4 = s4_output_df_mean_final.append(s4_output_df_mean_final.mean(axis=0), ignore_index = True)
mean_df_scenario_4 =mean_df_scenario_4.astype(str)
mean_df_scenario_4.to_excel(writer,sheet_name='City mean',index=False)

# %%
# scenario 1 city median

# %%
median_columns_list_4 = ['received_to_entered_time','entered_to_first_billed','first_billed_to_last_billed',
'entered_to_last_billed','entered_to_label_printed', 'last_billed_to_label_printed', 'label_printed_to_drug_picked',
'drug_picked_to_rph_verified', 'rph_verified_to_pharmacy_pickedup', 'rph_verified_to_batch_creation',
'batch_creation_to_delivered', 'rph_verified_to_delivered', 'ibd_processing_start_to_end', 'ibd_processing_end_to_first_billed',
'rph_verified_to_delivery_pickedup', 'delivery_pickedup_to_delivered', 'final_received_to_delivered', 
'time_to_identify_pa_is_required',
'waiting_time_for_ibd_processing',
'ibd_processing_end_to_label_printed',
'rx_entered_to_callins_processing_start',
'ibd_processing_end_to_first_billed',
'time_taken_by_rx_to_be_picked_up_by_IBD_team',
'time_taken_by_IBD_team_to_process_rx',
'time_taken_for_call_for_insurance_process']

    
list_median_time_received_to_entered_time_4 = []
list_median_time_entered_to_first_billed_4 = []
list_median_time_first_billed_to_last_billed_4 = []
list_median_time_entered_to_last_billed_4 = []
list_median_time_entered_to_label_printed_4 = []

list_median_time_last_billed_to_label_printed_4 = []
list_median_time_label_printed_to_drug_picked_4 = []
list_median_time_drug_picked_to_rph_verified_4 = []
list_median_time_rph_verified_to_pharmacy_pickedup_4 = []
list_median_time_rph_verified_to_batch_creation_4 = []
list_median_time_batch_creation_to_delivered_4 = []
list_median_time_rph_verified_to_delivered_4 = []
list_median_time_ibd_processing_start_to_end_4 = []
list_median_time_ibd_processing_end_to_first_billed_4 = []
list_median_time_rph_verified_to_delivery_pickedup_4 = []
list_median_time_delivery_pickedup_to_delivered_4 = []
list_median_time_final_received_to_delivered_4 = []

list_median_time_time_to_identify_pa_is_required_4 = []
list_median_time_waiting_time_for_ibd_processing_4 = []
list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_4 = []
list_median_time_ibd_processing_end_to_label_printed_4 = []
list_median_time_rx_entered_to_callins_processing_start_4 = []

list_median_time_time_taken_by_IBD_team_to_process_rx_4 = []
list_median_time_time_taken_for_call_for_insurance_process_4 = []


pharmacy_loc_4 = []
month_key_4 = []

for i in np.unique(scenario_4_df.pharmacy_loc):
    loc_4 = i
    pharmacy_loc_4.append(i)
    x_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'received_to_entered_time')
    list_median_time_received_to_entered_time_4.append(x_4)
    y_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'entered_to_first_billed')
    list_median_time_entered_to_first_billed_4.append(y_4)
    z_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'first_billed_to_last_billed')
    list_median_time_first_billed_to_last_billed_4.append(z_4)
    a_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'entered_to_last_billed')
    list_median_time_entered_to_last_billed_4.append(a_4)
    b_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'entered_to_label_printed')
    list_median_time_entered_to_label_printed_4.append(b_4)
    
    
    r_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'last_billed_to_label_printed')
    list_median_time_last_billed_to_label_printed_4.append(r_4)
    e_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'label_printed_to_drug_picked')
    list_median_time_label_printed_to_drug_picked_4.append(e_4)
    f_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'drug_picked_to_rph_verified')
    list_median_time_drug_picked_to_rph_verified_4.append(f_4)
    g_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_pharmacy_pickedup')
    list_median_time_rph_verified_to_pharmacy_pickedup_4.append(g_4)
    h_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_batch_creation')
    list_median_time_rph_verified_to_batch_creation_4.append(h_4)
    j_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'batch_creation_to_delivered')
    list_median_time_batch_creation_to_delivered_4.append(j_4)
    l_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_delivered')
    list_median_time_rph_verified_to_delivered_4.append(l_4)
    m_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'ibd_processing_start_to_end')
    list_median_time_ibd_processing_start_to_end_4.append(m_4)
    n_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_first_billed')
    list_median_time_ibd_processing_end_to_first_billed_4.append(n_4)
    o_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rph_verified_to_delivery_pickedup')
    list_median_time_rph_verified_to_delivery_pickedup_4.append(o_4)
    p_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'delivery_pickedup_to_delivered')
    list_median_time_delivery_pickedup_to_delivered_4.append(p_4)
    q_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'final_received_to_delivered')
    list_median_time_final_received_to_delivered_4.append(q_4)


    t_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_to_identify_pa_is_required')
    list_median_time_time_to_identify_pa_is_required_4.append(t_4)
    
    u_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'waiting_time_for_ibd_processing')
    list_median_time_waiting_time_for_ibd_processing_4.append(u_4)
    
    v_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_taken_by_rx_to_be_picked_up_by_IBD_team')
    list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_4.append(v_4)
    
    w_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'ibd_processing_end_to_label_printed')
    list_median_time_ibd_processing_end_to_label_printed_4.append(w_4)
    
    c_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'rx_entered_to_callins_processing_start')
    list_median_time_rx_entered_to_callins_processing_start_4.append(c_4)
    
    ff_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_taken_by_IBD_team_to_process_rx')
    list_median_time_time_taken_by_IBD_team_to_process_rx_4.append(ff_4)
    
    cc_4 = get_median_timedelta(scenario_4_df[scenario_4_df['pharmacy_loc']==str(i)],'time_taken_for_call_for_insurance_process')
    list_median_time_time_taken_for_call_for_insurance_process_4.append(cc_4)

    
    
    
s4_output_df_median = pd.DataFrame()
s4_output_df_median['pharmacy_loc'] = pharmacy_loc_4
s4_output_df_median['median_time_received_to_entered_time'] = list_median_time_received_to_entered_time_4
s4_output_df_median['median_time_received_to_entered_time_hr'] = round(s4_output_df_median['median_time_received_to_entered_time'].dt.total_seconds()/3600,2) 

s4_output_df_median['median_time_entered_to_first_billed'] = list_median_time_entered_to_first_billed_4
s4_output_df_median['median_time_entered_to_first_billed_hr'] = round(s4_output_df_median['median_time_entered_to_first_billed'].dt.total_seconds()/3600,2) 

s4_output_df_median['median_time_first_billed_to_last_billed'] = list_median_time_first_billed_to_last_billed_4
s4_output_df_median['median_time_first_billed_to_last_billed_hr'] = round(s4_output_df_median['median_time_first_billed_to_last_billed'].dt.total_seconds()/3600,2) 

s4_output_df_median['median_time_entered_to_last_billed'] = list_median_time_entered_to_last_billed_4
s4_output_df_median['median_time_entered_to_last_billed_hr'] = round(s4_output_df_median['median_time_entered_to_last_billed'].dt.total_seconds()/3600,2) 

s4_output_df_median['median_time_entered_to_label_printed'] = list_median_time_entered_to_label_printed_4
s4_output_df_median['median_time_entered_to_label_printed_hr'] = round(s4_output_df_median['median_time_entered_to_label_printed'].dt.total_seconds()/3600,2)



s4_output_df_median['median_time_last_billed_to_label_printed'] = list_median_time_last_billed_to_label_printed_4
s4_output_df_median['median_time_last_billed_to_label_printed_hr'] = round(s4_output_df_median['median_time_last_billed_to_label_printed'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_label_printed_to_drug_picked'] = list_median_time_label_printed_to_drug_picked_4
s4_output_df_median['median_time_label_printed_to_drug_picked_hr'] = round(s4_output_df_median['median_time_label_printed_to_drug_picked'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_drug_picked_to_rph_verified'] = list_median_time_drug_picked_to_rph_verified_4
s4_output_df_median['median_time_drug_picked_to_rph_verified_hr'] = round(s4_output_df_median['median_time_drug_picked_to_rph_verified'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'] = list_median_time_rph_verified_to_pharmacy_pickedup_4
s4_output_df_median['median_time_rph_verified_to_pharmacy_pickedup_hr'] = round(s4_output_df_median['median_time_rph_verified_to_pharmacy_pickedup'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_rph_verified_to_batch_creation'] = list_median_time_rph_verified_to_batch_creation_4
s4_output_df_median['median_time_rph_verified_to_batch_creation_hr'] = round(s4_output_df_median['median_time_rph_verified_to_batch_creation'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_batch_creation_to_delivered'] = list_median_time_batch_creation_to_delivered_4
s4_output_df_median['median_time_batch_creation_to_delivered_hr'] = round(s4_output_df_median['median_time_batch_creation_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_rph_verified_to_delivered'] = list_median_time_rph_verified_to_delivered_4
s4_output_df_median['median_time_rph_verified_to_delivered_hr'] = round(s4_output_df_median['median_time_rph_verified_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_ibd_processing_start_to_end'] = list_median_time_ibd_processing_start_to_end_4
#s4_output_df_median['median_time_ibd_processing_start_to_end_hr'] = round(s4_output_df_median['median_time_ibd_processing_start_to_end'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_ibd_processing_end_to_first_billed'] = list_median_time_ibd_processing_end_to_first_billed_4
# s4_output_df_median['median_time_ibd_processing_end_to_first_billed_hr'] = round(s4_output_df_median['median_time_ibd_processing_end_to_first_billed'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_rph_verified_to_delivery_pickedup'] = list_median_time_rph_verified_to_delivery_pickedup_4
# s4_output_df_median['median_time_rph_verified_to_delivery_pickedup_hr'] = round(s4_output_df_median['median_time_rph_verified_to_delivery_pickedup'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_delivery_pickedup_to_delivered'] = list_median_time_delivery_pickedup_to_delivered_4
# s4_output_df_median['median_time_delivery_pickedup_to_delivered_hr'] = round(s4_output_df_median['median_time_delivery_pickedup_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_final_received_to_delivered'] = list_median_time_final_received_to_delivered_4
# s4_output_df_median['median_time_final_received_to_delivered_hr'] = round(s4_output_df_median['median_time_final_received_to_delivered'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_time_to_identify_pa_is_required'] = list_median_time_time_to_identify_pa_is_required_4
# s4_output_df_median['median_time_time_to_identify_pa_is_required_hr'] = round(s4_output_df_median['median_time_time_to_identify_pa_is_required'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_waiting_time_for_ibd_processing'] = list_median_time_waiting_time_for_ibd_processing_4
# s4_output_df_median['median_time_waiting_time_for_ibd_processing_hr'] = round(s4_output_df_median['median_time_waiting_time_for_ibd_processing'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'] = list_median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_4
# s4_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team_hr'] = round(s4_output_df_median['median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_ibd_processing_end_to_label_printed'] = list_median_time_ibd_processing_end_to_label_printed_4
# s4_output_df_median['median_time_ibd_processing_end_to_label_printed_hr'] = round(s4_output_df_median['median_time_ibd_processing_end_to_label_printed'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_rx_entered_to_callins_processing_start'] = list_median_time_rx_entered_to_callins_processing_start_4
#s4_output_df_median['median_time_rx_entered_to_callins_processing_start_hr'] = round(s4_output_df_median['median_time_rx_entered_to_callins_processing_start'].dt.total_seconds()/3600,2)


s4_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'] = list_median_time_time_taken_by_IBD_team_to_process_rx_4
# s4_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx_hr'] = round(s4_output_df_median['median_time_time_taken_by_IBD_team_to_process_rx'].dt.total_seconds()/3600,2)

s4_output_df_median['median_time_time_taken_for_call_for_insurance_process'] = list_median_time_time_taken_for_call_for_insurance_process_4
#s4_output_df_median['median_time_time_taken_for_call_for_insurance_process_hr'] = round(s4_output_df_median['median_time_time_taken_for_call_for_insurance_process'].dt.total_seconds()/3600,2)

# %%
s4_output_df_median_final = pd.merge(s4_output_df_median, city_wise_rx_4, on = 'pharmacy_loc', how = 'left')
s4_output_df_median_final = s4_output_df_median_final.append(s4_output_df_median_final.median(axis=0), ignore_index = True)
s4_output_df_median_final.to_clipboard(index=False)

median_df_scenario_4 = s4_output_df_median_final 
median_df_scenario_4= median_df_scenario_4.astype(str)
median_df_scenario_4.to_excel(writer,sheet_name='City median',index=False)

# %%
colnames = s4_output_df_median_final.columns[~s4_output_df_median_final.columns.str.contains(pat = '_hr')]
#colnames

# %%
scenario_4_df_time = s4_output_df_median_final[['pharmacy_loc', 'median_time_received_to_entered_time',
       'median_time_entered_to_first_billed',
       'median_time_first_billed_to_last_billed',
       'median_time_entered_to_last_billed',
       'median_time_entered_to_label_printed',
       'median_time_last_billed_to_label_printed',
       'median_time_label_printed_to_drug_picked',
       'median_time_drug_picked_to_rph_verified',
       'median_time_rph_verified_to_pharmacy_pickedup',
       'median_time_rph_verified_to_batch_creation',
       'median_time_batch_creation_to_delivered',
       'median_time_rph_verified_to_delivered',
       'median_time_ibd_processing_start_to_end',
       'median_time_ibd_processing_end_to_first_billed',
       'median_time_rph_verified_to_delivery_pickedup',
       'median_time_delivery_pickedup_to_delivered',
       'median_time_final_received_to_delivered',
       'median_time_time_to_identify_pa_is_required',
       'median_time_waiting_time_for_ibd_processing',
       'median_time_time_taken_by_rx_to_be_picked_up_by_IBD_team',
       'median_time_ibd_processing_end_to_label_printed',
       'median_time_rx_entered_to_callins_processing_start',
       'median_time_time_taken_by_IBD_team_to_process_rx',
       'median_time_time_taken_for_call_for_insurance_process',
       'rx_code_key_location']]

# %%
scenario_4_df_time = scenario_4_df_time[['pharmacy_loc','median_time_received_to_entered_time',
'median_time_rx_entered_to_callins_processing_start',
'median_time_time_taken_for_call_for_insurance_process',
'median_time_first_billed_to_last_billed',
'median_time_last_billed_to_label_printed',
'median_time_label_printed_to_drug_picked',
'median_time_drug_picked_to_rph_verified',
'median_time_rph_verified_to_pharmacy_pickedup',
'median_time_rph_verified_to_delivered',
'median_time_final_received_to_delivered']]

# %%
scenario_4_df_time['pharmacy_loc'] = scenario_4_df_time['pharmacy_loc'].fillna('Overall')

# %%
scenario_4_df_time = scenario_4_df_time.set_index('pharmacy_loc')
scenario_4_df_time
# Out:
#              median_time_received_to_entered_time  \
# pharmacy_loc
# FL-MI                             0 days 03:01:30
# MD-BA                             0 days 01:10:30
# NC-RA                             0 days 00:47:24
# NJ-SO                             0 days 01:30:00
# NY-BK                             0 days 00:28:00
# NY-MA                      0 days 01:10:08.500000
# PA-PH                             0 days 00:39:00
# Overall                    0 days 01:10:08.500000
#
#              median_time_rx_entered_to_callins_processing_start  \
# pharmacy_loc
# FL-MI                                           0 days 02:27:59
# MD-BA                                           0 days 00:05:15
# NC-RA                                           0 days 00:49:05
# NJ-SO                                           0 days 01:39:08
# NY-BK                                           0 days 00:08:52
# NY-MA                                           0 days 02:09:30
# ...

# %%
for i in scenario_4_df_time.columns:
    #scenario_4_df_time[i] = scenario_4_df_time[i].astype(str).str[0:15]
    scenario_4_df_time[i] = pd.to_timedelta(scenario_4_df_time[i]).dt.round('s')

# %%
my_string  = scenario_4_df_time.columns.str[12:]
new_column_names = []
for i in my_string:
    nn = i.replace("_", " ")
    new_column_names.append(nn)

scenario_4_df_time.columns = new_column_names

# cols = scenario_4_df_time.columns.str[12:]
# scenario_4_df_time.columns = cols

# %%
split_scenario_4_df1 = scenario_4_df_time[scenario_4_df_time.columns[0:6]]
split_scenario_4_df2 = scenario_4_df_time[scenario_4_df_time.columns[6:]]

# %%
df_style1 = split_scenario_4_df1.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style1.set_properties(subset=df_style1.columns, **{'width': '120px'})
df_style1.set_table_styles([border_design])
df_style2 = split_scenario_4_df2.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=0)
df_style2.set_properties(subset=df_style2.columns, **{'width': '120px'})

df_style2.set_table_styles([border_design])
# Out:
# <style  type="text/css" >
#     #T_d613f_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_d613f_row0_col0{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #93d168;
#             color:  #000000;
#             width:  120px;
#         }#T_d613f_row0_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
# ...

# %%
dfi.export(df_style1, output_distribution_sce_4+'split_scenario_4_df1_new.png')
dfi.export(df_style2, output_distribution_sce_4+'split_scenario_4_df2_new.png')

# %%
scenario_4_min_df = scenario_4_df_time.iloc[:-1,:]
scenario_4_min_df
# Out:
#              received to entered time rx entered to callins processing start  \
# pharmacy_loc
# FL-MI                 0 days 03:01:30                        0 days 02:27:59
# MD-BA                 0 days 01:10:30                        0 days 00:05:15
# NC-RA                 0 days 00:47:24                        0 days 00:49:05
# NJ-SO                 0 days 01:30:00                        0 days 01:39:08
# NY-BK                 0 days 00:28:00                        0 days 00:08:52
# NY-MA                 0 days 01:10:08                        0 days 02:09:30
# PA-PH                 0 days 00:39:00                        0 days 00:01:41
#
#              time taken for call for insurance process  \
# pharmacy_loc
# FL-MI                                  0 days 23:35:40
# MD-BA                                  4 days 01:35:03
# NC-RA                                  1 days 03:28:30
# NJ-SO                                  1 days 19:07:41
# ...

# %%
scenario_4_df_min_values = pd.DataFrame(columns=['min value','pharmacy loc'],index=range(0,len(scenario_4_min_df.columns)))
scenario_4_df_min_values['min value'] = scenario_4_min_df.min(axis=0).values
scenario_4_df_min_values['pharmacy loc'] = scenario_4_min_df.idxmin().values
scenario_4_df_min_values['deltatime'] = scenario_4_min_df.columns

scenario_4_df_min_values['text'] = scenario_4_df_min_values['pharmacy loc']+' - '+scenario_4_df_min_values['min value'].astype(str)

# %%
# %store l scenario_4_df_min_values
# Out:
# Stored 'l' (Timedelta)
# Stored 'scenario_4_df_min_values' (DataFrame)

# %%
writer.save()

# %%
df.head(5)
# Out:
#    Unnamed: 0 pharmacy_location       rxno     presnpi          ndc  \
# 0           0             NY-BK  1157987-0  1871998476  75987004005
# 1           1             NJ-SO  1199550-0  1417203928  50222030260
# 2           2             NY-BK  1158109-0  1760484687  55513071001
# 3           3             NY-BK  1158579-0  1184913063  00169413602
# 4           4             NJ-SO  1198582-0  1437198009  00023916360
#
#   trackrx_status  patientno  track_erx_received    track_rx_entered  \
# 0              F     620373 2021-12-09 12:31:00 2021-12-09 12:39:00
# 1              B      77426 2021-10-15 14:03:00 2021-10-15 17:34:00
# 2              B     602577 2021-12-09 14:37:00 2021-12-09 14:50:00
# 3              F     559221 2021-12-10 13:29:00 2021-12-10 13:54:00
# 4              B      24019 2021-10-12 16:26:00 2021-10-13 09:38:25
#
#   rx_entered_date_verification      filled_datekey final_rx_pickedup  \
# 0          2021-12-09 12:39:00 2021-12-31 13:00:00               NaT
# ...

# %%
# def get_median_timedelta_updated(df,timecolumn):
#     try:
#         df = df[df[timecolumn]!='NA']
#         df = df[pd.notnull(df[timecolumn])]
#         df = df[df[timecolumn]>dt.timedelta(0)]

#         meantimedelta =  statistics.median(df[timecolumn].values.tolist())

#         return pd.to_timedelta(meantimedelta)
#     except:
#         pass

# %%
# df_b = df[df['trackrx_last_status'] == 'B']

# %%
# df_b = df_b[['rx_code_key_location', 'filled_datekey', 'final_received_to_delivered', 'end_billed_datetime', 'first_billed_datetime']]

# %%
# df_b['quickest_rx'] = pd.to_datetime(df_b['end_billed_datetime']) - pd.to_datetime(df_b['first_billed_datetime'])

# %%
# df_b

# %%
# df_b['Week_Number'] = df_b['filled_datekey'].dt.week

# %%
# df_b_quickest = df_b[df_b['quickest_rx'] == '0 days 00:00:00']

# %%
# df_b_quickest

# %%
# list_week = []

# list_median = []

# for i in np.unique(df_b_quickest.Week_Number):
#     df_b_new = df_b_quickest[df_b_quickest['Week_Number'] == i]
#     mean_new = get_median_timedelta_updated(df_b_new, 'final_received_to_delivered')
#     list_week.append(i)
#     list_median.append(mean_new)
    
# week_median_df = pd.DataFrame()
# week_median_df['Week_Number'] = list_week
# week_median_df['final_received_to_delivered_median'] =list_median
# week_median_df['final_received_to_delivered_median'] = week_median_df['final_received_to_delivered_median'].dt.round('s')
# week_median_df['final_received_to_delivered_hr'] = week_median_df['final_received_to_delivered_median'].dt.total_seconds()/3600

# %%
# week_median_df.to_csv('final_received_to_delivered_week_median_df_endbilled_first_billed_same.csv')

# %%
# df_b

# %%
# list_week = []

# list_median = []

# for i in np.unique(df_b.Week_Number):
#     df_b_new = df_b[df_b['Week_Number'] == i]
#     mean_new = get_median_timedelta_updated(df_b_new, 'final_received_to_delivered')
#     list_week.append(i)
#     list_median.append(mean_new)
    
# week_median_df = pd.DataFrame()
# week_median_df['Week_Number'] = list_week
# week_median_df['final_received_to_delivered_median'] =list_median
# week_median_df['final_received_to_delivered_median'] = week_median_df['final_received_to_delivered_median'].dt.round('s')
# week_median_df['final_received_to_delivered_hr'] = week_median_df['final_received_to_delivered_median'].dt.total_seconds()/3600

# %%
# week_median_df.to_csv('final_received_to_delivered_week_median_df.csv')

# %%
# trial_30 = df_b[df_b['Week_Number'] == 30]
# trial_30
