# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
import datetime as dt
from datetime import date
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.style as style
style.use('fivethirtyeight')
import dataframe_image as dfi
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'Nunito'
plt.rcParams['font.size'] = 10

# %%
color_code = ['#80ADF7','#EFBA50']
font_name = 'Nunito'
font_size = 10
font_size_title = 12
font_weight = 'bold'
orange_color = '#EFBA50'
blue_color = '#80ADF7'
grey_color = '#B0BCC8'
green_color = '#9EEDE0'
red_color = '#FD7284'
# color_code2 = [blue_color, grey_color]

background_color = "#F1F1F1"
border_color = "#B0BCC8"
text_align = 'center'
border_width ="0.5px"
border_style = 'solid'

body_design = { 'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align}
body_design2 = {'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align,'width':'70px'}
body_design3 = { 'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align,'width':'120px'}

border_design = {'selector': 'th', 'props': [('background-color' , background_color),('border-style' ,border_style),('font-family',font_name),('font-size',font_size),('border-width',border_width),('text-align',text_align),('border-color',border_color)]}
bar_width=0.5

# %%
# %run operations_utils.py

# %%
# %run path_changer_new.py

# %%
# df = pd.read_csv(source_file_path+'rx_flow_data_july21_final_updated.csv')

# %%
# df['track_rx_recieved_new'] =  pd.to_datetime(df.track_erx_received, dayfirst = False)
# df['track_rx_entered_new'] =  pd.to_datetime(df.track_rx_entered, dayfirst = False)
# df['max_date'] = df[['track_rx_recieved_new','track_rx_entered_new']].max(axis=1)
# df['max_date_only'] = df['max_date'].dt.date
# df['pharmacy_loc'] = df['rx_code_key_location'].astype(str).str[0:5]

# %%
# six_months = date.today() - relativedelta(months=+6)
# six_months = six_months.strftime("%Y-%m")
# six_month_date = str(six_months)+"-01"
# six_month_date

# %%
# df['filled_datekey_new'] =  pd.to_datetime(df.filled_datekey, dayfirst = False)

# %%
# df = df[df['filled_datekey_new'] > six_month_date]

# %%
# df['times_processed_ibd_regular_new'] = df['times_processed_ibd_regular'].notnull()
# df['times_processed_ibd_2K_new'] = df['times_processed_ibd_2K'].notnull()

# %%
# df['mon_key'] = df['max_date'].dt.strftime('%m-%y')

# df['mon_key_2'] = df['max_date'].dt.strftime('%b-%y')

# # df = df[df['mon_key_2']!='Jul-21']

# %%
# df['trackrx_last_ibdtag_new'] = df['trackrx_last_ibdtag'].notnull()

# %%
# df['status_callforins_day01_new'] = df['status_callforins_day01'].notnull()

# %%
# df['times_processed_callforins_day02_new'] = df['times_processed_callforins_day02'].notnull()

# %%
# df['times_processed_callforins_day03_new'] = df['times_processed_callforins_day03'].notnull()

# %%
# #now apply all on scenario
# df['c1'] = pd.to_timedelta(df['time_consumed_callforins_day01'], errors = 'coerce')
# df['c2'] = pd.to_timedelta(df['time_consumed_callforins_day02'], errors = 'coerce')
# df['c3'] = pd.to_timedelta(df['time_consumed_callforins_day03'], errors = 'coerce')

# %%
# df['total_call'] = df[['c1','c2','c3']].sum(axis=1)

# %%
# def get_time_value(x):
#     return x > 0

# %%
# df['total_call_2'] = df['total_call'].dt.total_seconds()

# %%
# df['is_call'] = df['total_call_2'].apply(lambda x: get_time_value(x))

# %%
# pharmacy_loc_list = ['FL-MI', 'MD-BA', 'NC-RA', 'NJ-SO', 'NY-BK', 'NY-MA', 'PA-PH']
# df = df[df['pharmacy_loc'].isin(pharmacy_loc_list)]
# df.pharmacy_loc.unique()

# %%
# %store -r main_odf_new

# %%
df = main_odf_new

# %%
df['TOTALRXAMOUNT'] = df['TOTALRXAMOUNT'].astype(str)
df['TOTALRXAMOUNT'] = df['TOTALRXAMOUNT'].apply(lambda x: x.replace(',',''))
df['TOTALRXAMOUNT'] = df['TOTALRXAMOUNT'].astype(float)

# %%
df['trackrx_last_status_new'] = df['trackrx_last_status']
df['trackrx_last_status_new'] = df['trackrx_last_status_new'].replace(['F','T','U'], 'NB')
df['trackrx_last_status_new'] = df['trackrx_last_status_new'].replace(np.nan, 'B')

# %%
df['rx_revenue'] = df['TOTALRXAMOUNT']

# %%
Rx_with_IBD_value_less_2k = df[(df['trackrx_last_ibdtag_new'] == True) & (df['times_processed_ibd_regular_new'] == True)]
Rx_with_IBD_value_greater_2k = df[(df['trackrx_last_ibdtag_new'] == True) & (df['times_processed_ibd_2K_new'] == True)]

# %%
# Rx_with_IBD_value_less_2k = df[(df['trackrx_last_ibdtag_new'] == True) & (df['status_callforins_day01_new'] == False) & (df['times_processed_ibd_regular_new'] == True)]

# Rx_with_IBD_2k = df[(df['trackrx_last_ibdtag_new'] == True) & (df['times_processed_ibd_regular_new'] == False) & (df['times_processed_ibd_2K_new'] == False) & (df['total_processing_time_ibd_new'] == False)]

# rx_list =  Rx_with_IBD_2k['rx_code_key_location'].to_list()

# # Rx_with_IBD2 = Rx_with_IBD[~Rx_with_IBD['rx_code_key_location'].isin(rx_list)]
# Rx_with_IBD_value_less_2k = Rx_with_IBD_value_less_2k[~Rx_with_IBD_value_less_2k['rx_code_key_location'].isin(rx_list)]

# %%
# Rx_with_IBD_value_greater_2k = df[(df['trackrx_last_ibdtag_new'] == True) & (df['status_callforins_day01_new'] == False) & (df['times_processed_ibd_2K_new'] == True)]


# Rx_with_IBD_value_greater_2k = Rx_with_IBD_value_greater_2k[~Rx_with_IBD_value_greater_2k['rx_code_key_location'].isin(rx_list)]

# %% [markdown]
# # Overall >2< level IBD for revenue and count

# %%
# Rx_with_IBD_value_less_2k_revenue_pivot

# %%
# Rx_with_IBD_value_less_2k billed
Rx_with_IBD_value_less_2k_billed = Rx_with_IBD_value_less_2k[Rx_with_IBD_value_less_2k['trackrx_last_status_new'] == 'B']

# %%
Rx_with_IBD_value_less_2k_count_pivot_billed = pd.pivot_table(Rx_with_IBD_value_less_2k_billed, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_count_pivot_billed.rename(columns = {'rx_code_key_location':'Rx count for IBD < 2k', 'pharmacy_loc': 'Pharmacy loc'}, inplace = True)

Rx_with_IBD_value_less_2k_revenue_pivot_billed = pd.pivot_table(Rx_with_IBD_value_less_2k_billed, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_revenue_pivot_billed.rename(columns = {'rx_revenue':'Rx revenue for IBD < 2k($)', 'pharmacy_loc': 'Pharmacy loc'}, inplace = True)

# %%
# Rx_with_IBD_value_greater_2k_revenue_pivot

# %%
# Rx_with_IBD_value_greater_2k billed
Rx_with_IBD_value_greater_2k_billed = Rx_with_IBD_value_greater_2k[Rx_with_IBD_value_greater_2k['trackrx_last_status_new'] == 'B']

# %%
#Rx_with_IBD_value_greater_2k
Rx_with_IBD_value_greater_2k_count_pivot_billed = pd.pivot_table(Rx_with_IBD_value_greater_2k_billed, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_count_pivot_billed.rename(columns = {'rx_code_key_location':'Rx count for IBD > 2k', 'pharmacy_loc': 'Pharmacy loc'}, inplace = True)

Rx_with_IBD_value_greater_2k_revenue_pivot_billed = pd.pivot_table(Rx_with_IBD_value_greater_2k_billed, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_revenue_pivot_billed.rename(columns = {'rx_revenue':'Rx revenue for IBD > 2k($)', 'pharmacy_loc': 'Pharmacy loc'}, inplace = True)

Rx_with_IBD_value_greater_2k_count_pivot_billed
# Out:
#   Pharmacy loc  Rx count for IBD > 2k
# 0        MD-BA                     89
# 1        NC-RA                     11
# 2        NJ-SO                     73
# 3        NY-BK                    236
# 4        NY-MA                      8
# 5        PA-PH                     81

# %%
Rx_count_IBD_less_and_greater_than_2k = pd.merge(Rx_with_IBD_value_less_2k_count_pivot_billed, Rx_with_IBD_value_greater_2k_count_pivot_billed, on = 'Pharmacy loc', how = 'left')
Rx_count_IBD_less_and_greater_than_2k = Rx_count_IBD_less_and_greater_than_2k.append(Rx_count_IBD_less_and_greater_than_2k.sum(axis=0), ignore_index = True)
Rx_count_IBD_less_and_greater_than_2k.iloc[[len(Rx_count_IBD_less_and_greater_than_2k)-1],[0]] = 'Overall'
Rx_count_IBD_less_and_greater_than_2k = Rx_count_IBD_less_and_greater_than_2k.set_index('Pharmacy loc')
Rx_count_IBD_less_and_greater_than_2k = Rx_count_IBD_less_and_greater_than_2k.replace(np.nan,0)
Rx_count_IBD_less_and_greater_than_2k = Rx_count_IBD_less_and_greater_than_2k[Rx_count_IBD_less_and_greater_than_2k.columns[:]].div(6,0).astype(int)
Rx_count_IBD_less_and_greater_than_2k
# Out:
#               Rx count for IBD < 2k  Rx count for IBD > 2k
# Pharmacy loc
# FL-MI                            79                      0
# MD-BA                           109                     14
# NC-RA                            83                      1
# NJ-SO                           436                     12
# NY-BK                           420                     39
# NY-MA                            44                      1
# PA-PH                           163                     13
# Overall                        1338                     83

# %%
Rx_count_IBD_less_and_greater_than_2k['Total Count'] = Rx_count_IBD_less_and_greater_than_2k[['Rx count for IBD < 2k', 'Rx count for IBD > 2k']].sum(axis=1)
Rx_count_IBD_less_and_greater_than_2k
# Out:
#               Rx count for IBD < 2k  Rx count for IBD > 2k  Total Count
# Pharmacy loc
# FL-MI                            79                      0           79
# MD-BA                           109                     14          123
# NC-RA                            83                      1           84
# NJ-SO                           436                     12          448
# NY-BK                           420                     39          459
# NY-MA                            44                      1           45
# PA-PH                           163                     13          176
# Overall                        1338                     83         1421

# %%
Rx_count_IBD_less_and_greater_than_2k['Rx count for IBD < 2k %'] = round(Rx_count_IBD_less_and_greater_than_2k['Rx count for IBD < 2k']/Rx_count_IBD_less_and_greater_than_2k['Total Count']*100,0).astype(int)
Rx_count_IBD_less_and_greater_than_2k['Rx count for IBD > 2k %'] = round(Rx_count_IBD_less_and_greater_than_2k['Rx count for IBD > 2k']/Rx_count_IBD_less_and_greater_than_2k['Total Count']*100,0).astype(int)
Rx_count_IBD_less_and_greater_than_2k
# Out:
#               Rx count for IBD < 2k  Rx count for IBD > 2k  Total Count  \
# Pharmacy loc
# FL-MI                            79                      0           79
# MD-BA                           109                     14          123
# NC-RA                            83                      1           84
# NJ-SO                           436                     12          448
# NY-BK                           420                     39          459
# NY-MA                            44                      1           45
# PA-PH                           163                     13          176
# Overall                        1338                     83         1421
#
#               Rx count for IBD < 2k %  Rx count for IBD > 2k %
# Pharmacy loc
# FL-MI                             100                        0
# MD-BA                              89                       11
# NC-RA                              99                        1
# NJ-SO                              97                        3
# NY-BK                              92                        8
# NY-MA                              98                        2
# PA-PH                              93                        7
# Overall                            94                        6

# %%
Rx_count_IBD_less_and_greater_than_2k_final = Rx_count_IBD_less_and_greater_than_2k[['Total Count','Rx count for IBD < 2k', 'Rx count for IBD < 2k %', 'Rx count for IBD > 2k', 'Rx count for IBD > 2k %']]
#Rx_count_IBD_less_and_greater_than_2k_final = Rx_count_IBD_less_and_greater_than_2k_final.set_index('Pharmacy loc')
Rx_count_IBD_less_and_greater_than_2k_final = Rx_count_IBD_less_and_greater_than_2k_final.rename(columns = {'Rx count for IBD < 2k %': ' %', 'Rx count for IBD > 2k %': '% '})
Rx_count_IBD_less_and_greater_than_2k_final
# Out:
#               Total Count  Rx count for IBD < 2k    %  Rx count for IBD > 2k  \
# Pharmacy loc
# FL-MI                  79                     79  100                      0
# MD-BA                 123                    109   89                     14
# NC-RA                  84                     83   99                      1
# NJ-SO                 448                    436   97                     12
# NY-BK                 459                    420   92                     39
# NY-MA                  45                     44   98                      1
# PA-PH                 176                    163   93                     13
# Overall              1421                   1338   94                     83
#
#               %
# Pharmacy loc
# FL-MI          0
# MD-BA         11
# NC-RA          1
# NJ-SO          3
# NY-BK          8
# NY-MA          2
# PA-PH          7
# Overall        6

# %%
subset_value = (Rx_count_IBD_less_and_greater_than_2k_final.index.tolist()[:-1],['Rx count for IBD < 2k', 'Rx count for IBD > 2k'])

df_style1 = Rx_count_IBD_less_and_greater_than_2k_final.style.set_properties(**body_design).background_gradient(cmap='RdYlGn_r',axis=1, subset = subset_value).format("{:,}")
df_style1.set_table_styles([border_design])
df_style1
# Out:
# <style  type="text/css" >
#     #T_f8b34_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_f8b34_row0_col0,#T_f8b34_row0_col2,#T_f8b34_row0_col4,#T_f8b34_row1_col0,#T_f8b34_row1_col2,#T_f8b34_row1_col4,#T_f8b34_row2_col0,#T_f8b34_row2_col2,#T_f8b34_row2_col4,#T_f8b34_row3_col0,#T_f8b34_row3_col2,#T_f8b34_row3_col4,#T_f8b34_row4_col0,#T_f8b34_row4_col2,#T_f8b34_row4_col4,#T_f8b34_row5_col0,#T_f8b34_row5_col2,#T_f8b34_row5_col4,#T_f8b34_row6_col0,#T_f8b34_row6_col2,#T_f8b34_row6_col4,#T_f8b34_row7_col0,#T_f8b34_row7_col1,#T_f8b34_row7_col2,#T_f8b34_row7_col3,#T_f8b34_row7_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#         }#T_f8b34_row0_col1,#T_f8b34_row1_col1,#T_f8b34_row2_col1,#T_f8b34_row3_col1,#T_f8b34_row4_col1,#T_f8b34_row5_col1,#T_f8b34_row6_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_f8b34_row0_col3,#T_f8b34_row1_col3,#T_f8b34_row2_col3,#T_f8b34_row3_col3,#T_f8b34_row4_col3,#T_f8b34_row5_col3,#T_f8b34_row6_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }</style><table id="T_f8b34_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Rx count for IBD < 2k</th>        <th class="col_heading level0 col2" > %</th>        <th class="col_heading level0 col3" >Rx count for IBD > 2k</th>        <th class="col_heading level0 col4" >% </th>    </tr>    <tr>        <th class="index_name level0" >Pharmacy loc</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f8b34_level0_row0" class="row_heading level0 row0" >FL-MI</th>
#                         <td id="T_f8b34_row0_col0" class="data row0 col0" >79</td>
#                         <td id="T_f8b34_row0_col1" class="data row0 col1" >79</td>
#                         <td id="T_f8b34_row0_col2" class="data row0 col2" >100</td>
#                         <td id="T_f8b34_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_f8b34_row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row1" class="row_heading level0 row1" >MD-BA</th>
#                         <td id="T_f8b34_row1_col0" class="data row1 col0" >123</td>
#                         <td id="T_f8b34_row1_col1" class="data row1 col1" >109</td>
#                         <td id="T_f8b34_row1_col2" class="data row1 col2" >89</td>
#                         <td id="T_f8b34_row1_col3" class="data row1 col3" >14</td>
#                         <td id="T_f8b34_row1_col4" class="data row1 col4" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row2" class="row_heading level0 row2" >NC-RA</th>
#                         <td id="T_f8b34_row2_col0" class="data row2 col0" >84</td>
#                         <td id="T_f8b34_row2_col1" class="data row2 col1" >83</td>
#                         <td id="T_f8b34_row2_col2" class="data row2 col2" >99</td>
#                         <td id="T_f8b34_row2_col3" class="data row2 col3" >1</td>
#                         <td id="T_f8b34_row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row3" class="row_heading level0 row3" >NJ-SO</th>
#                         <td id="T_f8b34_row3_col0" class="data row3 col0" >448</td>
#                         <td id="T_f8b34_row3_col1" class="data row3 col1" >436</td>
#                         <td id="T_f8b34_row3_col2" class="data row3 col2" >97</td>
#                         <td id="T_f8b34_row3_col3" class="data row3 col3" >12</td>
#                         <td id="T_f8b34_row3_col4" class="data row3 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row4" class="row_heading level0 row4" >NY-BK</th>
#                         <td id="T_f8b34_row4_col0" class="data row4 col0" >459</td>
#                         <td id="T_f8b34_row4_col1" class="data row4 col1" >420</td>
#                         <td id="T_f8b34_row4_col2" class="data row4 col2" >92</td>
#                         <td id="T_f8b34_row4_col3" class="data row4 col3" >39</td>
#                         <td id="T_f8b34_row4_col4" class="data row4 col4" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row5" class="row_heading level0 row5" >NY-MA</th>
#                         <td id="T_f8b34_row5_col0" class="data row5 col0" >45</td>
#                         <td id="T_f8b34_row5_col1" class="data row5 col1" >44</td>
#                         <td id="T_f8b34_row5_col2" class="data row5 col2" >98</td>
#                         <td id="T_f8b34_row5_col3" class="data row5 col3" >1</td>
#                         <td id="T_f8b34_row5_col4" class="data row5 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row6" class="row_heading level0 row6" >PA-PH</th>
#                         <td id="T_f8b34_row6_col0" class="data row6 col0" >176</td>
#                         <td id="T_f8b34_row6_col1" class="data row6 col1" >163</td>
#                         <td id="T_f8b34_row6_col2" class="data row6 col2" >93</td>
#                         <td id="T_f8b34_row6_col3" class="data row6 col3" >13</td>
#                         <td id="T_f8b34_row6_col4" class="data row6 col4" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_f8b34_level0_row7" class="row_heading level0 row7" >Overall</th>
#                         <td id="T_f8b34_row7_col0" class="data row7 col0" >1,421</td>
#                         <td id="T_f8b34_row7_col1" class="data row7 col1" >1,338</td>
#                         <td id="T_f8b34_row7_col2" class="data row7 col2" >94</td>
#                         <td id="T_f8b34_row7_col3" class="data row7 col3" >83</td>
#                         <td id="T_f8b34_row7_col4" class="data row7 col4" >6</td>
#             </tr>
#     </tbody></table>

# %%
dfi.export(df_style1, ibd_images+'rx_count_ibd_less_and_greater_than_2k_final_new.png')

# %%
Rx_Revenue_IBD_less_and_greater_than_2k = pd.merge(Rx_with_IBD_value_less_2k_revenue_pivot_billed, Rx_with_IBD_value_greater_2k_revenue_pivot_billed, on = 'Pharmacy loc', how = 'left')
Rx_Revenue_IBD_less_and_greater_than_2k
# Out:
#   Pharmacy loc  Rx revenue for IBD < 2k($)  Rx revenue for IBD > 2k($)
# 0        FL-MI                   655160.90                         NaN
# 1        MD-BA                  1261769.45                   420814.52
# 2        NC-RA                   921683.41                    61196.26
# 3        NJ-SO                  3762763.06                   308028.51
# 4        NY-BK                  2824613.21                  1057785.21
# 5        NY-MA                   102689.43                     9107.78
# 6        PA-PH                  1662136.20                   259110.63

# %%
# revenue
Rx_Revenue_IBD_less_and_greater_than_2k = Rx_Revenue_IBD_less_and_greater_than_2k.append(Rx_Revenue_IBD_less_and_greater_than_2k.sum(axis = 0), ignore_index = True)
Rx_Revenue_IBD_less_and_greater_than_2k.iloc[[7],[0]] = 'Overall'
Rx_Revenue_IBD_less_and_greater_than_2k
# Out:
#   Pharmacy loc  Rx revenue for IBD < 2k($)  Rx revenue for IBD > 2k($)
# 0        FL-MI                   655160.90                         NaN
# 1        MD-BA                  1261769.45                   420814.52
# 2        NC-RA                   921683.41                    61196.26
# 3        NJ-SO                  3762763.06                   308028.51
# 4        NY-BK                  2824613.21                  1057785.21
# 5        NY-MA                   102689.43                     9107.78
# 6        PA-PH                  1662136.20                   259110.63
# 7      Overall                 11190815.66                  2116042.91

# %%
for i in Rx_Revenue_IBD_less_and_greater_than_2k.columns[1:]:
    Rx_Revenue_IBD_less_and_greater_than_2k = Rx_Revenue_IBD_less_and_greater_than_2k.replace(np.nan,0)
    Rx_Revenue_IBD_less_and_greater_than_2k[i] = Rx_Revenue_IBD_less_and_greater_than_2k[i].astype(int)

# %%
Rx_Revenue_IBD_less_and_greater_than_2k = Rx_Revenue_IBD_less_and_greater_than_2k.set_index('Pharmacy loc')
Rx_Revenue_IBD_less_and_greater_than_2k = Rx_Revenue_IBD_less_and_greater_than_2k[Rx_Revenue_IBD_less_and_greater_than_2k.columns[:]].div(6,0).astype(int)
Rx_Revenue_IBD_less_and_greater_than_2k
# Out:
#               Rx revenue for IBD < 2k($)  Rx revenue for IBD > 2k($)
# Pharmacy loc
# FL-MI                             109193                           0
# MD-BA                             210294                       70135
# NC-RA                             153613                       10199
# NJ-SO                             627127                       51338
# NY-BK                             470768                      176297
# NY-MA                              17114                        1517
# PA-PH                             277022                       43185
# Overall                          1865135                      352673

# %%
Rx_Revenue_IBD_less_and_greater_than_2k['Total Revenue($)'] = Rx_Revenue_IBD_less_and_greater_than_2k[['Rx revenue for IBD < 2k($)', 'Rx revenue for IBD > 2k($)']].sum(axis=1)
Rx_Revenue_IBD_less_and_greater_than_2k
# Out:
#               Rx revenue for IBD < 2k($)  Rx revenue for IBD > 2k($)  \
# Pharmacy loc
# FL-MI                             109193                           0
# MD-BA                             210294                       70135
# NC-RA                             153613                       10199
# NJ-SO                             627127                       51338
# NY-BK                             470768                      176297
# NY-MA                              17114                        1517
# PA-PH                             277022                       43185
# Overall                          1865135                      352673
#
#               Total Revenue($)
# Pharmacy loc
# FL-MI                   109193
# MD-BA                   280429
# NC-RA                   163812
# NJ-SO                   678465
# NY-BK                   647065
# NY-MA                    18631
# PA-PH                   320207
# Overall                2217808

# %%
Rx_Revenue_IBD_less_and_greater_than_2k['Rx revenue for IBD < 2k %'] = round(Rx_Revenue_IBD_less_and_greater_than_2k['Rx revenue for IBD < 2k($)']/Rx_Revenue_IBD_less_and_greater_than_2k['Total Revenue($)']*100,0).astype(int)
Rx_Revenue_IBD_less_and_greater_than_2k['Rx revenue for IBD > 2k %'] = round(Rx_Revenue_IBD_less_and_greater_than_2k['Rx revenue for IBD > 2k($)']/Rx_Revenue_IBD_less_and_greater_than_2k['Total Revenue($)']*100,0).astype(int)
Rx_Revenue_IBD_less_and_greater_than_2k
# Out:
#               Rx revenue for IBD < 2k($)  Rx revenue for IBD > 2k($)  \
# Pharmacy loc
# FL-MI                             109193                           0
# MD-BA                             210294                       70135
# NC-RA                             153613                       10199
# NJ-SO                             627127                       51338
# NY-BK                             470768                      176297
# NY-MA                              17114                        1517
# PA-PH                             277022                       43185
# Overall                          1865135                      352673
#
#               Total Revenue($)  Rx revenue for IBD < 2k %  \
# Pharmacy loc
# FL-MI                   109193                        100
# MD-BA                   280429                         75
# NC-RA                   163812                         94
# NJ-SO                   678465                         92
# NY-BK                   647065                         73
# NY-MA                    18631                         92
# PA-PH                   320207                         87
# Overall                2217808                         84
#
#               Rx revenue for IBD > 2k %
# Pharmacy loc
# FL-MI                                 0
# MD-BA                                25
# NC-RA                                 6
# NJ-SO                                 8
# NY-BK                                27
# NY-MA                                 8
# PA-PH                                13
# Overall                              16

# %%
Rx_Revenue_IBD_less_and_greater_than_2k_final = Rx_Revenue_IBD_less_and_greater_than_2k[['Total Revenue($)', 'Rx revenue for IBD < 2k($)', 'Rx revenue for IBD < 2k %', 'Rx revenue for IBD > 2k($)', 'Rx revenue for IBD > 2k %']]
#Rx_Revenue_IBD_less_and_greater_than_2k_final = Rx_Revenue_IBD_less_and_greater_than_2k_final.set_index('Pharmacy loc')
Rx_Revenue_IBD_less_and_greater_than_2k_final = Rx_Revenue_IBD_less_and_greater_than_2k_final.rename(columns = {'Rx revenue for IBD < 2k %': ' %', 'Rx revenue for IBD > 2k %': '% '})
Rx_Revenue_IBD_less_and_greater_than_2k_final
# Out:
#               Total Revenue($)  Rx revenue for IBD < 2k($)    %  \
# Pharmacy loc
# FL-MI                   109193                      109193  100
# MD-BA                   280429                      210294   75
# NC-RA                   163812                      153613   94
# NJ-SO                   678465                      627127   92
# NY-BK                   647065                      470768   73
# NY-MA                    18631                       17114   92
# PA-PH                   320207                      277022   87
# Overall                2217808                     1865135   84
#
#               Rx revenue for IBD > 2k($)  %
# Pharmacy loc
# FL-MI                                  0   0
# MD-BA                              70135  25
# NC-RA                              10199   6
# NJ-SO                              51338   8
# NY-BK                             176297  27
# NY-MA                               1517   8
# PA-PH                              43185  13
# Overall                           352673  16

# %%
subset_value = (Rx_Revenue_IBD_less_and_greater_than_2k_final.index.tolist()[:-1],['Rx revenue for IBD < 2k($)', 'Rx revenue for IBD > 2k($)'])
df_style2 = Rx_Revenue_IBD_less_and_greater_than_2k_final.style.set_properties(**body_design).background_gradient(cmap='RdYlGn',axis=1, subset = subset_value).format("{:,}")
df_style2.set_table_styles([border_design])
df_style2
# Out:
# <style  type="text/css" >
#     #T_2beee_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_2beee_row0_col0,#T_2beee_row0_col2,#T_2beee_row0_col4,#T_2beee_row1_col0,#T_2beee_row1_col2,#T_2beee_row1_col4,#T_2beee_row2_col0,#T_2beee_row2_col2,#T_2beee_row2_col4,#T_2beee_row3_col0,#T_2beee_row3_col2,#T_2beee_row3_col4,#T_2beee_row4_col0,#T_2beee_row4_col2,#T_2beee_row4_col4,#T_2beee_row5_col0,#T_2beee_row5_col2,#T_2beee_row5_col4,#T_2beee_row6_col0,#T_2beee_row6_col2,#T_2beee_row6_col4,#T_2beee_row7_col0,#T_2beee_row7_col1,#T_2beee_row7_col2,#T_2beee_row7_col3,#T_2beee_row7_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#         }#T_2beee_row0_col1,#T_2beee_row1_col1,#T_2beee_row2_col1,#T_2beee_row3_col1,#T_2beee_row4_col1,#T_2beee_row5_col1,#T_2beee_row6_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_2beee_row0_col3,#T_2beee_row1_col3,#T_2beee_row2_col3,#T_2beee_row3_col3,#T_2beee_row4_col3,#T_2beee_row5_col3,#T_2beee_row6_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }</style><table id="T_2beee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Revenue($)</th>        <th class="col_heading level0 col1" >Rx revenue for IBD < 2k($)</th>        <th class="col_heading level0 col2" > %</th>        <th class="col_heading level0 col3" >Rx revenue for IBD > 2k($)</th>        <th class="col_heading level0 col4" >% </th>    </tr>    <tr>        <th class="index_name level0" >Pharmacy loc</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2beee_level0_row0" class="row_heading level0 row0" >FL-MI</th>
#                         <td id="T_2beee_row0_col0" class="data row0 col0" >109,193</td>
#                         <td id="T_2beee_row0_col1" class="data row0 col1" >109,193</td>
#                         <td id="T_2beee_row0_col2" class="data row0 col2" >100</td>
#                         <td id="T_2beee_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_2beee_row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row1" class="row_heading level0 row1" >MD-BA</th>
#                         <td id="T_2beee_row1_col0" class="data row1 col0" >280,429</td>
#                         <td id="T_2beee_row1_col1" class="data row1 col1" >210,294</td>
#                         <td id="T_2beee_row1_col2" class="data row1 col2" >75</td>
#                         <td id="T_2beee_row1_col3" class="data row1 col3" >70,135</td>
#                         <td id="T_2beee_row1_col4" class="data row1 col4" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row2" class="row_heading level0 row2" >NC-RA</th>
#                         <td id="T_2beee_row2_col0" class="data row2 col0" >163,812</td>
#                         <td id="T_2beee_row2_col1" class="data row2 col1" >153,613</td>
#                         <td id="T_2beee_row2_col2" class="data row2 col2" >94</td>
#                         <td id="T_2beee_row2_col3" class="data row2 col3" >10,199</td>
#                         <td id="T_2beee_row2_col4" class="data row2 col4" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row3" class="row_heading level0 row3" >NJ-SO</th>
#                         <td id="T_2beee_row3_col0" class="data row3 col0" >678,465</td>
#                         <td id="T_2beee_row3_col1" class="data row3 col1" >627,127</td>
#                         <td id="T_2beee_row3_col2" class="data row3 col2" >92</td>
#                         <td id="T_2beee_row3_col3" class="data row3 col3" >51,338</td>
#                         <td id="T_2beee_row3_col4" class="data row3 col4" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row4" class="row_heading level0 row4" >NY-BK</th>
#                         <td id="T_2beee_row4_col0" class="data row4 col0" >647,065</td>
#                         <td id="T_2beee_row4_col1" class="data row4 col1" >470,768</td>
#                         <td id="T_2beee_row4_col2" class="data row4 col2" >73</td>
#                         <td id="T_2beee_row4_col3" class="data row4 col3" >176,297</td>
#                         <td id="T_2beee_row4_col4" class="data row4 col4" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row5" class="row_heading level0 row5" >NY-MA</th>
#                         <td id="T_2beee_row5_col0" class="data row5 col0" >18,631</td>
#                         <td id="T_2beee_row5_col1" class="data row5 col1" >17,114</td>
#                         <td id="T_2beee_row5_col2" class="data row5 col2" >92</td>
#                         <td id="T_2beee_row5_col3" class="data row5 col3" >1,517</td>
#                         <td id="T_2beee_row5_col4" class="data row5 col4" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row6" class="row_heading level0 row6" >PA-PH</th>
#                         <td id="T_2beee_row6_col0" class="data row6 col0" >320,207</td>
#                         <td id="T_2beee_row6_col1" class="data row6 col1" >277,022</td>
#                         <td id="T_2beee_row6_col2" class="data row6 col2" >87</td>
#                         <td id="T_2beee_row6_col3" class="data row6 col3" >43,185</td>
#                         <td id="T_2beee_row6_col4" class="data row6 col4" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_2beee_level0_row7" class="row_heading level0 row7" >Overall</th>
#                         <td id="T_2beee_row7_col0" class="data row7 col0" >2,217,808</td>
#                         <td id="T_2beee_row7_col1" class="data row7 col1" >1,865,135</td>
#                         <td id="T_2beee_row7_col2" class="data row7 col2" >84</td>
#                         <td id="T_2beee_row7_col3" class="data row7 col3" >352,673</td>
#                         <td id="T_2beee_row7_col4" class="data row7 col4" >16</td>
#             </tr>
#     </tbody></table>

# %%
dfi.export(df_style2, ibd_images+'rx_revenue_ibd_less_and_greater_than_2k_final_new.png')

# %% [markdown]
# # IBD Denied

# %%
ibd_not_possible_list = ['IBD DENIED CALL MD TO SWITCH', 'IBD DENIED 2K+ (AMT)', 'IBD NOT POSSIBLE']

# %%
### Rx_with_IBD_value_less_2k

# %%
Rx_with_IBD_value_less_2k_denied = Rx_with_IBD_value_less_2k[Rx_with_IBD_value_less_2k['trackrx_last_ibdtag'].isin(ibd_not_possible_list)]

# %%
Rx_with_IBD_value_less_2k_denied
# Out:
#         Unnamed: 0 pharmacy_location       rxno       presnpi          ndc  \
# 2586          2586             NY-MA   923960-0    1659869956  00299595030
# 2872          2872             FL-MI   776012-0    1356552178  00187540004
# 3028          3028             NY-MA   926190-0    1023084696  00187511045
# 3129          3129             NY-MA   928798-0    1770974610  00591352530
# 5348          5348             NY-BK  1155154-0    1871855270  50383080416
# ...            ...               ...        ...           ...          ...
# 363455      363455             NY-MA   925637-0  1144516121.0  70727052925
# 363513      363513             NY-MA   925902-0  1497199202.0  45802043733
# 363516      363516             NY-MA   925901-0  1497199202.0  45802089626
# 363533      363533             NY-MA   923230-0  1194164186.0  71776002430
# 363609      363609             NY-MA   923867-0  1093880957.0  57599000200
#
#        trackrx_status  patientno  track_erx_received    track_rx_entered  \
# 2586                F      74161 2021-10-12 09:10:00 2021-10-12 00:00:00
# 2872                B      22472 2021-10-14 15:06:00 2021-10-15 11:23:00
# 3028                F      74438                 NaT 2021-11-11 00:00:00
# 3129                F      71354 2021-12-20 13:11:00 2021-12-20 00:00:00
# 5348                F     619969 2021-12-02 11:48:00 2021-12-02 11:58:00
# ...               ...        ...                 ...                 ...
# 363455              F      73961                 NaT 2021-11-02 17:18:00
# 363513              F      72232 2021-11-08 11:14:00 2021-11-08 00:00:00
# 363516              F      72232 2021-11-08 11:14:00 2021-11-08 00:00:00
# 363533              F      74192                 NaT 2021-10-01 19:00:00
# 363609              F      73051                 NaT 2021-10-06 16:30:00
#
#        rx_entered_date_verification      filled_datekey final_rx_pickedup  \
# 2586            2021-10-12 11:51:00 2021-10-12 00:00:00               NaT
# 2872            2021-10-15 11:23:00 2021-10-19 11:22:41        2021-10-22
# 3028                            NaN 2021-11-11 00:00:00               NaT
# 3129            2021-12-20 13:41:00 2021-12-20 00:00:00               NaT
# 5348            2021-12-02 11:58:00 2021-12-31 00:00:00               NaT
# ...                             ...                 ...               ...
# 363455                          NaN 2021-11-03 00:00:00               NaT
# 363513          2021-11-08 15:10:00 2021-11-08 00:00:00               NaT
# 363516          2021-11-08 15:10:00 2021-11-08 00:00:00               NaT
# 363533                          NaN 2021-10-04 00:00:00               NaT
# 363609                          NaN 2021-10-11 00:00:00               NaT
#
#           rx_delivered_date track_label_printed final_rx_drug_picks  \
# 2586                    NaN                 NaT                 NaT
# 2872    2021-10-22 12:42:57 2021-10-20 12:54:31 2021-10-19 16:45:00
# 3028                    NaN                 NaT                 NaT
# 3129                    NaN                 NaT                 NaT
# 5348                    NaN                 NaT                 NaT
# ...                     ...                 ...                 ...
# 363455                  NaN 2021-11-03 14:02:25                 NaT
# 363513                  NaN                 NaT                 NaT
# 363516                  NaN                 NaT                 NaT
# 363533                  NaN 2021-10-04 11:48:55                 NaT
# 363609                  NaN 2021-10-11 12:33:35                 NaT
#
#         final_rx_rph_picks             last_run rx_code_key_location  \
# 2586                   NaT  2022-01-07 01:20:41       NY-MA-923960-0
# 2872   2021-10-19 17:12:57  2022-01-07 01:20:41       FL-MI-776012-0
# 3028                   NaT  2022-01-07 01:20:41       NY-MA-926190-0
# 3129                   NaT  2022-01-07 01:20:41       NY-MA-928798-0
# 5348                   NaT  2022-01-11 01:20:42      NY-BK-1155154-0
# ...                    ...                  ...                  ...
# 363455                 NaT  2022-01-05 01:20:44       NY-MA-925637-0
# 363513                 NaT  2022-01-05 01:20:44       NY-MA-925902-0
# 363516                 NaT  2022-01-05 01:20:44       NY-MA-925901-0
# 363533                 NaT  2022-01-05 01:20:44       NY-MA-923230-0
# 363609                 NaT  2022-01-05 01:20:44       NY-MA-923867-0
#
#              nabp first_billed_datetime end_billed_datetime  \
# 2586    3308055.0                   NaT                 NaT
# 2872    5744859.0   2021-10-19 16:40:39 2021-10-19 16:40:39
# 3028    3308055.0                   NaT                 NaT
# 3129    3308055.0                   NaT                 NaT
# 5348    3352779.0   2021-12-02 12:22:04 2021-12-02 12:22:25
# ...           ...                   ...                 ...
# 363455  3308055.0                   NaT                 NaT
# 363513  3308055.0   2021-12-20 09:46:07 2021-12-20 09:46:07
# 363516  3308055.0                   NaT                 NaT
# 363533  3308055.0                   NaT                 NaT
# 363609  3308055.0                   NaT                 NaT
#
#        trackrx_processing_date_starttime       processing_end  \
# 2586                 2021-10-12 11:51:26  2022-01-06 14:20:39
# 2872                 2021-10-15 11:22:56  2022-01-06 15:08:22
# 3028                 2021-11-12 12:01:15  2022-01-06 14:32:40
# 3129                 2021-12-20 13:41:09  2022-01-06 13:56:39
# 5348                 2021-12-02 11:59:06  2022-01-10 12:51:16
# ...                                  ...                  ...
# 363455               2021-11-03 14:01:58  2022-01-05 03:57:24
# 363513               2021-11-08 15:09:50  2022-01-05 03:57:24
# 363516               2021-11-08 15:09:47  2022-01-05 03:57:24
# 363533               2021-10-04 11:45:23  2022-01-05 03:57:24
# 363609               2021-10-11 12:32:10  2022-01-05 03:57:24
#
#              IBD IN PROCESS IBD FIDELIS  IBD REQUIRED  IBD $2K+  IBD IS $2K+  \
# 2586                    NaN         NaN           NaN       NaN          NaN
# 2872                    NaN         NaN           NaN       NaN          NaN
# 3028                    NaN         NaN           NaN       NaN          NaN
# 3129                    NaN         NaN           NaN       NaN          NaN
# 5348                    NaN         NaN           NaN       NaN          NaN
# ...                     ...         ...           ...       ...          ...
# 363455                  NaN         NaN           NaN       NaN          NaN
# 363513                  NaN         NaN           NaN       NaN          NaN
# 363516                  NaN         NaN           NaN       NaN          NaN
# 363533  2021-10-11 15:16:47         NaN           NaN       NaN          NaN
# 363609  2021-10-13 11:44:24         NaN           NaN       NaN          NaN
#
#         IBD 2K  IBD IS 2K IBD SPECIALITY                  IBD  \
# 2586       NaN        NaN            NaN  2021-10-22 10:22:58
# 2872       NaN        NaN            NaN  2021-10-18 10:43:59
# 3028       NaN        NaN            NaN  2022-01-04 08:43:16
# 3129       NaN        NaN            NaN  2021-12-20 16:06:00
# 5348       NaN        NaN            NaN  2021-12-20 09:55:29
# ...        ...        ...            ...                  ...
# 363455     NaN        NaN            NaN  2021-11-15 09:53:48
# 363513     NaN        NaN            NaN  2021-11-16 16:16:26
# 363516     NaN        NaN            NaN  2021-11-09 11:42:29
# 363533     NaN        NaN            NaN  2021-10-14 10:51:02
# 363609     NaN        NaN            NaN  2021-12-23 14:50:33
#
#                 IBD REGULAR         TO BE BILLED         CALL FOR INS  \
# 2586                    NaN  2021-10-12 11:53:26                  NaN
# 2872                    NaN  2021-10-15 11:22:56                  NaN
# 3028                    NaN  2021-12-30 12:33:06  2021-12-30 12:27:43
# 3129                    NaN                  NaN                  NaN
# 5348                    NaN                  NaN  2021-12-02 11:59:06
# ...                     ...                  ...                  ...
# 363455                  NaN                  NaN                  NaN
# 363513  2021-11-11 12:42:07  2021-11-08 15:09:50                  NaN
# 363516                  NaN  2021-11-08 15:09:47                  NaN
# 363533  2021-10-08 12:20:51                  NaN                  NaN
# 363609  2021-10-13 10:00:47                  NaN                  NaN
#
#        CALL FOR INS (KOREAN/CH)   CALL FOR INS DAY 2 CALL FOR INS DAY 3  \
# 2586                        NaN                  NaN                NaN
# 2872                        NaN                  NaN                NaN
# 3028                        NaN  2021-12-30 12:27:43                NaN
# 3129                        NaN                  NaN                NaN
# 5348                        NaN                  NaN                NaN
# ...                         ...                  ...                ...
# 363455                      NaN                  NaN                NaN
# 363513                      NaN                  NaN                NaN
# 363516                      NaN                  NaN                NaN
# 363533                      NaN                  NaN                NaN
# 363609                      NaN                  NaN                NaN
#
#        CALL FOR INS (KOREAN/CHINESE) CAL FOR INS (KOREAN/CHINESE) is_pickedup  \
# 2586                             NaN                          NaN         NaN
# 2872                             NaN                          NaN       False
# 3028                             NaN                          NaN         NaN
# 3129                             NaN                          NaN         NaN
# 5348                             NaN                          NaN         NaN
# ...                              ...                          ...         ...
# 363455                           NaN                          NaN         NaN
# 363513                           NaN                          NaN         NaN
# 363516                           NaN                          NaN         NaN
# 363533                           NaN                          NaN         NaN
# 363609                           NaN                          NaN         NaN
#
#         is_eRx trackrx_statusflow trackrx_last_status trackrx_last_delivery  \
# 2586      True               U->F                   F                   NaN
# 2872      True               U->B                   B                     D
# 3028     False               U->F                   F                   NaN
# 3129      True               U->F                   F                   NaN
# 5348      True         U->B->U->F                   F                   NaN
# ...        ...                ...                 ...                   ...
# 363455   False               U->F                   F                   NaN
# 363513    True         U->B->U->F                   F                   NaN
# 363516    True               U->F                   F                   NaN
# 363533   False               U->F                   F                   NaN
# 363609   False               U->F                   F                   NaN
#
#        trackrx_delivery_flow trackrx_pickuptime_flow trackrx_pickedup_flow  \
# 2586                     NaN                     NaN                   ->N
# 2872                 None->D          None->12:42 PM                   ->Y
# 3028                     NaN                     NaN                   ->N
# 3129                     NaN                     NaN                   ->N
# 5348                     NaN                     NaN                   NaN
# ...                      ...                     ...                   ...
# 363455                   NaN                     NaN                   ->N
# 363513                   NaN                     NaN                   ->N
# 363516                   NaN                     NaN                   ->N
# 363533                   NaN                     NaN                   ->N
# 363609                   NaN                     NaN                   ->N
#
#        trackrx_last_pickuped trackrx_last_ibdtag trackrx_last_callinstag  \
# 2586                       N    IBD NOT POSSIBLE                     NaN
# 2872                       Y    IBD NOT POSSIBLE                     NaN
# 3028                       N    IBD NOT POSSIBLE            TO BE BILLED
# 3129                       N    IBD NOT POSSIBLE                     NaN
# 5348                     NaN    IBD NOT POSSIBLE                     IBD
# ...                      ...                 ...                     ...
# 363455                     N    IBD NOT POSSIBLE                     NaN
# 363513                     N    IBD NOT POSSIBLE                     NaN
# 363516                     N    IBD NOT POSSIBLE                     NaN
# 363533                     N    IBD NOT POSSIBLE                     NaN
# 363609                     N    IBD NOT POSSIBLE                     NaN
#
#         end_filed_datetime trackrx_callins_processing_start  \
# 2586   2021-12-30 18:55:41                              NaT
# 2872                   NaT                              NaT
# 3028   2022-01-06 14:29:39              2021-12-15 18:24:08
# 3129   2021-12-30 21:08:45                              NaT
# 5348   2022-01-01 11:06:56              2021-12-02 11:59:06
# ...                    ...                              ...
# 363455 2022-01-04 21:06:12                              NaT
# 363513 2021-12-30 22:36:42                              NaT
# 363516 2021-12-30 22:37:08                              NaT
# 363533 2022-01-04 21:03:10                              NaT
# 363609 2022-01-04 21:02:43                              NaT
#
#        ibd_processing_enddatetime trackrx_ibd_processing_start  \
# 2586                          NaT          2021-10-12 16:35:32
# 2872                          NaT          2021-10-15 17:36:29
# 3028                          NaT          2022-01-03 16:39:13
# 3129                          NaT          2021-12-20 13:41:09
# 5348                          NaT          2021-12-02 12:31:41
# ...                           ...                          ...
# 363455                        NaT          2021-11-03 14:02:05
# 363513                        NaT          2021-11-08 17:23:22
# 363516                        NaT          2021-11-08 17:23:30
# 363533        2021-10-14 10:51:02          2021-10-04 11:46:13
# 363609        2021-11-02 09:04:37          2021-10-11 12:32:19
#
#        time_consumed_ibd_regular  times_processed_ibd_regular  \
# 2586             0 days 20:20:44                          1.0
# 2872             2 days 17:07:30                          1.0
# 3028             0 days 16:04:03                          1.0
# 3129             0 days 02:24:51                          1.0
# 5348             0 days 00:45:02                          1.0
# ...                          ...                          ...
# 363455           0 days 21:51:26                          1.0
# 363513           5 days 21:53:42                          2.0
# 363516           0 days 18:18:59                          1.0
# 363533           3 days 06:55:00                          2.0
# 363609           3 days 04:01:24                          3.0
#
#        status_ibd_regular time_consumed_ibd_2K  times_processed_ibd_2K  \
# 2586            completed                  NaT                     NaN
# 2872            completed                  NaT                     NaN
# 3028            completed                  NaT                     NaN
# 3129            completed                  NaT                     NaN
# 5348            completed                  NaT                     NaN
# ...                   ...                  ...                     ...
# 363455          completed                  NaT                     NaN
# 363513          completed                  NaT                     NaN
# 363516          completed                  NaT                     NaN
# 363533          completed                  NaT                     NaN
# 363609          completed                  NaT                     NaN
#
#        status_ibd_2K total_processing_time_ibd  times_processed_ibd  \
# 2586             NaN                       NaT                  NaN
# 2872             NaN                       NaT                  NaN
# 3028             NaN                       NaT                  NaN
# 3129             NaN                       NaT                  NaN
# 5348             NaN                       NaT                  NaN
# ...              ...                       ...                  ...
# 363455           NaN                       NaT                  NaN
# 363513           NaN                       NaT                  NaN
# 363516           NaN                       NaT                  NaN
# 363533           NaN           2 days 19:34:15                  1.0
# 363609           NaN          19 days 21:20:13                  1.0
#
#        ibd_final_status time_consumed_callforins_day01  \
# 2586                NaN                            NaN
# 2872                NaN                            NaN
# 3028                NaN               14 days 18:03:35
# 3129                NaN                            NaN
# 5348                NaN                0 days 00:32:35
# ...                 ...                            ...
# 363455              NaN                            NaN
# 363513              NaN                            NaN
# 363516              NaN                            NaN
# 363533        completed                            NaN
# 363609        completed                            NaN
#
#         times_processed_callforins_day01 status_callforins_day01  \
# 2586                                 NaN                     NaN
# 2872                                 NaN                     NaN
# 3028                                 1.0               completed
# 3129                                 NaN                     NaN
# 5348                                 1.0               completed
# ...                                  ...                     ...
# 363455                               NaN                     NaN
# 363513                               NaN                     NaN
# 363516                               NaN                     NaN
# 363533                               NaN                     NaN
# 363609                               NaN                     NaN
#
#        time_consumed_callforins_day02  times_processed_callforins_day02  \
# 2586                              NaN                               NaN
# 2872                              NaN                               NaN
# 3028                  0 days 00:05:23                               1.0
# 3129                              NaN                               NaN
# 5348                              NaN                               NaN
# ...                               ...                               ...
# 363455                            NaN                               NaN
# 363513                            NaN                               NaN
# 363516                            NaN                               NaN
# 363533                            NaN                               NaN
# 363609                            NaN                               NaN
#
#        status_callforins_day02 time_consumed_callforins_day03  \
# 2586                       NaN                            NaN
# 2872                       NaN                            NaN
# 3028                 completed                            NaN
# 3129                       NaN                            NaN
# 5348                       NaN                            NaN
# ...                        ...                            ...
# 363455                     NaN                            NaN
# 363513                     NaN                            NaN
# 363516                     NaN                            NaN
# 363533                     NaN                            NaN
# 363609                     NaN                            NaN
#
#         times_processed_callforins_day03 status_callforins_day03   city  \
# 2586                                 NaN                     NaN    NaN
# 2872                                 NaN                     NaN  MIAMI
# 3028                                 NaN                     NaN    NaN
# 3129                                 NaN                     NaN    NaN
# 5348                                 NaN                     NaN    NaN
# ...                                  ...                     ...    ...
# 363455                               NaN                     NaN    NaN
# 363513                               NaN                     NaN    NaN
# 363516                               NaN                     NaN    NaN
# 363533                               NaN                     NaN    NaN
# 363609                               NaN                     NaN    NaN
#
#        track_rx_filled                                 DRUGNAME  QTY  \
# 2586               NaT                                      NaN  NaN
# 2872        2021-10-19  JUBLIA 10% SOL (00187-5400-04) -8134902  4.0
# 3028               NaT                                      NaN  NaN
# 3129               NaT                                      NaN  NaN
# 5348               NaT                                      NaN  NaN
# ...                ...                                      ...  ...
# 363455             NaT                                      NaN  NaN
# 363513             NaT                                      NaN  NaN
# 363516             NaT                                      NaN  NaN
# 363533             NaT                                      NaN  NaN
# 363609             NaT                                      NaN  NaN
#
#        PATIENTCOPAY  TOTALINSPAID   PATZIP      PATDOB INSCODE       DATEO  \
# 2586            NaN           NaN      NaN         NaN     NaN         NaN
# 2872           65.0        570.33  33134.0  07-13-1957   FLB68  2021-10-14
# 3028            NaN           NaN      NaN         NaN     NaN         NaN
# 3129            NaN           NaN      NaN         NaN     NaN         NaN
# 5348            NaN           NaN      NaN         NaN     NaN         NaN
# ...             ...           ...      ...         ...     ...         ...
# 363455          NaN           NaN      NaN         NaN     NaN         NaN
# 363513          NaN           NaN      NaN         NaN     NaN         NaN
# 363516          NaN           NaN      NaN         NaN     NaN         NaN
# 363533          NaN           NaN      NaN         NaN     NaN         NaN
# 363609          NaN           NaN      NaN         NaN     NaN         NaN
#
#        PATFNAME PATLNAME PATMOBILENO    PATPHONE patsex  TOTALRXAMOUNT  \
# 2586        NaN      NaN         NaN         NaN    NaN            NaN
# 2872     SILVIA    VIDAL              3057854186      F         635.33
# 3028        NaN      NaN         NaN         NaN    NaN            NaN
# 3129        NaN      NaN         NaN         NaN    NaN            NaN
# 5348        NaN      NaN         NaN         NaN    NaN            NaN
# ...         ...      ...         ...         ...    ...            ...
# 363455      NaN      NaN         NaN         NaN    NaN            NaN
# 363513      NaN      NaN         NaN         NaN    NaN            NaN
# 363516      NaN      NaN         NaN         NaN    NaN            NaN
# 363533      NaN      NaN         NaN         NaN    NaN            NaN
# 363609      NaN      NaN         NaN         NaN    NaN            NaN
#
#         patientno_mms workflow_last_status workflow_last_change_datetime  \
# 2586              NaN                  NaN                           NaT
# 2872          22472.0  PICKED UP/DELIVERED           2021-10-25 15:23:26
# 3028              NaN                  NaN                           NaT
# 3129              NaN                  NaN                           NaT
# 5348              NaN                  NaN                           NaT
# ...               ...                  ...                           ...
# 363455            NaN                  NaN                           NaT
# 363513            NaN                  NaN                           NaT
# 363516            NaN                  NaN                           NaT
# 363533            NaN                  NaN                           NaT
# 363609            NaN                  NaN                           NaT
#
#        cxrev_last_datetime  times_cx_reversed delrev_last_datetime  \
# 2586                   NaT                NaN                  NaT
# 2872                   NaT                NaN                  NaT
# 3028                   NaT                NaN                  NaT
# 3129                   NaT                NaN                  NaT
# 5348                   NaT                NaN                  NaT
# ...                    ...                ...                  ...
# 363455                 NaT                NaN                  NaT
# 363513                 NaT                NaN                  NaT
# 363516                 NaT                NaN                  NaT
# 363533                 NaT                NaN                  NaT
# 363609                 NaT                NaN                  NaT
#
#        times_del_reversed       batchno       batchcreatedon batchclosedon  \
# 2586                  NaN           NaN                  NaN           NaN
# 2872                  NaN  BN2110210006  2021-10-21 13:31:00           NaN
# 3028                  NaN           NaN                  NaN           NaN
# 3129                  NaN           NaN                  NaN           NaN
# 5348                  NaN           NaN                  NaN           NaN
# ...                   ...           ...                  ...           ...
# 363455                NaN           NaN                  NaN           NaN
# 363513                NaN           NaN                  NaN           NaN
# 363516                NaN           NaN                  NaN           NaN
# 363533                NaN           NaN                  NaN           NaN
# 363609                NaN           NaN                  NaN           NaN
#
#        deliverydate      driver          phone patient_phone_x  \
# 2586            NaN         NaN            NaN             NaN
# 2872            NaN  JCU         (305)785-4186      3057854186
# 3028            NaN         NaN            NaN             NaN
# 3129            NaN         NaN            NaN             NaN
# 5348            NaN         NaN            NaN             NaN
# ...             ...         ...            ...             ...
# 363455          NaN         NaN            NaN             NaN
# 363513          NaN         NaN            NaN             NaN
# 363516          NaN         NaN            NaN             NaN
# 363533          NaN         NaN            NaN             NaN
# 363609          NaN         NaN            NaN             NaN
#
#        batch_delivery_date batch_delivery_datetime batch_creation_datetime  \
# 2586                   NaN                     NaN                     NaT
# 2872            2021-10-21     2021-10-21 13:31:00     2021-10-21 13:31:00
# 3028                   NaN                     NaN                     NaT
# 3129                   NaN                     NaN                     NaT
# 5348                   NaN                     NaN                     NaT
# ...                    ...                     ...                     ...
# 363455                 NaN                     NaN                     NaT
# 363513                 NaN                     NaN                     NaT
# 363516                 NaN                     NaN                     NaT
# 363533                 NaN                     NaN                     NaT
# 363609                 NaN                     NaN                     NaT
#
#             batch_id  no_times_batch_created delivery_date shortId_of status  \
# 2586             NaN                     NaN           NaT        NaN    NaN
# 2872    BN2110210006                     1.0           NaT        NaN    NaN
# 3028             NaN                     NaN           NaT        NaN    NaN
# 3129             NaN                     NaN           NaT        NaN    NaN
# 5348             NaN                     NaN           NaT        NaN    NaN
# ...              ...                     ...           ...        ...    ...
# 363455           NaN                     NaN           NaT        NaN    NaN
# 363513           NaN                     NaN           NaT        NaN    NaN
# 363516           NaN                     NaN           NaT        NaN    NaN
# 363533           NaN                     NaN           NaT        NaN    NaN
# 363609           NaN                     NaN           NaT        NaN    NaN
#
#         patient_phone_y  patient_zipcode delivery_time  Driver Number  \
# 2586                NaN              NaN           NaN            NaN
# 2872                NaN              NaN           NaN            NaN
# 3028                NaN              NaN           NaN            NaN
# 3129                NaN              NaN           NaN            NaN
# 5348                NaN              NaN           NaN            NaN
# ...                 ...              ...           ...            ...
# 363455              NaN              NaN           NaN            NaN
# 363513              NaN              NaN           NaN            NaN
# 363516              NaN              NaN           NaN            NaN
# 363533              NaN              NaN           NaN            NaN
# 363609              NaN              NaN           NaN            NaN
#
#        didSucceed match_method rx_no_fill zone_name  \
# 2586          NaN          NaN        NaN       NaN
# 2872          NaN          NaN        NaN       NaN
# 3028          NaN          NaN        NaN       NaN
# 3129          NaN          NaN        NaN       NaN
# 5348          NaN          NaN        NaN       NaN
# ...           ...          ...        ...       ...
# 363455        NaN          NaN        NaN       NaN
# 363513        NaN          NaN        NaN       NaN
# 363516        NaN          NaN        NaN       NaN
# 363533        NaN          NaN        NaN       NaN
# 363609        NaN          NaN        NaN       NaN
#
#         delivery_patient_zip_code dl_app_delivery_created_time  \
# 2586                          NaN                          NaN
# 2872                          NaN                          NaN
# 3028                          NaN                          NaN
# 3129                          NaN                          NaN
# 5348                          NaN                          NaN
# ...                           ...                          ...
# 363455                        NaN                          NaN
# 363513                        NaN                          NaN
# 363516                        NaN                          NaN
# 363533                        NaN                          NaN
# 363609                        NaN                          NaN
#
#        dl_app_delivery_time onfleet_short_id  delivery_id driver_name  \
# 2586                    NaN              NaN          NaN         NaN
# 2872                    NaN              NaN          NaN         NaN
# 3028                    NaN              NaN          NaN         NaN
# 3129                    NaN              NaN          NaN         NaN
# 5348                    NaN              NaN          NaN         NaN
# ...                     ...              ...          ...         ...
# 363455                  NaN              NaN          NaN         NaN
# 363513                  NaN              NaN          NaN         NaN
# 363516                  NaN              NaN          NaN         NaN
# 363533                  NaN              NaN          NaN         NaN
# 363609                  NaN              NaN          NaN         NaN
#
#        onfleet_state pharmacy_location_dl  pharmacy_nabp rx_no_fill_px  \
# 2586             NaN                  NaN            NaN           NaN
# 2872             NaN                  NaN            NaN           NaN
# 3028             NaN                  NaN            NaN           NaN
# 3129             NaN                  NaN            NaN           NaN
# 5348             NaN                  NaN            NaN           NaN
# ...              ...                  ...            ...           ...
# 363455           NaN                  NaN            NaN           NaN
# 363513           NaN                  NaN            NaN           NaN
# 363516           NaN                  NaN            NaN           NaN
# 363533           NaN                  NaN            NaN           NaN
# 363609           NaN                  NaN            NaN           NaN
#
#        task_completed slot_start slot_end pharmacy_location_px refill_tag  \
# 2586              NaN        NaN      NaN                  NaN        New
# 2872              NaN        NaN      NaN                  NaN        New
# 3028              NaN        NaN      NaN                  NaN        New
# 3129              NaN        NaN      NaN                  NaN        New
# 5348              NaN        NaN      NaN                  NaN        New
# ...               ...        ...      ...                  ...        ...
# 363455            NaN        NaN      NaN                  NaN        New
# 363513            NaN        NaN      NaN                  NaN        New
# 363516            NaN        NaN      NaN                  NaN        New
# 363533            NaN        NaN      NaN                  NaN        New
# 363609            NaN        NaN      NaN                  NaN        New
#
#         new_delivered_date  PATPHONE_len  PATMOBILENO_len shortId_mms  \
# 2586                   NaT             3                3         NaN
# 2872   2021-10-22 12:42:57            10               10         NaN
# 3028                   NaT             3                3         NaN
# 3129                   NaT             3                3         NaN
# 5348                   NaT             3                3         NaN
# ...                    ...           ...              ...         ...
# 363455                 NaT             3                3         NaN
# 363513                 NaT             3                3         NaN
# 363516                 NaT             3                3         NaN
# 363533                 NaT             3                3         NaN
# 363609                 NaT             3                3         NaN
#
#        new_shortId status_tag   id  rx_number rx_status patient_id  \
# 2586           NaN        NaN  NaN        NaN       NaN        NaN
# 2872           NaN  Delivered  NaN        NaN       NaN        NaN
# 3028           NaN        NaN  NaN        NaN       NaN        NaN
# 3129           NaN        NaN  NaN        NaN       NaN        NaN
# 5348           NaN        NaN  NaN        NaN       NaN        NaN
# ...            ...        ...  ...        ...       ...        ...
# 363455         NaN        NaN  NaN        NaN       NaN        NaN
# 363513         NaN        NaN  NaN        NaN       NaN        NaN
# 363516         NaN        NaN  NaN        NaN       NaN        NaN
# 363533         NaN        NaN  NaN        NaN       NaN        NaN
# 363609         NaN        NaN  NaN        NaN       NaN        NaN
#
#        prescriber_id insurance_id drug_name drug_form followup_tag  copay  \
# 2586             NaN          NaN       NaN       NaN          NaN    NaN
# 2872             NaN          NaN       NaN       NaN          NaN    NaN
# 3028             NaN          NaN       NaN       NaN          NaN    NaN
# 3129             NaN          NaN       NaN       NaN          NaN    NaN
# 5348             NaN          NaN       NaN       NaN          NaN    NaN
# ...              ...          ...       ...       ...          ...    ...
# 363455           NaN          NaN       NaN       NaN          NaN    NaN
# 363513           NaN          NaN       NaN       NaN          NaN    NaN
# 363516           NaN          NaN       NaN       NaN          NaN    NaN
# 363533           NaN          NaN       NaN       NaN          NaN    NaN
# 363609           NaN          NaN       NaN       NaN          NaN    NaN
#
#         amount ndc_prsc  quantity  fill_number reversed reversal_reason  \
# 2586       NaN      NaN       NaN          NaN      NaN             NaN
# 2872       NaN      NaN       NaN          NaN      NaN             NaN
# 3028       NaN      NaN       NaN          NaN      NaN             NaN
# 3129       NaN      NaN       NaN          NaN      NaN             NaN
# 5348       NaN      NaN       NaN          NaN      NaN             NaN
# ...        ...      ...       ...          ...      ...             ...
# 363455     NaN      NaN       NaN          NaN      NaN             NaN
# 363513     NaN      NaN       NaN          NaN      NaN             NaN
# 363516     NaN      NaN       NaN          NaN      NaN             NaN
# 363533     NaN      NaN       NaN          NaN      NaN             NaN
# 363609     NaN      NaN       NaN          NaN      NaN             NaN
#
#        reversal_fill_date  day_supply status_prsc created_at id_task  \
# 2586                  NaN         NaN         NaN        NaN     NaN
# 2872                  NaN         NaN         NaN        NaN     NaN
# 3028                  NaN         NaN         NaN        NaN     NaN
# 3129                  NaN         NaN         NaN        NaN     NaN
# 5348                  NaN         NaN         NaN        NaN     NaN
# ...                   ...         ...         ...        ...     ...
# 363455                NaN         NaN         NaN        NaN     NaN
# 363513                NaN         NaN         NaN        NaN     NaN
# 363516                NaN         NaN         NaN        NaN     NaN
# 363533                NaN         NaN         NaN        NaN     NaN
# 363609                NaN         NaN         NaN        NaN     NaN
#
#        status_id associate_id_prsc is_scheduled  scheduled_time error_status  \
# 2586         NaN               NaN          NaN             NaN          NaN
# 2872         NaN               NaN          NaN             NaN          NaN
# 3028         NaN               NaN          NaN             NaN          NaN
# 3129         NaN               NaN          NaN             NaN          NaN
# 5348         NaN               NaN          NaN             NaN          NaN
# ...          ...               ...          ...             ...          ...
# 363455       NaN               NaN          NaN             NaN          NaN
# 363513       NaN               NaN          NaN             NaN          NaN
# 363516       NaN               NaN          NaN             NaN          NaN
# 363533       NaN               NaN          NaN             NaN          NaN
# 363609       NaN               NaN          NaN             NaN          NaN
#
#        claimed_at created_at_task is_all_reversal_rxs completed_at  \
# 2586          NaN             NaN                 NaN          NaN
# 2872          NaN             NaN                 NaN          NaN
# 3028          NaN             NaN                 NaN          NaN
# 3129          NaN             NaN                 NaN          NaN
# 5348          NaN             NaN                 NaN          NaN
# ...           ...             ...                 ...          ...
# 363455        NaN             NaN                 NaN          NaN
# 363513        NaN             NaN                 NaN          NaN
# 363516        NaN             NaN                 NaN          NaN
# 363533        NaN             NaN                 NaN          NaN
# 363609        NaN             NaN                 NaN          NaN
#
#        cancelled_at cancellation_reason  pharmacy_nabp_prsc  \
# 2586            NaN                 NaN                 NaN
# 2872            NaN                 NaN                 NaN
# 3028            NaN                 NaN                 NaN
# 3129            NaN                 NaN                 NaN
# 5348            NaN                 NaN                 NaN
# ...             ...                 ...                 ...
# 363455          NaN                 NaN                 NaN
# 363513          NaN                 NaN                 NaN
# 363516          NaN                 NaN                 NaN
# 363533          NaN                 NaN                 NaN
# 363609          NaN                 NaN                 NaN
#
#        earliest_fill_date  rx_numbers_count rx_numbers_list  total_awp  \
# 2586                  NaN               NaN             NaN        NaN
# 2872                  NaN               NaN             NaN        NaN
# 3028                  NaN               NaN             NaN        NaN
# 3129                  NaN               NaN             NaN        NaN
# 5348                  NaN               NaN             NaN        NaN
# ...                   ...               ...             ...        ...
# 363455                NaN               NaN             NaN        NaN
# 363513                NaN               NaN             NaN        NaN
# 363516                NaN               NaN             NaN        NaN
# 363533                NaN               NaN             NaN        NaN
# 363609                NaN               NaN             NaN        NaN
#
#         days_contacted latest_contacted_at insurance_category  parent_id  \
# 2586               NaN                 NaN                NaN        NaN
# 2872               NaN                 NaN                NaN        NaN
# 3028               NaN                 NaN                NaN        NaN
# 3129               NaN                 NaN                NaN        NaN
# 5348               NaN                 NaN                NaN        NaN
# ...                ...                 ...                ...        ...
# 363455             NaN                 NaN                NaN        NaN
# 363513             NaN                 NaN                NaN        NaN
# 363516             NaN                 NaN                NaN        NaN
# 363533             NaN                 NaN                NaN        NaN
# 363609             NaN                 NaN                NaN        NaN
#
#        pharmacy_location_prsc id_cv contacted_at outcome created_at_cv id_sd  \
# 2586                      NaN   NaN          NaN     NaN           NaN   NaN
# 2872                      NaN   NaN          NaN     NaN           NaN   NaN
# 3028                      NaN   NaN          NaN     NaN           NaN   NaN
# 3129                      NaN   NaN          NaN     NaN           NaN   NaN
# 5348                      NaN   NaN          NaN     NaN           NaN   NaN
# ...                       ...   ...          ...     ...           ...   ...
# 363455                    NaN   NaN          NaN     NaN           NaN   NaN
# 363513                    NaN   NaN          NaN     NaN           NaN   NaN
# 363516                    NaN   NaN          NaN     NaN           NaN   NaN
# 363533                    NaN   NaN          NaN     NaN           NaN   NaN
# 363609                    NaN   NaN          NaN     NaN           NaN   NaN
#
#        payload status_sd created_at_sd delivery_type  \
# 2586       NaN       NaN           NaN           NaN
# 2872       NaN       NaN           NaN           NaN
# 3028       NaN       NaN           NaN           NaN
# 3129       NaN       NaN           NaN           NaN
# 5348       NaN       NaN           NaN           NaN
# ...        ...       ...           ...           ...
# 363455     NaN       NaN           NaN           NaN
# 363513     NaN       NaN           NaN           NaN
# 363516     NaN       NaN           NaN           NaN
# 363533     NaN       NaN           NaN           NaN
# 363609     NaN       NaN           NaN           NaN
#
#        pickup_date_scheduled_deliveries  \
# 2586                                NaN
# 2872                                NaN
# 3028                                NaN
# 3129                                NaN
# 5348                                NaN
# ...                                 ...
# 363455                              NaN
# 363513                              NaN
# 363516                              NaN
# 363533                              NaN
# 363609                              NaN
#
#        scheduled_startdate_scheduled_deliveries  \
# 2586                                        NaN
# 2872                                        NaN
# 3028                                        NaN
# 3129                                        NaN
# 5348                                        NaN
# ...                                         ...
# 363455                                      NaN
# 363513                                      NaN
# 363516                                      NaN
# 363533                                      NaN
# 363609                                      NaN
#
#        scheduled_enddate_scheduled_deliveries  \
# 2586                                      NaN
# 2872                                      NaN
# 3028                                      NaN
# 3129                                      NaN
# 5348                                      NaN
# ...                                       ...
# 363455                                    NaN
# 363513                                    NaN
# 363516                                    NaN
# 363533                                    NaN
# 363609                                    NaN
#
#         erxreceived_rxtimelines_boolean_d  \
# 2586                                 True
# 2872                                 True
# 3028                                False
# 3129                                 True
# 5348                                 True
# ...                                   ...
# 363455                              False
# 363513                               True
# 363516                               True
# 363533                              False
# 363609                              False
#
#         rx_entered_date_rxtimelines_boolean_d  \
# 2586                                     True
# 2872                                     True
# 3028                                     True
# 3129                                     True
# 5348                                     True
# ...                                       ...
# 363455                                   True
# 363513                                   True
# 363516                                   True
# 363533                                   True
# 363609                                   True
#
#         rx_entered_date_verification_boolean_d  \
# 2586                                      True
# 2872                                      True
# ...
# 2872                                   False
# 3028                                    True
# 3129                                   False
# 5348                                   False
# ...                                      ...
# 363455                                 False
# 363513                                 False
# 363516                                 False
# 363533                                 False
# 363609                                 False
#
#         times_processed_callforins_day03_new    final_rx_entered  \
# 2586                                   False 2021-10-12 00:00:00
# 2872                                   False 2021-10-15 11:23:00
# 3028                                   False 2021-11-11 00:00:00
# 3129                                   False 2021-12-20 00:00:00
# 5348                                   False 2021-12-02 11:58:00
# ...                                      ...                 ...
# 363455                                 False 2021-11-02 17:18:00
# 363513                                 False 2021-11-08 00:00:00
# 363516                                 False 2021-11-08 00:00:00
# 363533                                 False 2021-10-01 19:00:00
# 363609                                 False 2021-10-06 16:30:00
#
#                rx_delta rx_delta_day rx_delta_days_str  rx_delta_time2  \
# 2586    0 days 20:20:44       0 days              days 0 days 20:20:44
# 2872    2 days 17:07:30       2 days              days 0 days 17:07:30
# 3028    0 days 16:04:03       0 days              days 0 days 16:04:03
# 3129    0 days 02:24:51       0 days              days 0 days 02:24:51
# 5348    0 days 00:45:02       0 days              days 0 days 00:45:02
# ...                 ...          ...               ...             ...
# 363455  0 days 21:51:26       0 days              days 0 days 21:51:26
# 363513  5 days 21:53:42       5 days              days 0 days 21:53:42
# 363516  0 days 18:18:59       0 days              days 0 days 18:18:59
# 363533  6 days 02:29:15       6 days              days 0 days 02:29:15
# 363609 23 days 01:21:37      23 days              days 0 days 01:21:37
#
#        ibd_processing_end_rx_final received_to_entered_time  \
# 2586           2021-10-13 12:56:16        -1 days +14:50:00
# 2872           2021-10-18 10:43:59          0 days 20:17:00
# 3028           2022-01-04 08:43:16                       NA
# 3129           2021-12-20 16:06:00        -1 days +10:49:00
# 5348           2021-12-02 13:16:43          0 days 00:10:00
# ...                            ...                      ...
# 363455         2021-11-04 11:53:31                       NA
# 363513         2021-11-14 15:17:04        -1 days +12:46:00
# 363516         2021-11-09 11:42:29        -1 days +12:46:00
# 363533         2021-10-10 14:15:28                       NA
# 363609         2021-11-03 13:53:56                       NA
#
#        entered_to_first_billed first_billed_to_last_billed  \
# 2586                       NaT                         NaT
# 2872           4 days 05:17:39             0 days 00:00:00
# 3028                       NaT                         NaT
# 3129                       NaT                         NaT
# 5348           0 days 00:24:04             0 days 00:00:21
# ...                        ...                         ...
# 363455                     NaT                         NaT
# 363513        42 days 09:46:07             0 days 00:00:00
# 363516                     NaT                         NaT
# 363533                     NaT                         NaT
# 363609                     NaT                         NaT
#
#        entered_to_last_billed entered_to_label_printed  \
# 2586                      NaT                      NaT
# 2872          4 days 05:17:39          5 days 01:31:31
# 3028                      NaT                      NaT
# 3129                      NaT                      NaT
# 5348          0 days 00:24:25                      NaT
# ...                       ...                      ...
# 363455                    NaT          0 days 20:44:25
# 363513       42 days 09:46:07                      NaT
# 363516                    NaT                      NaT
# 363533                    NaT          2 days 16:48:55
# 363609                    NaT          4 days 20:03:35
#
#        last_billed_to_label_printed label_printed_to_drug_picked  \
# 2586                            NaT                          NaT
# 2872                0 days 20:13:52            -1 days +03:50:29
# 3028                            NaT                          NaT
# 3129                            NaT                          NaT
# 5348                            NaT                          NaT
# ...                             ...                          ...
# 363455                          NaT                          NaT
# 363513                          NaT                          NaT
# 363516                          NaT                          NaT
# 363533                          NaT                          NaT
# 363609                          NaT                          NaT
#
#        drug_picked_to_rph_verified rph_verified_to_pharmacy_pickedup  \
# 2586                           NaT                                NA
# 2872               0 days 00:27:57                                NA
# 3028                           NaT                                NA
# 3129                           NaT                                NA
# 5348                           NaT                                NA
# ...                            ...                               ...
# 363455                         NaT                                NA
# 363513                         NaT                                NA
# 363516                         NaT                                NA
# 363533                         NaT                                NA
# 363609                         NaT                                NA
#
#        rph_verified_to_batch_creation batch_creation_to_delivered  \
# 2586                               NA                          NA
# 2872                  1 days 20:18:03             0 days 23:11:57
# 3028                               NA                          NA
# 3129                               NA                          NA
# 5348                               NA                          NA
# ...                               ...                         ...
# 363455                             NA                          NA
# 363513                             NA                          NA
# 363516                             NA                          NA
# 363533                             NA                          NA
# 363609                             NA                          NA
#
#        rph_verified_to_delivered ibd_processing_start_to_end  \
# 2586                          NA                         NaT
# 2872             2 days 19:30:00                         NaT
# 3028                          NA                         NaT
# 3129                          NA                         NaT
# 5348                          NA                         NaT
# ...                          ...                         ...
# 363455                        NA                         NaT
# 363513                        NA                         NaT
# 363516                        NA                         NaT
# 363533                        NA          -10 days +00:55:11
# 363609                        NA          -22 days +03:27:42
#
#        time_to_identify_pa_is_required waiting_time_for_ibd_processing  \
# 2586                   0 days 16:35:32                             NaT
# 2872                   0 days 06:13:29                             NaT
# 3028                  53 days 16:39:13                             NaT
# 3129                   0 days 13:41:09                             NaT
# 5348                   0 days 00:33:41                             NaT
# ...                                ...                             ...
# 363455                 0 days 20:44:05                             NaT
# 363513                 0 days 17:23:22                             NaT
# 363516                 0 days 17:23:30                             NaT
# 363533                 2 days 16:46:13                 9 days 23:04:49
# 363609                 4 days 20:02:19                21 days 20:32:18
#
#        ibd_processing_end_to_label_printed  \
# 2586                                   NaT
# 2872                                   NaT
# 3028                                   NaT
# 3129                                   NaT
# 5348                                   NaT
# ...                                    ...
# 363455                                 NaT
# 363513                                 NaT
# 363516                                 NaT
# 363533                  -10 days +00:57:53
# 363609                  -22 days +03:28:58
#
#        rx_entered_to_callins_processing_start  \
# 2586                                      NaT
# 2872                                      NaT
# 3028                         34 days 18:24:08
# 3129                                      NaT
# 5348                          0 days 00:01:06
# ...                                       ...
# 363455                                    NaT
# 363513                                    NaT
# 363516                                    NaT
# 363533                                    NaT
# 363609                                    NaT
#
#        ibd_processing_end_to_first_billed rph_verified_to_delivery_pickedup  \
# 2586                                  NaT                                NA
# 2872                      1 days 05:56:40                   2 days 06:47:03
# 3028                                  NaT                                NA
# 3129                                  NaT                                NA
# 5348                    -1 days +23:05:21                                NA
# ...                                   ...                               ...
# 363455                                NaT                                NA
# 363513                   35 days 18:29:03                                NA
# 363516                                NaT                                NA
# 363533                                NaT                                NA
# 363609                                NaT                                NA
#
#        delivery_pickedup_to_delivered      final_received  \
# 2586                               NA 2021-10-12 09:10:00
# 2872                  0 days 12:42:57 2021-10-14 15:06:00
# 3028                               NA 2021-11-11 00:00:00
# 3129                               NA 2021-12-20 13:11:00
# 5348                               NA 2021-12-02 11:48:00
# ...                               ...                 ...
# 363455                             NA 2021-11-02 17:18:00
# 363513                             NA 2021-11-08 11:14:00
# 363516                             NA 2021-11-08 11:14:00
# 363533                             NA 2021-10-01 19:00:00
# 363609                             NA 2021-10-06 16:30:00
#
#        final_received_to_delivered received_to_rph_verified  \
# 2586                           NaT                      NaT
# 2872               7 days 21:36:57          5 days 02:06:57
# 3028                           NaT                      NaT
# 3129                           NaT                      NaT
# 5348                           NaT                      NaT
# ...                            ...                      ...
# 363455                         NaT                      NaT
# 363513                         NaT                      NaT
# 363516                         NaT                      NaT
# 363533                         NaT                      NaT
# 363609                         NaT                      NaT
#
#        time_taken_by_rx_to_be_picked_up_by_IBD_team  \
# 2586                                            NaT
# 2872                                            NaT
# 3028                                            NaT
# 3129                                            NaT
# 5348                                            NaT
# ...                                             ...
# 363455                                          NaT
# 363513                                          NaT
# 363516                                          NaT
# 363533                                          NaT
# 363609                                          NaT
#
#        time_taken_by_IBD_team_to_process_rx               c1              c2  \
# 2586                                    NaT              NaT             NaT
# 2872                                    NaT              NaT             NaT
# 3028                                    NaT 14 days 18:03:35 0 days 00:05:23
# 3129                                    NaT              NaT             NaT
# 5348                                    NaT  0 days 00:32:35             NaT
# ...                                     ...              ...             ...
# 363455                                  NaT              NaT             NaT
# 363513                                  NaT              NaT             NaT
# 363516                                  NaT              NaT             NaT
# 363533                      2 days 19:34:15              NaT             NaT
# 363609                     19 days 21:20:13              NaT             NaT
#
#         c3       total_call time_taken_for_call_for_insurance_process  \
# 2586   NaT  0 days 00:00:00                           0 days 00:00:00
# 2872   NaT  0 days 00:00:00                           0 days 00:00:00
# 3028   NaT 14 days 18:08:58                          14 days 18:08:58
# 3129   NaT  0 days 00:00:00                           0 days 00:00:00
# 5348   NaT  0 days 00:32:35                           0 days 00:32:35
# ...     ..              ...                                       ...
# 363455 NaT  0 days 00:00:00                           0 days 00:00:00
# 363513 NaT  0 days 00:00:00                           0 days 00:00:00
# 363516 NaT  0 days 00:00:00                           0 days 00:00:00
# 363533 NaT  0 days 00:00:00                           0 days 00:00:00
# 363609 NaT  0 days 00:00:00                           0 days 00:00:00
#
#         total_call_2  is_call  total_processing_time_ibd_new  \
# 2586             0.0    False                          False
# 2872             0.0    False                          False
# 3028       1274938.0     True                          False
# 3129             0.0    False                          False
# 5348          1955.0     True                          False
# ...              ...      ...                            ...
# 363455           0.0    False                          False
# 363513           0.0    False                          False
# 363516           0.0    False                          False
# 363533           0.0    False                           True
# 363609           0.0    False                           True
#
#        trackrx_last_status_new  rx_revenue
# 2586                        NB         NaN
# 2872                         B      635.33
# 3028                        NB         NaN
# 3129                        NB         NaN
# 5348                        NB         NaN
# ...                        ...         ...
# 363455                      NB         NaN
# 363513                      NB         NaN
# 363516                      NB         NaN
# 363533                      NB         NaN
# 363609                      NB         NaN
#
# [1217 rows x 278 columns]

# %%
Rx_with_IBD_value_less_2k_denied_count_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_denied, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_denied_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_Denied'}, inplace = True)
Rx_with_IBD_value_less_2k_denied_count_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied
# 0        FL-MI                   96
# 1        MD-BA                  584
# 2        NC-RA                    6
# 3        NJ-SO                   64
# 4        NY-BK                  132
# 5        NY-MA                  120
# 6        PA-PH                  215

# %%
Rx_with_IBD_value_less_2k_denied_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_denied, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_denied_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_Denied'}, inplace = True)
Rx_with_IBD_value_less_2k_denied_revenue_pivot
# Out:
#   pharmacy_loc  rx_revenue_IBD_Denied
# 0        FL-MI               12487.93
# 1        MD-BA                4129.53
# 2        NC-RA                   0.00
# 3        NJ-SO                3508.00
# 4        NY-BK               11812.43
# 5        NY-MA                   0.00
# 6        PA-PH               33362.24

# %%
Rx_with_IBD_value_less_2k_denied_pivot = pd.merge(Rx_with_IBD_value_less_2k_denied_count_pivot, Rx_with_IBD_value_less_2k_denied_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_less_2k_denied_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied  rx_revenue_IBD_Denied
# 0        FL-MI                   96               12487.93
# 1        MD-BA                  584                4129.53
# 2        NC-RA                    6                   0.00
# 3        NJ-SO                   64                3508.00
# 4        NY-BK                  132               11812.43
# 5        NY-MA                  120                   0.00
# 6        PA-PH                  215               33362.24

# %%
Rx_with_IBD_value_less_2k_denied_pivot.append(Rx_with_IBD_value_less_2k_denied_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %%
### Rx_with_IBD_value_greater_2k_denied

# %%
Rx_with_IBD_value_greater_2k_denied = Rx_with_IBD_value_greater_2k[Rx_with_IBD_value_greater_2k['trackrx_last_ibdtag'].isin(ibd_not_possible_list)]

#Rx_with_IBD_value_greater_2k_IBD_df['IBD_status'] = Rx_with_IBD_value_greater_2k_IBD_df

# %%
Rx_with_IBD_value_greater_2k_denied
# Out:
#         Unnamed: 0 pharmacy_location       rxno       presnpi          ndc  \
# 7260          7260             MD-BA   208893-0    1619210598  00024591502
# 12432        12432             NJ-SO  1162638-0  1417203928.0  55513013760
# 13217        13217             NY-BK  1143607-0  1477711422.0  00024591502
# 14975        14975             MD-BA   209365-0  1669929451.0  70539000102
# 16826        16826             MD-BA   209158-0  1528254232.0  65649030302
# ...            ...               ...        ...           ...          ...
# 352963      352963             MD-BA   204141-0  1871905810.0  67877062690
# 354010      354010             MD-BA   203569-0  1205896727.0  72626260101
# 356966      356966             MD-BA   199045-0  1205447448.0  75987002201
# 358627      358627             MD-BA   210097-0  1164663605.0  00024591502
# 359629      359629             MD-BA   203658-0  1508319120.0  00024591401
#
#        trackrx_status  patientno  track_erx_received    track_rx_entered  \
# 7260                F      15396 2021-09-30 10:38:00 2021-09-30 11:12:00
# 12432               F      66496                 NaT 2021-05-21 12:17:00
# 13217               F     618509 2021-10-29 11:12:00 2021-10-29 11:17:00
# 14975               F      15603                 NaT 2021-10-11 11:04:00
# 16826               F      15513 2021-10-05 16:36:00 2021-10-05 16:41:00
# ...               ...        ...                 ...                 ...
# 352963              F      13128                 NaT 2021-07-02 11:52:00
# 354010              F      12890                 NaT 2021-06-24 12:31:00
# 356966              F      10713                 NaT 2021-04-07 14:04:00
# 358627              F      15903 2021-10-26 09:36:00 2021-10-26 10:05:00
# 359629              F      12939 2021-06-24 16:52:00 2021-06-24 18:21:00
#
#        rx_entered_date_verification      filled_datekey final_rx_pickedup  \
# 7260            2021-09-30 11:12:00 2021-10-19 11:11:48               NaT
# 12432           2021-05-21 12:17:00 2021-12-29 00:00:00               NaT
# 13217           2021-10-29 11:17:00 2021-12-06 11:16:40               NaT
# 14975           2021-10-11 11:04:00 2021-11-19 11:03:39               NaT
# 16826           2021-10-05 16:41:00 2021-10-22 16:40:36               NaT
# ...                             ...                 ...               ...
# 352963          2021-07-02 11:52:00 2021-10-16 11:52:08               NaT
# 354010          2021-06-24 12:31:00 2021-09-23 00:00:00               NaT
# 356966          2021-04-07 14:04:00 2021-07-22 14:03:52               NaT
# 358627   2021-10-26 10:05:00.000000 2021-12-06 10:05:23               NaT
# 359629          2021-06-24 18:21:00 2021-12-21 20:43:37               NaT
#
#        rx_delivered_date track_label_printed final_rx_drug_picks  \
# 7260                 NaN                 NaT                 NaT
# 12432                NaN                 NaT                 NaT
# 13217                NaN                 NaT                 NaT
# 14975                NaN                 NaT                 NaT
# 16826                NaN                 NaT                 NaT
# ...                  ...                 ...                 ...
# 352963               NaN                 NaT                 NaT
# 354010               NaN                 NaT                 NaT
# 356966               NaN                 NaT                 NaT
# 358627               NaN                 NaT                 NaT
# 359629               NaN                 NaT                 NaT
#
#        final_rx_rph_picks                    last_run rx_code_key_location  \
# 7260                  NaT         2022-01-11 01:20:42       MD-BA-208893-0
# 12432                 NaT         2021-12-30 01:21:17      NJ-SO-1162638-0
# 13217                 NaT         2021-12-20 01:23:58      NY-BK-1143607-0
# 14975                 NaT         2021-11-20 01:20:21       MD-BA-209365-0
# 16826                 NaT         2021-10-23 01:20:49       MD-BA-209158-0
# ...                   ...                         ...                  ...
# 352963                NaT         2021-10-16 01:23:40       MD-BA-204141-0
# 354010                NaT         2021-09-29 01:29:16       MD-BA-203569-0
# 356966                NaT         2021-09-22 03:19:33       MD-BA-199045-0
# 358627                NaT  2021-12-07 01:20:19.000000       MD-BA-210097-0
# 359629                NaT         2021-12-22 01:24:48       MD-BA-203658-0
#
#              nabp first_billed_datetime end_billed_datetime  \
# 7260    2143674.0                   NaT                 NaT
# 12432   3135868.0                   NaT                 NaT
# 13217   3352779.0                   NaT                 NaT
# 14975   2143674.0                   NaT                 NaT
# 16826   2143674.0                   NaT                 NaT
# ...           ...                   ...                 ...
# 352963  2143674.0                   NaT                 NaT
# 354010  2143674.0                   NaT                 NaT
# 356966  2143674.0                   NaT                 NaT
# 358627  2143674.0                   NaT                 NaT
# 359629  2143674.0                   NaT                 NaT
#
#        trackrx_processing_date_starttime              processing_end  \
# 7260                 2021-09-30 11:13:24         2022-01-10 15:38:44
# 12432                2021-05-21 12:14:26         2021-12-29 15:12:35
# 13217                2021-10-29 11:18:48         2021-12-29 15:53:09
# 14975                2021-10-11 11:14:37         2021-11-19 16:33:57
# 16826                2021-10-05 16:41:14         2021-10-22 09:30:54
# ...                                  ...                         ...
# 352963               2021-07-02 11:52:17         2021-10-15 17:00:10
# 354010               2021-06-24 12:32:01         2021-09-23 16:36:57
# 356966               2021-04-07 14:04:14         2021-07-22 12:49:47
# 358627               2021-10-26 10:05:24  2021-12-06 11:12:31.000000
# 359629               2021-06-24 18:22:07         2021-12-21 10:43:53
#
#                     IBD IN PROCESS IBD FIDELIS  IBD REQUIRED  IBD $2K+  \
# 7260           2021-10-15 11:13:41         NaN           NaN       NaN
# 12432          2021-06-21 10:47:12         NaN           NaN       NaN
# 13217          2021-10-29 16:12:12         NaN           NaN       NaN
# 14975          2021-10-28 10:38:30         NaN           NaN       NaN
# 16826          2021-10-14 11:22:54         NaN           NaN       NaN
# ...                            ...         ...           ...       ...
# 352963                         NaN         NaN           NaN       NaN
# 354010         2021-07-15 15:59:04         NaN           NaN       NaN
# 356966                         NaN         NaN           NaN       NaN
# 358627  2021-10-27 18:20:36.000000         NaN           NaN       NaN
# 359629         2021-10-27 18:18:39         NaN           NaN       NaN
#
#         IBD IS $2K+  IBD 2K  IBD IS 2K              IBD SPECIALITY  \
# 7260            NaN     NaN        NaN         2021-10-04 16:07:39
# 12432           NaN     NaN        NaN         2021-05-21 12:17:37
# 13217           NaN     NaN        NaN         2021-10-29 12:04:54
# 14975           NaN     NaN        NaN         2021-10-12 09:22:36
# 16826           NaN     NaN        NaN         2021-10-14 11:17:59
# ...             ...     ...        ...                         ...
# 352963          NaN     NaN        NaN         2021-07-30 14:29:25
# 354010          NaN     NaN        NaN         2021-06-30 17:27:51
# 356966          NaN     NaN        NaN         2021-04-07 14:04:29
# 358627          NaN     NaN        NaN  2021-10-27 10:29:18.000000
# 359629          NaN     NaN        NaN         2021-10-25 15:57:01
#
#                                IBD          IBD REGULAR         TO BE BILLED  \
# 7260           2021-10-19 10:13:38  2021-10-04 16:00:19  2021-09-30 11:13:28
# 12432          2021-12-29 14:20:49                  NaN                  NaN
# 13217          2021-11-05 15:35:37                  NaN  2021-10-29 11:18:49
# 14975          2021-10-28 12:15:38                  NaN                  NaN
# 16826          2021-10-18 16:05:07                  NaN  2021-10-05 16:41:34
# ...                            ...                  ...                  ...
# 352963         2021-10-06 11:53:12                  NaN  2021-10-06 10:13:44
# 354010         2021-08-26 16:32:20                  NaN  2021-06-25 10:00:39
# 356966         2021-04-07 14:39:40                  NaN                  NaN
# 358627  2021-11-05 10:39:18.000000                  NaN                  NaN
# 359629         2021-11-12 15:31:50                  NaN                  NaN
#
#                CALL FOR INS CALL FOR INS (KOREAN/CH)   CALL FOR INS DAY 2  \
# 7260                    NaN                      NaN                  NaN
# 12432   2021-05-21 12:14:26                      NaN                  NaN
# 13217                   NaN                      NaN                  NaN
# 14975                   NaN                      NaN                  NaN
# 16826                   NaN                      NaN                  NaN
# ...                     ...                      ...                  ...
# 352963  2021-07-23 13:42:26                      NaN  2021-07-16 15:20:52
# 354010                  NaN                      NaN                  NaN
# 356966                  NaN                      NaN                  NaN
# 358627                  NaN                      NaN                  NaN
# 359629  2021-07-21 15:59:11                      NaN  2021-07-16 12:44:37
#
#          CALL FOR INS DAY 3 CALL FOR INS (KOREAN/CHINESE)  \
# 7260                    NaN                           NaN
# 12432                   NaN                           NaN
# 13217                   NaN                           NaN
# 14975                   NaN                           NaN
# 16826                   NaN                           NaN
# ...                     ...                           ...
# 352963  2021-07-23 13:42:26                           NaN
# 354010                  NaN                           NaN
# 356966                  NaN                           NaN
# 358627                  NaN                           NaN
# 359629  2021-07-21 15:59:11                           NaN
#
#        CAL FOR INS (KOREAN/CHINESE) is_pickedup  is_eRx trackrx_statusflow  \
# 7260                            NaN         NaN    True               U->F
# 12432                           NaN         NaN   False               U->F
# 13217                           NaN         NaN    True               U->F
# 14975                           NaN         NaN   False               U->F
# 16826                           NaN         NaN    True               U->F
# ...                             ...         ...     ...                ...
# 352963                          NaN         NaN   False               U->F
# 354010                          NaN         NaN   False               U->F
# 356966                          NaN         NaN   False               U->F
# 358627                          NaN         NaN    True               U->F
# 359629                          NaN         NaN    True               U->F
#
#        trackrx_last_status trackrx_last_delivery trackrx_delivery_flow  \
# 7260                     F                   NaN                   NaN
# 12432                    F                   NaN                   NaN
# 13217                    F                   NaN                   NaN
# 14975                    F                   NaN                   NaN
# 16826                    F                   NaN                   NaN
# ...                    ...                   ...                   ...
# 352963                   F                   NaN                   NaN
# 354010                   F                   NaN                   NaN
# 356966                   F                   NaN                   NaN
# 358627                   F                   NaN                   NaN
# 359629                   F                   NaN                   NaN
#
#        trackrx_pickuptime_flow trackrx_pickedup_flow trackrx_last_pickuped  \
# 7260                       NaN                   ->N                     N
# 12432                      NaN                   ->N                     N
# 13217                      NaN                   ->N                     N
# 14975                      NaN                   ->N                     N
# 16826                      NaN                   ->N                     N
# ...                        ...                   ...                   ...
# 352963                     NaN                   ->N                     N
# 354010                     NaN                   ->N                     N
# 356966                     NaN                   ->N                     N
# 358627                     NaN                   ->N                     N
# 359629                     NaN                   ->N                     N
#
#                  trackrx_last_ibdtag trackrx_last_callinstag  \
# 7260    IBD DENIED CALL MD TO SWITCH                     NaN
# 12432           IBD DENIED 2K+ (AMT)          IBD SPECIALITY
# 13217   IBD DENIED CALL MD TO SWITCH                     NaN
# 14975               IBD NOT POSSIBLE                     NaN
# 16826   IBD DENIED CALL MD TO SWITCH                     NaN
# ...                              ...                     ...
# 352963              IBD NOT POSSIBLE          IBD SPECIALITY
# 354010  IBD DENIED CALL MD TO SWITCH                     NaN
# 356966              IBD NOT POSSIBLE                     NaN
# 358627  IBD DENIED CALL MD TO SWITCH                     NaN
# 359629  IBD DENIED CALL MD TO SWITCH                     IBD
#
#         end_filed_datetime trackrx_callins_processing_start  \
# 7260   2021-10-19 10:25:18                              NaT
# 12432  2021-12-29 15:12:34              2021-05-21 12:14:26
# 13217  2021-12-06 19:11:06                              NaT
# 14975  2021-11-18 17:01:48                              NaT
# 16826  2021-10-22 09:30:54                              NaT
# ...                    ...                              ...
# 352963 2021-10-15 17:00:08              2021-07-02 11:55:19
# 354010 2021-09-23 16:36:57                              NaT
# 356966 2021-07-22 12:49:47                              NaT
# 358627 2021-12-06 11:12:31                              NaT
# 359629 2021-12-21 10:43:53              2021-06-24 18:22:07
#
#        ibd_processing_enddatetime trackrx_ibd_processing_start  \
# 7260          2021-10-19 10:13:38          2021-09-30 13:06:25
# 12432         2021-06-21 16:32:12          2021-05-21 12:17:37
# 13217         2021-11-05 15:35:37          2021-10-29 11:54:00
# 14975         2021-10-28 12:15:39          2021-10-11 11:14:47
# 16826         2021-10-18 16:05:08          2021-10-06 09:20:55
# ...                           ...                          ...
# 352963                        NaT          2021-07-30 14:29:26
# 354010        2021-08-26 16:32:21          2021-06-24 12:32:12
# 356966                        NaT          2021-04-07 14:04:29
# 358627        2021-11-03 16:59:01          2021-10-26 10:06:20
# 359629        2021-11-12 15:31:50          2021-10-25 10:48:09
#
#        time_consumed_ibd_regular  times_processed_ibd_regular  \
# 7260             0 days 00:23:20                          3.0
# 12432                        NaT                          NaN
# 13217            0 days 00:10:54                          1.0
# 14975            0 days 01:29:12                          1.0
# 16826            0 days 01:22:06                          1.0
# ...                          ...                          ...
# 352963           0 days 00:17:39                          1.0
# 354010           0 days 01:10:08                          1.0
# 356966                       NaT                          NaN
# 358627           0 days 03:22:37                          1.0
# 359629           0 days 00:45:05                          1.0
#
#        status_ibd_regular time_consumed_ibd_2K  times_processed_ibd_2K  \
# 7260            completed      2 days 17:52:44                     2.0
# 12432           exception     30 days 22:29:35                     1.0
# 13217           completed      0 days 00:26:50                     1.0
# 14975           completed      0 days 04:18:15                     1.0
# 16826           completed      0 days 00:04:55                     1.0
# ...                   ...                  ...                     ...
# 352963          completed      0 days 02:30:32                     1.0
# 354010          completed     12 days 17:05:01                     1.0
# 356966          exception      0 days 00:35:12                     1.0
# 358627          completed      0 days 07:51:18                     1.0
# 359629          completed      2 days 02:21:38                     1.0
#
#        status_ibd_2K total_processing_time_ibd  times_processed_ibd  \
# 7260       completed          12 days 20:11:24                  3.0
# 12432      completed           0 days 05:45:00                  1.0
# 13217      completed           6 days 23:23:25                  1.0
# 14975      completed           6 days 22:12:23                  2.0
# 16826      completed           4 days 04:42:13                  1.0
# ...              ...                       ...                  ...
# 352963     completed                       NaT                  NaN
# 354010     completed          46 days 06:34:43                  4.0
# 356966     completed                       NaT                  NaN
# 358627     completed           6 days 22:38:25                  1.0
# 359629     completed          15 days 21:13:11                  1.0
#
#        ibd_final_status time_consumed_callforins_day01  \
# 7260          completed                            NaN
# 12432         completed                0 days 00:03:11
# 13217         completed                            NaN
# 14975         completed                            NaN
# 16826         completed                            NaN
# ...                 ...                            ...
# 352963              NaN               14 days 03:25:34
# 354010        completed                            NaN
# 356966              NaN                            NaN
# 358627        completed                            NaN
# 359629        completed               21 days 18:22:30
#
#         times_processed_callforins_day01 status_callforins_day01  \
# 7260                                 NaN                     NaN
# 12432                                1.0               completed
# 13217                                NaN                     NaN
# 14975                                NaN                     NaN
# 16826                                NaN                     NaN
# ...                                  ...                     ...
# 352963                               1.0               completed
# 354010                               NaN                     NaN
# 356966                               NaN                     NaN
# 358627                               NaN                     NaN
# 359629                               1.0               completed
#
#        time_consumed_callforins_day02  times_processed_callforins_day02  \
# 7260                              NaN                               NaN
# 12432                             NaN                               NaN
# 13217                             NaN                               NaN
# 14975                             NaN                               NaN
# 16826                             NaN                               NaN
# ...                               ...                               ...
# 352963                6 days 22:21:34                               1.0
# 354010                            NaN                               NaN
# 356966                            NaN                               NaN
# 358627                            NaN                               NaN
# 359629                5 days 03:14:34                               1.0
#
#        status_callforins_day02 time_consumed_callforins_day03  \
# 7260                       NaN                            NaN
# 12432                      NaN                            NaN
# 13217                      NaN                            NaN
# 14975                      NaN                            NaN
# 16826                      NaN                            NaN
# ...                        ...                            ...
# 352963               completed                7 days 00:46:59
# 354010                     NaN                            NaN
# 356966                     NaN                            NaN
# 358627                     NaN                            NaN
# 359629               completed               95 days 18:48:58
#
#         times_processed_callforins_day03 status_callforins_day03 city  \
# 7260                                 NaN                     NaN  NaN
# 12432                                NaN                     NaN  NaN
# 13217                                NaN                     NaN  NaN
# 14975                                NaN                     NaN  NaN
# 16826                                NaN                     NaN  NaN
# ...                                  ...                     ...  ...
# 352963                               1.0               completed  NaN
# 354010                               NaN                     NaN  NaN
# 356966                               NaN                     NaN  NaN
# 358627                               NaN                     NaN  NaN
# 359629                               1.0               completed  NaN
#
#        track_rx_filled DRUGNAME  QTY PATIENTCOPAY  TOTALINSPAID PATZIP PATDOB  \
# 7260               NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 12432              NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 13217              NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 14975              NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 16826              NaT      NaN  NaN          NaN           NaN    NaN    NaN
# ...                ...      ...  ...          ...           ...    ...    ...
# 352963             NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 354010             NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 356966             NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 358627             NaT      NaN  NaN          NaN           NaN    NaN    NaN
# 359629             NaT      NaN  NaN          NaN           NaN    NaN    NaN
#
#        INSCODE DATEO PATFNAME PATLNAME PATMOBILENO PATPHONE patsex  \
# 7260       NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 12432      NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 13217      NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 14975      NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 16826      NaN   NaN      NaN      NaN         NaN      NaN    NaN
# ...        ...   ...      ...      ...         ...      ...    ...
# 352963     NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 354010     NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 356966     NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 358627     NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 359629     NaN   NaN      NaN      NaN         NaN      NaN    NaN
#
#         TOTALRXAMOUNT  patientno_mms workflow_last_status  \
# 7260              NaN            NaN                  NaN
# 12432             NaN            NaN                  NaN
# 13217             NaN            NaN                  NaN
# 14975             NaN            NaN                  NaN
# 16826             NaN            NaN                  NaN
# ...               ...            ...                  ...
# 352963            NaN            NaN                  NaN
# 354010            NaN            NaN                  NaN
# 356966            NaN            NaN                  NaN
# 358627            NaN            NaN                  NaN
# 359629            NaN            NaN                  NaN
#
#        workflow_last_change_datetime cxrev_last_datetime  times_cx_reversed  \
# 7260                             NaT                 NaT                NaN
# 12432                            NaT                 NaT                NaN
# 13217                            NaT                 NaT                NaN
# 14975                            NaT                 NaT                NaN
# 16826                            NaT                 NaT                NaN
# ...                              ...                 ...                ...
# 352963                           NaT                 NaT                NaN
# 354010                           NaT                 NaT                NaN
# 356966                           NaT                 NaT                NaN
# 358627                           NaT                 NaT                NaN
# 359629                           NaT                 NaT                NaN
#
#        delrev_last_datetime times_del_reversed batchno batchcreatedon  \
# 7260                    NaT                NaN     NaN            NaN
# 12432                   NaT                NaN     NaN            NaN
# 13217                   NaT                NaN     NaN            NaN
# 14975                   NaT                NaN     NaN            NaN
# 16826                   NaT                NaN     NaN            NaN
# ...                     ...                ...     ...            ...
# 352963                  NaT                NaN     NaN            NaN
# 354010                  NaT                NaN     NaN            NaN
# 356966                  NaT                NaN     NaN            NaN
# 358627                  NaT                NaN     NaN            NaN
# 359629                  NaT                NaN     NaN            NaN
#
#        batchclosedon deliverydate driver phone patient_phone_x  \
# 7260             NaN          NaN    NaN   NaN             NaN
# 12432            NaN          NaN    NaN   NaN             NaN
# 13217            NaN          NaN    NaN   NaN             NaN
# 14975            NaN          NaN    NaN   NaN             NaN
# 16826            NaN          NaN    NaN   NaN             NaN
# ...              ...          ...    ...   ...             ...
# 352963           NaN          NaN    NaN   NaN             NaN
# 354010           NaN          NaN    NaN   NaN             NaN
# 356966           NaN          NaN    NaN   NaN             NaN
# 358627           NaN          NaN    NaN   NaN             NaN
# 359629           NaN          NaN    NaN   NaN             NaN
#
#        batch_delivery_date batch_delivery_datetime batch_creation_datetime  \
# 7260                   NaN                     NaN                     NaT
# 12432                  NaN                     NaN                     NaT
# 13217                  NaN                     NaN                     NaT
# 14975                  NaN                     NaN                     NaT
# 16826                  NaN                     NaN                     NaT
# ...                    ...                     ...                     ...
# 352963                 NaN                     NaN                     NaT
# 354010                 NaN                     NaN                     NaT
# 356966                 NaN                     NaN                     NaT
# 358627                 NaN                     NaN                     NaT
# 359629                 NaN                     NaN                     NaT
#
#        batch_id  no_times_batch_created delivery_date shortId_of status  \
# 7260        NaN                     NaN           NaT        NaN    NaN
# 12432       NaN                     NaN           NaT        NaN    NaN
# 13217       NaN                     NaN           NaT        NaN    NaN
# 14975       NaN                     NaN           NaT        NaN    NaN
# 16826       NaN                     NaN           NaT        NaN    NaN
# ...         ...                     ...           ...        ...    ...
# 352963      NaN                     NaN           NaT        NaN    NaN
# 354010      NaN                     NaN           NaT        NaN    NaN
# 356966      NaN                     NaN           NaT        NaN    NaN
# 358627      NaN                     NaN           NaT        NaN    NaN
# 359629      NaN                     NaN           NaT        NaN    NaN
#
#         patient_phone_y  patient_zipcode delivery_time  Driver Number  \
# 7260                NaN              NaN           NaN            NaN
# 12432               NaN              NaN           NaN            NaN
# 13217               NaN              NaN           NaN            NaN
# 14975               NaN              NaN           NaN            NaN
# 16826               NaN              NaN           NaN            NaN
# ...                 ...              ...           ...            ...
# 352963              NaN              NaN           NaN            NaN
# 354010              NaN              NaN           NaN            NaN
# 356966              NaN              NaN           NaN            NaN
# 358627              NaN              NaN           NaN            NaN
# 359629              NaN              NaN           NaN            NaN
#
#        didSucceed match_method rx_no_fill zone_name  \
# 7260          NaN          NaN        NaN       NaN
# 12432         NaN          NaN        NaN       NaN
# 13217         NaN          NaN        NaN       NaN
# 14975         NaN          NaN        NaN       NaN
# 16826         NaN          NaN        NaN       NaN
# ...           ...          ...        ...       ...
# 352963        NaN          NaN        NaN       NaN
# 354010        NaN          NaN        NaN       NaN
# 356966        NaN          NaN        NaN       NaN
# 358627        NaN          NaN        NaN       NaN
# 359629        NaN          NaN        NaN       NaN
#
#         delivery_patient_zip_code dl_app_delivery_created_time  \
# 7260                          NaN                          NaN
# 12432                         NaN                          NaN
# 13217                         NaN                          NaN
# 14975                         NaN                          NaN
# 16826                         NaN                          NaN
# ...                           ...                          ...
# 352963                        NaN                          NaN
# 354010                        NaN                          NaN
# 356966                        NaN                          NaN
# 358627                        NaN                          NaN
# 359629                        NaN                          NaN
#
#        dl_app_delivery_time onfleet_short_id  delivery_id driver_name  \
# 7260                    NaN              NaN          NaN         NaN
# 12432                   NaN              NaN          NaN         NaN
# 13217                   NaN              NaN          NaN         NaN
# 14975                   NaN              NaN          NaN         NaN
# 16826                   NaN              NaN          NaN         NaN
# ...                     ...              ...          ...         ...
# 352963                  NaN              NaN          NaN         NaN
# 354010                  NaN              NaN          NaN         NaN
# 356966                  NaN              NaN          NaN         NaN
# 358627                  NaN              NaN          NaN         NaN
# 359629                  NaN              NaN          NaN         NaN
#
#        onfleet_state pharmacy_location_dl  pharmacy_nabp rx_no_fill_px  \
# 7260             NaN                  NaN            NaN           NaN
# 12432            NaN                  NaN            NaN           NaN
# 13217            NaN                  NaN            NaN           NaN
# 14975            NaN                  NaN            NaN           NaN
# 16826            NaN                  NaN            NaN           NaN
# ...              ...                  ...            ...           ...
# 352963           NaN                  NaN            NaN           NaN
# 354010           NaN                  NaN            NaN           NaN
# 356966           NaN                  NaN            NaN           NaN
# 358627           NaN                  NaN            NaN           NaN
# 359629           NaN                  NaN            NaN           NaN
#
#        task_completed slot_start slot_end pharmacy_location_px refill_tag  \
# 7260              NaN        NaN      NaN                  NaN        New
# 12432             NaN        NaN      NaN                  NaN        New
# 13217             NaN        NaN      NaN                  NaN        New
# 14975             NaN        NaN      NaN                  NaN        New
# 16826             NaN        NaN      NaN                  NaN        New
# ...               ...        ...      ...                  ...        ...
# 352963            NaN        NaN      NaN                  NaN        New
# 354010            NaN        NaN      NaN                  NaN        New
# 356966            NaN        NaN      NaN                  NaN        New
# 358627            NaN        NaN      NaN                  NaN        New
# 359629            NaN        NaN      NaN                  NaN        New
#
#        new_delivered_date  PATPHONE_len  PATMOBILENO_len shortId_mms  \
# 7260                  NaT             3                3         NaN
# 12432                 NaT             3                3         NaN
# 13217                 NaT             3                3         NaN
# 14975                 NaT             3                3         NaN
# 16826                 NaT             3                3         NaN
# ...                   ...           ...              ...         ...
# 352963                NaT             3                3         NaN
# 354010                NaT             3                3         NaN
# 356966                NaT             3                3         NaN
# 358627                NaT             3                3         NaN
# 359629                NaT             3                3         NaN
#
#        new_shortId status_tag   id  rx_number rx_status patient_id  \
# 7260           NaN        NaN  NaN        NaN       NaN        NaN
# 12432          NaN        NaN  NaN        NaN       NaN        NaN
# 13217          NaN        NaN  NaN        NaN       NaN        NaN
# 14975          NaN        NaN  NaN        NaN       NaN        NaN
# 16826          NaN        NaN  NaN        NaN       NaN        NaN
# ...            ...        ...  ...        ...       ...        ...
# 352963         NaN        NaN  NaN        NaN       NaN        NaN
# 354010         NaN        NaN  NaN        NaN       NaN        NaN
# 356966         NaN        NaN  NaN        NaN       NaN        NaN
# 358627         NaN        NaN  NaN        NaN       NaN        NaN
# 359629         NaN        NaN  NaN        NaN       NaN        NaN
#
#        prescriber_id insurance_id drug_name drug_form followup_tag  copay  \
# 7260             NaN          NaN       NaN       NaN          NaN    NaN
# 12432            NaN          NaN       NaN       NaN          NaN    NaN
# 13217            NaN          NaN       NaN       NaN          NaN    NaN
# 14975            NaN          NaN       NaN       NaN          NaN    NaN
# 16826            NaN          NaN       NaN       NaN          NaN    NaN
# ...              ...          ...       ...       ...          ...    ...
# 352963           NaN          NaN       NaN       NaN          NaN    NaN
# 354010           NaN          NaN       NaN       NaN          NaN    NaN
# 356966           NaN          NaN       NaN       NaN          NaN    NaN
# 358627           NaN          NaN       NaN       NaN          NaN    NaN
# 359629           NaN          NaN       NaN       NaN          NaN    NaN
#
#         amount ndc_prsc  quantity  fill_number reversed reversal_reason  \
# 7260       NaN      NaN       NaN          NaN      NaN             NaN
# 12432      NaN      NaN       NaN          NaN      NaN             NaN
# 13217      NaN      NaN       NaN          NaN      NaN             NaN
# 14975      NaN      NaN       NaN          NaN      NaN             NaN
# 16826      NaN      NaN       NaN          NaN      NaN             NaN
# ...        ...      ...       ...          ...      ...             ...
# 352963     NaN      NaN       NaN          NaN      NaN             NaN
# 354010     NaN      NaN       NaN          NaN      NaN             NaN
# 356966     NaN      NaN       NaN          NaN      NaN             NaN
# 358627     NaN      NaN       NaN          NaN      NaN             NaN
# 359629     NaN      NaN       NaN          NaN      NaN             NaN
#
#        reversal_fill_date  day_supply status_prsc created_at id_task  \
# 7260                  NaN         NaN         NaN        NaN     NaN
# 12432                 NaN         NaN         NaN        NaN     NaN
# 13217                 NaN         NaN         NaN        NaN     NaN
# 14975                 NaN         NaN         NaN        NaN     NaN
# 16826                 NaN         NaN         NaN        NaN     NaN
# ...                   ...         ...         ...        ...     ...
# 352963                NaN         NaN         NaN        NaN     NaN
# 354010                NaN         NaN         NaN        NaN     NaN
# 356966                NaN         NaN         NaN        NaN     NaN
# 358627                NaN         NaN         NaN        NaN     NaN
# 359629                NaN         NaN         NaN        NaN     NaN
#
#        status_id associate_id_prsc is_scheduled  scheduled_time error_status  \
# 7260         NaN               NaN          NaN             NaN          NaN
# 12432        NaN               NaN          NaN             NaN          NaN
# 13217        NaN               NaN          NaN             NaN          NaN
# 14975        NaN               NaN          NaN             NaN          NaN
# 16826        NaN               NaN          NaN             NaN          NaN
# ...          ...               ...          ...             ...          ...
# 352963       NaN               NaN          NaN             NaN          NaN
# 354010       NaN               NaN          NaN             NaN          NaN
# 356966       NaN               NaN          NaN             NaN          NaN
# 358627       NaN               NaN          NaN             NaN          NaN
# 359629       NaN               NaN          NaN             NaN          NaN
#
#        claimed_at created_at_task is_all_reversal_rxs completed_at  \
# 7260          NaN             NaN                 NaN          NaN
# 12432         NaN             NaN                 NaN          NaN
# 13217         NaN             NaN                 NaN          NaN
# 14975         NaN             NaN                 NaN          NaN
# 16826         NaN             NaN                 NaN          NaN
# ...           ...             ...                 ...          ...
# 352963        NaN             NaN                 NaN          NaN
# 354010        NaN             NaN                 NaN          NaN
# 356966        NaN             NaN                 NaN          NaN
# 358627        NaN             NaN                 NaN          NaN
# 359629        NaN             NaN                 NaN          NaN
#
#        cancelled_at cancellation_reason  pharmacy_nabp_prsc  \
# 7260            NaN                 NaN                 NaN
# 12432           NaN                 NaN                 NaN
# 13217           NaN                 NaN                 NaN
# 14975           NaN                 NaN                 NaN
# 16826           NaN                 NaN                 NaN
# ...             ...                 ...                 ...
# 352963          NaN                 NaN                 NaN
# 354010          NaN                 NaN                 NaN
# 356966          NaN                 NaN                 NaN
# 358627          NaN                 NaN                 NaN
# 359629          NaN                 NaN                 NaN
#
#        earliest_fill_date  rx_numbers_count rx_numbers_list  total_awp  \
# 7260                  NaN               NaN             NaN        NaN
# 12432                 NaN               NaN             NaN        NaN
# 13217                 NaN               NaN             NaN        NaN
# 14975                 NaN               NaN             NaN        NaN
# 16826                 NaN               NaN             NaN        NaN
# ...                   ...               ...             ...        ...
# 352963                NaN               NaN             NaN        NaN
# 354010                NaN               NaN             NaN        NaN
# 356966                NaN               NaN             NaN        NaN
# 358627                NaN               NaN             NaN        NaN
# 359629                NaN               NaN             NaN        NaN
#
#         days_contacted latest_contacted_at insurance_category  parent_id  \
# 7260               NaN                 NaN                NaN        NaN
# 12432              NaN                 NaN                NaN        NaN
# 13217              NaN                 NaN                NaN        NaN
# 14975              NaN                 NaN                NaN        NaN
# 16826              NaN                 NaN                NaN        NaN
# ...                ...                 ...                ...        ...
# 352963             NaN                 NaN                NaN        NaN
# 354010             NaN                 NaN                NaN        NaN
# 356966             NaN                 NaN                NaN        NaN
# 358627             NaN                 NaN                NaN        NaN
# 359629             NaN                 NaN                NaN        NaN
#
#        pharmacy_location_prsc id_cv contacted_at outcome created_at_cv id_sd  \
# 7260                      NaN   NaN          NaN     NaN           NaN   NaN
# 12432                     NaN   NaN          NaN     NaN           NaN   NaN
# 13217                     NaN   NaN          NaN     NaN           NaN   NaN
# 14975                     NaN   NaN          NaN     NaN           NaN   NaN
# 16826                     NaN   NaN          NaN     NaN           NaN   NaN
# ...                       ...   ...          ...     ...           ...   ...
# 352963                    NaN   NaN          NaN     NaN           NaN   NaN
# 354010                    NaN   NaN          NaN     NaN           NaN   NaN
# 356966                    NaN   NaN          NaN     NaN           NaN   NaN
# 358627                    NaN   NaN          NaN     NaN           NaN   NaN
# 359629                    NaN   NaN          NaN     NaN           NaN   NaN
#
#        payload status_sd created_at_sd delivery_type  \
# 7260       NaN       NaN           NaN           NaN
# 12432      NaN       NaN           NaN           NaN
# 13217      NaN       NaN           NaN           NaN
# 14975      NaN       NaN           NaN           NaN
# 16826      NaN       NaN           NaN           NaN
# ...        ...       ...           ...           ...
# 352963     NaN       NaN           NaN           NaN
# 354010     NaN       NaN           NaN           NaN
# 356966     NaN       NaN           NaN           NaN
# 358627     NaN       NaN           NaN           NaN
# 359629     NaN       NaN           NaN           NaN
#
#        pickup_date_scheduled_deliveries  \
# 7260                                NaN
# 12432                               NaN
# 13217                               NaN
# 14975                               NaN
# 16826                               NaN
# ...                                 ...
# 352963                              NaN
# 354010                              NaN
# 356966                              NaN
# 358627                              NaN
# 359629                              NaN
#
#        scheduled_startdate_scheduled_deliveries  \
# 7260                                        NaN
# 12432                                       NaN
# 13217                                       NaN
# 14975                                       NaN
# 16826                                       NaN
# ...                                         ...
# 352963                                      NaN
# 354010                                      NaN
# 356966                                      NaN
# 358627                                      NaN
# 359629                                      NaN
#
#        scheduled_enddate_scheduled_deliveries  \
# 7260                                      NaN
# 12432                                     NaN
# 13217                                     NaN
# 14975                                     NaN
# 16826                                     NaN
# ...                                       ...
# 352963                                    NaN
# 354010                                    NaN
# 356966                                    NaN
# 358627                                    NaN
# 359629                                    NaN
#
#         erxreceived_rxtimelines_boolean_d  \
# 7260                                 True
# 12432                               False
# 13217                                True
# 14975                               False
# 16826                                True
# ...                                   ...
# 352963                              False
# 354010                              False
# 356966                              False
# 358627                               True
# 359629                               True
#
#         rx_entered_date_rxtimelines_boolean_d  \
# 7260                                     True
# 12432                                    True
# 13217                                    True
# 14975                                    True
# 16826                                    True
# ...                                       ...
# 352963                                   True
# 354010                                   True
# 356966                                   True
# 358627                                   True
# 359629                                   True
#
#         rx_entered_date_verification_boolean_d  \
# 7260                                      True
# 12432                                     True
# 13217                                     True
# 14975                                     True
# 16826                                     True
# ...                                        ...
# 352963                                    True
# 354010                                    True
# 356966                                    True
# 358627                                    True
# ...
# 16826                                  False
# ...                                      ...
# 352963                                  True
# 354010                                 False
# 356966                                 False
# 358627                                 False
# 359629                                  True
#
#         times_processed_callforins_day03_new    final_rx_entered  \
# 7260                                   False 2021-09-30 11:12:00
# 12432                                  False 2021-05-21 12:17:00
# 13217                                  False 2021-10-29 11:17:00
# 14975                                  False 2021-10-11 11:04:00
# 16826                                  False 2021-10-05 16:41:00
# ...                                      ...                 ...
# 352963                                  True 2021-07-02 11:52:00
# 354010                                 False 2021-06-24 12:31:00
# 356966                                 False 2021-04-07 14:04:00
# 358627                                 False 2021-10-26 10:05:00
# 359629                                  True 2021-06-24 18:21:00
#
#                rx_delta rx_delta_day rx_delta_days_str  rx_delta_time2  \
# 7260   15 days 14:27:28      15 days              days 0 days 14:27:28
# 12432  31 days 04:14:35      31 days              days 0 days 04:14:35
# 13217   7 days 00:01:09       7 days              days 0 days 00:01:09
# 14975   7 days 03:59:50       7 days              days 0 days 03:59:50
# 16826   4 days 06:09:14       4 days              days 0 days 06:09:14
# ...                 ...          ...               ...             ...
# 352963  0 days 02:48:11       0 days              days 0 days 02:48:11
# 354010 59 days 00:49:52      59 days              days 0 days 00:49:52
# 356966  0 days 00:35:12       0 days              days 0 days 00:35:12
# 358627  7 days 09:52:20       7 days              days 0 days 09:52:20
# 359629 18 days 00:19:54      18 days              days 0 days 00:19:54
#
#        ibd_processing_end_rx_final received_to_entered_time  \
# 7260           2021-10-16 03:33:53          0 days 00:34:00
# 12432          2021-06-21 16:32:12                       NA
# 13217          2021-11-05 11:55:09          0 days 00:05:00
# 14975          2021-10-18 15:14:37                       NA
# 16826          2021-10-10 15:30:09          0 days 00:05:00
# ...                            ...                      ...
# 352963         2021-07-30 17:17:37                       NA
# 354010         2021-08-22 13:22:04                       NA
# 356966         2021-04-07 14:39:41                       NA
# 358627         2021-11-02 19:58:40          0 days 00:29:00
# 359629         2021-11-12 11:08:03          0 days 01:29:00
#
#        entered_to_first_billed first_billed_to_last_billed  \
# 7260                       NaT                         NaT
# 12432                      NaT                         NaT
# 13217                      NaT                         NaT
# 14975                      NaT                         NaT
# 16826                      NaT                         NaT
# ...                        ...                         ...
# 352963                     NaT                         NaT
# 354010                     NaT                         NaT
# 356966                     NaT                         NaT
# 358627                     NaT                         NaT
# 359629                     NaT                         NaT
#
#        entered_to_last_billed entered_to_label_printed  \
# 7260                      NaT                      NaT
# 12432                     NaT                      NaT
# 13217                     NaT                      NaT
# 14975                     NaT                      NaT
# 16826                     NaT                      NaT
# ...                       ...                      ...
# 352963                    NaT                      NaT
# 354010                    NaT                      NaT
# 356966                    NaT                      NaT
# 358627                    NaT                      NaT
# 359629                    NaT                      NaT
#
#        last_billed_to_label_printed label_printed_to_drug_picked  \
# 7260                            NaT                          NaT
# 12432                           NaT                          NaT
# 13217                           NaT                          NaT
# 14975                           NaT                          NaT
# 16826                           NaT                          NaT
# ...                             ...                          ...
# 352963                          NaT                          NaT
# 354010                          NaT                          NaT
# 356966                          NaT                          NaT
# 358627                          NaT                          NaT
# 359629                          NaT                          NaT
#
#        drug_picked_to_rph_verified rph_verified_to_pharmacy_pickedup  \
# 7260                           NaT                                NA
# 12432                          NaT                                NA
# 13217                          NaT                                NA
# 14975                          NaT                                NA
# 16826                          NaT                                NA
# ...                            ...                               ...
# 352963                         NaT                                NA
# 354010                         NaT                                NA
# 356966                         NaT                                NA
# 358627                         NaT                                NA
# 359629                         NaT                                NA
#
#        rph_verified_to_batch_creation batch_creation_to_delivered  \
# 7260                               NA                          NA
# 12432                              NA                          NA
# 13217                              NA                          NA
# 14975                              NA                          NA
# 16826                              NA                          NA
# ...                               ...                         ...
# 352963                             NA                          NA
# 354010                             NA                          NA
# 356966                             NA                          NA
# 358627                             NA                          NA
# 359629                             NA                          NA
#
#        rph_verified_to_delivered ibd_processing_start_to_end  \
# 7260                          NA          -19 days +02:52:47
# 12432                         NA          -32 days +19:45:25
# 13217                         NA           -8 days +20:18:23
# 14975                         NA          -18 days +22:59:08
# 16826                         NA          -13 days +17:15:47
# ...                          ...                         ...
# 352963                        NA                         NaT
# 354010                        NA          -64 days +19:59:51
# 356966                        NA                         NaT
# 358627                        NA           -9 days +17:07:19
# 359629                        NA          -19 days +19:16:19
#
#        time_to_identify_pa_is_required waiting_time_for_ibd_processing  \
# 7260                   0 days 01:54:25                18 days 21:07:13
# 12432                  0 days 00:00:37                31 days 04:14:35
# 13217                  0 days 00:37:00                 7 days 03:41:37
# 14975                  0 days 00:10:47                17 days 01:00:52
# 16826                  0 days 16:39:55                12 days 06:44:13
# ...                                ...                             ...
# 352963                28 days 02:37:26                             NaT
# 354010                 0 days 00:01:12                63 days 04:00:09
# 356966                 0 days 00:00:29                             NaT
# 358627                 0 days 00:01:20                 8 days 06:52:41
# 359629               122 days 16:27:09                18 days 04:43:41
#
#        ibd_processing_end_to_label_printed  \
# 7260                                   NaT
# 12432                                  NaT
# 13217                                  NaT
# 14975                                  NaT
# 16826                                  NaT
# ...                                    ...
# 352963                                 NaT
# 354010                                 NaT
# 356966                                 NaT
# 358627                                 NaT
# 359629                                 NaT
#
#        rx_entered_to_callins_processing_start  \
# 7260                                      NaT
# 12432                       -1 days +23:57:26
# 13217                                     NaT
# 14975                                     NaT
# 16826                                     NaT
# ...                                       ...
# 352963                        0 days 00:03:19
# 354010                                    NaT
# 356966                                    NaT
# 358627                                    NaT
# 359629                        0 days 00:01:07
#
#        ibd_processing_end_to_first_billed rph_verified_to_delivery_pickedup  \
# 7260                                  NaT                                NA
# 12432                                 NaT                                NA
# 13217                                 NaT                                NA
# 14975                                 NaT                                NA
# 16826                                 NaT                                NA
# ...                                   ...                               ...
# 352963                                NaT                                NA
# 354010                                NaT                                NA
# 356966                                NaT                                NA
# 358627                                NaT                                NA
# 359629                                NaT                                NA
#
#        delivery_pickedup_to_delivered      final_received  \
# 7260                               NA 2021-09-30 10:38:00
# 12432                              NA 2021-05-21 12:17:00
# 13217                              NA 2021-10-29 11:12:00
# 14975                              NA 2021-10-11 11:04:00
# 16826                              NA 2021-10-05 16:36:00
# ...                               ...                 ...
# 352963                             NA 2021-07-02 11:52:00
# 354010                             NA 2021-06-24 12:31:00
# 356966                             NA 2021-04-07 14:04:00
# 358627                             NA 2021-10-26 09:36:00
# 359629                             NA 2021-06-24 16:52:00
#
#        final_received_to_delivered received_to_rph_verified  \
# 7260                           NaT                      NaT
# 12432                          NaT                      NaT
# 13217                          NaT                      NaT
# 14975                          NaT                      NaT
# 16826                          NaT                      NaT
# ...                            ...                      ...
# 352963                         NaT                      NaT
# 354010                         NaT                      NaT
# 356966                         NaT                      NaT
# 358627                         NaT                      NaT
# 359629                         NaT                      NaT
#
#        time_taken_by_rx_to_be_picked_up_by_IBD_team  \
# 7260                                2 days 18:16:04
# 12432                                           NaT
# 13217                               0 days 00:37:44
# 14975                               0 days 05:47:27
# 16826                               0 days 01:27:01
# ...                                             ...
# 352963                              0 days 02:48:11
# 354010                             12 days 18:15:09
# 356966                                          NaT
# 358627                              0 days 11:13:55
# 359629                              2 days 03:06:43
#
#        time_taken_by_IBD_team_to_process_rx               c1              c2  \
# 7260                       12 days 20:11:24              NaT             NaT
# 12432                       0 days 05:45:00  0 days 00:03:11             NaT
# 13217                       6 days 23:23:25              NaT             NaT
# 14975                       6 days 22:12:23              NaT             NaT
# 16826                       4 days 04:42:13              NaT             NaT
# ...                                     ...              ...             ...
# 352963                                  NaT 14 days 03:25:34 6 days 22:21:34
# 354010                     46 days 06:34:43              NaT             NaT
# 356966                                  NaT              NaT             NaT
# 358627                      6 days 22:38:25              NaT             NaT
# 359629                     15 days 21:13:11 21 days 18:22:30 5 days 03:14:34
#
#                      c3        total_call  \
# 7260                NaT   0 days 00:00:00
# 12432               NaT   0 days 00:03:11
# 13217               NaT   0 days 00:00:00
# 14975               NaT   0 days 00:00:00
# 16826               NaT   0 days 00:00:00
# ...                 ...               ...
# 352963  7 days 00:46:59  28 days 02:34:07
# 354010              NaT   0 days 00:00:00
# 356966              NaT   0 days 00:00:00
# 358627              NaT   0 days 00:00:00
# 359629 95 days 18:48:58 122 days 16:26:02
#
#        time_taken_for_call_for_insurance_process  total_call_2  is_call  \
# 7260                             0 days 00:00:00           0.0    False
# 12432                            0 days 00:03:11         191.0     True
# 13217                            0 days 00:00:00           0.0    False
# 14975                            0 days 00:00:00           0.0    False
# 16826                            0 days 00:00:00           0.0    False
# ...                                          ...           ...      ...
# 352963                          28 days 02:34:07     2428447.0     True
# 354010                           0 days 00:00:00           0.0    False
# 356966                           0 days 00:00:00           0.0    False
# 358627                           0 days 00:00:00           0.0    False
# 359629                         122 days 16:26:02    10599962.0     True
#
#         total_processing_time_ibd_new trackrx_last_status_new  rx_revenue
# 7260                             True                      NB         NaN
# 12432                            True                      NB         NaN
# 13217                            True                      NB         NaN
# 14975                            True                      NB         NaN
# 16826                            True                      NB         NaN
# ...                               ...                     ...         ...
# 352963                          False                      NB         NaN
# 354010                           True                      NB         NaN
# 356966                          False                      NB         NaN
# 358627                           True                      NB         NaN
# 359629                           True                      NB         NaN
#
# [101 rows x 278 columns]

# %%
Rx_with_IBD_value_greater_2k_denied_count_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_denied, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_denied_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_Denied'}, inplace = True)
Rx_with_IBD_value_greater_2k_denied_count_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied
# 0        MD-BA                   69
# 1        NJ-SO                    7
# 2        NY-BK                    7
# 3        NY-MA                    6
# 4        PA-PH                   12

# %%
Rx_with_IBD_value_greater_2k_denied_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_denied, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_denied_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_Denied'}, inplace = True)
Rx_with_IBD_value_greater_2k_denied_revenue_pivot
# Out:
#   pharmacy_loc  rx_revenue_IBD_Denied
# 0        MD-BA                   0.00
# 1        NJ-SO                3508.00
# 2        NY-BK                  14.58
# 3        NY-MA                   0.00
# 4        PA-PH                   0.00

# %%
Rx_with_IBD_value_greater_2k_denied_pivot = pd.merge(Rx_with_IBD_value_greater_2k_denied_count_pivot, Rx_with_IBD_value_greater_2k_denied_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_greater_2k_denied_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied  rx_revenue_IBD_Denied
# 0        MD-BA                   69                   0.00
# 1        NJ-SO                    7                3508.00
# 2        NY-BK                    7                  14.58
# 3        NY-MA                    6                   0.00
# 4        PA-PH                   12                   0.00

# %%
Rx_with_IBD_value_greater_2k_denied_pivot.append(Rx_with_IBD_value_greater_2k_denied_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %% [markdown]
# # IBD not possible

# %%
ibd_possible_list = ['TO BE BILLED', 'CALL FOR INS', 'CALL MD (SEE NOTES)',
       'SPEAK WITH INSURANCE', 
        'IBD IS 2K+',
       'IBD IN PROCESS â€“ DARSHI', 'IBD IN PROCESS - MITCHELL', '0',
       'HIV', 'HORIZON-BILL', 'HORIZON-CALL', 'O/O', 'IBD IS $2K+',
       'IBD IN PROCESS - DANIEL', 'COPAY COUNSELING (SEE NOTES)',
       'CALL FOR INS DAY 2', 'COMPLICATED RX ( SEE NOTES)',
       'REFIL-CALLING', 'SALES-FOLLOWUP', 'HORIZON-OK TO BILL',
       'COUPON BILL', 'IBD DONE BY MD', 'SPEAK WITH INS',
       'IBD IN PROCESS - KARIM', 'IBD CHART NOTES REQ - 2K+',
       'DELIVER TO MD OFFICE', 'IBD CHART NOTES REQ - TIARA',
        'COMPLICATED RX (NOTES)',
       'COPAY SPECIALTY', 'DERM GROUP', 'CALL MD TO SWITCH',
       'REFILL CALLING OPTUMRX', 'IBD REQUIRED', 'DE-PD DERMATOLOGY',
       'IBD IN PROCESS - DARSHI', 'IBD IN PROCESS - KATHERINE',
       'NEW PX APP', 'CALL MD TO SWITCH-ACCT. MGT', 'RH-I RHEUMATOLOGY',
       'HUMIRA NURSE AMBASSADOR', 'SMS NRBP 1',
       'COMPLICATED RX (SEE NOTES)', 'IBD CHART NOTES REQ- CHRISTINE',
       "WORKER'S COMP", 'IBD FIDELIS', 'IBD IN PROCESS - TAMIKAH',
       'CX LANGUAGE SPANISH', 'IBD IN PROCESS - CHIARA',
       'REFILL-CALLING OPTUMRX', 'IBD IN PROCESS - ASHLEY',
       'COPAY COUNSELLING', 'IBD CHART NOTES REQ',
       'IBD IN PROCESS - TATYANNA', 'DEL REVERSALS']

# %%
Rx_with_IBD_value_less_2k_possible = Rx_with_IBD_value_less_2k[Rx_with_IBD_value_less_2k['trackrx_last_ibdtag'].isin(ibd_possible_list)]

# %%
Rx_with_IBD_value_less_2k_possible_count_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_possible, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_possible_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_Denied'}, inplace = True)
Rx_with_IBD_value_less_2k_possible_count_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied
# 0        FL-MI                 1390
# 1        MD-BA                 1957
# 2        NC-RA                  770
# 3        NJ-SO                 6879
# 4        NY-BK                 7330
# 5        NY-MA                  671
# 6        PA-PH                 3140

# %%
Rx_with_IBD_value_less_2k_possible_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_possible, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_possible_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_Denied'}, inplace = True)
Rx_with_IBD_value_less_2k_possible_revenue_pivot
# Out:
#   pharmacy_loc  rx_revenue_IBD_Denied
# 0        FL-MI              605783.62
# 1        MD-BA             1349435.51
# 2        NC-RA              496980.19
# 3        NJ-SO             3660477.03
# 4        NY-BK             2884611.68
# 5        NY-MA              103797.21
# 6        PA-PH             1687912.41

# %%
Rx_with_IBD_value_less_2k_possible_pivot = pd.merge(Rx_with_IBD_value_less_2k_possible_count_pivot, Rx_with_IBD_value_less_2k_possible_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_less_2k_possible_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied  rx_revenue_IBD_Denied
# 0        FL-MI                 1390              605783.62
# 1        MD-BA                 1957             1349435.51
# 2        NC-RA                  770              496980.19
# 3        NJ-SO                 6879             3660477.03
# 4        NY-BK                 7330             2884611.68
# 5        NY-MA                  671              103797.21
# 6        PA-PH                 3140             1687912.41

# %%
Rx_with_IBD_value_less_2k_possible_pivot.append(Rx_with_IBD_value_less_2k_possible_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %%
### Rx_with_IBD_value_greater_2k_possible

# %%
Rx_with_IBD_value_greater_2k_possible = Rx_with_IBD_value_greater_2k[Rx_with_IBD_value_greater_2k['trackrx_last_ibdtag'].isin(ibd_possible_list)]

# %%
Rx_with_IBD_value_greater_2k_possible_count_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_possible, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_possible_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_possible'}, inplace = True)
Rx_with_IBD_value_greater_2k_possible_count_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_possible
# 0        MD-BA                    381
# 1        NC-RA                     28
# 2        NJ-SO                    270
# 3        NY-BK                    630
# 4        NY-MA                     44
# 5        PA-PH                    517

# %%
Rx_with_IBD_value_greater_2k_possible_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_possible, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_possible_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_possible'}, inplace = True)
Rx_with_IBD_value_greater_2k_possible_revenue_pivot
# Out:
#   pharmacy_loc  rx_revenue_IBD_possible
# 0        MD-BA                482180.16
# 1        NC-RA                 56229.31
# 2        NJ-SO                319876.94
# 3        NY-BK               1151978.53
# 4        NY-MA                  9107.78
# 5        PA-PH                362388.45

# %%
Rx_with_IBD_value_greater_2k_denied_pivot = pd.merge(Rx_with_IBD_value_greater_2k_possible_count_pivot, Rx_with_IBD_value_greater_2k_possible_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_greater_2k_denied_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_possible  rx_revenue_IBD_possible
# 0        MD-BA                    381                482180.16
# 1        NC-RA                     28                 56229.31
# 2        NJ-SO                    270                319876.94
# 3        NY-BK                    630               1151978.53
# 4        NY-MA                     44                  9107.78
# 5        PA-PH                    517                362388.45

# %%
Rx_with_IBD_value_greater_2k_denied_pivot.append(Rx_with_IBD_value_greater_2k_denied_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %% [markdown]
# # IBD billed & unbilled

# %%
# Rx_with_IBD_value_less_2k_denied
# Rx_with_IBD_value_greater_2k_denied
# Rx_with_IBD_value_less_2k_possible
# Rx_with_IBD_value_greater_2k_possible

# %%
# Rx_with_IBD_value_less_2k_denied billed & unbilled

# %%
Rx_with_IBD_value_less_2k_denied_billed = Rx_with_IBD_value_less_2k_denied[Rx_with_IBD_value_less_2k_denied['trackrx_last_status_new']=='B']

# %%
Rx_with_IBD_value_less_2k_denied_billed_count_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_denied_billed, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_denied_billed_count_pivot.rename(columns = {'pharmacy_loc': 'pharmacy loc', 'rx_code_key_location':'Rx count for IBD < 2k'}, inplace = True)
#Rx_with_IBD_value_less_2k_denied_billed_count_pivot

Rx_with_IBD_value_less_2k_denied_billed_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_denied_billed, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_denied_billed_revenue_pivot.rename(columns = {'pharmacy_loc': 'pharmacy loc', 'rx_revenue':'Rx revenue for IBD < 2k($)'}, inplace = True)
#Rx_with_IBD_value_less_2k_denied_billed_revenue_pivot

Rx_with_IBD_value_less_2k_denied_billed_pivot = pd.merge(Rx_with_IBD_value_less_2k_denied_billed_count_pivot, Rx_with_IBD_value_less_2k_denied_billed_revenue_pivot, on='pharmacy loc', how='left')
Rx_with_IBD_value_less_2k_denied_billed_pivot
# Out:
#   pharmacy loc  Rx count for IBD < 2k  Rx revenue for IBD < 2k($)
# 0        FL-MI                     19                    12487.93
# 1        MD-BA                      1                       83.28
# 2        NY-BK                     47                    11713.10
# 3        PA-PH                     24                    30916.06

# %%
Rx_with_IBD_value_less_2k_denied_billed_pivot.append(Rx_with_IBD_value_less_2k_denied_billed_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %%
# Rx_with_IBD_value_less_2k_denied_unbilled

# %%
Rx_with_IBD_value_less_2k_denied_unbilled = Rx_with_IBD_value_less_2k_denied[Rx_with_IBD_value_less_2k_denied['trackrx_last_status_new']=='NB']

# %%
Rx_with_IBD_value_less_2k_denied_unbilled_count_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_denied_unbilled, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_denied_unbilled_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_Denied_unbilled'}, inplace = True)
#Rx_with_IBD_value_less_2k_denied_unbilled_count_pivot

Rx_with_IBD_value_less_2k_denied_unbilled_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_denied_unbilled, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_denied_unbilled_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_Denied_unbilled'}, inplace = True)
#Rx_with_IBD_value_less_2k_denied_unbilled_revenue_pivot

Rx_with_IBD_value_less_2k_denied_unbilled_pivot = pd.merge(Rx_with_IBD_value_less_2k_denied_unbilled_count_pivot, Rx_with_IBD_value_less_2k_denied_unbilled_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_less_2k_denied_unbilled_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_Denied_unbilled  rx_revenue_IBD_Denied_unbilled
# 0        FL-MI                            77                            0.00
# 1        MD-BA                           583                         4046.25
# 2        NC-RA                             6                            0.00
# 3        NJ-SO                            64                         3508.00
# 4        NY-BK                            85                           99.33
# 5        NY-MA                           120                            0.00
# 6        PA-PH                           191                         2446.18

# %%
Rx_with_IBD_value_less_2k_denied_unbilled_pivot.append(Rx_with_IBD_value_less_2k_denied_unbilled_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %%
### Rx_with_IBD_value_less_2k_possible billed & unbilled

# %%
Rx_with_IBD_value_less_2k_possible_billed = Rx_with_IBD_value_less_2k_possible[Rx_with_IBD_value_less_2k_possible['trackrx_last_status_new']=='B']

# %%
Rx_with_IBD_value_less_2k_possible_billed_count_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_possible_billed, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_possible_billed_count_pivot.rename(columns = {'pharmacy_loc': 'pharmacy loc', 'rx_code_key_location':'Rx count for IBD < 2k'}, inplace = True)
#Rx_with_IBD_value_less_2k_possible_billed_count_pivot

Rx_with_IBD_value_less_2k_possible_billed_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_possible_billed, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_possible_billed_revenue_pivot.rename(columns = {'pharmacy_loc': 'pharmacy loc', 'rx_revenue':'Rx revenue for IBD < 2k($)'}, inplace = True)
#Rx_with_IBD_value_less_2k_possible_billed_revenue_pivot

Rx_with_IBD_value_less_2k_possible_billed_pivot = pd.merge(Rx_with_IBD_value_less_2k_possible_billed_count_pivot, Rx_with_IBD_value_less_2k_possible_billed_revenue_pivot, on='pharmacy loc', how='left')
Rx_with_IBD_value_less_2k_possible_billed_pivot
# Out:
#   pharmacy loc  Rx count for IBD < 2k  Rx revenue for IBD < 2k($)
# 0        FL-MI                    436                   600199.46
# 1        MD-BA                    655                  1261047.57
# 2        NC-RA                    296                   496547.74
# 3        NJ-SO                   2556                  3548827.06
# 4        NY-BK                   2343                  2726975.58
# 5        NY-MA                    265                   102592.46
# 6        PA-PH                    898                  1576641.15

# %%
Rx_with_IBD_value_less_2k_possible_billed_pivot.append(Rx_with_IBD_value_less_2k_possible_billed_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %%
Rx_with_IBD_value_less_2k_possible_unbilled = Rx_with_IBD_value_less_2k_possible[Rx_with_IBD_value_less_2k_possible['trackrx_last_status_new']=='NB']

# %%
Rx_with_IBD_value_less_2k_possible_unbilled_count_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_possible_unbilled, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_less_2k_possible_unbilled_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_possible_unbilled'}, inplace = True)

Rx_with_IBD_value_less_2k_possible_unbilled_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_less_2k_possible_unbilled, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_less_2k_possible_unbilled_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_possible_unbilled'}, inplace = True)

Rx_with_IBD_value_less_2k_possible_unbilled_pivot = pd.merge(Rx_with_IBD_value_less_2k_possible_unbilled_count_pivot, Rx_with_IBD_value_less_2k_possible_unbilled_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_less_2k_possible_unbilled_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_possible_unbilled  \
# 0        FL-MI                             954
# 1        MD-BA                            1302
# 2        NC-RA                             474
# 3        NJ-SO                            4323
# 4        NY-BK                            4987
# 5        NY-MA                             406
# 6        PA-PH                            2242
#
#    rx_revenue_IBD_possible_unbilled
# 0                           5584.16
# 1                          88387.94
# 2                            432.45
# 3                         111649.97
# 4                         157636.10
# 5                           1204.75
# 6                         111271.26

# %%
Rx_with_IBD_value_less_2k_possible_unbilled_pivot.append(Rx_with_IBD_value_less_2k_possible_unbilled_pivot.sum(axis=0), ignore_index=True).to_clipboard(index=False)

# %%
## Rx_with_IBD_value_greater_2k_denied billed & unbilled

# %%
Rx_with_IBD_value_greater_2k_denied_billed = Rx_with_IBD_value_greater_2k_denied[Rx_with_IBD_value_greater_2k_denied['trackrx_last_status_new']=='B']

# %%
Rx_with_IBD_value_greater_2k_denied_billed_count_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_denied_billed, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_denied_billed_count_pivot.rename(columns = {'pharmacy_loc': 'pharmacy loc','rx_code_key_location':'Rx count for IBD > 2k'}, inplace = True)
#Rx_with_IBD_value_greater_2k_denied_billed_count_pivot

Rx_with_IBD_value_greater_2k_denied_billed_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_denied_billed, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_denied_billed_revenue_pivot.rename(columns = {'pharmacy_loc': 'pharmacy loc','rx_revenue':'Rx revenue for IBD > 2k($)'}, inplace = True)
#Rx_with_IBD_value_greater_2k_denied_billed_revenue_pivot

Rx_with_IBD_value_greater_2k_denied_billed_pivot = pd.merge(Rx_with_IBD_value_greater_2k_denied_billed_count_pivot, Rx_with_IBD_value_greater_2k_denied_billed_revenue_pivot, on='pharmacy loc', how='left')
Rx_with_IBD_value_greater_2k_denied_billed_pivot
# Out:
#   pharmacy loc  Rx count for IBD > 2k  Rx revenue for IBD > 2k($)
# 0        NY-BK                      1                       14.58

# %%
Rx_with_IBD_value_greater_2k_denied_unbilled = Rx_with_IBD_value_greater_2k_denied[Rx_with_IBD_value_greater_2k_denied['trackrx_last_status_new']=='NB']

# %%
Rx_with_IBD_value_greater_2k_denied_unbilled_count_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_denied_unbilled, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_denied_unbilled_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_denied_unbilled'}, inplace = True)

Rx_with_IBD_value_greater_2k_denied_unbilled_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_denied_unbilled, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_denied_unbilled_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_denied_unbilled'}, inplace = True)

Rx_with_IBD_value_greater_2k_denied_unbilled_pivot = pd.merge(Rx_with_IBD_value_greater_2k_denied_unbilled_count_pivot, Rx_with_IBD_value_greater_2k_denied_unbilled_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_greater_2k_denied_unbilled_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_denied_unbilled  rx_revenue_IBD_denied_unbilled
# 0        MD-BA                            69                             0.0
# 1        NJ-SO                             7                          3508.0
# 2        NY-BK                             6                             0.0
# 3        NY-MA                             6                             0.0
# 4        PA-PH                            12                             0.0

# %%
Rx_with_IBD_value_greater_2k_denied_unbilled_pivot.append(Rx_with_IBD_value_greater_2k_denied_unbilled_pivot.sum(axis=0),ignore_index=True).to_clipboard(index=False)

# %%
## Rx_with_IBD_value_greater_2k_possible billed & unbilled

# %%
Rx_with_IBD_value_greater_2k_possible_billed = Rx_with_IBD_value_greater_2k_possible[Rx_with_IBD_value_greater_2k_possible['trackrx_last_status_new']=='B']

# %%
Rx_with_IBD_value_greater_2k_possible_billed_count_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_possible_billed, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_possible_billed_count_pivot.rename(columns = {'pharmacy_loc':'pharmacy loc','rx_code_key_location':'Rx count for IBD > 2k'}, inplace = True)
#Rx_with_IBD_value_greater_2k_possible_billed_count_pivot

Rx_with_IBD_value_greater_2k_possible_billed_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_possible_billed, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_possible_billed_revenue_pivot.rename(columns = {'pharmacy_loc':'pharmacy loc', 'rx_revenue':'Rx revenue for IBD > 2k($)'}, inplace = True)
#Rx_with_IBD_value_greater_2k_possible_billed_revenue_pivot

Rx_with_IBD_value_greater_2k_possible_billed_pivot = pd.merge(Rx_with_IBD_value_greater_2k_possible_billed_count_pivot, Rx_with_IBD_value_greater_2k_possible_billed_revenue_pivot, on='pharmacy loc', how='left')
Rx_with_IBD_value_greater_2k_possible_billed_pivot
# Out:
#   pharmacy loc  Rx count for IBD > 2k  Rx revenue for IBD > 2k($)
# 0        MD-BA                     89                   420814.52
# 1        NC-RA                      9                    56229.31
# 2        NJ-SO                     70                   304733.54
# 3        NY-BK                    225                  1042447.24
# 4        NY-MA                      8                     9107.78
# 5        PA-PH                     80                   257058.36

# %%
Rx_with_IBD_value_greater_2k_possible_billed_pivot.append(Rx_with_IBD_value_greater_2k_possible_billed_pivot.sum(axis=0),ignore_index=True).to_clipboard(index=False)

# %%
Rx_with_IBD_value_greater_2k_possible_unbilled = Rx_with_IBD_value_greater_2k_possible[Rx_with_IBD_value_greater_2k_possible['trackrx_last_status_new']=='NB']

# %%
Rx_with_IBD_value_greater_2k_possible_unbilled_count_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_possible_unbilled, values = ['rx_code_key_location'], index = ['pharmacy_loc'], aggfunc = 'count').reset_index()
Rx_with_IBD_value_greater_2k_possible_unbilled_count_pivot.rename(columns = {'rx_code_key_location':'rx_count_IBD_possible_unbilled'}, inplace = True)

Rx_with_IBD_value_greater_2k_possible_unbilled_revenue_pivot = pd.pivot_table(Rx_with_IBD_value_greater_2k_possible_unbilled, values = ['rx_revenue'], index = ['pharmacy_loc'], aggfunc = 'sum').reset_index()
Rx_with_IBD_value_greater_2k_possible_unbilled_revenue_pivot.rename(columns = {'rx_revenue':'rx_revenue_IBD_possible_unbilled'}, inplace = True)

Rx_with_IBD_value_greater_2k_possible_unbilled_pivot = pd.merge(Rx_with_IBD_value_greater_2k_possible_unbilled_count_pivot, Rx_with_IBD_value_greater_2k_possible_unbilled_revenue_pivot, on='pharmacy_loc', how='left')
Rx_with_IBD_value_greater_2k_possible_unbilled_pivot
# Out:
#   pharmacy_loc  rx_count_IBD_possible_unbilled  \
# 0        MD-BA                             292
# 1        NC-RA                              19
# 2        NJ-SO                             200
# 3        NY-BK                             405
# 4        NY-MA                              36
# 5        PA-PH                             437
#
#    rx_revenue_IBD_possible_unbilled
# 0                          61365.64
# 1                              0.00
# 2                          15143.40
# 3                         109531.29
# 4                              0.00
# 5                         105330.09

# %%
#final data frames for Count & Revenue

# %% [raw]
# # IBD denied count

# %% [raw]
# Rx_with_IBD_value_greater_2k_possible_unbilled_pivot.append(Rx_with_IBD_value_greater_2k_possible_unbilled_pivot.sum(axis=0),ignore_index=True)

# %% [raw]
# IBD_denied_count_less_and_greater_than_2k = pd.merge(Rx_with_IBD_value_less_2k_denied_billed_count_pivot, Rx_with_IBD_value_greater_2k_denied_billed_count_pivot, on = 'pharmacy loc', how = 'outer')
# IBD_denied_count_less_and_greater_than_2k = IBD_denied_count_less_and_greater_than_2k.append(IBD_denied_count_less_and_greater_than_2k.sum(axis = 0), ignore_index = True)
# IBD_denied_count_less_and_greater_than_2k.iloc[[len(IBD_denied_count_less_and_greater_than_2k)-1],[0]] = 'Overall'
# IBD_denied_count_less_and_greater_than_2k = IBD_denied_count_less_and_greater_than_2k.fillna(0)
# IBD_denied_count_less_and_greater_than_2k = IBD_denied_count_less_and_greater_than_2k.set_index('pharmacy loc')
# IBD_denied_count_less_and_greater_than_2k = IBD_denied_count_less_and_greater_than_2k[IBD_denied_count_less_and_greater_than_2k.columns[:]].div(6,0).astype(int)
# IBD_denied_count_less_and_greater_than_2k

# %% [raw]
# #IBD_denied_count_less_and_greater_than_2k = IBD_denied_count_less_and_greater_than_2k.fillna(0)
# #IBD_denied_count_less_and_greater_than_2k = IBD_denied_count_less_and_greater_than_2k.set_index('pharmacy loc')
# IBD_denied_count_less_and_greater_than_2k['Total Count'] = IBD_denied_count_less_and_greater_than_2k[['Rx count for IBD < 2k', 'Rx count for IBD > 2k']].sum(axis=1)
# IBD_denied_count_less_and_greater_than_2k['Rx count for IBD < 2k %'] = round(IBD_denied_count_less_and_greater_than_2k['Rx count for IBD < 2k']/IBD_denied_count_less_and_greater_than_2k['Total Count']*100,0).astype(int)
# IBD_denied_count_less_and_greater_than_2k['Rx count for IBD > 2k %'] = round(IBD_denied_count_less_and_greater_than_2k['Rx count for IBD > 2k']/IBD_denied_count_less_and_greater_than_2k['Total Count']*100,0).astype(int)
# IBD_denied_count_less_and_greater_than_2k

# %% [raw]
# IBD_denied_count_less_and_greater_than_2k_final = IBD_denied_count_less_and_greater_than_2k[['Total Count', 'Rx count for IBD < 2k', 'Rx count for IBD < 2k %', 'Rx count for IBD > 2k', 'Rx count for IBD > 2k %']]
# #IBD_denied_count_less_and_greater_than_2k_final = IBD_denied_count_less_and_greater_than_2k_final.set_index('pharmacy loc')
# IBD_denied_count_less_and_greater_than_2k_final = IBD_denied_count_less_and_greater_than_2k_final.rename(columns = {'Rx count for IBD < 2k %': ' %', 'Rx count for IBD > 2k %': '% '})
# IBD_denied_count_less_and_greater_than_2k_final

# %% [raw]
# for i in IBD_denied_count_less_and_greater_than_2k_final.columns:
#     IBD_denied_count_less_and_greater_than_2k_final[i] = IBD_denied_count_less_and_greater_than_2k_final[i].astype(int)

# %% [raw]
# subset_value = (IBD_denied_count_less_and_greater_than_2k_final.index.to_list()[:-1], ['Rx count for IBD < 2k', 'Rx count for IBD > 2k'])
# df_style3 = IBD_denied_count_less_and_greater_than_2k_final.style.set_properties(**{'text-align': 'center','border-color':'white','border-width':'thin','border-style':'solid'}).background_gradient(cmap='RdYlGn',axis=1, subset = subset_value).format("{:,}")
# df_style3

# %% [raw]
# # dfi.export(df_style3, ibd_images+'ibd_denied_count_less_and_greater_than_2k_final_new.png')

# %% [raw]
# # IBD denied revenue

# %% [raw]
# IBD_denied_revenue_less_and_greater_than_2k = pd.merge(Rx_with_IBD_value_less_2k_denied_billed_revenue_pivot, Rx_with_IBD_value_greater_2k_denied_billed_revenue_pivot, on = 'pharmacy loc', how = 'outer')
# IBD_denied_revenue_less_and_greater_than_2k = IBD_denied_revenue_less_and_greater_than_2k.append(IBD_denied_revenue_less_and_greater_than_2k.sum(axis = 0), ignore_index = True)
# IBD_denied_revenue_less_and_greater_than_2k.iloc[[len(IBD_denied_revenue_less_and_greater_than_2k)-1],[0]] = 'Overall'
# IBD_denied_revenue_less_and_greater_than_2k = IBD_denied_revenue_less_and_greater_than_2k.fillna(0)
# IBD_denied_revenue_less_and_greater_than_2k = IBD_denied_revenue_less_and_greater_than_2k.set_index('pharmacy loc')
# IBD_denied_revenue_less_and_greater_than_2k = IBD_denied_revenue_less_and_greater_than_2k.astype(int)
# IBD_denied_revenue_less_and_greater_than_2k = IBD_denied_revenue_less_and_greater_than_2k[IBD_denied_revenue_less_and_greater_than_2k.columns[:]].div(6,0).astype(int)
# IBD_denied_revenue_less_and_greater_than_2k

# %% [raw]
# IBD_denied_revenue_less_and_greater_than_2k['Total Revenue($)'] = IBD_denied_revenue_less_and_greater_than_2k[['Rx revenue for IBD < 2k($)', 'Rx revenue for IBD > 2k($)']].sum(axis=1)
# IBD_denied_revenue_less_and_greater_than_2k['Rx revenue for IBD < 2k %'] = round(IBD_denied_revenue_less_and_greater_than_2k['Rx revenue for IBD < 2k($)']/IBD_denied_revenue_less_and_greater_than_2k['Total Revenue($)']*100,0).astype(int)
# IBD_denied_revenue_less_and_greater_than_2k['Rx revenue for IBD > 2k %'] = round(IBD_denied_revenue_less_and_greater_than_2k['Rx revenue for IBD > 2k($)']/IBD_denied_revenue_less_and_greater_than_2k['Total Revenue($)']*100,0).astype(int)
# IBD_denied_revenue_less_and_greater_than_2k

# %% [raw]
# IBD_denied_revenue_less_and_greater_than_2k_final = IBD_denied_revenue_less_and_greater_than_2k[['Total Revenue($)', 'Rx revenue for IBD < 2k($)', 'Rx revenue for IBD < 2k %', 'Rx revenue for IBD > 2k($)', 'Rx revenue for IBD > 2k %']]
# #IBD_denied_revenue_less_and_greater_than_2k_final = IBD_denied_revenue_less_and_greater_than_2k_final.set_index('pharmacy loc')
# IBD_denied_revenue_less_and_greater_than_2k_final = IBD_denied_revenue_less_and_greater_than_2k_final.rename(columns = {'Rx revenue for IBD < 2k %': ' %', 'Rx revenue for IBD > 2k %': '% '})
# IBD_denied_revenue_less_and_greater_than_2k_final

# %% [raw]
# for i in IBD_denied_revenue_less_and_greater_than_2k_final.columns:
#     IBD_denied_revenue_less_and_greater_than_2k_final[i] = IBD_denied_revenue_less_and_greater_than_2k_final[i].astype(int)

# %% [raw]
# subset_value = (IBD_denied_revenue_less_and_greater_than_2k_final.index.to_list()[:-1], ['Rx revenue for IBD < 2k($)', 'Rx revenue for IBD > 2k($)'])
# df_style4 = IBD_denied_revenue_less_and_greater_than_2k_final.style.set_properties(**{'text-align': 'center','border-color':'white','border-width':'thin','border-style':'solid'}).background_gradient(cmap='RdYlGn',axis=1, subset = subset_value).format("{:,}")
# # dfi.export(df_style4, ibd_images+'ibd_denied_revenue_less_and_greater_than_2k_final_new.png')
# df_style4

# %% [raw]
# # IBD not possible count

# %% [raw]
# IBD_not_possible_count_less_and_greater_than_2k = pd.merge(Rx_with_IBD_value_less_2k_possible_billed_count_pivot, Rx_with_IBD_value_greater_2k_possible_billed_count_pivot, on = 'pharmacy loc', how = 'outer')
# IBD_not_possible_count_less_and_greater_than_2k = IBD_not_possible_count_less_and_greater_than_2k.append(IBD_not_possible_count_less_and_greater_than_2k.sum(axis = 0), ignore_index = True)
# IBD_not_possible_count_less_and_greater_than_2k = IBD_not_possible_count_less_and_greater_than_2k.fillna(0)
# IBD_not_possible_count_less_and_greater_than_2k.iloc[[7],[0]] = 'Overall'
# IBD_not_possible_count_less_and_greater_than_2k = IBD_not_possible_count_less_and_greater_than_2k.set_index('pharmacy loc')
# IBD_not_possible_count_less_and_greater_than_2k = IBD_not_possible_count_less_and_greater_than_2k[IBD_not_possible_count_less_and_greater_than_2k.columns[:]].div(6,0).astype(int)
# IBD_not_possible_count_less_and_greater_than_2k['Total count'] = IBD_not_possible_count_less_and_greater_than_2k[['Rx count for IBD < 2k', 'Rx count for IBD > 2k']].sum(axis=1)
# IBD_not_possible_count_less_and_greater_than_2k

# %% [raw]
# #IBD_not_possible_count_less_and_greater_than_2k['Total count'] = IBD_not_possible_count_less_and_greater_than_2k[['Rx count for IBD < 2k', 'Rx count for IBD > 2k']].sum(axis=1)
# IBD_not_possible_count_less_and_greater_than_2k['Rx count for IBD < 2k %'] = round(IBD_not_possible_count_less_and_greater_than_2k['Rx count for IBD < 2k']/IBD_not_possible_count_less_and_greater_than_2k['Total count']*100,0).astype(int)
# IBD_not_possible_count_less_and_greater_than_2k['Rx count for IBD > 2k %'] = round(IBD_not_possible_count_less_and_greater_than_2k['Rx count for IBD > 2k']/IBD_not_possible_count_less_and_greater_than_2k['Total count']*100,0).astype(int)
# IBD_not_possible_count_less_and_greater_than_2k

# %% [raw]
# IBD_not_possible_count_less_and_greater_than_2k_final = IBD_not_possible_count_less_and_greater_than_2k[['Total count', 'Rx count for IBD < 2k', 'Rx count for IBD < 2k %', 'Rx count for IBD > 2k', 'Rx count for IBD > 2k %']]
# #IBD_not_possible_count_less_and_greater_than_2k_final = IBD_not_possible_count_less_and_greater_than_2k_final.set_index('pharmacy loc')
# IBD_not_possible_count_less_and_greater_than_2k_final = IBD_not_possible_count_less_and_greater_than_2k_final.rename(columns = {'Rx count for IBD < 2k %': ' %', 'Rx count for IBD > 2k %': '% '})
# IBD_not_possible_count_less_and_greater_than_2k_final

# %% [raw]
# subset_value = (IBD_not_possible_count_less_and_greater_than_2k_final.index.to_list()[:-1], ['Rx count for IBD < 2k', 'Rx count for IBD > 2k'])
# df_style5 = IBD_not_possible_count_less_and_greater_than_2k_final.style.set_properties(**{'text-align': 'center','border-color':'white','border-width':'thin','border-style':'solid'}).background_gradient(cmap='RdYlGn',axis=1, subset = subset_value).format("{:,}")
# # dfi.export(df_style5, ibd_images+'ibd_not_possible_count_less_and_greater_than_2k_final_new.png')
# df_style5

# %% [raw]
# # IBD not possible revenue

# %% [raw]
# IBD_not_possible_revenue_less_and_greater_than_2k = pd.merge(Rx_with_IBD_value_less_2k_possible_billed_revenue_pivot, Rx_with_IBD_value_greater_2k_possible_billed_revenue_pivot, on = 'pharmacy loc', how = 'outer')
# IBD_not_possible_revenue_less_and_greater_than_2k = IBD_not_possible_revenue_less_and_greater_than_2k.append(IBD_not_possible_revenue_less_and_greater_than_2k.sum(axis = 0), ignore_index = True)
# IBD_not_possible_revenue_less_and_greater_than_2k = IBD_not_possible_revenue_less_and_greater_than_2k.fillna(0)
# IBD_not_possible_revenue_less_and_greater_than_2k.iloc[[len(IBD_not_possible_revenue_less_and_greater_than_2k)-1],[0]] = 'Overall'
#
# IBD_not_possible_revenue_less_and_greater_than_2k = IBD_not_possible_revenue_less_and_greater_than_2k.set_index('pharmacy loc')
# IBD_not_possible_revenue_less_and_greater_than_2k = IBD_not_possible_revenue_less_and_greater_than_2k[IBD_not_possible_revenue_less_and_greater_than_2k.columns[:]].div(6,0).astype(int)
# IBD_not_possible_revenue_less_and_greater_than_2k

# %% [raw]
# IBD_not_possible_revenue_less_and_greater_than_2k['Total Revenue ($)'] = IBD_not_possible_revenue_less_and_greater_than_2k[['Rx revenue for IBD < 2k($)', 'Rx revenue for IBD > 2k($)']].sum(axis=1)
# IBD_not_possible_revenue_less_and_greater_than_2k['Rx revenue for IBD < 2k %'] = round(IBD_not_possible_revenue_less_and_greater_than_2k['Rx revenue for IBD < 2k($)']/IBD_not_possible_revenue_less_and_greater_than_2k['Total Revenue ($)']*100,0).astype(int)
# IBD_not_possible_revenue_less_and_greater_than_2k['Rx revenue for IBD > 2k %'] = round(IBD_not_possible_revenue_less_and_greater_than_2k['Rx revenue for IBD > 2k($)']/IBD_not_possible_revenue_less_and_greater_than_2k['Total Revenue ($)']*100,0).astype(int)
# IBD_not_possible_revenue_less_and_greater_than_2k

# %% [raw]
# IBD_not_possible_revenue_less_and_greater_than_2k_final = IBD_not_possible_revenue_less_and_greater_than_2k[['Total Revenue ($)', 'Rx revenue for IBD < 2k($)', 'Rx revenue for IBD < 2k %', 'Rx revenue for IBD > 2k($)', 'Rx revenue for IBD > 2k %']]
# #IBD_not_possible_revenue_less_and_greater_than_2k_final = IBD_not_possible_revenue_less_and_greater_than_2k_final.set_index('pharmacy loc')
# IBD_not_possible_revenue_less_and_greater_than_2k_final = IBD_not_possible_revenue_less_and_greater_than_2k_final.rename(columns = {'Rx revenue for IBD < 2k %': ' %', 'Rx revenue for IBD > 2k %': '% '})
# IBD_not_possible_revenue_less_and_greater_than_2k_final

# %% [raw]
# for i in IBD_not_possible_revenue_less_and_greater_than_2k_final.columns:
#     IBD_not_possible_revenue_less_and_greater_than_2k_final[i] = IBD_not_possible_revenue_less_and_greater_than_2k_final[i].astype(int)

# %% [raw]
# subset_value = (IBD_not_possible_revenue_less_and_greater_than_2k_final.index.to_list()[:-1], ['Rx revenue for IBD < 2k($)', 'Rx revenue for IBD > 2k($)'])
# df_style6 = IBD_not_possible_revenue_less_and_greater_than_2k_final.style.set_properties(**{'text-align': 'center','border-color':'white','border-width':'thin','border-style':'solid'}).background_gradient(cmap='RdYlGn',axis=1, subset = subset_value).format("{:,}")
# # dfi.export(df_style6, ibd_images+'ibd_not_possible_revenue_less_and_greater_than_2k_final_new.png')
# df_style6
