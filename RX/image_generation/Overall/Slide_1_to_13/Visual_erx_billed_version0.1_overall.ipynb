# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')
from datetime import date
from dateutil.relativedelta import relativedelta
import dataframe_image as dfi
from adjustText import adjust_text

plt.rcParams['font.family'] = 'Nunito'
plt.rcParams['font.size'] = 10

# %%
color_code = ['#80ADF7','#EFBA50']
font_name = 'Nunito'
font_size = 10
font_size_title = 12
font_weight = 'bold'
orange_color = '#EFBA50'
blue_color = '#80ADF7'
grey_color = '#B0BCC8'
green_color = '#9EEDE0'
red_color = '#FD7284'
# color_code2 = [blue_color, grey_color]

background_color = "#F1F1F1"
border_color = "#B0BCC8"
text_align = 'center'
border_width ="0.5px"
border_style = 'solid'
body_design = {'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align}
body_design2 = {'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align,'width':'70px'}
body_design3 = { 'background' : "white", 'color' : 'black',  'border-color' : border_color, 'border-width' : border_width, 'border-style' : border_style,'font-family':font_name,'font-size':font_size,'text-align':text_align,'width':'120px'}

border_design = {'selector': 'th', 'props': [('background-color' , background_color),('border-style' ,border_style),('font-family',font_name),('font-size',font_size),('border-width',border_width),('text-align',text_align),('border-color',border_color)]}
bar_width=0.5

# %%
# %run operations_utils.py

# %%
# %run path_changer_overall.py

# %%
df = pd.read_csv(source_file_path + "rx_flow_dec21.csv") #change

# %%
df2 = pd.read_excel("C:/Users/vidhi.mittal/Downloads/columns.xlsx")

# %%
df2 = df2.head(224)
df2.head()
# Out:
#     Old column names  Filter         New_column  Unnamed: 3  \
# 0         Unnamed: 0     NaN                NaN         NaN
# 1  pharmacy_location     1.0  pharmacy_location         NaN
# 2               rxno     1.0               rxno         NaN
# 3            presnpi     1.0            presnpi         NaN
# 4                ndc     1.0                ndc         NaN
#
#         final_names2  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                NaN         NaN         NaN         NaN         NaN
# 1  pharmacy_location         NaN         NaN         NaN         NaN
# 2               rxno         NaN         NaN         NaN         NaN
# 3            presnpi         NaN         NaN         NaN         NaN
# 4                ndc         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0         NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN
#
#                      Dec-21 file        final_names
# 0                     Unnamed: 0         Unnamed: 0
# 1  pharmacy_location_rxtimelines  pharmacy_location
# 2               rxno_rxtimelines               rxno
# 3            presnpi_rxtimelines            presnpi
# 4                ndc_rxtimelines                ndc

# %%
var = list(df2['final_names'].values)

# %%
df.columns = var
df.head(2)
# Out:
#    Unnamed: 0 pharmacy_location       rxno     presnpi          ndc  \
# 0           0             NY-BK  1157987-0  1871998476  75987004005
# 1           1             NJ-SO  1199550-0  1417203928  50222030260
#
#   trackrx_status  patientno          erxreceived      rx_entered_date  \
# 0              F     620373  2021-12-09 12:31:00  2021-12-09 12:39:00
# 1              B      77426  2021-10-15 14:03:00  2021-10-15 17:34:00
#
#   rx_entered_date_verification     rx_filledon_date     rx_pickedup_date  \
# 0          2021-12-09 12:39:00  2021-12-31 13:00:00                  NaN
# 1          2021-10-15 17:34:00  2021-11-30 11:46:08  2021-12-02 00:00:00
#
#   rx_delivered_date   rx_labelprint_date     rx_drugpick_date  \
# 0               NaN  2021-12-14 10:39:55  2021-12-14 10:02:00
# 1               NaN  2021-11-30 18:50:21  2021-11-30 18:54:00
#
#        rx_rphpick_date             last_run rx_code_key_location       nabp  \
# 0  2021-12-14 10:40:08  2022-01-09 01:21:07      NY-BK-1157987-0  3352779.0
# 1  2021-12-01 09:25:19  2022-01-09 01:21:07      NJ-SO-1199550-0  3135868.0
#
#      first_billed_date     last_billed_date     processing_start  \
# 0  2021-12-13 09:41:32  2021-12-31 15:31:15  2021-12-09 12:39:24
# 1  2021-11-06 09:01:57  2021-11-30 13:08:06  2021-10-15 18:59:55
#
#         processing_end       IBD IN PROCESS IBD FIDELIS  IBD REQUIRED  \
# 0  2022-01-08 12:42:41                  NaN         NaN           NaN
# 1  2022-01-08 15:14:31  2021-11-01 16:07:54         NaN           NaN
#
#    IBD $2K+  IBD IS $2K+  IBD 2K  IBD IS 2K IBD SPECIALITY  \
# 0       NaN          NaN     NaN        NaN            NaN
# 1       NaN          NaN     NaN        NaN            NaN
#
#                    IBD          IBD REGULAR         TO BE BILLED CALL FOR INS  \
# 0  2021-12-09 15:21:57                  NaN  2021-12-13 09:38:39          NaN
# 1  2021-11-01 16:07:54  2021-10-29 10:29:38  2021-10-18 09:53:58          NaN
#
#   CALL FOR INS (KOREAN/CH) CALL FOR INS DAY 2 CALL FOR INS DAY 3  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
#
#   CALL FOR INS (KOREAN/CHINESE) CAL FOR INS (KOREAN/CHINESE)  is_pickedup  \
# 0                           NaN                          NaN        False
# 1                           NaN                          NaN        False
#
#    is_eRx trackrx_statusflow trackrx_last_status_tag trackrx_last_delivery  \
# 0    True         U->B->U->F                       F                   NaN
# 1    True   U->B->U->F->U->B                       B                     D
#
#   trackrx_delivery_flow trackrx_pickuptime_flow trackrx_pickedup_flow  \
# 0                   NaN                     NaN                   ->N
# 1               None->D           None->3:32 PM                ->N->Y
#
#   trackrx_last_pickuped trackrx_last_ibdtag trackrx_last_callinstag  \
# 0                     N          TIME STUDY                     NaN
# 1                     Y                   0                     NaN
#
#     end_filed_datetime trackrx_callins_processing_start  \
# 0  2022-01-08 12:16:15                              NaN
# 1  2021-11-19 11:46:07                              NaN
#
#   ibd_processing_enddatetime trackrx_ibd_processing_start  \
# 0                        NaN          2021-12-09 12:44:54
# 1        2021-11-06 09:04:28          2021-10-18 11:09:31
#
#   time_consumed_ibd_regular  times_processed_ibd_regular status_ibd_regular  \
# 0           0 days 02:37:03                          1.0          completed
# 1           3 days 06:57:30                          2.0          completed
#
#   time_consumed_ibd_2K  times_processed_ibd_2K status_ibd_2K  \
# 0                  NaN                     NaN           NaN
# 1                  NaN                     NaN           NaN
#
#   total_processing_time_ibd  times_processed_ibd ibd_final_status  \
# 0                       NaN                  NaN              NaN
# 1           4 days 16:56:34                  1.0        completed
#
#   time_consumed_callforins_day01  times_processed_callforins_day01  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
#
#   status_callforins_day01 time_consumed_callforins_day02  \
# 0                     NaN                            NaN
# 1                     NaN                            NaN
#
#    times_processed_callforins_day02 status_callforins_day02  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
#
#   time_consumed_callforins_day03  times_processed_callforins_day03  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
#
#   status_callforins_day03 city datef DRUGNAME  QTY PATIENTCOPAY  TOTALINSPAID  \
# 0                     NaN  NaN   NaN      NaN  NaN          NaN           NaN
# 1                     NaN  NaN   NaN      NaN  NaN          NaN           NaN
#
#   PATZIP PATDOB INSCODE DATEO PATFNAME PATLNAME patmobileno patphone patsex  \
# 0    NaN    NaN     NaN   NaN      NaN      NaN         NaN      NaN    NaN
# 1    NaN    NaN     NaN   NaN      NaN      NaN         NaN      NaN    NaN
#
#    totalrxamount  patientno_mms workflow_last_status  \
# 0            NaN            NaN                  NaN
# 1            NaN            NaN  PICKED UP/DELIVERED
#
#   workflow_last_change_datetime cxrev_last_datetime  times_cx_reversed  \
# 0           2021-12-17 13:00:43                 NaN                NaN
# 1           2021-12-01 13:59:47                 NaN                NaN
#
#   delrev_last_datetime times_del_reversed batchno batchcreatedon  \
# 0                  NaN                NaN     NaN            NaN
# 1                  NaN                NaN     NaN            NaN
#
#   batchclosedon deliverydate driver phone patient_phone_x batch_delivery_date  \
# 0           NaN          NaN    NaN   NaN             NaN                 NaN
# 1           NaN          NaN    NaN   NaN             NaN                 NaN
#
#   batch_delivery_datetime batch_creation_datetime batch_id  \
# 0                     NaN                     NaN      NaN
# 1                     NaN                     NaN      NaN
#
#    no_times_batch_created delivery_date shortId_of status  patient_phone_y  \
# 0                     NaN           NaN        NaN    NaN              NaN
# 1                     NaN           NaN        NaN    NaN              NaN
#
#    patient_zipcode delivery_time  Driver Number didSucceed match_method  \
# 0              NaN           NaN            NaN        NaN          NaN
# 1              NaN           NaN            NaN        NaN          NaN
#
#   rx_no_fill zone_name  delivery_patient_zip_code  \
# 0        NaN       NaN                        NaN
# 1  1199550-0    Zone 3                     7083.0
#
#   dl_app_delivery_created_time dl_app_delivery_time onfleet_short_id  \
# 0                          NaN                  NaN              NaN
# 1          2021-11-30 19:39:44  2021-12-02 23:44:20         183e0ac3
#
#    delivery_id               driver_name onfleet_state pharmacy_location_dl  \
# 0          NaN                       NaN           NaN                  NaN
# 1     201092.0  HealthEx Day of Delivery     COMPLETED                NJ-SO
#
#    pharmacy_nabp rx_no_fill_px       task_completed           slot_start  \
# 0            NaN           NaN                  NaN                  NaN
# 1      3135868.0     1199550-0  2021-11-30 23:39:40  2021-12-02 21:00:00
#
#               slot_end pharmacy_location_px refill_tag   new_delivered_date  \
# 0                  NaN                  NaN        New                  NaN
# 1  2021-12-03 00:00:00                NJ-SO        New  2021-12-02 23:44:20
#
#    PATPHONE_len  PATMOBILENO_len shortId_mms new_shortId status_tag  \
# 0             3                3         NaN         NaN        NaN
# 1             3                3         NaN    183e0ac3  Delivered
#
#                                      id  rx_number           rx_status  \
# 0  c31579a5-6933-438a-8846-8bf6616b4f8c  1157987.0            Reversal
# 1  8fc27f27-0f43-4814-8361-e98d7ab6d4fb  1199550.0  Ready for delivery
#
#                              patient_id                         prescriber_id  \
# 0  f72b814b-5e01-4812-8064-e9a053b1368d  f1967c16-407b-11eb-b378-0242ac130002
# 1  74d86f09-a4f1-43ce-8aee-7dd6db2cdaec  36c74da0-b131-42b7-9fa3-cc4c5c8beb0f
#
#                            insurance_id             drug_name drug_form  \
# 0                                   NaN  Drug Name: 1157987-0       NaN
# 1  14371075-f3bf-48cc-a656-fbb379592cd5         ENSTILAR FOAM      FOAM
#
#   followup_tag  copay   amount       ndc_prsc  quantity  fill_number reversed  \
# 0          NaN   25.0    25.00       999999.0       NaN          0.0     True
# 1   NEW PX APP    4.0  1235.41  50222030260.0      60.0          0.0      NaN
#
#                    reversal_reason   reversal_fill_date  day_supply  \
# 0  Patient no longer takes this RX  2022-01-07 00:00:00         NaN
# 1                              NaN                  NaN        20.0
#
#    status_prsc           created_at                               id_task  \
# 0          NaN  2022-01-05 15:39:23  7ce9870e-35a1-4bbf-b9be-24f97fc7f688
# 1  PA_APPROVED  2021-11-30 18:16:49  44f3760e-8013-493c-a45b-08f62900a26c
#
#                               status_id                     associate_id_prsc  \
# 0  dae11221-7cde-41a7-b522-fe51a448095f  ed82bf38-485a-42ec-ab82-1c4cc6cd5157
# 1  dae11221-7cde-41a7-b522-fe51a448095f  a131a2e6-a3d3-431f-9c1d-2af6e1eea868
#
#   is_scheduled  scheduled_time error_status           claimed_at  \
# 0          NaN             NaN          NaN  2022-01-07 15:45:56
# 1         True             NaN          NaN                  NaN
#
#        created_at_task is_all_reversal_rxs         completed_at cancelled_at  \
# 0  2022-01-05 15:39:23                True  2022-01-07 15:48:44          NaN
# 1  2021-11-30 18:16:49                 NaN  2021-11-30 23:39:40          NaN
#
#   cancellation_reason  pharmacy_nabp_prsc earliest_fill_date  \
# 0                 NaN           3352779.0                NaN
# 1                 NaN           3135868.0         2021-11-30
#
#    rx_numbers_count rx_numbers_list  total_awp  days_contacted  \
# 0               1.0       1157987-0        NaN             2.0
# 1               1.0       1199550-0    1402.74             0.0
#
#    latest_contacted_at insurance_category  parent_id pharmacy_location_prsc  \
# 0  2022-01-07 15:46:13                NaN        NaN                  NY-BK
# 1                  NaN         Commercial        NaN                  NJ-SO
#
#                                   id_cv         contacted_at  \
# 0  80b7cbbd-d3fa-4a31-a193-d8c56365a7ea  2022-01-07 15:46:13
# 1                                   NaN                  NaN
#
#             outcome        created_at_cv  \
# 0  Patient answered  2022-01-07 15:46:13
# 1               NaN                  NaN
#
#                                   id_sd  \
# 0                                   NaN
# 1  6da4e431-2434-472f-b8a8-8793648b124a
#
#                                              payload status_sd  \
# 0                                                NaN       NaN
# 1  {'taskId': '44f3760e-8013-493c-a45b-08f62900a2...      sent
#
#          created_at_sd       delivery_type pickup_date_scheduled_deliveries  \
# 0                  NaN                 NaN                              NaN
# 1  2021-11-30 23:39:40  scheduled-delivery                              NaN
#
#   scheduled_startdate_scheduled_deliveries  \
# 0                                      NaN
# 1                      2021-12-02 21:00:00
#
#   scheduled_enddate_scheduled_deliveries  erxreceived_rxtimelines_boolean_d  \
# 0                                    NaN                               True
# 1                    2021-12-03 00:00:00                               True
#
#    rx_entered_date_rxtimelines_boolean_d  \
# 0                                   True
# 1                                   True
#
#    rx_entered_date_verification_boolean_d  \
# 0                                    True
# 1                                    True
#
#    rx_filledon_date_rxtimelines_boolean_d  \
# 0                                    True
# 1                                    True
#
#    rx_pickedup_date_rxtimelines_boolean_d  new_delivered_date_d_boolean_d  \
# 0                                   False                           False
# 1                                   False                            True
#
#    rx_labelprint_date_verification_boolean_d  \
# 0                                       True
# 1                                       True
#
#    rx_drugpick_date_verification_boolean_d  \
# 0                                     True
# 1                                     True
#
#    rx_rphpick_date_verification_boolean_d  \
# 0                                    True
# 1                                    True
#
#    first_billed_date_claimslog_boolean_d  \
# 0                                   True
# 1                                   True
#
#    last_billed_date_claimslog_boolean_d  processing_start_claimslog_boolean_d  \
# 0                                  True                                  True
# 1                                  True                                  True
#
#    processing_end_claimslog_boolean_d  current_status_rx_d  \
# 0                                True                11100
# 1                                True                11101
#
#   Overall_Visibility_for_Rx_d erxreceived_rxtimelines_ltz_d  \
# 0            Rx with only IBD     2021-12-09 07:31:00-05:00
# 1            Rx with only IBD     2021-10-15 10:03:00-04:00
#
#   rx_entered_date_rxtimelines_ltz_d first_billed_date_claimslog_ltz_d  \
# 0         2021-12-09 07:39:00-05:00         2021-12-13 04:41:32-05:00
# 1         2021-10-15 13:34:00-04:00         2021-11-06 05:01:57-04:00
#
#   last_billed_date_claimslog_ltz_d rx_drugpick_date_verification_ltz_d  \
# 0        2021-12-31 10:31:15-05:00           2021-12-14 05:02:00-05:00
# 1        2021-11-30 08:08:06-05:00           2021-11-30 13:54:00-05:00
#
#   rx_rphpick_date_verification_ltz_d pickup_date_scheduled_deliveries_ltz_d  \
# 0          2021-12-14 05:40:08-05:00                                    NaN
# 1          2021-12-01 04:25:19-05:00                                    NaN
#
#   scheduled_startdate_scheduled_deliveries_ltz_d  \
# 0                                            NaN
# 1                      2021-12-02 16:00:00-05:00
#
#   scheduled_enddate_scheduled_deliveries_ltz_d   new_delivered_date_ltz_d  \
# 0                                          NaN                        NaN
# 1                    2021-12-02 19:00:00-05:00  2021-12-02 18:44:20-05:00
#
#   created_at_contactevents_ltz_d rx_filledon_date_rxtimelines_ltz_d  \
# 0      2022-01-07 10:46:13-05:00          2021-12-31 08:00:00-05:00
# 1                            NaN          2021-11-30 06:46:08-05:00
#
#   is_rescheduled_d  rescheduling_count_d             last_run
# 0              NaN                   1.0  2022-01-10 06:31:22
# 1              NaN                   1.0  2022-01-10 06:31:22

# %%
df.is_pickedup.value_counts()
# Out:
# False    322969
# True      41720
# Name: is_pickedup, dtype: int64

# %%
def f(row):
        if row['status_tag'] == 'Delivered':
                return False
        elif row.status_tag == 'Pickedup':
                return True
        else:    
            return np.nan

# %%
df['is_pickedup'] = df.apply(f, axis = 1)

# %%
# for i in df.columns:
#     if (df[i].dtype == 'object') & (df[i].nunique() < 10):
#         print(i)
#         print(df[i].unique())
#         print("===============================================")
#     else:
#         pass

# %%
# df[['trackrx_status','status','track_erx_received','track_rx_entered','filled_datekey','track_rx_pickedup','track_rx_delivered','track_label_printed','final_rx_drug_picks','final_rx_rph_picks','first_billed_datetime','end_billed_datetime','trackrx_processing_date_starttime','PATMOBILENO','PATPHONE','TOTALRXAMOUNT','trackrx_last_status']]

# %%
df.rename(columns = {'erxreceived': 'track_erx_received',
 'rx_entered_date': 'track_rx_entered',
 'datef': 'track_rx_filled',
 'rx_filledon_date':'filled_datekey',
 'rx_pickedup_date': 'final_rx_pickedup',
 'new_delivered_date':'track_rx_delivered',
 'rx_labelprint_date': 'track_label_printed',
 'rx_drugpick_date': 'final_rx_drug_picks',
 'rx_rphpick_date': 'final_rx_rph_picks',
 'first_billed_date': 'first_billed_datetime',
 'last_billed_date': 'end_billed_datetime',
 'processing_start': 'trackrx_processing_date_starttime',
 'patmobileno': 'PATMOBILENO',
 'patphone': 'PATPHONE',
 'totalrxamount': 'TOTALRXAMOUNT',
 'trackrx_last_status_tag': 'trackrx_last_status'}, inplace = True)

# %%
# df.rename(columns = {'erxreceived': 'track_erx_received',           #'status': 'trackrx_status','status_y': 'status'
#  'rx_entered_date': 'track_rx_entered',
#  'rx_filledon_date': 'filled_datekey',
#  'rx_pickedup_date': 'track_rx_pickedup',
#   'new_delivered_date': 'track_rx_delivered',

# #  'rx_delivered_date': 'track_rx_delivered',
#  'rx_labelprint_date': 'track_label_printed',
#  'rx_drugpick_date': 'final_rx_drug_picks',
#  'rx_rphpick_date': 'final_rx_rph_picks',
#  'first_billed_date': 'first_billed_datetime',
#  'last_billed_date': 'end_billed_datetime',
#  'processing_start': 'trackrx_processing_date_starttime',
#  'patmobileno': 'PATMOBILENO',
#  'patphone': 'PATPHONE',
#  'totalrxamount': 'TOTALRXAMOUNT',
#  'trackrx_status': 'trackrx_last_status'}, inplace = True)

# %%
df['status']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 364684    NaN
# 364685    NaN
# 364686    NaN
# 364687    NaN
# 364688    NaN
# Name: status, Length: 364689, dtype: object

# %%
df['track_rx_recieved_new'] =  pd.to_datetime(df.track_erx_received, dayfirst = False)
df['track_rx_entered_new'] =  pd.to_datetime(df.track_rx_entered, dayfirst = False)
df['filled_datekey'] =  pd.to_datetime(df.filled_datekey, dayfirst = False)

# df['max_date'] = df[['track_rx_recieved_new','track_rx_entered_new']].max(axis=1)
# df['max_date_only'] = df['max_date'].dt.date
df['pharmacy_loc'] = df['rx_code_key_location'].astype(str).str[0:5]
df['mon_key'] = df['filled_datekey'].dt.strftime('%m-%y')
df['mon_key_2'] = df['filled_datekey'].dt.strftime('%b-%y')
# df = df[df['mon_key_2']!='Jan-21']

# %%
df['mon_key_2'].value_counts()
# Out:
# Sep-21    66430
# Oct-21    61721
# Nov-21    61410
# Aug-21    61322
# Dec-21    59265
# Jul-21    54541
# Name: mon_key_2, dtype: int64

# %%
df['mon_key'].min()
# Out:
# '07-21'

# %%
mon = ['Jul-21','Aug-21','Sep-21','Oct-21','Nov-21','Dec-21']  #change
df = df[df['mon_key_2'].isin(mon)] 
df['mon_key'].min()
# Out:
# '07-21'

# %%
df['mon_key'].max()
# Out:
# '12-21'

# %%
df.status.unique()
# Out:
# array([nan, 'completed'], dtype=object)

# %%
df.head(1)
# Out:
#    Unnamed: 0 pharmacy_location       rxno     presnpi          ndc  \
# 0           0             NY-BK  1157987-0  1871998476  75987004005
#
#   trackrx_status  patientno   track_erx_received     track_rx_entered  \
# 0              F     620373  2021-12-09 12:31:00  2021-12-09 12:39:00
#
#   rx_entered_date_verification      filled_datekey final_rx_pickedup  \
# 0          2021-12-09 12:39:00 2021-12-31 13:00:00               NaN
#
#   rx_delivered_date  track_label_printed  final_rx_drug_picks  \
# 0               NaN  2021-12-14 10:39:55  2021-12-14 10:02:00
#
#     final_rx_rph_picks             last_run rx_code_key_location       nabp  \
# 0  2021-12-14 10:40:08  2022-01-09 01:21:07      NY-BK-1157987-0  3352779.0
#
#   first_billed_datetime  end_billed_datetime  \
# 0   2021-12-13 09:41:32  2021-12-31 15:31:15
#
#   trackrx_processing_date_starttime       processing_end IBD IN PROCESS  \
# 0               2021-12-09 12:39:24  2022-01-08 12:42:41            NaN
#
#   IBD FIDELIS  IBD REQUIRED  IBD $2K+  IBD IS $2K+  IBD 2K  IBD IS 2K  \
# 0         NaN           NaN       NaN          NaN     NaN        NaN
#
#   IBD SPECIALITY                  IBD IBD REGULAR         TO BE BILLED  \
# 0            NaN  2021-12-09 15:21:57         NaN  2021-12-13 09:38:39
#
#   CALL FOR INS CALL FOR INS (KOREAN/CH) CALL FOR INS DAY 2 CALL FOR INS DAY 3  \
# 0          NaN                      NaN                NaN                NaN
#
#   CALL FOR INS (KOREAN/CHINESE) CAL FOR INS (KOREAN/CHINESE) is_pickedup  \
# 0                           NaN                          NaN         NaN
#
#    is_eRx trackrx_statusflow trackrx_last_status trackrx_last_delivery  \
# 0    True         U->B->U->F                   F                   NaN
#
#   trackrx_delivery_flow trackrx_pickuptime_flow trackrx_pickedup_flow  \
# 0                   NaN                     NaN                   ->N
#
#   trackrx_last_pickuped trackrx_last_ibdtag trackrx_last_callinstag  \
# 0                     N          TIME STUDY                     NaN
#
#     end_filed_datetime trackrx_callins_processing_start  \
# 0  2022-01-08 12:16:15                              NaN
#
#   ibd_processing_enddatetime trackrx_ibd_processing_start  \
# 0                        NaN          2021-12-09 12:44:54
#
#   time_consumed_ibd_regular  times_processed_ibd_regular status_ibd_regular  \
# 0           0 days 02:37:03                          1.0          completed
#
#   time_consumed_ibd_2K  times_processed_ibd_2K status_ibd_2K  \
# 0                  NaN                     NaN           NaN
#
#   total_processing_time_ibd  times_processed_ibd ibd_final_status  \
# 0                       NaN                  NaN              NaN
#
#   time_consumed_callforins_day01  times_processed_callforins_day01  \
# 0                            NaN                               NaN
#
#   status_callforins_day01 time_consumed_callforins_day02  \
# 0                     NaN                            NaN
#
#    times_processed_callforins_day02 status_callforins_day02  \
# 0                               NaN                     NaN
#
#   time_consumed_callforins_day03  times_processed_callforins_day03  \
# 0                            NaN                               NaN
#
#   status_callforins_day03 city track_rx_filled DRUGNAME  QTY PATIENTCOPAY  \
# 0                     NaN  NaN             NaN      NaN  NaN          NaN
#
#    TOTALINSPAID PATZIP PATDOB INSCODE DATEO PATFNAME PATLNAME PATMOBILENO  \
# 0           NaN    NaN    NaN     NaN   NaN      NaN      NaN         NaN
#
#   PATPHONE patsex  TOTALRXAMOUNT  patientno_mms workflow_last_status  \
# 0      NaN    NaN            NaN            NaN                  NaN
#
#   workflow_last_change_datetime cxrev_last_datetime  times_cx_reversed  \
# 0           2021-12-17 13:00:43                 NaN                NaN
#
#   delrev_last_datetime times_del_reversed batchno batchcreatedon  \
# 0                  NaN                NaN     NaN            NaN
#
#   batchclosedon deliverydate driver phone patient_phone_x batch_delivery_date  \
# 0           NaN          NaN    NaN   NaN             NaN                 NaN
#
#   batch_delivery_datetime batch_creation_datetime batch_id  \
# 0                     NaN                     NaN      NaN
#
#    no_times_batch_created delivery_date shortId_of status  patient_phone_y  \
# 0                     NaN           NaN        NaN    NaN              NaN
#
#    patient_zipcode delivery_time  Driver Number didSucceed match_method  \
# 0              NaN           NaN            NaN        NaN          NaN
#
#   rx_no_fill zone_name  delivery_patient_zip_code  \
# 0        NaN       NaN                        NaN
#
#   dl_app_delivery_created_time dl_app_delivery_time onfleet_short_id  \
# 0                          NaN                  NaN              NaN
#
#    delivery_id driver_name onfleet_state pharmacy_location_dl  pharmacy_nabp  \
# 0          NaN         NaN           NaN                  NaN            NaN
#
#   rx_no_fill_px task_completed slot_start slot_end pharmacy_location_px  \
# 0           NaN            NaN        NaN      NaN                  NaN
#
#   refill_tag track_rx_delivered  PATPHONE_len  PATMOBILENO_len shortId_mms  \
# 0        New                NaN             3                3         NaN
#
#   new_shortId status_tag                                    id  rx_number  \
# 0         NaN        NaN  c31579a5-6933-438a-8846-8bf6616b4f8c  1157987.0
#
#   rx_status                            patient_id  \
# 0  Reversal  f72b814b-5e01-4812-8064-e9a053b1368d
#
#                           prescriber_id insurance_id             drug_name  \
# 0  f1967c16-407b-11eb-b378-0242ac130002          NaN  Drug Name: 1157987-0
#
#   drug_form followup_tag  copay  amount  ndc_prsc  quantity  fill_number  \
# 0       NaN          NaN   25.0    25.0  999999.0       NaN          0.0
#
#   reversed                  reversal_reason   reversal_fill_date  day_supply  \
# 0     True  Patient no longer takes this RX  2022-01-07 00:00:00         NaN
#
#   status_prsc           created_at                               id_task  \
# 0         NaN  2022-01-05 15:39:23  7ce9870e-35a1-4bbf-b9be-24f97fc7f688
#
#                               status_id                     associate_id_prsc  \
# 0  dae11221-7cde-41a7-b522-fe51a448095f  ed82bf38-485a-42ec-ab82-1c4cc6cd5157
#
#   is_scheduled  scheduled_time error_status           claimed_at  \
# 0          NaN             NaN          NaN  2022-01-07 15:45:56
#
#        created_at_task is_all_reversal_rxs         completed_at cancelled_at  \
# 0  2022-01-05 15:39:23                True  2022-01-07 15:48:44          NaN
#
#   cancellation_reason  pharmacy_nabp_prsc earliest_fill_date  \
# 0                 NaN           3352779.0                NaN
#
#    rx_numbers_count rx_numbers_list  total_awp  days_contacted  \
# 0               1.0       1157987-0        NaN             2.0
#
#    latest_contacted_at insurance_category  parent_id pharmacy_location_prsc  \
# 0  2022-01-07 15:46:13                NaN        NaN                  NY-BK
#
#                                   id_cv         contacted_at  \
# 0  80b7cbbd-d3fa-4a31-a193-d8c56365a7ea  2022-01-07 15:46:13
#
#             outcome        created_at_cv id_sd payload status_sd  \
# 0  Patient answered  2022-01-07 15:46:13   NaN     NaN       NaN
#
#   created_at_sd delivery_type pickup_date_scheduled_deliveries  \
# 0           NaN           NaN                              NaN
#
#   scheduled_startdate_scheduled_deliveries  \
# 0                                      NaN
#
#   scheduled_enddate_scheduled_deliveries  erxreceived_rxtimelines_boolean_d  \
# 0                                    NaN                               True
#
#    rx_entered_date_rxtimelines_boolean_d  \
# 0                                   True
#
#    rx_entered_date_verification_boolean_d  \
# 0                                    True
#
#    rx_filledon_date_rxtimelines_boolean_d  \
# 0                                    True
#
#    rx_pickedup_date_rxtimelines_boolean_d  new_delivered_date_d_boolean_d  \
# 0                                   False                           False
#
#    rx_labelprint_date_verification_boolean_d  \
# 0                                       True
#
#    rx_drugpick_date_verification_boolean_d  \
# 0                                     True
#
#    rx_rphpick_date_verification_boolean_d  \
# 0                                    True
#
#    first_billed_date_claimslog_boolean_d  \
# 0                                   True
#
#    last_billed_date_claimslog_boolean_d  processing_start_claimslog_boolean_d  \
# 0                                  True                                  True
#
#    processing_end_claimslog_boolean_d  current_status_rx_d  \
# 0                                True                11100
#
#   Overall_Visibility_for_Rx_d erxreceived_rxtimelines_ltz_d  \
# 0            Rx with only IBD     2021-12-09 07:31:00-05:00
#
#   rx_entered_date_rxtimelines_ltz_d first_billed_date_claimslog_ltz_d  \
# 0         2021-12-09 07:39:00-05:00         2021-12-13 04:41:32-05:00
#
#   last_billed_date_claimslog_ltz_d rx_drugpick_date_verification_ltz_d  \
# 0        2021-12-31 10:31:15-05:00           2021-12-14 05:02:00-05:00
#
#   rx_rphpick_date_verification_ltz_d pickup_date_scheduled_deliveries_ltz_d  \
# 0          2021-12-14 05:40:08-05:00                                    NaN
#
#   scheduled_startdate_scheduled_deliveries_ltz_d  \
# 0                                            NaN
#
#   scheduled_enddate_scheduled_deliveries_ltz_d new_delivered_date_ltz_d  \
# 0                                          NaN                      NaN
#
#   created_at_contactevents_ltz_d rx_filledon_date_rxtimelines_ltz_d  \
# 0      2022-01-07 10:46:13-05:00          2021-12-31 08:00:00-05:00
#
#   is_rescheduled_d  rescheduling_count_d             last_run  \
# 0              NaN                   1.0  2022-01-10 06:31:22
#
#   track_rx_recieved_new track_rx_entered_new pharmacy_loc mon_key mon_key_2
# 0   2021-12-09 12:31:00  2021-12-09 12:39:00        NY-BK   12-21    Dec-21

# %%
# df[(df['is_pickedup'] == False) & (df['status'] == 'completed')]

# %%
# six_months = date.today() - relativedelta(months=+6)
# six_months = six_months.strftime("%Y-%m")

# six_month_date = str(six_months)+"-01"
# six_month_date

# %%
# five_months = date.today() - relativedelta(months=+5)
# five_months = five_months.strftime("%Y-%m")

# five_month_date = str(five_months)+"-01"
# five_month_date

# %%
# four_months = date.today() - relativedelta(months=+4)
# four_months

# %%
df['is_eRx'].value_counts()
# Out:
# False    188486
# True     176203
# Name: is_eRx, dtype: int64

# %%
df['trackrx_last_status'].value_counts()
# Out:
# B    250078
# F     84671
# T      8905
# U      1039
# Name: trackrx_last_status, dtype: int64

# %%
df['trackrx_last_status_new'] = df['trackrx_last_status'].replace(['F', 'U', 'T'], 'NB')

# %%
df['trackrx_last_status_new'].value_counts()
# Out:
# B     250078
# NB     94615
# Name: trackrx_last_status_new, dtype: int64

# %%
# conditions = [
#     (df['is_pickedup'] == False) & (df['track_rx_delivered'].notnull()),
#     (df['is_pickedup'] == True)
#     ]
# # , del_data['status'] == 'NaN'
# # create a list of the values we want to assign for each condition
# values = ['Delivered', 'Pickedup']

# # create a new column and use np.select to assign values to it using our lists as arguments
# df['delivery_status'] = np.select(conditions, values)
# df['delivery_status'].replace('0', np.nan, inplace = True)
# # display updated DataFrame

# %%
df['delivery_status'] = df['status_tag']

# %%
df['delivery_status'].value_counts()
# Out:
# Delivered    186573
# Pickedup      41720
# Name: delivery_status, dtype: int64

# %%
df = df.rename(columns = {'pharmacy_loc': 'pharmacy loc'})

# %%
#df = df[(df['pharmacy loc'] != 'TX-DA') | (df['pharmacy loc'] != 'TX-SA')]

df = df.loc[(df['pharmacy loc'] != 'TX-DA') & (df['pharmacy loc'] != 'FL-OR')&(df['pharmacy loc'] != 'TX-SA') & (df['pharmacy loc'] != 'GA-AT') & (df['pharmacy loc'] != 'NY-UC') & (df['pharmacy loc'] != 'CT-NH')& (df['pharmacy loc'] != 'CT-CT')]

df['pharmacy loc'].unique()
# Out:
# array(['NY-BK', 'NJ-SO', 'PA-PH', 'MD-BA', 'FL-MI', 'NY-MA', 'NC-RA'],
#       dtype=object)

# %%
df['trackrx_last_status_new'].value_counts()
# Out:
# B     231006
# NB     86707
# Name: trackrx_last_status_new, dtype: int64

# %%
df = df[df['trackrx_last_status_new'].isin(['B','NB'])]

# %%
dff = df.copy()

# %%
pd.pivot_table(df, values = 'rx_code_key_location', columns = 'is_eRx', index = 'trackrx_last_status_new', aggfunc = 'count').reset_index()
# Out:
# is_eRx trackrx_last_status_new   False    True
# 0                            B  127597  103409
# 1                           NB   38034   48673

# %%
erx_data_overall = pd.pivot_table(df, values = 'rx_code_key_location', columns = 'is_eRx', index = 'trackrx_last_status_new', aggfunc = 'count').reset_index()
erx_data_overall['Total'] = erx_data_overall[False] + erx_data_overall[True]
erx_data_overall['not eRx'] = round((erx_data_overall[False]/erx_data_overall['Total'])*100,2)
erx_data_overall['eRx'] = round((erx_data_overall[True]/erx_data_overall['Total'])*100,2)
erx_data_plot = erx_data_overall[['trackrx_last_status_new', 'not eRx', 'eRx']]
erx_data_plot.set_index('trackrx_last_status_new', inplace = True)
erx_data_plot = erx_data_plot.fillna(0)

# erx_data_plot.drop(index='None',inplace=True)

# %%
erx_data_overall = erx_data_overall.fillna(0)
# erx_data_overall.drop(index=2,inplace=True)

# %%
ax = erx_data_plot.plot(kind = "bar",figsize=(10,5),rot=360,color=color_code,width=bar_width)

#list_values = [erx_data[False][0], erx_data[True][0], erx_data[False][1], erx_data[True][1]]
list_values = [erx_data_overall[False][0], erx_data_overall[False][1], erx_data_overall[True][0], erx_data_overall[True][1]]

for p,k in zip(ax.patches, list_values):
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, str(int(height))+'%', horizontalalignment='center', verticalalignment='center')
    ax.text(x+width/2, y+height+2, f'{int(k):,}', horizontalalignment='center', verticalalignment='center')
    
plt.ylabel("% of Rx")
plt.xlabel("Rx status")
plt.title("Mode of transfer by billing status",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

plt.xticks((0,1), ('Billed', 'Non Billed'))

plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# plt.show()
plt.savefig(output_image_path+'Mode_of_transfer_by_billing_status.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()
# Out:
# findfont: Font family ['Nunito'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Nunito'] not found. Falling back to DejaVu Sans.

# %%
erx_data = df[['rx_code_key_location', 'is_eRx','mon_key_2', 'trackrx_last_status_new', 'pharmacy loc', 'is_pickedup']]
#erx_data

# %%
# erx_data1 = erx_data[(erx_data['max_date'] > six_month_date)]
# erx_data1.sort_values(by= 'max_date')

# %%
erx_data1 = erx_data.copy()

# %%
eRx_month_wise = pd.pivot_table(erx_data1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()

eRx_month_wise['mon_key_2'] = pd.to_datetime(eRx_month_wise['mon_key_2'], format = "%b-%y")
eRx_month_wise['mon_key_3'] = eRx_month_wise['mon_key_2'].dt.strftime('%b-%y')
eRx_month_wise.sort_values(by = 'mon_key_2', inplace = True)
eRx_month_wise.drop(columns = 'mon_key_2', inplace = True)
eRx_month_wise.rename(columns = {'mon_key_3':'mon_key_2'}, inplace = True)
eRx_month_wise
# Out:
# is_eRx  False   True mon_key_2
# 2       23051  25376    Jul-21
# 0       26908  27595    Aug-21
# 5       31186  26945    Sep-21
# 4       28051  24646    Oct-21
# 3       27823  23203    Nov-21
# 1       28612  24317    Dec-21

# %%
eRx_month_wise_line = eRx_month_wise
eRx_month_wise_line.columns
eRx_month_wise_line['Total'] = eRx_month_wise[False] + eRx_month_wise[True]
eRx_month_wise_line['Per change'] = round(eRx_month_wise['Total'].pct_change()*100,2)
eRx_month_wise_line = eRx_month_wise_line.fillna(0)
#eRx_month_wise_line['Per change'] = eRx_month_wise_line['Per change'].astype(str) + ' %'
#eRx_month_wise_line.iloc[[0],[4]] = ' '
eRx_month_wise_line
# Out:
# is_eRx  False   True mon_key_2  Total  Per change
# 2       23051  25376    Jul-21  48427        0.00
# 0       26908  27595    Aug-21  54503       12.55
# 5       31186  26945    Sep-21  58131        6.66
# 4       28051  24646    Oct-21  52697       -9.35
# 3       27823  23203    Nov-21  51026       -3.17
# 1       28612  24317    Dec-21  52929        3.73

# %%
eRx_month_wise = pd.pivot_table(erx_data1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()

eRx_month_wise['mon_key_2'] = pd.to_datetime(eRx_month_wise['mon_key_2'], format = "%b-%y")
eRx_month_wise['mon_key_3'] = eRx_month_wise['mon_key_2'].dt.strftime('%b-%y')
eRx_month_wise.sort_values(by = 'mon_key_2', inplace = True)
eRx_month_wise.drop(columns = 'mon_key_2', inplace = True)
eRx_month_wise.rename(columns = {'mon_key_3':'mon_key_2'}, inplace = True)
eRx_month_wise
# Out:
# is_eRx  False   True mon_key_2
# 2       23051  25376    Jul-21
# 0       26908  27595    Aug-21
# 5       31186  26945    Sep-21
# 4       28051  24646    Oct-21
# 3       27823  23203    Nov-21
# 1       28612  24317    Dec-21

# %%
ax = eRx_month_wise.plot(kind = 'bar', stacked = True, x = 'mon_key_2', rot = 360, figsize = (10,5), legend = False,color=color_code,width=bar_width)
eRx_month_wise_line.plot(ax = ax, kind = 'line', x = 'mon_key_2', y = 'Total', color = 'grey', legend = False)


for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, f'{int(height):,}', horizontalalignment='center', verticalalignment='center')
    
#f'{int(p.get_height()):,}'


rects = ax.patches

texts=[]

for rect, total, per in zip(rects, eRx_month_wise_line['Total'], eRx_month_wise_line['Per change']):
    text = ax.text(rect.get_x() + rect.get_width() / 2, total, f'{int(total):,}'+' '+ '(' + str(per) +'%'+')',
            ha='center', va='center')
    texts.append(text)
adjust_text(texts)

max_y_limit = eRx_month_wise_line['Total'].max()
per_10 = (10/100) * max_y_limit + max_y_limit
ax.set_ylim(0, per_10)

plt.ylabel("Count of Rx")
plt.xlabel("Month Year")
plt.title("Overall Rx M-o-M analysis",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

# red_patch = mpatches.Patch(color='orange', label='eRx')
# blue_patch = mpatches.Patch(color='steelblue', label='not eRx')
# trend_patch = mpatches.Patch(color='grey', label='Total')
# plt.legend(handles=[red_patch, blue_patch, trend_patch], title='is eRx?', bbox_to_anchor=(1.0, 1), loc='upper left')
plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=3, borderaxespad=0.,fontsize = font_size)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
#plt.legend(title='is eRx?', bbox_to_anchor=(1.0, 1), loc='upper left')
# plt.show()
plt.savefig(output_image_path+'Overall_M-o-M_analysis_Rx_count.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()

# %%
eRx_pharmacy_wise = pd.pivot_table(erx_data1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['pharmacy loc'], aggfunc = 'count').reset_index()
eRx_pharmacy_wise.rename(columns = {False: 'False', True: 'True'}, inplace =True)

df_total = eRx_pharmacy_wise['False'] + eRx_pharmacy_wise['True']
eRx_pharmacy_wise['False'] = eRx_pharmacy_wise[eRx_pharmacy_wise.columns[1:2]].div(df_total, 0)*100
eRx_pharmacy_wise['True'] = eRx_pharmacy_wise[eRx_pharmacy_wise.columns[2:]].div(df_total, 0)*100

ax = eRx_pharmacy_wise.plot(kind = 'bar', stacked = True, x = 'pharmacy loc',legend = False,figsize=(10,5),rot=360,color=color_code,width=bar_width)

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, '{:.0f}%'.format(height), horizontalalignment='center', verticalalignment='center')

plt.ylabel("% of Rx")
plt.xlabel("City Location")
plt.title("Mode of Rx Transfer Overall",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

#plt.legend(title='is eRx?', bbox_to_anchor=(1.0, 1), loc='upper left')
# orange_patch = mpatches.Patch(color='orange', label='eRx')
# blue_patch = mpatches.Patch(color='steelblue', label='not eRx')
# plt.legend(handles=[orange_patch, blue_patch], title='is eRx?', bbox_to_anchor=(1.0, 1), loc='upper left')

plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)
#ax.axis('Off')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# plt.show()
plt.savefig(output_image_path+'Mode_of_Rx_transfer_Overall.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()

# %%
erx_data1['is_eRx'].value_counts()
# Out:
# False    165631
# True     152082
# Name: is_eRx, dtype: int64

# %%
overall_pharmacy_wise_Rx = pd.pivot_table(erx_data1, values = 'rx_code_key_location', columns = 'pharmacy loc', index = ['is_eRx'], aggfunc = 'count').reset_index()
overall_pharmacy_wise_Rx = overall_pharmacy_wise_Rx.append(overall_pharmacy_wise_Rx.sum(axis=0), ignore_index = True)
overall_pharmacy_wise_Rx['Total'] = overall_pharmacy_wise_Rx.sum(axis=1)

overall_pharmacy_wise_Rx = overall_pharmacy_wise_Rx.rename(columns = {'is_eRx': 'pharmacy loc/is eRx'})
overall_pharmacy_wise_Rx.iloc[[0],[0]] = 'not eRx'
overall_pharmacy_wise_Rx.iloc[[1],[0]] = 'is eRx'
overall_pharmacy_wise_Rx.iloc[[2],[0]] = 'Total'
overall_pharmacy_wise_Rx.set_index('pharmacy loc/is eRx', inplace = True)
#np.argsort(overall_pharmacy_wise_Rx, axis=0)
#overall_pharmacy_wise_Rx['Total'] = overall_pharmacy_wise_Rx.sum(axis=1)
overall_pharmacy_wise_Rx = overall_pharmacy_wise_Rx[overall_pharmacy_wise_Rx.columns[:]].div(6, 0).astype(int)

overall_pharmacy_wise_Rx = overall_pharmacy_wise_Rx.sort_values(overall_pharmacy_wise_Rx.last_valid_index(), axis=1, ascending = False)
overall_pharmacy_wise_Rx = overall_pharmacy_wise_Rx[['NY-BK', 'NJ-SO', 'PA-PH', 'FL-MI', 'NY-MA', 'MD-BA', 'NC-RA','Total']]
overall_pharmacy_wise_Rx

subset_value = (overall_pharmacy_wise_Rx.index.to_list()[:-1], 
               ['NY-BK', 'NJ-SO', 'PA-PH', 'FL-MI', 'NY-MA', 'MD-BA', 'NC-RA'])

df_style = overall_pharmacy_wise_Rx.style.set_properties(**body_design).background_gradient(cmap='GnBu',axis=1, subset = subset_value).format("{:,}")
df_style.set_table_styles([border_design])
#df_style = overall_pharmacy_wise_Rx.style.background_gradient(cmap ='GnBu', axis = 1).format("{:,}")
dfi.export(df_style, output_image_path+'overall_pharmacy_wise_Rx_count.png')
df_style
# Out:
# <style  type="text/css" >
#     #T_cbba3_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_cbba3_row0_col0,#T_cbba3_row1_col0{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #084081;
#             color:  #f1f1f1;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_cbba3_row0_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #48accf;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #48accf;
#             color:  #000000;
#         }#T_cbba3_row0_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d4eece;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d4eece;
#             color:  #000000;
#         }#T_cbba3_row0_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #bae4bd;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #bae4bd;
#             color:  #000000;
#         }#T_cbba3_row0_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #ddf2d7;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #ddf2d7;
#             color:  #000000;
#         }#T_cbba3_row0_col5{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #ebf7e5;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #ebf7e5;
#             color:  #000000;
#         }#T_cbba3_row0_col6,#T_cbba3_row1_col5{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f7fcf0;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_cbba3_row0_col7,#T_cbba3_row1_col7,#T_cbba3_row2_col0,#T_cbba3_row2_col1,#T_cbba3_row2_col2,#T_cbba3_row2_col3,#T_cbba3_row2_col4,#T_cbba3_row2_col5,#T_cbba3_row2_col6,#T_cbba3_row2_col7{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#         }#T_cbba3_row1_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #87d1c0;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #87d1c0;
#             color:  #000000;
#         }#T_cbba3_row1_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dbf1d5;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }#T_cbba3_row1_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #e1f3dc;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }#T_cbba3_row1_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;

# %%
# Billed

# %%
erx_data_billed = erx_data[erx_data['trackrx_last_status_new'] == 'B']
erx_data_billed
# erx_data_billed1 = erx_data_billed[(erx_data_billed['max_date'] > six_month_date)]
erx_data_billed1 = erx_data_billed

# %%
erx_data1.is_eRx.unique()
# Out:
# array([ True, False])

# %%
pd.pivot_table(erx_data1,values=['rx_code_key_location'],index=['is_eRx'],aggfunc='count')/6
# Out:
#         rx_code_key_location
# is_eRx
# False           27605.166667
# True            25347.000000

# %%
billed_pie_pivot = (pd.pivot_table(erx_data1,values=['rx_code_key_location'],index=['is_eRx'],aggfunc='count')/6).reset_index()
# billed_pie_pivot.iloc[0,1]=32208
# billed_pie_pivot.iloc[1,1]=4086
billed_pie_pivot
# Out:
#    is_eRx  rx_code_key_location
# 0   False          27605.166667
# 1    True          25347.000000

# %%
billed_pie_pivot = (pd.pivot_table(erx_data_billed1,values=['rx_code_key_location'],index=['is_eRx'],aggfunc='count')/6).reset_index()
# billed_pie_pivot.iloc[0,1]=32208
# billed_pie_pivot.iloc[1,1]=4086


mylabels = (billed_pie_pivot['rx_code_key_location']).to_list()
my_labels = 'not eRx '+str(f'{int(mylabels[0]):,}'),'eRx '+str(f'{int(mylabels[1]):,}')
my_explode = (0, 0.1)
plt.pie(billed_pie_pivot['rx_code_key_location']/6, labels=my_labels, autopct='%1.2f%%', startangle=90, shadow = False, explode=my_explode,colors=color_code)
plt.title('Mode of Rx Transfer Billed',fontsize = font_size_title,fontweight=font_weight ,fontname = font_name)
plt.axis('equal')
# plt.show()

plt.savefig(output_image_path+'Mode_of_Rx_Transfer_Billed_pie.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()

# %%
billed_eRx_month_wise = pd.pivot_table(erx_data_billed1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()
# billed_eRx_month_wise['mon_key_3'] = pd.to_datetime(billed_eRx_month_wise['mon_key_2'], format = '%b-%y')
# billed_eRx_month_wise.sort_values(by = 'mon_key_3')
# billed_eRx_month_wise.drop(columns = 'mon_key_3')
# billed_eRx_month_wise

billed_eRx_month_wise['mon_key_2'] = pd.to_datetime(billed_eRx_month_wise['mon_key_2'], format = "%b-%y")
billed_eRx_month_wise['mon_key_3'] = billed_eRx_month_wise['mon_key_2'].dt.strftime('%b-%y')
billed_eRx_month_wise.sort_values(by = 'mon_key_2', inplace = True)
billed_eRx_month_wise.drop(columns = 'mon_key_2', inplace = True)
billed_eRx_month_wise.rename(columns = {'mon_key_3':'mon_key_2'}, inplace = True)
billed_eRx_month_wise
# Out:
# is_eRx  False   True mon_key_2
# 2       18674  17540    Jul-21
# 0       20494  18094    Aug-21
# 5       21860  17481    Sep-21
# 4       21180  17036    Oct-21
# 3       22541  16503    Nov-21
# 1       22848  16755    Dec-21

# %%
billed_eRx_month_wise_line = billed_eRx_month_wise
billed_eRx_month_wise_line.columns
billed_eRx_month_wise_line['Total'] = billed_eRx_month_wise[False] + billed_eRx_month_wise[True]
billed_eRx_month_wise_line['per change'] = round(billed_eRx_month_wise['Total'].pct_change()*100,2)
billed_eRx_month_wise_line = billed_eRx_month_wise_line.fillna(0)
billed_eRx_month_wise_line
# Out:
# is_eRx  False   True mon_key_2  Total  per change
# 2       18674  17540    Jul-21  36214        0.00
# 0       20494  18094    Aug-21  38588        6.56
# 5       21860  17481    Sep-21  39341        1.95
# 4       21180  17036    Oct-21  38216       -2.86
# 3       22541  16503    Nov-21  39044        2.17
# 1       22848  16755    Dec-21  39603        1.43

# %%
billed_eRx_month_wise = pd.pivot_table(erx_data_billed1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()
# billed_eRx_month_wise['mon_key_3'] = pd.to_datetime(billed_eRx_month_wise['mon_key_2'], format = '%b-%y')
# billed_eRx_month_wise.sort_values(by = 'mon_key_3')
# billed_eRx_month_wise.drop(columns = 'mon_key_3')
# billed_eRx_month_wise

billed_eRx_month_wise['mon_key_2'] = pd.to_datetime(billed_eRx_month_wise['mon_key_2'], format = "%b-%y")
billed_eRx_month_wise['mon_key_3'] = billed_eRx_month_wise['mon_key_2'].dt.strftime('%b-%y')
billed_eRx_month_wise.sort_values(by = 'mon_key_2', inplace = True)
billed_eRx_month_wise.drop(columns = 'mon_key_2', inplace = True)
billed_eRx_month_wise.rename(columns = {'mon_key_3':'mon_key_2'}, inplace = True)
billed_eRx_month_wise
# Out:
# is_eRx  False   True mon_key_2
# 2       18674  17540    Jul-21
# 0       20494  18094    Aug-21
# 5       21860  17481    Sep-21
# 4       21180  17036    Oct-21
# 3       22541  16503    Nov-21
# 1       22848  16755    Dec-21

# %%
ax = billed_eRx_month_wise.plot(kind = 'bar', stacked = True, x = 'mon_key_2', rot = 360, figsize = (10,5), legend = False,color=color_code,width=bar_width)
billed_eRx_month_wise_line.plot(ax = ax, kind = 'line', x = 'mon_key_2', y = 'Total', color = 'grey', legend = False)

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, f'{int(height):,}', horizontalalignment='center', verticalalignment='center')

rects = ax.patches

texts = []

for rect, total, per in zip(rects, billed_eRx_month_wise_line['Total'], billed_eRx_month_wise_line['per change']):
    text = ax.text(rect.get_x() + rect.get_width() / 2, total, f'{int(total):,}'+' '+ '(' + str(per) +'%'+')',
            ha='center', va='center')
    texts.append(text)
adjust_text(texts)
plt.ylabel("Count of Rx")
plt.xlabel("Month Year")
plt.title("Billed Rx M-o-M analysis",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

max_y_limit = billed_eRx_month_wise_line['Total'].max()
per_10 = (10/100) * max_y_limit + max_y_limit
ax.set_ylim(0, per_10)

orange_patch = mpatches.Patch(color=orange_color, label='eRx')
blue_patch = mpatches.Patch(color=blue_color, label='not eRx')
trend_patch = mpatches.Patch(color=grey_color, label='Total')
plt.legend(handles=[orange_patch, blue_patch, trend_patch],bbox_to_anchor=(0.70, 1.08), ncol=3, borderaxespad=0.,fontsize = font_size)
# plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=3, borderaxespad=0.,fontsize = font_size)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
#plt.legend(title='is eRx?', bbox_to_anchor=(1.0, 1), loc='upper left')
# plt.show()
plt.savefig(output_image_path+'billed_M-o-M_analysis_eRx.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()

# %%
billed_eRx_pharmacy_wise = pd.pivot_table(erx_data_billed1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['pharmacy loc'], aggfunc = 'count').reset_index()
billed_eRx_pharmacy_wise.rename(columns = {False: 'False', True: 'True'}, inplace =True)

df_total = billed_eRx_pharmacy_wise['False'] + billed_eRx_pharmacy_wise['True']
billed_eRx_pharmacy_wise['False'] = billed_eRx_pharmacy_wise[billed_eRx_pharmacy_wise.columns[1:2]].div(df_total, 0)*100
billed_eRx_pharmacy_wise['True'] = billed_eRx_pharmacy_wise[billed_eRx_pharmacy_wise.columns[2:]].div(df_total, 0)*100

ax = billed_eRx_pharmacy_wise.plot(kind = 'bar', stacked = True, x = 'pharmacy loc',figsize=(10,5),rot=360,color=color_code,width=bar_width, legend = False)

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, '{:.0f}%'.format(height), horizontalalignment='center', verticalalignment='center')


plt.ylabel("Percentage Rx")
plt.xlabel("Pharmacy Location")
plt.title("Location wise mode of Rx Transfer",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

plt.legend(title='is eRx?', bbox_to_anchor=(1.0, 1), loc='upper left')
orange_patch = mpatches.Patch(color=orange_color, label='eRx')
blue_patch = mpatches.Patch(color=blue_color, label='not eRx')
plt.legend(handles=[orange_patch, blue_patch],bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)
# plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
# plt.show()
plt.savefig(output_image_path+'Location_wise_mode_of_Rx_Transfer_billed.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()

# %%
erx_data_billed1['pharmacy loc'].value_counts()
# Out:
# NY-BK    94427
# NJ-SO    49991
# FL-MI    27716
# PA-PH    21577
# NY-MA    19069
# MD-BA     9229
# NC-RA     8997
# Name: pharmacy loc, dtype: int64

# %%
pd.pivot_table(erx_data_billed1, values = 'rx_code_key_location', columns = 'pharmacy loc', index = ['is_eRx'], aggfunc = 'count').reset_index()
# Out:
# pharmacy loc  is_eRx  FL-MI  MD-BA  NC-RA  NJ-SO  NY-BK  NY-MA  PA-PH
# 0              False  18355   5369   3336  28769  48857  11529  11382
# 1               True   9361   3860   5661  21222  45570   7540  10195

# %%
Billed_pharmacy_wise_Rx = pd.pivot_table(erx_data_billed1, values = 'rx_code_key_location', columns = 'pharmacy loc', index = ['is_eRx'], aggfunc = 'count').reset_index()
Billed_pharmacy_wise_Rx = Billed_pharmacy_wise_Rx.append(Billed_pharmacy_wise_Rx.sum(axis=0), ignore_index = True)

Billed_pharmacy_wise_Rx = Billed_pharmacy_wise_Rx.rename(columns = {'is_eRx': 'pharmacy loc/is eRx'})
Billed_pharmacy_wise_Rx.iloc[[0],[0]] = 'not eRx'
Billed_pharmacy_wise_Rx.iloc[[1],[0]] = 'is eRx'
Billed_pharmacy_wise_Rx.iloc[[2],[0]] = 'Total'
Billed_pharmacy_wise_Rx.set_index('pharmacy loc/is eRx', inplace = True)
Billed_pharmacy_wise_Rx['Total'] = Billed_pharmacy_wise_Rx.sum(axis=1)
Billed_pharmacy_wise_Rx = Billed_pharmacy_wise_Rx[Billed_pharmacy_wise_Rx.columns[:]].div(6,0).astype(int)
Billed_pharmacy_wise_Rx = Billed_pharmacy_wise_Rx.sort_values(Billed_pharmacy_wise_Rx.last_valid_index(), axis=1, ascending = False)
# print(Billed_pharmacy_wise_Rx)
Billed_pharmacy_wise_Rx = Billed_pharmacy_wise_Rx[['NY-BK', 'NJ-SO', 'PA-PH', 'FL-MI', 'NY-MA', 'MD-BA', 'NC-RA','Total']]
#illed_pharmacy_wise_Rx

subset_value = (Billed_pharmacy_wise_Rx.index.to_list()[:-1], 
               ['NY-BK', 'NJ-SO', 'PA-PH', 'FL-MI', 'NY-MA', 'MD-BA', 'NC-RA'])

df_style = Billed_pharmacy_wise_Rx.style.set_properties(**body_design).background_gradient(cmap='GnBu',axis=1, subset = subset_value).format("{:,}")
df_style.set_table_styles([border_design])
#f_style = Billed_pharmacy_wise_Rx.style.background_gradient(cmap ='GnBu', axis = 1).format("{:,}")

dfi.export(df_style, output_image_path+'Billed_pharmacy_wise_Rx_count_table.png')
df_style
# Out:
# <style  type="text/css" >
#     #T_fca91_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_fca91_row0_col0,#T_fca91_row1_col0{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #084081;
#             color:  #f1f1f1;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_fca91_row0_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #65c0cb;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #65c0cb;
#             color:  #000000;
#         }#T_fca91_row0_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d8f0d2;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }#T_fca91_row0_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #b5e2bb;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #b5e2bb;
#             color:  #000000;
#         }#T_fca91_row0_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d7efd1;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d7efd1;
#             color:  #000000;
#         }#T_fca91_row0_col5,#T_fca91_row1_col6{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #eff9e9;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #eff9e9;
#             color:  #000000;
#         }#T_fca91_row0_col6,#T_fca91_row1_col5{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f7fcf0;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_fca91_row0_col7,#T_fca91_row1_col7,#T_fca91_row2_col0,#T_fca91_row2_col1,#T_fca91_row2_col2,#T_fca91_row2_col3,#T_fca91_row2_col4,#T_fca91_row2_col5,#T_fca91_row2_col6,#T_fca91_row2_col7{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#         }#T_fca91_row1_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #99d7ba;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #99d7ba;
#             color:  #000000;
#         }#T_fca91_row1_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dcf1d7;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dcf1d7;
#             color:  #000000;
#         }#T_fca91_row1_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dff3da;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_fca91_row1_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             bo

# %%
# month wise analysis for city billed rx count

# %%
pd.pivot_table( erx_data1, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()
# Out:
# is_eRx mon_key_2  False   True
# 0         Aug-21  26908  27595
# 1         Dec-21  28612  24317
# 2         Jul-21  23051  25376
# 3         Nov-21  27823  23203
# 4         Oct-21  28051  24646
# 5         Sep-21  31186  26945

# %%
# for i in np.unique(erx_data1['pharmacy loc']):
#     print(i)
#     df = erx_data1[erx_data1['pharmacy loc'] == i]
#     df_B = df[df['trackrx_last_status_new'] == 'B']
# #     df_B =  df_B.loc[( df_B['max_date'] > six_month_date)]

#     df_B_eRx =  df_B[ df_B['is_eRx'] == True]
#     #df_B_non_eRx =  df_B[ df_B['is_eRx'] == False]

#     eRx_month_wise_eRx = pd.pivot_table( df_B_eRx, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()
#     eRx_month_wise_eRx['mon_key_2'] = pd.to_datetime( eRx_month_wise_eRx['mon_key_2'], format = "%b-%y")
#     eRx_month_wise_eRx['mon_key_3'] =  eRx_month_wise_eRx['mon_key_2'].dt.strftime('%b-%y')
#     eRx_month_wise_eRx.sort_values(by = 'mon_key_2', inplace = True)
#     eRx_month_wise_eRx.drop(columns = 'mon_key_2', inplace = True)
#     eRx_month_wise_eRx.rename(columns = {'mon_key_3': 'mon_key_2'}, inplace =True)
# #     print(eRx_month_wise_eRx)
#     eRx_month_wise_eRx['per_growth'] =  round(eRx_month_wise_eRx[True].pct_change()*100,2)

#     avgdf = pd.DataFrame(columns = [True, 'mon_key_2'], index=range(0,1))
#     avgdf[True] = int( eRx_month_wise_eRx[True].mean())
#     avgdf['mon_key_2'] = 'avg'

#     eRx_month_wise_eRx =  eRx_month_wise_eRx.append(avgdf)
#     eRx_month_wise_eRx = eRx_month_wise_eRx.fillna(0)
#     eRx_month_wise_line =  eRx_month_wise_eRx
    
#     if len(eRx_month_wise_eRx) == 5:
#         c = [blue_color, blue_color, blue_color, blue_color, green_color]
#     elif len(eRx_month_wise_eRx) == 6:
#         c = [blue_color, blue_color, blue_color, blue_color,blue_color ,green_color]
#     else:
#         c = [blue_color, blue_color, blue_color, blue_color, blue_color,blue_color, green_color]

#     ax =  eRx_month_wise_eRx.plot(kind = 'bar', x = 'mon_key_2', y = True, rot = 360, figsize = (10,5), legend = False, color=c,width=bar_width)

#     for p in ax.patches:
#         width, height = p.get_width(), p.get_height()
#         x, y = p.get_xy() 
#         ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), horizontalalignment='center', verticalalignment='center', color = 'black')
    
#     ax2 =  eRx_month_wise_line[:-1].plot(ax = ax, secondary_y=True, kind = 'line', x = 'mon_key_2', y = 'per_growth', color = 'black', legend = False)
    
#     texts = []
    
#     for p,k in zip(ax.patches,  eRx_month_wise_line.per_growth):
#         width, height = p.get_width(), p.get_height()
#         x, y = p.get_xy() 
#         text = ax.text(x+width/2, y+height, str(round(k,2))+'%', horizontalalignment='center', verticalalignment='center')
#         texts.append(text)
#     adjust_text(texts)
    
#     labels = [item.get_text() for item in ax.get_xticklabels()]
#     labels[6] = 'Avg'

#     ax.set_xticklabels(labels)
    
#     ax.set_xlabel("Month Year")
#     ax.set_ylabel('Count of Rx')
#     ax2.set_ylabel('per_growth')
#     #ax.set_ylim(0,1400)
#     max_y_limit = eRx_month_wise_line[True].max()
#     per_10 = (10/100) * max_y_limit + max_y_limit
#     ax.set_ylim(0, per_10)

#     plt.xlabel("Month Year")
#     plt.title(str(i)+" eRx M-o-M analysis Trend",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

# #     plt.legend(title='eRx', bbox_to_anchor=(1.0, 1), loc='upper left')
#     plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)
    
#     ax.spines['top'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.spines['right'].set_visible(False)
#     ax.spines['bottom'].set_visible(False)
    
#     ax2.spines['top'].set_visible(False)
#     ax2.spines['left'].set_visible(False)
#     ax2.spines['right'].set_visible(False)
#     ax2.spines['bottom'].set_visible(False)
#     plt.show()
# #     plt.savefig(output_image_path+str(i)+'_billed_eRx_trend.png', bbox_inches='tight', dpi=300,pad_inches = 0)
# #     plt.close()

# %%
for i in np.unique(erx_data1['pharmacy loc']):
    df = erx_data1[erx_data1['pharmacy loc'] == i]
    df_B = df[df['trackrx_last_status_new'] == 'B']
#     df_B =  df_B.loc[( df_B['max_date'] > six_month_date)]

    df_B_eRx =  df_B[ df_B['is_eRx'] == True]
    #df_B_non_eRx =  df_B[ df_B['is_eRx'] == False]

    eRx_month_wise_eRx = pd.pivot_table( df_B_eRx, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()
    eRx_month_wise_eRx['mon_key_2'] = pd.to_datetime( eRx_month_wise_eRx['mon_key_2'], format = "%b-%y")
    eRx_month_wise_eRx['mon_key_3'] =  eRx_month_wise_eRx['mon_key_2'].dt.strftime('%b-%y')
    eRx_month_wise_eRx.sort_values(by = 'mon_key_2', inplace = True)
    eRx_month_wise_eRx.drop(columns = 'mon_key_2', inplace = True)
    eRx_month_wise_eRx.rename(columns = {'mon_key_3': 'mon_key_2'}, inplace =True)

    eRx_month_wise_eRx['per_growth'] =  round(eRx_month_wise_eRx[True].pct_change()*100,2)

    avgdf = pd.DataFrame(columns = [True, 'mon_key_2'], index=range(0,1))
    avgdf[True] = int( eRx_month_wise_eRx[True].mean())
    avgdf['mon_key_2'] = 'avg'

    eRx_month_wise_eRx =  eRx_month_wise_eRx.append(avgdf)
    eRx_month_wise_eRx = eRx_month_wise_eRx.fillna(0)
    eRx_month_wise_line =  eRx_month_wise_eRx
    
    if len(eRx_month_wise_eRx) == 5:
        c = [blue_color, blue_color, blue_color, blue_color, green_color]
    elif len(eRx_month_wise_eRx) == 6:
        c = [blue_color, blue_color, blue_color, blue_color,blue_color ,green_color]
    else:
        c = [blue_color, blue_color, blue_color, blue_color, blue_color,blue_color, green_color]

    ax =  eRx_month_wise_eRx.plot(kind = 'bar', x = 'mon_key_2', y = True, rot = 360, figsize = (10,5), legend = False, color=c,width=bar_width)

    for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), horizontalalignment='center', verticalalignment='center', color = 'black')
    
    ax2 =  eRx_month_wise_line[:-1].plot(ax = ax, secondary_y=True, kind = 'line', x = 'mon_key_2', y = 'per_growth', color = 'black', legend = False)
    
    texts = []
    
    for p,k in zip(ax.patches,  eRx_month_wise_line.per_growth):
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        text = ax.text(x+width/2, y+height, str(round(k,2))+'%', horizontalalignment='center', verticalalignment='center')
        texts.append(text)
    adjust_text(texts)
    
    labels = [item.get_text() for item in ax.get_xticklabels()]
    labels[6] = 'Avg'

    ax.set_xticklabels(labels)
    
    ax.set_xlabel("Month Year")
    ax.set_ylabel('Count of Rx')
    ax2.set_ylabel('per_growth')
    #ax.set_ylim(0,1400)
    max_y_limit = eRx_month_wise_line[True].max()
    per_10 = (10/100) * max_y_limit + max_y_limit
    ax.set_ylim(0, per_10)

    plt.xlabel("Month Year")
    plt.title(str(i)+" eRx M-o-M analysis Trend",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

#     plt.legend(title='eRx', bbox_to_anchor=(1.0, 1), loc='upper left')
    
    plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)
    
    
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
    ax2.spines['top'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
#     plt.show()
    plt.savefig(output_image_path+str(i)+'_billed_eRx_trend.png', bbox_inches='tight', dpi=300,pad_inches = 0)
    plt.close()

# %%
# month wise analysis for city billed non rx count

# %%
for i in np.unique(erx_data1['pharmacy loc']):
    FL_MI_df = erx_data1[erx_data1['pharmacy loc'] == i]
    FL_MI_df_B = FL_MI_df[FL_MI_df['trackrx_last_status_new'] == 'B']
#     FL_MI_df_B = FL_MI_df_B.loc[(FL_MI_df_B['max_date'] > six_month_date)]

    #FL_MI_df_B_eRx = FL_MI_df_B[FL_MI_df_B['is_eRx'] == True]
    FL_MI_df_B_non_eRx = FL_MI_df_B[FL_MI_df_B['is_eRx'] == False]

    FL_MI_eRx_month_wise_eRx = pd.pivot_table(FL_MI_df_B_non_eRx, values = 'rx_code_key_location', columns = 'is_eRx', index = ['mon_key_2'], aggfunc = 'count').reset_index()
    FL_MI_eRx_month_wise_eRx['mon_key_2'] = pd.to_datetime(FL_MI_eRx_month_wise_eRx['mon_key_2'], format = "%b-%y")
    FL_MI_eRx_month_wise_eRx['mon_key_3'] = FL_MI_eRx_month_wise_eRx['mon_key_2'].dt.strftime('%b-%y')
    FL_MI_eRx_month_wise_eRx.sort_values(by = 'mon_key_2', inplace = True)
    FL_MI_eRx_month_wise_eRx.drop(columns = 'mon_key_2', inplace = True)
    FL_MI_eRx_month_wise_eRx.rename(columns = {'mon_key_3': 'mon_key_2'}, inplace =True)

    FL_MI_eRx_month_wise_eRx['per_growth'] = round(FL_MI_eRx_month_wise_eRx[False].pct_change()*100,2)
    #FL_MI_eRx_month_wise_eRx
    avgdf = pd.DataFrame(columns = [False, 'mon_key_2'], index=range(0,1))
    avgdf[False] = int(FL_MI_eRx_month_wise_eRx[False].mean())
    avgdf['mon_key_2'] = 'avg'

    FL_MI_eRx_month_wise_eRx = FL_MI_eRx_month_wise_eRx.append(avgdf)
    FL_MI_eRx_month_wise_eRx = FL_MI_eRx_month_wise_eRx.fillna(0)
    FL_MI_eRx_month_wise_line = FL_MI_eRx_month_wise_eRx
    
    if len(eRx_month_wise_eRx) == 5:
        c = [blue_color, blue_color, blue_color, blue_color, green_color]
    elif len(eRx_month_wise_eRx) == 6:
        c = [blue_color, blue_color, blue_color, blue_color,blue_color ,green_color]
    else:
        c = [blue_color, blue_color, blue_color, blue_color, blue_color,blue_color, green_color]
        
    ax = FL_MI_eRx_month_wise_eRx.plot(kind = 'bar', x = 'mon_key_2', y = False, rot = 360, figsize = (10,5), legend = False, color=c,width=bar_width)

    for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), horizontalalignment='center', verticalalignment='center', color = 'black')
    
    ax2 = FL_MI_eRx_month_wise_line[:-1].plot(ax = ax, secondary_y=True, kind = 'line', x = 'mon_key_2', y = 'per_growth', color = 'black', legend = False)

    texts = []
    
    for p,k in zip(ax.patches, FL_MI_eRx_month_wise_line.per_growth):
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        text = ax.text(x+width/2, y+height, str(round(k,2))+'%', horizontalalignment='center', verticalalignment='center')
        texts.append(text)
        
    labels = [item.get_text() for item in ax.get_xticklabels()]
    labels[6] = 'Avg'

    ax.set_xticklabels(labels)    
        
    adjust_text(texts)
    ax.set_xlabel("Month Year")
    ax.set_ylabel('Count of Rx')
    ax2.set_ylabel('per_growth')
    #ax.set_ylim(0,1400)

    max_y_limit = FL_MI_eRx_month_wise_line[False].max()
    per_10 = (10/100) * max_y_limit + max_y_limit
    ax.set_ylim(0, per_10)

    plt.title(str(i)+" non eRx M-o-M analysis Trend",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

#     plt.legend(title='non eRx', bbox_to_anchor=(1.0, 1), loc='upper left')
    plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)

    ax2.spines['top'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)

    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
#     plt.show()
    plt.savefig(output_image_path+str(i)+'_billed_non_eRx_trend.png', bbox_inches='tight', dpi=300,pad_inches = 0)
    plt.close()

# %%
# Delivery analysis

# %%
erx_data
# Out:
#        rx_code_key_location  is_eRx mon_key_2 trackrx_last_status_new  \
# 0           NY-BK-1157987-0    True    Dec-21                      NB
# 1           NJ-SO-1199550-0    True    Nov-21                       B
# 2           NY-BK-1158109-0    True    Dec-21                       B
# 3           NY-BK-1158579-0    True    Dec-21                      NB
# 4           NJ-SO-1198582-0    True    Oct-21                       B
# ...                     ...     ...       ...                     ...
# 364684      NY-BK-1159606-0    True    Dec-21                       B
# 364685      NY-BK-1159601-0    True    Dec-21                       B
# 364686      NY-BK-1159599-0    True    Dec-21                       B
# 364687      NY-BK-1159597-0    True    Dec-21                       B
# 364688      NY-BK-1160648-0    True    Dec-21                       B
#
#        pharmacy loc is_pickedup
# 0             NY-BK         NaN
# 1             NJ-SO       False
# 2             NY-BK       False
# 3             NY-BK         NaN
# 4             NJ-SO       False
# ...             ...         ...
# 364684        NY-BK       False
# 364685        NY-BK       False
# 364686        NY-BK       False
# 364687        NY-BK       False
# 364688        NY-BK       False
#
# [317713 rows x 6 columns]

# %%
dff
# Out:
#         Unnamed: 0 pharmacy_location       rxno     presnpi          ndc  \
# 0                0             NY-BK  1157987-0  1871998476  75987004005
# 1                1             NJ-SO  1199550-0  1417203928  50222030260
# 2                2             NY-BK  1158109-0  1760484687  55513071001
# 3                3             NY-BK  1158579-0  1184913063  00169413602
# 4                4             NJ-SO  1198582-0  1437198009  00023916360
# ...            ...               ...        ...         ...          ...
# 364684      364684             NY-BK  1159606-0  1295221612  31722082730
# 364685      364685             NY-BK  1159601-0  1295221612  68180035206
# 364686      364686             NY-BK  1159599-0  1295221612  50111043402
# 364687      364687             NY-BK  1159597-0  1295221612  65862001305
# 364688      364688             NY-BK  1160648-0  1609263318  16103035611
#
#        trackrx_status  patientno   track_erx_received     track_rx_entered  \
# 0                   F     620373  2021-12-09 12:31:00  2021-12-09 12:39:00
# 1                   B      77426  2021-10-15 14:03:00  2021-10-15 17:34:00
# 2                   B     602577  2021-12-09 14:37:00  2021-12-09 14:50:00
# 3                   F     559221  2021-12-10 13:29:00  2021-12-10 13:54:00
# 4                   B      24019  2021-10-12 16:26:00  2021-10-13 09:38:25
# ...               ...        ...                  ...                  ...
# 364684              B     530035  2021-12-14 10:51:00  2021-12-14 11:00:00
# 364685              B     530035  2021-12-14 10:51:00  2021-12-14 10:58:00
# 364686              B     530035  2021-12-14 10:51:00  2021-12-14 10:57:00
# 364687              B     530035  2021-12-14 10:51:00  2021-12-14 10:57:00
# 364688              B     585260  2021-12-16 10:28:00  2021-12-16 10:33:00
#
#        rx_entered_date_verification      filled_datekey    final_rx_pickedup  \
# 0               2021-12-09 12:39:00 2021-12-31 13:00:00                  NaN
# 1               2021-10-15 17:34:00 2021-11-30 11:46:08  2021-12-02 00:00:00
# 2               2021-12-09 14:50:00 2021-12-31 00:00:00                  NaN
# 3               2021-12-10 13:54:00 2021-12-22 17:16:00                  NaN
# 4               2021-10-13 09:45:00 2021-10-13 09:38:25  2021-10-20 00:00:00
# ...                             ...                 ...                  ...
# 364684          2021-12-14 11:00:00 2021-12-27 10:59:33  2022-01-03 00:00:00
# 364685          2021-12-14 10:58:00 2021-12-27 10:57:36  2022-01-03 00:00:00
# 364686          2021-12-14 10:57:00 2021-12-27 10:57:08  2022-01-03 00:00:00
# 364687          2021-12-14 10:57:00 2021-12-27 10:56:32  2022-01-03 00:00:00
# 364688          2021-12-16 10:33:00 2021-12-29 14:19:00  2022-01-08 00:00:00
#
#           rx_delivered_date  track_label_printed  final_rx_drug_picks  \
# 0                       NaN  2021-12-14 10:39:55  2021-12-14 10:02:00
# 1                       NaN  2021-11-30 18:50:21  2021-11-30 18:54:00
# 2                       NaN  2022-01-01 10:21:54  2022-01-03 12:29:00
# 3                       NaN  2021-12-22 17:57:00                  NaN
# 4       2021-10-20 21:09:54  2021-10-13 14:39:26  2021-10-13 14:39:00
# ...                     ...                  ...                  ...
# 364684                  NaN  2021-12-27 07:31:02  2021-12-27 10:27:00
# 364685                  NaN  2021-12-27 07:31:05  2021-12-27 10:27:00
# 364686                  NaN  2021-12-27 07:30:53  2021-12-27 10:27:00
# 364687                  NaN  2021-12-27 07:31:07  2021-12-27 10:31:00
# 364688  2022-01-08 17:20:42  2021-12-29 14:19:54  2021-12-29 14:33:00
#
#          final_rx_rph_picks             last_run rx_code_key_location  \
# 0       2021-12-14 10:40:08  2022-01-09 01:21:07      NY-BK-1157987-0
# 1       2021-12-01 09:25:19  2022-01-09 01:21:07      NJ-SO-1199550-0
# 2       2022-01-03 13:09:50  2022-01-09 01:21:07      NY-BK-1158109-0
# 3                       NaN  2022-01-09 01:21:07      NY-BK-1158579-0
# 4       2021-10-13 15:19:06  2022-01-09 01:21:07      NJ-SO-1198582-0
# ...                     ...                  ...                  ...
# 364684  2021-12-27 12:26:04  2022-01-09 01:21:07      NY-BK-1159606-0
# 364685  2021-12-27 12:26:15  2022-01-09 01:21:07      NY-BK-1159601-0
# 364686  2021-12-27 12:26:43  2022-01-09 01:21:07      NY-BK-1159599-0
# 364687  2021-12-27 12:26:54  2022-01-09 01:21:07      NY-BK-1159597-0
# 364688  2021-12-29 14:33:25  2022-01-09 01:21:07      NY-BK-1160648-0
#
#              nabp first_billed_datetime  end_billed_datetime  \
# 0       3352779.0   2021-12-13 09:41:32  2021-12-31 15:31:15
# 1       3135868.0   2021-11-06 09:01:57  2021-11-30 13:08:06
# 2       3352779.0   2021-12-31 13:50:51  2021-12-31 13:50:51
# 3       3352779.0   2021-12-10 13:57:26  2021-12-22 17:16:45
# 4       3135868.0   2021-10-13 14:05:14  2021-10-13 14:05:14
# ...           ...                   ...                  ...
# 364684  3352779.0   2021-12-27 07:20:29  2021-12-27 07:20:29
# 364685  3352779.0   2021-12-27 07:20:22  2021-12-27 07:20:22
# 364686  3352779.0   2021-12-27 07:20:20  2021-12-27 07:20:20
# 364687  3352779.0   2021-12-27 07:20:17  2021-12-27 10:31:07
# 364688  3352779.0   2021-12-16 10:35:01  2021-12-29 14:19:50
#
#        trackrx_processing_date_starttime       processing_end  \
# 0                    2021-12-09 12:39:24  2022-01-08 12:42:41
# 1                    2021-10-15 18:59:55  2022-01-08 15:14:31
# 2                    2021-12-09 14:53:30  2022-01-08 11:48:17
# 3                    2021-12-10 13:51:58  2022-01-08 11:12:07
# 4                    2021-10-13 14:05:14  2022-01-08 12:19:12
# ...                                  ...                  ...
# 364684               2021-12-14 11:00:20  2022-01-08 16:30:15
# 364685               2021-12-14 11:00:16  2022-01-08 16:30:15
# 364686               2021-12-14 11:00:24  2022-01-08 16:30:15
# 364687               2021-12-14 11:00:22  2022-01-08 16:30:15
# 364688               2021-12-16 10:33:19  2022-01-08 17:33:07
#
#              IBD IN PROCESS IBD FIDELIS  IBD REQUIRED  IBD $2K+  IBD IS $2K+  \
# 0                       NaN         NaN           NaN       NaN          NaN
# 1       2021-11-01 16:07:54         NaN           NaN       NaN          NaN
# 2       2021-12-27 11:50:49         NaN           NaN       NaN          NaN
# 3                       NaN         NaN           NaN       NaN          NaN
# 4                       NaN         NaN           NaN       NaN          NaN
# ...                     ...         ...           ...       ...          ...
# 364684                  NaN         NaN           NaN       NaN          NaN
# 364685                  NaN         NaN           NaN       NaN          NaN
# 364686                  NaN         NaN           NaN       NaN          NaN
# 364687                  NaN         NaN           NaN       NaN          NaN
# 364688                  NaN         NaN           NaN       NaN          NaN
#
#         IBD 2K  IBD IS 2K IBD SPECIALITY                  IBD  \
# 0          NaN        NaN            NaN  2021-12-09 15:21:57
# 1          NaN        NaN            NaN  2021-11-01 16:07:54
# 2          NaN        NaN            NaN  2021-12-27 11:50:49
# 3          NaN        NaN            NaN                  NaN
# 4          NaN        NaN            NaN                  NaN
# ...        ...        ...            ...                  ...
# 364684     NaN        NaN            NaN                  NaN
# 364685     NaN        NaN            NaN                  NaN
# 364686     NaN        NaN            NaN                  NaN
# 364687     NaN        NaN            NaN                  NaN
# 364688     NaN        NaN            NaN                  NaN
#
#                 IBD REGULAR         TO BE BILLED CALL FOR INS  \
# 0                       NaN  2021-12-13 09:38:39          NaN
# 1       2021-10-29 10:29:38  2021-10-18 09:53:58          NaN
# 2       2021-12-24 16:04:00                  NaN          NaN
# 3                       NaN  2021-12-10 13:51:58          NaN
# 4                       NaN                  NaN          NaN
# ...                     ...                  ...          ...
# 364684                  NaN                  NaN          NaN
# 364685                  NaN                  NaN          NaN
# 364686                  NaN                  NaN          NaN
# 364687                  NaN                  NaN          NaN
# 364688                  NaN  2021-12-16 10:33:23          NaN
#
#        CALL FOR INS (KOREAN/CH) CALL FOR INS DAY 2 CALL FOR INS DAY 3  \
# 0                           NaN                NaN                NaN
# 1                           NaN                NaN                NaN
# 2                           NaN                NaN                NaN
# 3                           NaN                NaN                NaN
# 4                           NaN                NaN                NaN
# ...                         ...                ...                ...
# 364684                      NaN                NaN                NaN
# 364685                      NaN                NaN                NaN
# 364686                      NaN                NaN                NaN
# 364687                      NaN                NaN                NaN
# 364688                      NaN                NaN                NaN
#
#        CALL FOR INS (KOREAN/CHINESE) CAL FOR INS (KOREAN/CHINESE) is_pickedup  \
# 0                                NaN                          NaN         NaN
# 1                                NaN                          NaN       False
# 2                                NaN                          NaN       False
# 3                                NaN                          NaN         NaN
# 4                                NaN                          NaN       False
# ...                              ...                          ...         ...
# 364684                           NaN                          NaN       False
# 364685                           NaN                          NaN       False
# 364686                           NaN                          NaN       False
# 364687                           NaN                          NaN       False
# 364688                           NaN                          NaN       False
#
#         is_eRx trackrx_statusflow trackrx_last_status trackrx_last_delivery  \
# 0         True         U->B->U->F                   F                   NaN
# 1         True   U->B->U->F->U->B                   B                     D
# 2         True               U->B                   B                     D
# 3         True         U->B->U->F                   F                   NaN
# 4         True               U->B                   B                     D
# ...        ...                ...                 ...                   ...
# 364684    True               U->B                   B                   NaN
# 364685    True               U->B                   B                   NaN
# 364686    True               U->B                   B                   NaN
# 364687    True               U->B                   B                   NaN
# 364688    True               U->B                   B                     D
#
#        trackrx_delivery_flow trackrx_pickuptime_flow trackrx_pickedup_flow  \
# 0                        NaN                     NaN                   ->N
# 1                    None->D           None->3:32 PM                ->N->Y
# 2                    None->D                     NaN                   NaN
# 3              None->D->None                     NaN                   ->N
# 4                    None->D           None->2:32 PM                   ->Y
# ...                      ...                     ...                   ...
# 364684         None->D->None           None->4:25 PM                   ->Y
# 364685         None->D->None           None->4:25 PM                   ->Y
# 364686         None->D->None           None->4:25 PM                   ->Y
# 364687         None->D->None           None->4:25 PM                   ->Y
# 364688               None->D           None->5:20 PM                   ->Y
#
#        trackrx_last_pickuped trackrx_last_ibdtag trackrx_last_callinstag  \
# 0                          N          TIME STUDY                     NaN
# 1                          Y                   0                     NaN
# 2                        NaN                   0                     NaN
# 3                          N                 NaN                     NaN
# 4                          Y                 NaN                     NaN
# ...                      ...                 ...                     ...
# 364684                     Y                 NaN                     NaN
# 364685                     Y                 NaN                     NaN
# 364686                     Y                 NaN                     NaN
# 364687                     Y                 NaN                     NaN
# 364688                     Y                 NaN                     NaN
#
#          end_filed_datetime trackrx_callins_processing_start  \
# 0       2022-01-08 12:16:15                              NaN
# 1       2021-11-19 11:46:07                              NaN
# 2                       NaN                              NaN
# 3       2021-12-23 15:56:35                              NaN
# 4                       NaN                              NaN
# ...                     ...                              ...
# 364684                  NaN                              NaN
# 364685                  NaN                              NaN
# 364686                  NaN                              NaN
# 364687                  NaN                              NaN
# 364688                  NaN                              NaN
#
#        ibd_processing_enddatetime trackrx_ibd_processing_start  \
# 0                             NaN          2021-12-09 12:44:54
# 1             2021-11-06 09:04:28          2021-10-18 11:09:31
# 2             2021-12-31 13:50:55          2021-12-23 09:35:06
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 364684                        NaN                          NaN
# 364685                        NaN                          NaN
# 364686                        NaN                          NaN
# 364687                        NaN                          NaN
# 364688                        NaN                          NaN
#
#        time_consumed_ibd_regular  times_processed_ibd_regular  \
# 0                0 days 02:37:03                          1.0
# 1                3 days 06:57:30                          2.0
# 2                3 days 21:33:48                          2.0
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 364684                       NaN                          NaN
# 364685                       NaN                          NaN
# 364686                       NaN                          NaN
# 364687                       NaN                          NaN
# 364688                       NaN                          NaN
#
#        status_ibd_regular time_consumed_ibd_2K  times_processed_ibd_2K  \
# 0               completed                  NaN                     NaN
# 1               completed                  NaN                     NaN
# 2               completed                  NaN                     NaN
# 3                     NaN                  NaN                     NaN
# 4                     NaN                  NaN                     NaN
# ...                   ...                  ...                     ...
# 364684                NaN                  NaN                     NaN
# 364685                NaN                  NaN                     NaN
# 364686                NaN                  NaN                     NaN
# 364687                NaN                  NaN                     NaN
# 364688                NaN                  NaN                     NaN
#
#        status_ibd_2K total_processing_time_ibd  times_processed_ibd  \
# 0                NaN                       NaN                  NaN
# 1                NaN           4 days 16:56:34                  1.0
# 2                NaN           4 days 02:00:06                  1.0
# 3                NaN                       NaN                  NaN
# 4                NaN                       NaN                  NaN
# ...              ...                       ...                  ...
# 364684           NaN                       NaN                  NaN
# 364685           NaN                       NaN                  NaN
# 364686           NaN                       NaN                  NaN
# 364687           NaN                       NaN                  NaN
# 364688           NaN                       NaN                  NaN
#
#        ibd_final_status time_consumed_callforins_day01  \
# 0                   NaN                            NaN
# 1             completed                            NaN
# 2             completed                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# ...                 ...                            ...
# 364684              NaN                            NaN
# 364685              NaN                            NaN
# 364686              NaN                            NaN
# 364687              NaN                            NaN
# 364688              NaN                            NaN
#
#         times_processed_callforins_day01 status_callforins_day01  \
# 0                                    NaN                     NaN
# 1                                    NaN                     NaN
# 2                                    NaN                     NaN
# 3                                    NaN                     NaN
# 4                                    NaN                     NaN
# ...                                  ...                     ...
# 364684                               NaN                     NaN
# 364685                               NaN                     NaN
# 364686                               NaN                     NaN
# 364687                               NaN                     NaN
# 364688                               NaN                     NaN
#
#        time_consumed_callforins_day02  times_processed_callforins_day02  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 364684                            NaN                               NaN
# 364685                            NaN                               NaN
# 364686                            NaN                               NaN
# 364687                            NaN                               NaN
# 364688                            NaN                               NaN
#
#        status_callforins_day02 time_consumed_callforins_day03  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ...                        ...                            ...
# 364684                     NaN                            NaN
# 364685                     NaN                            NaN
# 364686                     NaN                            NaN
# 364687                     NaN                            NaN
# 364688                     NaN                            NaN
#
#         times_processed_callforins_day03 status_callforins_day03        city  \
# 0                                    NaN                     NaN         NaN
# 1                                    NaN                     NaN         NaN
# 2                                    NaN                     NaN         NaN
# 3                                    NaN                     NaN         NaN
# 4                                    NaN                     NaN  SOMERVILLE
# ...                                  ...                     ...         ...
# 364684                               NaN                     NaN         NaN
# 364685                               NaN                     NaN         NaN
# 364686                               NaN                     NaN         NaN
# 364687                               NaN                     NaN         NaN
# 364688                               NaN                     NaN         NaN
#
#        track_rx_filled                                      DRUGNAME    QTY  \
# 0                  NaN                                           NaN    NaN
# 1                  NaN                                           NaN    NaN
# 2                  NaN                                           NaN    NaN
# 3                  NaN                                           NaN    NaN
# 4           2021-10-13  RESTASIS* 0.05% EMUL (00023-9163-60) -ew2831  180.0
# ...                ...                                           ...    ...
# 364684             NaN                                           NaN    NaN
# 364685             NaN                                           NaN    NaN
# 364686             NaN                                           NaN    NaN
# 364687             NaN                                           NaN    NaN
# 364688             NaN                                           NaN    NaN
#
#        PATIENTCOPAY  TOTALINSPAID  PATZIP      PATDOB INSCODE       DATEO  \
# 0               NaN           NaN     NaN         NaN     NaN         NaN
# 1               NaN           NaN     NaN         NaN     NaN         NaN
# 2               NaN           NaN     NaN         NaN     NaN         NaN
# 3               NaN           NaN     NaN         NaN     NaN         NaN
# 4               0.0       1970.51  7086.0  05-27-1943     AC1  2021-10-12
# ...             ...           ...     ...         ...     ...         ...
# 364684          NaN           NaN     NaN         NaN     NaN         NaN
# 364685          NaN           NaN     NaN         NaN     NaN         NaN
# 364686          NaN           NaN     NaN         NaN     NaN         NaN
# 364687          NaN           NaN     NaN         NaN     NaN         NaN
# 364688          NaN           NaN     NaN         NaN     NaN         NaN
#
#        PATFNAME PATLNAME PATMOBILENO    PATPHONE patsex  TOTALRXAMOUNT  \
# 0           NaN      NaN         NaN         NaN    NaN            NaN
# 1           NaN      NaN         NaN         NaN    NaN            NaN
# 2           NaN      NaN         NaN         NaN    NaN            NaN
# 3           NaN      NaN         NaN         NaN    NaN            NaN
# 4         DORIS   FERMIN  2019814027  2014729358      F        1970.51
# ...         ...      ...         ...         ...    ...            ...
# 364684      NaN      NaN         NaN         NaN    NaN            NaN
# 364685      NaN      NaN         NaN         NaN    NaN            NaN
# 364686      NaN      NaN         NaN         NaN    NaN            NaN
# 364687      NaN      NaN         NaN         NaN    NaN            NaN
# 364688      NaN      NaN         NaN         NaN    NaN            NaN
#
#         patientno_mms   workflow_last_status workflow_last_change_datetime  \
# 0                 NaN                    NaN           2021-12-17 13:00:43
# 1                 NaN    PICKED UP/DELIVERED           2021-12-01 13:59:47
# 2                 NaN  SCHEDULED FUTURE DATE           2021-12-31 16:26:18
# 3                 NaN            CX-REVERSAL           2021-12-22 17:00:36
# 4             24019.0    PICKED UP/DELIVERED           2021-10-21 17:48:19
# ...               ...                    ...                           ...
# 364684            NaN         ROBO DIALING 2           2021-12-28 09:54:39
# 364685            NaN         ROBO DIALING 2           2021-12-28 09:54:38
# 364686            NaN         ROBO DIALING 2           2021-12-28 09:54:37
# 364687            NaN         ROBO DIALING 2           2021-12-28 09:54:35
# 364688            NaN           DEL-REVERSAL           2021-12-29 11:14:56
#
#         cxrev_last_datetime  times_cx_reversed delrev_last_datetime  \
# 0                       NaN                NaN                  NaN
# 1                       NaN                NaN                  NaN
# 2                       NaN                NaN                  NaN
# 3       2021-12-22 17:00:36                1.0                  NaN
# 4                       NaN                NaN                  NaN
# ...                     ...                ...                  ...
# 364684                  NaN                NaN                  NaN
# 364685                  NaN                NaN                  NaN
# 364686                  NaN                NaN                  NaN
# 364687                  NaN                NaN                  NaN
# 364688                  NaN                NaN  2021-12-29 11:14:56
#
#          times_del_reversed       batchno       batchcreatedon  \
# 0                       NaN           NaN                  NaN
# 1                       NaN           NaN                  NaN
# 2                       NaN  BN2201030030  2022-01-03 19:24:00
# 3                       NaN           NaN                  NaN
# 4                       NaN  BN2110200008  2021-10-20 10:38:00
# ...                     ...           ...                  ...
# 364684                  NaN  BN2201030012  2022-01-03 10:53:00
# 364685                  NaN  BN2201030012  2022-01-03 10:53:00
# 364686                  NaN  BN2201030012  2022-01-03 10:53:00
# 364687                  NaN  BN2201030012  2022-01-03 10:53:00
# 364688  1970-01-01 00:00:01  BN2201080009  2022-01-08 11:07:00
#
#               batchclosedon         deliverydate      driver          phone  \
# 0                       NaN                  NaN         NaN            NaN
# 1                       NaN                  NaN         NaN            NaN
# 2                       NaN                  NaN  LEONARD     (646)344-9428
# 3                       NaN                  NaN         NaN            NaN
# 4                       NaN                  NaN  DRIVER 1    (201)472-9358
# ...                     ...                  ...         ...            ...
# 364684                  NaN                  NaN  ANTHONYE    (212)533-3281
# 364685                  NaN                  NaN  ANTHONYE    (212)533-3281
# 364686                  NaN                  NaN  ANTHONYE    (212)533-3281
# 364687                  NaN                  NaN  ANTHONYE    (212)533-3281
# 364688  2022-01-08 17:22:00  2022-01-08 17:20:00  J. MOESER   (646)934-9927
#
#        patient_phone_x batch_delivery_date batch_delivery_datetime  \
# 0                  NaN                 NaN                     NaN
# 1                  NaN                 NaN                     NaN
# 2           6463449428          2022-01-03     2022-01-03 19:24:00
# 3                  NaN                 NaN                     NaN
# 4           2014729358          2021-10-20     2021-10-20 10:38:00
# ...                ...                 ...                     ...
# 364684    2125333281.0          2022-01-03     2022-01-03 10:53:00
# 364685    2125333281.0          2022-01-03     2022-01-03 10:53:00
# 364686    2125333281.0          2022-01-03     2022-01-03 10:53:00
# 364687    2125333281.0          2022-01-03     2022-01-03 10:53:00
# 364688    6469349927.0          2022-01-08     2022-01-08 11:07:00
#
#        batch_creation_datetime      batch_id  no_times_batch_created  \
# 0                          NaN           NaN                     NaN
# 1                          NaN           NaN                     NaN
# 2          2022-01-03 19:24:00  BN2201030030                     1.0
# 3                          NaN           NaN                     NaN
# 4          2021-10-20 10:38:00  BN2110200008                     1.0
# ...                        ...           ...                     ...
# 364684     2022-01-03 10:53:00  BN2201030012                     1.0
# 364685     2022-01-03 10:53:00  BN2201030012                     1.0
# 364686     2022-01-03 10:53:00  BN2201030012                     1.0
# 364687     2022-01-03 10:53:00  BN2201030012                     1.0
# 364688     2022-01-08 11:07:00  BN2201080009                     1.0
#
#        delivery_date shortId_of status  patient_phone_y  patient_zipcode  \
# 0                NaN        NaN    NaN              NaN              NaN
# 1                NaN        NaN    NaN              NaN              NaN
# 2                NaN        NaN    NaN              NaN              NaN
# 3                NaN        NaN    NaN              NaN              NaN
# 4                NaN        NaN    NaN              NaN              NaN
# ...              ...        ...    ...              ...              ...
# 364684           NaN   2254d2fd    NaN              NaN              NaN
# 364685           NaN   2254d2fd    NaN              NaN              NaN
# 364686           NaN   2254d2fd    NaN              NaN              NaN
# 364687           NaN   2254d2fd    NaN              NaN              NaN
# 364688           NaN        NaN    NaN              NaN              NaN
#
#        delivery_time  Driver Number didSucceed match_method rx_no_fill  \
# 0                NaN            NaN        NaN          NaN        NaN
# 1                NaN            NaN        NaN          NaN  1199550-0
# 2                NaN            NaN        NaN          NaN  1158109-0
# 3                NaN            NaN        NaN          NaN  1158579-0
# 4                NaN            NaN        NaN          NaN  1198582-0
# ...              ...            ...        ...          ...        ...
# 364684           NaN            NaN        NaN          NaN  1159606-0
# 364685           NaN            NaN        NaN          NaN  1159601-0
# 364686           NaN            NaN        NaN          NaN  1159599-0
# 364687           NaN            NaN        NaN          NaN  1159597-0
# 364688           NaN            NaN        NaN          NaN  1160648-0
#
#        zone_name  delivery_patient_zip_code dl_app_delivery_created_time  \
# 0            NaN                        NaN                          NaN
# 1         Zone 3                     7083.0          2021-11-30 19:39:44
# 2         Zone 2                    11358.0          2021-12-31 17:25:49
# 3         Zone 1                    11233.0          2021-12-11 16:32:10
# 4         Zone 3                     7086.0          2021-10-15 12:50:34
# ...          ...                        ...                          ...
# 364684    Zone 1                    11206.0          2022-01-03 10:01:18
# 364685    Zone 1                    11206.0          2022-01-03 10:01:18
# 364686    Zone 1                    11206.0          2022-01-03 10:01:18
# 364687    Zone 1                    11206.0          2022-01-03 10:01:18
# 364688    Zone 4                    11220.0          2022-01-07 18:29:50
#
#        dl_app_delivery_time onfleet_short_id  delivery_id  \
# 0                       NaN              NaN          NaN
# 1       2021-12-02 23:44:20         183e0ac3     201092.0
# 2       2022-01-04 13:08:08         de52441b     224344.0
# 3                       NaN         d30a1ef4     210352.0
# 4       2021-10-20 14:42:35         2e7658bf     162640.0
# ...                     ...              ...          ...
# 364684  2022-01-03 14:14:41         d653f835     224857.0
# 364685  2022-01-03 14:14:41         d653f835     224857.0
# 364686  2022-01-03 14:14:41         d653f835     224857.0
# 364687  2022-01-03 14:14:41         d653f835     224857.0
# 364688  2022-01-08 13:22:10         97066ea5     230686.0
#
#                      driver_name       onfleet_state pharmacy_location_dl  \
# 0                            NaN                 NaN                  NaN
# 1       HealthEx Day of Delivery           COMPLETED                NJ-SO
# 2        Leonard Lewis 🚗 Z4+ ALL           COMPLETED                NY-BK
# 3                            NaN  DELETED_ON_ONFLEET                NY-BK
# 4       HealthEx Day of Delivery           COMPLETED                NJ-SO
# ...                          ...                 ...                  ...
# 364684           Anthony Estevez              FAILED                NY-BK
# 364685           Anthony Estevez              FAILED                NY-BK
# 364686           Anthony Estevez              FAILED                NY-BK
# 364687           Anthony Estevez              FAILED                NY-BK
# 364688           Jonathan Moeser           COMPLETED                NY-BK
#
#         pharmacy_nabp rx_no_fill_px       task_completed           slot_start  \
# 0                 NaN           NaN                  NaN                  NaN
# 1           3135868.0     1199550-0  2021-11-30 23:39:40  2021-12-02 21:00:00
# 2           3352779.0     1158109-0  2021-12-31 21:25:43  2022-01-04 17:00:00
# 3           3352779.0     1158579-0  2021-12-15 21:26:07  2021-12-17 17:00:00
# 4           3135868.0     1198582-0  2021-10-15 16:50:32  2021-10-22 20:00:00
# ...               ...           ...                  ...                  ...
# 364684      3352779.0     1159606-0  2022-01-03 14:01:13  2022-01-03 14:00:00
# 364685      3352779.0     1159601-0  2022-01-03 14:01:13  2022-01-03 14:00:00
# 364686      3352779.0     1159599-0  2022-01-03 14:01:13  2022-01-03 14:00:00
# 364687      3352779.0     1159597-0  2022-01-03 14:01:13  2022-01-03 14:00:00
# 364688      3352779.0     1160648-0  2022-01-07 22:29:48  2022-01-08 18:00:00
#
#                    slot_end pharmacy_location_px refill_tag  \
# 0                       NaN                  NaN        New
# 1       2021-12-03 00:00:00                NJ-SO        New
# 2       2022-01-04 20:00:00                NY-BK        New
# 3       2021-12-17 20:00:00                NY-BK        New
# 4       2021-10-22 23:00:00                NJ-SO        New
# ...                     ...                  ...        ...
# 364684  2022-01-04 02:00:00                NY-BK        New
# 364685  2022-01-04 02:00:00                NY-BK        New
# 364686  2022-01-04 02:00:00                NY-BK        New
# 364687  2022-01-04 02:00:00                NY-BK        New
# 364688  2022-01-08 21:00:00                NY-BK        New
#
#          track_rx_delivered  PATPHONE_len  PATMOBILENO_len shortId_mms  \
# 0                       NaN             3                3         NaN
# 1       2021-12-02 23:44:20             3                3         NaN
# 2       2022-01-04 13:08:08             3                3         NaN
# 3                       NaN             3                3         NaN
# 4       2021-10-20 14:42:35            10               10         NaN
# ...                     ...           ...              ...         ...
# 364684  2022-01-03 14:14:41             3                3         NaN
# 364685  2022-01-03 14:14:41             3                3         NaN
# 364686  2022-01-03 14:14:41             3                3         NaN
# 364687  2022-01-03 14:14:41             3                3         NaN
# 364688  2022-01-08 13:22:10             3                3         NaN
#
#        new_shortId status_tag                                    id  \
# 0              NaN        NaN  c31579a5-6933-438a-8846-8bf6616b4f8c
# 1         183e0ac3  Delivered  8fc27f27-0f43-4814-8361-e98d7ab6d4fb
# 2         de52441b  Delivered  0396d1ff-b44f-40ea-a792-2be0f42106b3
# 3              NaN        NaN  0d126211-11ac-45c8-b59e-ec2026c0212f
# 4         2e7658bf  Delivered  d939a587-ff3c-4287-8c77-400152ab7ca7
# ...            ...        ...                                   ...
# 364684    d653f835  Delivered  47534540-cec8-4801-b121-fde050e19de4
# 364685    d653f835  Delivered  c9490bbf-ab6f-4aa3-8e6c-74481025e06a
# 364686    d653f835  Delivered  779eb1d8-efb3-4cc1-ad76-7ea99c089606
# 364687    d653f835  Delivered  8e292cc1-2bb2-48a7-a2b2-869e38b542c2
# 364688    97066ea5  Delivered  0fa4282d-089a-4987-8a9c-4352a934a2b1
#
#         rx_number           rx_status                            patient_id  \
# 0       1157987.0            Reversal  f72b814b-5e01-4812-8064-e9a053b1368d
# 1       1199550.0  Ready for delivery  74d86f09-a4f1-43ce-8aee-7dd6db2cdaec
# 2       1158109.0  Ready for delivery  e5575d5f-a544-4246-b7ab-fefaea043cfe
# 3       1158579.0  Ready for delivery  46c249ed-307d-4a75-8d54-1367808215ec
# 4       1198582.0  Ready for delivery  5ab0036d-09ed-4449-a972-7ef94a8fb1be
# ...           ...                 ...                                   ...
# 364684  1159606.0  Ready for delivery  cae17372-0379-4029-bb9b-a2936a61a53e
# 364685  1159601.0  Ready for delivery  cae17372-0379-4029-bb9b-a2936a61a53e
# 364686  1159599.0  Ready for delivery  cae17372-0379-4029-bb9b-a2936a61a53e
# 364687  1159597.0  Ready for delivery  cae17372-0379-4029-bb9b-a2936a61a53e
# 364688  1160648.0  Ready for delivery  5ea7ee33-e353-46d5-a88f-99aa47c3824a
#
#                                prescriber_id  \
# 0       f1967c16-407b-11eb-b378-0242ac130002
# 1       36c74da0-b131-42b7-9fa3-cc4c5c8beb0f
# 2       f1967c16-407b-11eb-b378-0242ac130002
# 3       f1967c16-407b-11eb-b378-0242ac130002
# 4       f1967c16-407b-11eb-b378-0242ac130002
# ...                                      ...
# 364684  f1967c16-407b-11eb-b378-0242ac130002
# 364685  f1967c16-407b-11eb-b378-0242ac130002
# 364686  f1967c16-407b-11eb-b378-0242ac130002
# 364687  f1967c16-407b-11eb-b378-0242ac130002
# 364688  f1967c16-407b-11eb-b378-0242ac130002
#
#                                 insurance_id             drug_name drug_form  \
# 0                                        NaN  Drug Name: 1157987-0       NaN
# 1       14371075-f3bf-48cc-a656-fbb379592cd5         ENSTILAR FOAM      FOAM
# 2                                        NaN                PROLIA       NaN
# 3                                        NaN  Drug Name: 1158579-0       NaN
# 4                                        NaN  Drug Name: 1198582-0       NaN
# ...                                      ...                   ...       ...
# 364684                                   NaN  Drug Name: 1159606-0       NaN
# 364685                                   NaN  Drug Name: 1159601-0       NaN
# 364686                                   NaN  Drug Name: 1159599-0       NaN
# 364687                                   NaN  Drug Name: 1159597-0       NaN
# 364688                                   NaN  Drug Name: 1160648-0       NaN
#
#        followup_tag  copay   amount       ndc_prsc  quantity  fill_number  \
# 0               NaN  25.00    25.00       999999.0       NaN          0.0
# 1        NEW PX APP   4.00  1235.41  50222030260.0      60.0          0.0
# 2               NaN   0.00     0.00       999999.0       NaN          0.0
# 3               NaN   0.00     0.00       999999.0       NaN          0.0
# 4               NaN   0.00     0.00       999999.0       NaN          0.0
# ...             ...    ...      ...            ...       ...          ...
# 364684          NaN   0.00     0.00       999999.0       NaN          0.0
# 364685          NaN   0.00     0.00       999999.0       NaN          0.0
# 364686          NaN   0.00     0.00       999999.0       NaN          0.0
# 364687          NaN   0.00     0.00       999999.0       NaN          0.0
# 364688          NaN   0.26     0.26       999999.0       NaN          0.0
#
#        reversed                  reversal_reason   reversal_fill_date  \
# 0          True  Patient no longer takes this RX  2022-01-07 00:00:00
# 1           NaN                              NaN                  NaN
# 2           NaN                              NaN                  NaN
# 3           NaN                              NaN                  NaN
# 4           NaN                              NaN                  NaN
# ...         ...                              ...                  ...
# 364684      NaN                              NaN                  NaN
# 364685      NaN                              NaN                  NaN
# 364686      NaN                              NaN                  NaN
# 364687      NaN                              NaN                  NaN
# 364688      NaN                              NaN                  NaN
#
#         day_supply  status_prsc           created_at  \
# 0              NaN          NaN  2022-01-05 15:39:23
# 1             20.0  PA_APPROVED  2021-11-30 18:16:49
# 2              NaN          NaN  2021-12-31 21:24:42
# 3              NaN          NaN  2021-12-15 21:24:53
# 4              NaN          NaN  2021-10-15 16:49:34
# ...            ...          ...                  ...
# 364684         NaN          NaN  2022-01-03 13:59:13
# 364685         NaN          NaN  2022-01-03 13:59:13
# 364686         NaN          NaN  2022-01-03 13:59:13
# 364687         NaN          NaN  2022-01-03 13:59:13
# 364688         NaN          NaN  2022-01-07 22:27:54
#
#                                      id_task  \
# 0       7ce9870e-35a1-4bbf-b9be-24f97fc7f688
# 1       44f3760e-8013-493c-a45b-08f62900a26c
# 2       34d897f0-56f3-4bbf-b117-7be85fa99513
# 3       53ef642b-b525-47ff-941d-1f98be24b316
# 4       f92a3293-781a-4d5e-ab90-bda75c1e6ab7
# ...                                      ...
# 364684  155a6243-1bff-4e43-89fa-a8ce71b00462
# 364685  155a6243-1bff-4e43-89fa-a8ce71b00462
# 364686  155a6243-1bff-4e43-89fa-a8ce71b00462
# 364687  155a6243-1bff-4e43-89fa-a8ce71b00462
# 364688  5b959488-110b-49fc-a155-69c03c09ce09
#
#                                    status_id  \
# 0       dae11221-7cde-41a7-b522-fe51a448095f
# 1       dae11221-7cde-41a7-b522-fe51a448095f
# 2       dae11221-7cde-41a7-b522-fe51a448095f
# 3       dae11221-7cde-41a7-b522-fe51a448095f
# 4       dae11221-7cde-41a7-b522-fe51a448095f
# ...                                      ...
# 364684  dae11221-7cde-41a7-b522-fe51a448095f
# 364685  dae11221-7cde-41a7-b522-fe51a448095f
# 364686  dae11221-7cde-41a7-b522-fe51a448095f
# 364687  dae11221-7cde-41a7-b522-fe51a448095f
# 364688  dae11221-7cde-41a7-b522-fe51a448095f
#
#                            associate_id_prsc is_scheduled  scheduled_time  \
# 0       ed82bf38-485a-42ec-ab82-1c4cc6cd5157          NaN             NaN
# 1       a131a2e6-a3d3-431f-9c1d-2af6e1eea868         True             NaN
# 2       00655385-9329-464f-a682-b7cebdd39967         True             NaN
# 3       76e9dc10-67b4-412e-b7e8-41bd157c2206         True             NaN
# 4       07da8775-93d7-45a6-aacb-29961ad016c5         True             NaN
# ...                                      ...          ...             ...
# 364684  1122e837-d293-44c3-a254-9d88b588a38e         True             NaN
# 364685  1122e837-d293-44c3-a254-9d88b588a38e         True             NaN
# 364686  1122e837-d293-44c3-a254-9d88b588a38e         True             NaN
# 364687  1122e837-d293-44c3-a254-9d88b588a38e         True             NaN
# 364688  40c548a2-d8ba-43f2-be74-cc8d68c6c564         True             NaN
#
#        error_status           claimed_at      created_at_task  \
# 0               NaN  2022-01-07 15:45:56  2022-01-05 15:39:23
# 1               NaN                  NaN  2021-11-30 18:16:49
# 2               NaN  2021-12-31 21:24:42  2021-12-31 21:24:42
# 3               NaN  2021-12-15 21:24:54  2021-12-15 21:24:53
# 4               NaN  2021-10-15 16:49:34  2021-10-15 16:49:34
# ...             ...                  ...                  ...
# 364684          NaN  2022-01-03 13:59:14  2022-01-03 13:59:13
# 364685          NaN  2022-01-03 13:59:14  2022-01-03 13:59:13
# 364686          NaN  2022-01-03 13:59:14  2022-01-03 13:59:13
# 364687          NaN  2022-01-03 13:59:14  2022-01-03 13:59:13
# 364688          NaN  2022-01-07 22:27:54  2022-01-07 22:27:54
#
#        is_all_reversal_rxs         completed_at cancelled_at  \
# 0                     True  2022-01-07 15:48:44          NaN
# 1                      NaN  2021-11-30 23:39:40          NaN
# 2                      NaN  2021-12-31 21:25:43          NaN
# 3                      NaN  2021-12-15 21:26:07          NaN
# 4                      NaN  2021-10-15 16:50:32          NaN
# ...                    ...                  ...          ...
# 364684                 NaN  2022-01-03 14:01:13          NaN
# 364685                 NaN  2022-01-03 14:01:13          NaN
# 364686                 NaN  2022-01-03 14:01:13          NaN
# 364687                 NaN  2022-01-03 14:01:13          NaN
# 364688                 NaN  2022-01-07 22:29:48          NaN
#
#        cancellation_reason  pharmacy_nabp_prsc earliest_fill_date  \
# 0                      NaN           3352779.0                NaN
# 1                      NaN           3135868.0         2021-11-30
# 2                      NaN           3352779.0                NaN
# 3                      NaN           3352779.0                NaN
# 4                      NaN           3135868.0                NaN
# ...                    ...                 ...                ...
# 364684                 NaN           3352779.0                NaN
# 364685                 NaN           3352779.0                NaN
# 364686                 NaN           3352779.0                NaN
# 364687                 NaN           3352779.0                NaN
# 364688                 NaN           3352779.0                NaN
#
#         rx_numbers_count                                    rx_numbers_list  \
# 0                    1.0                                          1157987-0
# 1                    1.0                                          1199550-0
# 2                    1.0                                          1158109-0
# 3                    1.0                                          1158579-0
# 4                    2.0                                1198582-0,1198583-0
# ...                  ...                                                ...
# 364684               9.0  1152029-1,1159599-0,1149462-0,1152031-1,115959...
# 364685               9.0  1152029-1,1159599-0,1149462-0,1152031-1,115959...
# 364686               9.0  1152029-1,1159599-0,1149462-0,1152031-1,115959...
# 364687               9.0  1152029-1,1159599-0,1149462-0,1152031-1,115959...
# 364688               1.0                                          1160648-0
#
#         total_awp  days_contacted  latest_contacted_at insurance_category  \
# 0             NaN             2.0  2022-01-07 15:46:13                NaN
# 1         1402.74             0.0                  NaN         Commercial
# ...
# 364684                                   True
# 364685                                   True
# 364686                                   True
# 364687                                   True
# 364688                                   True
#
#         rx_entered_date_verification_boolean_d  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ...                                        ...
# 364684                                    True
# 364685                                    True
# 364686                                    True
# 364687                                    True
# 364688                                    True
#
#         rx_filledon_date_rxtimelines_boolean_d  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ...                                        ...
# 364684                                    True
# 364685                                    True
# 364686                                    True
# 364687                                    True
# 364688                                    True
#
#         rx_pickedup_date_rxtimelines_boolean_d  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 364684                                   False
# 364685                                   False
# 364686                                   False
# 364687                                   False
# 364688                                   False
#
#         new_delivered_date_d_boolean_d  \
# 0                                False
# 1                                 True
# 2                                 True
# 3                                False
# 4                                 True
# ...                                ...
# 364684                            True
# 364685                            True
# 364686                            True
# 364687                            True
# 364688                            True
#
#         rx_labelprint_date_verification_boolean_d  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
# ...                                           ...
# 364684                                       True
# 364685                                       True
# 364686                                       True
# 364687                                       True
# 364688                                       True
#
#         rx_drugpick_date_verification_boolean_d  \
# 0                                          True
# 1                                          True
# 2                                          True
# 3                                         False
# 4                                          True
# ...                                         ...
# 364684                                     True
# 364685                                     True
# 364686                                     True
# 364687                                     True
# 364688                                     True
#
#         rx_rphpick_date_verification_boolean_d  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                        False
# 4                                         True
# ...                                        ...
# 364684                                    True
# 364685                                    True
# 364686                                    True
# 364687                                    True
# 364688                                    True
#
#         first_billed_date_claimslog_boolean_d  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ...                                       ...
# 364684                                   True
# 364685                                   True
# 364686                                   True
# 364687                                   True
# 364688                                   True
#
#         last_billed_date_claimslog_boolean_d  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
# ...                                      ...
# 364684                                  True
# 364685                                  True
# 364686                                  True
# 364687                                  True
# 364688                                  True
#
#         processing_start_claimslog_boolean_d  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
# ...                                      ...
# 364684                                  True
# 364685                                  True
# 364686                                  True
# 364687                                  True
# 364688                                  True
#
#         processing_end_claimslog_boolean_d  current_status_rx_d  \
# 0                                     True                11100
# 1                                     True                11101
# 2                                     True                11101
# 3                                     True                11100
# 4                                     True                11101
# ...                                    ...                  ...
# 364684                                True                11101
# 364685                                True                11101
# 364686                                True                11101
# 364687                                True                11101
# 364688                                True                11101
#
#        Overall_Visibility_for_Rx_d erxreceived_rxtimelines_ltz_d  \
# 0                 Rx with only IBD     2021-12-09 07:31:00-05:00
# 1                 Rx with only IBD     2021-10-15 10:03:00-04:00
# 2                 Rx with only IBD     2021-12-09 09:37:00-05:00
# 3           Rx without IBD and CFI     2021-12-10 08:29:00-05:00
# 4           Rx without IBD and CFI     2021-10-12 12:26:00-04:00
# ...                            ...                           ...
# 364684      Rx without IBD and CFI     2021-12-14 05:51:00-05:00
# 364685      Rx without IBD and CFI     2021-12-14 05:51:00-05:00
# 364686      Rx without IBD and CFI     2021-12-14 05:51:00-05:00
# 364687      Rx without IBD and CFI     2021-12-14 05:51:00-05:00
# 364688      Rx without IBD and CFI     2021-12-16 05:28:00-05:00
#
#        rx_entered_date_rxtimelines_ltz_d first_billed_date_claimslog_ltz_d  \
# 0              2021-12-09 07:39:00-05:00         2021-12-13 04:41:32-05:00
# 1              2021-10-15 13:34:00-04:00         2021-11-06 05:01:57-04:00
# 2              2021-12-09 09:50:00-05:00         2021-12-31 08:50:51-05:00
# 3              2021-12-10 08:54:00-05:00         2021-12-10 08:57:26-05:00
# 4              2021-10-13 05:38:25-04:00         2021-10-13 10:05:14-04:00
# ...                                  ...                               ...
# 364684         2021-12-14 06:00:00-05:00         2021-12-27 02:20:29-05:00
# 364685         2021-12-14 05:58:00-05:00         2021-12-27 02:20:22-05:00
# 364686         2021-12-14 05:57:00-05:00         2021-12-27 02:20:20-05:00
# 364687         2021-12-14 05:57:00-05:00         2021-12-27 02:20:17-05:00
# 364688         2021-12-16 05:33:00-05:00         2021-12-16 05:35:01-05:00
#
#        last_billed_date_claimslog_ltz_d rx_drugpick_date_verification_ltz_d  \
# 0             2021-12-31 10:31:15-05:00           2021-12-14 05:02:00-05:00
# 1             2021-11-30 08:08:06-05:00           2021-11-30 13:54:00-05:00
# 2             2021-12-31 08:50:51-05:00           2022-01-03 07:29:00-05:00
# 3             2021-12-22 12:16:45-05:00                                 NaN
# 4             2021-10-13 10:05:14-04:00           2021-10-13 10:39:00-04:00
# ...                                 ...                                 ...
# 364684        2021-12-27 02:20:29-05:00           2021-12-27 05:27:00-05:00
# 364685        2021-12-27 02:20:22-05:00           2021-12-27 05:27:00-05:00
# 364686        2021-12-27 02:20:20-05:00           2021-12-27 05:27:00-05:00
# 364687        2021-12-27 05:31:07-05:00           2021-12-27 05:31:00-05:00
# 364688        2021-12-29 09:19:50-05:00           2021-12-29 09:33:00-05:00
#
#        rx_rphpick_date_verification_ltz_d  \
# 0               2021-12-14 05:40:08-05:00
# 1               2021-12-01 04:25:19-05:00
# 2               2022-01-03 08:09:50-05:00
# 3                                     NaN
# 4               2021-10-13 11:19:06-04:00
# ...                                   ...
# 364684          2021-12-27 07:26:04-05:00
# 364685          2021-12-27 07:26:15-05:00
# 364686          2021-12-27 07:26:43-05:00
# 364687          2021-12-27 07:26:54-05:00
# 364688          2021-12-29 09:33:25-05:00
#
#        pickup_date_scheduled_deliveries_ltz_d  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 364684                                    NaN
# 364685                                    NaN
# 364686                                    NaN
# 364687                                    NaN
# 364688                                    NaN
#
#        scheduled_startdate_scheduled_deliveries_ltz_d  \
# 0                                                 NaN
# 1                           2021-12-02 16:00:00-05:00
# 2                           2022-01-04 12:00:00-05:00
# 3                           2021-12-17 12:00:00-05:00
# 4                           2021-10-22 16:00:00-04:00
# ...                                               ...
# 364684                      2022-01-03 09:00:00-05:00
# 364685                      2022-01-03 09:00:00-05:00
# 364686                      2022-01-03 09:00:00-05:00
# 364687                      2022-01-03 09:00:00-05:00
# 364688                      2022-01-08 13:00:00-05:00
#
#        scheduled_enddate_scheduled_deliveries_ltz_d  \
# 0                                               NaN
# 1                         2021-12-02 19:00:00-05:00
# 2                         2022-01-04 15:00:00-05:00
# 3                         2021-12-17 15:00:00-05:00
# 4                         2021-10-22 19:00:00-04:00
# ...                                             ...
# 364684                    2022-01-03 21:00:00-05:00
# 364685                    2022-01-03 21:00:00-05:00
# 364686                    2022-01-03 21:00:00-05:00
# 364687                    2022-01-03 21:00:00-05:00
# 364688                    2022-01-08 16:00:00-05:00
#
#          new_delivered_date_ltz_d created_at_contactevents_ltz_d  \
# 0                             NaN      2022-01-07 10:46:13-05:00
# 1       2021-12-02 18:44:20-05:00                            NaN
# 2       2022-01-04 08:08:08-05:00      2021-12-31 16:24:46-05:00
# 3                             NaN      2021-12-15 16:25:01-05:00
# 4       2021-10-20 10:42:35-04:00      2021-10-15 12:49:43-04:00
# ...                           ...                            ...
# 364684  2022-01-03 09:14:41-05:00      2022-01-03 08:59:21-05:00
# 364685  2022-01-03 09:14:41-05:00      2022-01-03 08:59:21-05:00
# 364686  2022-01-03 09:14:41-05:00      2022-01-03 08:59:21-05:00
# 364687  2022-01-03 09:14:41-05:00      2022-01-03 08:59:21-05:00
# 364688  2022-01-08 08:22:10-05:00      2022-01-07 17:29:44-05:00
#
#        rx_filledon_date_rxtimelines_ltz_d is_rescheduled_d  \
# 0               2021-12-31 08:00:00-05:00              NaN
# 1               2021-11-30 06:46:08-05:00              NaN
# 2               2021-12-30 19:00:00-05:00              NaN
# 3               2021-12-22 12:16:00-05:00      Rescheduled
# 4               2021-10-13 05:38:25-04:00              NaN
# ...                                   ...              ...
# 364684          2021-12-27 05:59:33-05:00      Rescheduled
# 364685          2021-12-27 05:57:36-05:00      Rescheduled
# 364686          2021-12-27 05:57:08-05:00      Rescheduled
# 364687          2021-12-27 05:56:32-05:00      Rescheduled
# 364688          2021-12-29 09:19:00-05:00      Rescheduled
#
#         rescheduling_count_d             last_run track_rx_recieved_new  \
# 0                        1.0  2022-01-10 06:31:22   2021-12-09 12:31:00
# 1                        1.0  2022-01-10 06:31:22   2021-10-15 14:03:00
# 2                        NaN  2022-01-10 06:31:22   2021-12-09 14:37:00
# 3                        1.0  2022-01-10 06:31:22   2021-12-10 13:29:00
# 4                        NaN  2022-01-10 06:31:22   2021-10-12 16:26:00
# ...                      ...                  ...                   ...
# 364684                   1.0  2022-01-10 06:31:22   2021-12-14 10:51:00
# 364685                   1.0  2022-01-10 06:31:22   2021-12-14 10:51:00
# 364686                   1.0  2022-01-10 06:31:22   2021-12-14 10:51:00
# 364687                   1.0  2022-01-10 06:31:22   2021-12-14 10:51:00
# 364688                   1.0  2022-01-10 06:31:22   2021-12-16 10:28:00
#
#        track_rx_entered_new pharmacy loc mon_key mon_key_2  \
# 0       2021-12-09 12:39:00        NY-BK   12-21    Dec-21
# 1       2021-10-15 17:34:00        NJ-SO   11-21    Nov-21
# 2       2021-12-09 14:50:00        NY-BK   12-21    Dec-21
# 3       2021-12-10 13:54:00        NY-BK   12-21    Dec-21
# 4       2021-10-13 09:38:25        NJ-SO   10-21    Oct-21
# ...                     ...          ...     ...       ...
# 364684  2021-12-14 11:00:00        NY-BK   12-21    Dec-21
# 364685  2021-12-14 10:58:00        NY-BK   12-21    Dec-21
# 364686  2021-12-14 10:57:00        NY-BK   12-21    Dec-21
# 364687  2021-12-14 10:57:00        NY-BK   12-21    Dec-21
# 364688  2021-12-16 10:33:00        NY-BK   12-21    Dec-21
#
#        trackrx_last_status_new delivery_status
# 0                           NB             NaN
# 1                            B       Delivered
# 2                            B       Delivered
# 3                           NB             NaN
# 4                            B       Delivered
# ...                        ...             ...
# 364684                       B       Delivered
# 364685                       B       Delivered
# 364686                       B       Delivered
# 364687                       B       Delivered
# 364688                       B       Delivered
#
# [317713 rows x 231 columns]

# %%
pd.pivot_table(dff, values = 'rx_code_key_location', index=['delivery_status'], aggfunc = 'count').div(6)#.reset_index()
# Out:
#                  rx_code_key_location
# delivery_status
# Delivered                     29112.5
# Pickedup                       5525.0

# %%
# erx_delivery_data = erx_data[(erx_data['max_date'] > six_month_date)]
erx_delivery_data = erx_data
erx_delivery_data_pie_pivot = pd.pivot_table(dff, values = 'rx_code_key_location', index=['delivery_status'], aggfunc = 'count').reset_index()
# erx_delivery_data_pie_pivot.iloc[0,1]=32680
# erx_delivery_data_pie_pivot.iloc[1,1]=3632
mylabels = (erx_delivery_data_pie_pivot['rx_code_key_location']/6).to_list()
my_labels = 'Delivered '+str(f'{int(mylabels[0]):,}'),'pickedup '+str(f'{int(mylabels[1]):,}')
my_explode = (0, 0.1)
plt.pie(erx_delivery_data_pie_pivot['rx_code_key_location']/6, labels=my_labels, autopct='%1.2f%%', startangle=90, shadow = False, explode=my_explode,colors=color_code)
plt.title('Mode of Rx Transfer Delivery',fontsize = font_size_title,fontweight=font_weight ,fontname = font_name)
plt.axis('equal')

plt.savefig(output_image_path+'Mode_of_Rx_Transfer_Delivery.png', bbox_inches='tight', dpi=300,pad_inches = 0)
# plt.show()

plt.close()

# %%
erx_delivery_data['pharmacy loc'].unique()
# Out:
# array(['NY-BK', 'NJ-SO', 'PA-PH', 'MD-BA', 'FL-MI', 'NY-MA', 'NC-RA'],
#       dtype=object)

# %%
# erx_delivery_data = erx_data[(erx_data['max_date'] > six_month_date)]

erx_delivery_data_month_wise = pd.pivot_table(dff, values = 'rx_code_key_location', columns = 'delivery_status', index = ['mon_key_2'], aggfunc = 'count').reset_index()

erx_delivery_data_month_wise['mon_key_2'] = pd.to_datetime(erx_delivery_data_month_wise['mon_key_2'], format = "%b-%y")
erx_delivery_data_month_wise['mon_key_3'] = erx_delivery_data_month_wise['mon_key_2'].dt.strftime('%b-%y')
erx_delivery_data_month_wise.sort_values(by = 'mon_key_2', inplace = True)
erx_delivery_data_month_wise.drop(columns = 'mon_key_2', inplace = True)
erx_delivery_data_month_wise.rename(columns = {'mon_key_3':'mon_key_2'}, inplace = True)

erx_delivery_data_month_wise
# Out:
# delivery_status  Delivered  Pickedup mon_key_2
# 2                    28488      5058    Jul-21
# 0                    30078      5515    Aug-21
# 5                    31044      5414    Sep-21
# 4                    29508      5129    Oct-21
# 3                    29379      5341    Nov-21
# 1                    26178      6693    Dec-21

# %%
erx_delivery_data_month_wise_line = erx_delivery_data_month_wise
erx_delivery_data_month_wise_line.columns
erx_delivery_data_month_wise_line['Total'] = erx_delivery_data_month_wise_line['Pickedup'] + erx_delivery_data_month_wise_line['Delivered']
erx_delivery_data_month_wise_line['per change'] = round(erx_delivery_data_month_wise_line['Total'].pct_change()*100,2)
erx_delivery_data_month_wise_line = erx_delivery_data_month_wise_line.fillna(0)
erx_delivery_data_month_wise_line
# Out:
# delivery_status  Delivered  Pickedup mon_key_2  Total  per change
# 2                    28488      5058    Jul-21  33546        0.00
# 0                    30078      5515    Aug-21  35593        6.10
# 5                    31044      5414    Sep-21  36458        2.43
# 4                    29508      5129    Oct-21  34637       -4.99
# 3                    29379      5341    Nov-21  34720        0.24
# 1                    26178      6693    Dec-21  32871       -5.33

# %%
# erx_delivery_data = erx_data[(erx_data['max_date'] > six_month_date)]
erx_delivery_data = erx_data
erx_delivery_data_month_wise = pd.pivot_table(dff, values = 'rx_code_key_location', columns = 'delivery_status', index = ['mon_key_2'], aggfunc = 'count').reset_index()

erx_delivery_data_month_wise['mon_key_2'] = pd.to_datetime(erx_delivery_data_month_wise['mon_key_2'], format = "%b-%y")
erx_delivery_data_month_wise['mon_key_3'] = erx_delivery_data_month_wise['mon_key_2'].dt.strftime('%b-%y')
erx_delivery_data_month_wise.sort_values(by = 'mon_key_2', inplace = True)
erx_delivery_data_month_wise.drop(columns = 'mon_key_2', inplace = True)
erx_delivery_data_month_wise.rename(columns = {'mon_key_3':'mon_key_2'}, inplace = True)

erx_delivery_data_month_wise
# Out:
# delivery_status  Delivered  Pickedup mon_key_2
# 2                    28488      5058    Jul-21
# 0                    30078      5515    Aug-21
# 5                    31044      5414    Sep-21
# 4                    29508      5129    Oct-21
# 3                    29379      5341    Nov-21
# 1                    26178      6693    Dec-21

# %%
ax = erx_delivery_data_month_wise.plot(kind = 'bar', stacked = True, x = 'mon_key_2', rot = 360, figsize = (10,5), legend = False,color=color_code,width=bar_width)
erx_delivery_data_month_wise_line.plot(ax = ax, kind = 'line', x = 'mon_key_2', y = 'Total', color = 'grey', legend = False)

# # for p in ax.patches:
# #     b = p.get_bbox()
# #     val = "{}".format(int(p.get_height()))
# #     m = p.get_height()
# #     plt.annotate(val, ((b.x0 + b.x1)/2.05 , b.y1),fontsize=10, ha='center', va='center')

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, f'{int(height):,}', horizontalalignment='center', verticalalignment='center')

rects = ax.patches

texts = []

for rect, total, per in zip(rects, erx_delivery_data_month_wise_line['Total'], erx_delivery_data_month_wise_line['per change']):
    text = ax.text(rect.get_x() + rect.get_width() / 2, total, f'{int(total):,}'+' ('+str(per)+'% '+')',#str(per)+'% '+f'{int(total):,}',
            ha='center', va='center')
    texts.append(text)
adjust_text(texts)
    
plt.ylabel("Count of Rx")
plt.xlabel("Month Year")
plt.title("Rx Delivery M-o-M analysis",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

max_y_limit = erx_delivery_data_month_wise_line['Total'].max()
per_10 = (10/100) * max_y_limit + max_y_limit
ax.set_ylim(0, per_10)

# orange_patch = mpatches.Patch(color = 'orange', label = 'Pickedup')
# blue_patch = mpatches.Patch(color = 'steelblue', label = 'Delivered')
# trend = mpatches.Patch(color = 'grey', label = 'Total')
plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=3, borderaxespad=0.,fontsize = font_size)
# plt.legend(handles = [orange_patch, blue_patch, trend],title='is pickedup?', bbox_to_anchor=(1.0, 1), loc='upper left')

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.savefig(output_image_path+'Delivery_M-o-M_analysis_eRx.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()
# plt.show()

# %%
erx_delivery_data_pharmacy_wise = pd.pivot_table(dff, values = 'rx_code_key_location', columns = 'delivery_status', index = ['pharmacy loc'], aggfunc = 'count').reset_index()
erx_delivery_data_pharmacy_wise.rename(columns = {False: 'False', True: 'True'}, inplace =True)
# print(erx_delivery_data_pharmacy_wise)
df_total = erx_delivery_data_pharmacy_wise['Delivered'] + erx_delivery_data_pharmacy_wise['Pickedup']
erx_delivery_data_pharmacy_wise['Delivered'] = erx_delivery_data_pharmacy_wise[erx_delivery_data_pharmacy_wise.columns[1:2]].div(df_total, 0)*100
erx_delivery_data_pharmacy_wise['Pickedup'] = erx_delivery_data_pharmacy_wise[erx_delivery_data_pharmacy_wise.columns[2:]].div(df_total, 0)*100

ax = erx_delivery_data_pharmacy_wise.plot(kind = 'bar', stacked = True, x = 'pharmacy loc',figsize=(10,5),rot=360,color=color_code,width=bar_width)

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.text(x+width/2, y+height/2, '{:.0f}%'.format(height), horizontalalignment='center', verticalalignment='center')

plt.ylabel("Percentage Rx")
plt.xlabel("Pharmacy Location")
plt.title("Location wise mode of Delivery",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

# orange_patch = mpatches.Patch(color = 'orange', label = 'Pickedup')
# blue_patch = mpatches.Patch(color = 'steelblue', label = 'Delivered')

# plt.legend(handles = [orange_patch, blue_patch],title='is pickedup?', bbox_to_anchor=(1.0, 1), loc='upper left')
plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=2, borderaxespad=0.,fontsize = font_size)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
#erx_delivery_data_pharmacy_wise

plt.savefig(output_image_path+'Location_wise_mode_of_delivery.png', bbox_inches='tight', dpi=300,pad_inches = 0)
plt.close()
# plt.show()

# %%
len(erx_delivery_data)
# Out:
# 317713

# %%
erx_delivery_data_pharmacy_wise_Rx_tbl = pd.pivot_table(dff, values = 'rx_code_key_location', columns = 'pharmacy loc', index = ['delivery_status'], aggfunc = 'count').reset_index()
#erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl.rename(columns = {'pharmacy_loc': 'pharmacy loc'})
erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl.append(erx_delivery_data_pharmacy_wise_Rx_tbl.sum(axis=0), ignore_index = True)

erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl.rename(columns = {'delivery_status': 'pharmacy loc/is pickedup'})
erx_delivery_data_pharmacy_wise_Rx_tbl.iloc[[0],[0]] = 'Delivered'
erx_delivery_data_pharmacy_wise_Rx_tbl.iloc[[1],[0]] = 'Pickedup'
erx_delivery_data_pharmacy_wise_Rx_tbl.iloc[[2],[0]] = 'Total'
erx_delivery_data_pharmacy_wise_Rx_tbl
erx_delivery_data_pharmacy_wise_Rx_tbl.set_index('pharmacy loc/is pickedup', inplace = True)
erx_delivery_data_pharmacy_wise_Rx_tbl['Total'] = erx_delivery_data_pharmacy_wise_Rx_tbl.sum(axis=1)
erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl.fillna(0)
erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl[erx_delivery_data_pharmacy_wise_Rx_tbl.columns[:]].div(6,0).astype(int)
erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl.sort_values(erx_delivery_data_pharmacy_wise_Rx_tbl.last_valid_index(), axis = 1, ascending = False)
erx_delivery_data_pharmacy_wise_Rx_tbl
subset_value = (erx_delivery_data_pharmacy_wise_Rx_tbl.index.to_list()[:-1], 
               ['NY-BK', 'NJ-SO', 'PA-PH', 'FL-MI', 'NY-MA', 'MD-BA', 'NC-RA'])

erx_delivery_data_pharmacy_wise_Rx_tbl = erx_delivery_data_pharmacy_wise_Rx_tbl[['NY-BK', 'NJ-SO', 'PA-PH', 'FL-MI', 'NY-MA', 'MD-BA', 'NC-RA','Total']]

df_style = erx_delivery_data_pharmacy_wise_Rx_tbl.style.set_properties(**body_design).background_gradient(cmap='GnBu',axis=1, subset = subset_value).format("{:,}")
df_style.set_table_styles([border_design])
#df_style = erx_delivery_data_pharmacy_wise_Rx_tbl.style.background_gradient(cmap ='GnBu', axis = 1).format("{:,}")
dfi.export(df_style, output_image_path+'erx_delivery_data_pharmacy_wise_Rx_count_table.png')
df_style
# Out:
# <style  type="text/css" >
#     #T_c7cab_ th {
#           background-color: #F1F1F1;
#           border-style: solid;
#           font-family: Nunito;
#           font-size: 10;
#           border-width: 0.5px;
#           text-align: center;
#           border-color: #B0BCC8;
#     }#T_c7cab_row0_col0,#T_c7cab_row1_col0{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #084081;
#             color:  #f1f1f1;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_c7cab_row0_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #7fcdc3;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #7fcdc3;
#             color:  #000000;
#         }#T_c7cab_row0_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dcf1d7;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #dcf1d7;
#             color:  #000000;
#         }#T_c7cab_row0_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #e6f6e1;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #e6f6e1;
#             color:  #000000;
#         }#T_c7cab_row0_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #edf8e7;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #edf8e7;
#             color:  #000000;
#         }#T_c7cab_row0_col5{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f1faeb;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f1faeb;
#             color:  #000000;
#         }#T_c7cab_row0_col6,#T_c7cab_row1_col5{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f7fcf0;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_c7cab_row0_col7,#T_c7cab_row1_col7,#T_c7cab_row2_col0,#T_c7cab_row2_col1,#T_c7cab_row2_col2,#T_c7cab_row2_col3,#T_c7cab_row2_col4,#T_c7cab_row2_col5,#T_c7cab_row2_col6,#T_c7cab_row2_col7{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#         }#T_c7cab_row1_col1{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #91d4bd;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #91d4bd;
#             color:  #000000;
#         }#T_c7cab_row1_col2{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f0f9e9;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }#T_c7cab_row1_col3{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d7efd1;
#             color:  #000000;
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;
#             border-style:  solid;
#             font-family:  Nunito;
#             font-size:  10;
#             text-align:  center;
#             background-color:  #d7efd1;
#             color:  #000000;
#         }#T_c7cab_row1_col4{
#             background:  white;
#             color:  black;
#             border-color:  #B0BCC8;
#             border-width:  0.5px;

# %%
# erx_delivery_data

# %%
# Rx as pickedup

# %%
erx_delivery_data['pharmacy loc'].unique()
# Out:
# array(['NY-BK', 'NJ-SO', 'PA-PH', 'MD-BA', 'FL-MI', 'NY-MA', 'NC-RA'],
#       dtype=object)

# %%
for i in np.unique(erx_delivery_data['pharmacy loc']):
    delivery_df = dff[dff['pharmacy loc'] == i]

    D_pickedup = delivery_df[delivery_df['is_pickedup'] == True]
    #FL_MI_d_delivered = delivery_df[delivery_df['is_pickedup'] == False]

    delivery_Rx_month_wise = pd.pivot_table(D_pickedup, values = 'rx_code_key_location', columns = 'delivery_status', index = ['mon_key_2'], aggfunc = 'count').reset_index()
#     print(delivery_Rx_month_wise)
    delivery_Rx_month_wise['mon_key_2'] = pd.to_datetime(delivery_Rx_month_wise['mon_key_2'], format = "%b-%y")
    delivery_Rx_month_wise['mon_key_3'] = delivery_Rx_month_wise['mon_key_2'].dt.strftime('%b-%y')
    delivery_Rx_month_wise.sort_values(by = 'mon_key_2', inplace = True)
    delivery_Rx_month_wise.drop(columns = 'mon_key_2', inplace = True)
    delivery_Rx_month_wise.rename(columns = {'mon_key_3': 'mon_key_2'}, inplace =True)
    delivery_Rx_month_wise['per_growth'] = round(delivery_Rx_month_wise['Pickedup'].pct_change()*100,2)
#     print(delivery_Rx_month_wise)
    avgdf = pd.DataFrame(columns = ['Pickedup', 'mon_key_2'], index=range(0,1))
    avgdf['Pickedup'] = int(delivery_Rx_month_wise['Pickedup'].mean())
    avgdf['mon_key_2'] = 'avg'

    delivery_Rx_month_wise = delivery_Rx_month_wise.append(avgdf)
    delivery_Rx_month_wise = delivery_Rx_month_wise.fillna(0)
    delivery_Rx_month_wise_line = delivery_Rx_month_wise
    
    if len(delivery_Rx_month_wise) == 5:
        c = [blue_color, blue_color, blue_color, blue_color, green_color]
    elif len(delivery_Rx_month_wise) == 6:
        c = [blue_color, blue_color, blue_color, blue_color,blue_color, green_color]
    else:
        c = [blue_color, blue_color, blue_color, blue_color, blue_color,blue_color, green_color]
        
    ax = delivery_Rx_month_wise.plot(kind = 'bar', x = 'mon_key_2', y = 'Pickedup', rot = 360, figsize = (10,5), legend = False, color=c,width=bar_width)
    
    for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), horizontalalignment='center', verticalalignment='center', color = 'black')
    
    ax2 = delivery_Rx_month_wise_line[:-1].plot(ax = ax, secondary_y=True, kind = 'line', x = 'mon_key_2', y = 'per_growth', color = 'black', legend = False)
    texts = []
    for p,k in zip(ax.patches, delivery_Rx_month_wise_line.per_growth):
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        text = ax.text(x+width/2, y+height, str(round(k,2))+'%', horizontalalignment='center', verticalalignment='center')
        texts.append(text)
    adjust_text(texts)
    
    labels = [item.get_text() for item in ax.get_xticklabels()]
    labels[6] = 'Avg'

    ax.set_xticklabels(labels)
    
    ax.set_xlabel('Month Year')
    ax.set_ylabel('Count of Rx')
    ax2.set_ylabel('per_growth')
    #ax.set_ylim(0,1400)
    max_y_limit = delivery_Rx_month_wise_line['Pickedup'].max()
    per_10 = (10/100) * max_y_limit + max_y_limit
    ax.set_ylim(0, per_10)
    
    plt.xlabel("Month Year")
    plt.title(str(i)+" Rx pickedup M-o-M analysis",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

    ax2.spines['top'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=1, borderaxespad=0.,fontsize = font_size)
#     plt.legend(title='Pickedup', bbox_to_anchor=(1.0, 1), loc='upper left')
    #delivery_Rx_month_wise

    plt.savefig(output_image_path+str(i)+'_pickedup_trend.png', bbox_inches='tight', dpi=300,pad_inches = 0)
    plt.close()
#     plt.show()

# %%
# Rx as delivered

# %%
for i in np.unique(erx_delivery_data['pharmacy loc']):
    delivery_df = dff[dff['pharmacy loc'] == i]

    #D_pickedup = delivery_df[delivery_df['is_pickedup'] == True]
    D_delivered = delivery_df[delivery_df['is_pickedup'] == False]

    delivery_Rx_month_wise = pd.pivot_table(D_delivered, values = 'rx_code_key_location', columns = 'delivery_status', index = ['mon_key_2'], aggfunc = 'count').reset_index()
    delivery_Rx_month_wise['mon_key_2'] = pd.to_datetime(delivery_Rx_month_wise['mon_key_2'], format = "%b-%y")
    delivery_Rx_month_wise['mon_key_3'] = delivery_Rx_month_wise['mon_key_2'].dt.strftime('%b-%y')
    delivery_Rx_month_wise.sort_values(by = 'mon_key_2', inplace = True)
    delivery_Rx_month_wise.drop(columns = 'mon_key_2', inplace = True)
    delivery_Rx_month_wise.rename(columns = {'mon_key_3': 'mon_key_2'}, inplace =True)
#     print(delivery_Rx_month_wise)
    delivery_Rx_month_wise['per_growth'] = round(delivery_Rx_month_wise['Delivered'].pct_change()*100,2)

    avgdf = pd.DataFrame(columns = ['Delivered', 'mon_key_2'], index=range(0,1))
    avgdf['Delivered'] = int(delivery_Rx_month_wise['Delivered'].mean())
    avgdf['mon_key_2'] = 'avg'

    delivery_Rx_month_wise = delivery_Rx_month_wise.append(avgdf)
    delivery_Rx_month_wise = delivery_Rx_month_wise.fillna(0)
    delivery_Rx_month_wise_line = delivery_Rx_month_wise
    
    if len(delivery_Rx_month_wise_line) == 5:
        c = [blue_color, blue_color, blue_color, blue_color, green_color]
    elif len(delivery_Rx_month_wise_line) == 6:
        c = [blue_color, blue_color, blue_color, blue_color,blue_color, green_color]
    else:
        c = [blue_color, blue_color, blue_color, blue_color, blue_color,blue_color, green_color]

    ax = delivery_Rx_month_wise.plot(kind = 'bar', x = 'mon_key_2', y = 'Delivered', rot = 360, figsize = (10,5), legend = False, color=c,width=bar_width)

    for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        ax.text(x+width/2, y+height/2, '{:.0f}'.format(height), horizontalalignment='center', verticalalignment='center', color = 'black')
    
    ax2 = delivery_Rx_month_wise_line[:-1].plot(ax = ax, secondary_y=True, kind = 'line', x = 'mon_key_2', y = 'per_growth', color = 'black', legend = False)
    
    texts = []
    
    for p,k in zip(ax.patches, delivery_Rx_month_wise_line.per_growth):
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        text = ax.text(x+width/2, y+height, str(round(k,2))+'%', horizontalalignment='center', verticalalignment='center')
        texts.append(text)
    adjust_text(texts)
    
    labels = [item.get_text() for item in ax.get_xticklabels()]
    labels[6] = 'Avg'

    ax.set_xticklabels(labels)
    
    ax.set_xlabel('Month Year')
    ax.set_ylabel('Count of Rx')
    ax2.set_ylabel('per_growth')
    #ax.set_ylim(0,1400)
    max_y_limit = delivery_Rx_month_wise_line['Delivered'].max()
    per_10 = (10/100) * max_y_limit + max_y_limit
    ax.set_ylim(0, per_10)
    
    plt.xlabel("Month Year")
    plt.title(str(i)+" Rx delivered M-o-M analysis",fontsize = font_size_title,fontweight=font_weight ,fontname = font_name, x=0.5, y=1.1)

    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

    ax2.spines['top'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['bottom'].set_visible(False)
    plt.legend(bbox_to_anchor=(0.70, 1.08), ncol=1, borderaxespad=0.,fontsize = font_size)
#     plt.legend(title='Delivered', bbox_to_anchor=(1.0, 1), loc='upper left')
    #delivery_Rx_month_wise

    plt.savefig(output_image_path+str(i)+'_delivered_trend.png', bbox_inches='tight', dpi=300,pad_inches = 0)
    plt.close()
#     plt.show()

# %% [markdown]
# ## Automation

# %%
import datetime
# df.sort_values(by = 'mon_key', inplace = True)
months_list = eRx_month_wise['mon_key_2'].unique()
start_to_end_month = [months_list[0],months_list[-1]]
for i in range(len(start_to_end_month)):
    if i==0:
        start_month = start_to_end_month[i]
        print(start_month)
    else:
        end_month = start_to_end_month[i]
        print(end_month)
# Out:
# Jul-21
# Dec-21

# %%
import pptx
import pandas as pd
import numpy as np
import glob
from pptx.enum.shapes import MSO_SHAPE_TYPE
from pptx.util import Inches
import copy
from pptx.shapes.autoshape import Shape

from pptx.shapes.graphfrm import GraphicFrame

from pptx.dml.color import RGBColor
from pptx.enum.dml import MSO_THEME_COLOR

from pptx.util import Inches,Pt
from pptx.enum.text import PP_ALIGN
from pptx.enum.dml import MSO_LINE
from pptx.enum.text import MSO_ANCHOR
from pptx.enum.dml import MSO_COLOR_TYPE, MSO_FILL
import re

# %%
_EMUS_PER_INCH = 914400
_EMUS_PER_CENTIPOINT = 127
_EMUS_PER_CM = 360000
_EMUS_PER_MM = 36000
_EMUS_PER_PT = 12700

# %%
ppt_output = pptx.Presentation()

# %%
wbr_template = pptx.Presentation('template_overall_up.pptx')

# %%
ppt_output.slide_width = wbr_template.slide_width
ppt_output.slide_height = wbr_template.slide_height

# %%
image_replace_path = output_image_path

# %%
""" create base template file """
writer = pd.ExcelWriter('excel.xlsx', engine='xlsxwriter')

for slide in wbr_template.slides:
    slide_no = (wbr_template.slides.index(slide))+1
    sheetname = "slide_{:02d}".format(slide_no)
    tdf = pd.DataFrame()
    
    for shape in slide.shapes:
        odf = pd.DataFrame([['','','','','','']],\
                           columns=['slide_no','shape_name','shape_type','shape_id','template_value','replace_value'])
        #odf = pd.DataFrame([])
        odf['slide_no'] = sheetname
        odf['shape_name'] = shape.name
        odf['shape_id'] = shape.shape_id
        
        if shape.shape_type == MSO_SHAPE_TYPE.PICTURE:
            odf['shape_type'] ='image'
            try:
                odf['template_value'] = copy.deepcopy(shape).element.xpath("//p:nvPicPr//p:cNvPr/@descr")[0] 
            except:
                odf['template_value'] = shape.name
        if shape.shape_type == MSO_SHAPE_TYPE.TEXT_BOX:
            odf['shape_type'] = 'text box'
            odf['template_value'] = shape.text
        
        tdf = tdf.append(odf)
    
    tdf.to_excel(writer,sheet_name=sheetname,index=False)

writer.save()

# %%
schemecolormap = {'accent1': MSO_THEME_COLOR.ACCENT_1,\
                 'accent2': MSO_THEME_COLOR.ACCENT_2,\
                  'accent3': MSO_THEME_COLOR.ACCENT_3,\
                  'accent4': MSO_THEME_COLOR.ACCENT_4,\
                  'accent5': MSO_THEME_COLOR.ACCENT_5,\
                  'accent6': MSO_THEME_COLOR.ACCENT_6,\
                  'bg1': MSO_THEME_COLOR.BACKGROUND_1,\
                  'bg2': MSO_THEME_COLOR.BACKGROUND_2,\
                  'dk1': MSO_THEME_COLOR.DARK_1,\
                  'dk2': MSO_THEME_COLOR.DARK_2,\
                  'lt1': MSO_THEME_COLOR.LIGHT_1,\
                  'lt2': MSO_THEME_COLOR.LIGHT_2,\
                  'tx1': MSO_THEME_COLOR.TEXT_1,\
                  'tx2': MSO_THEME_COLOR.TEXT_2
                 
                 }

# %%
paragraph_align_map = {
    "ctr": PP_ALIGN.CENTER,\
    "r": PP_ALIGN.RIGHT,
    "l": PP_ALIGN.LEFT,
    
}

# %%
box_border_dashmap = {
    
    "solid": MSO_LINE.SOLID,\
    "dot": MSO_LINE.ROUND_DOT,\
    "dash": MSO_LINE.DASH,\
    "lgDash": MSO_LINE.LONG_DASH,\
    "dashDot": MSO_LINE.DASH_DOT,\
    "lgDashDot": MSO_LINE.LONG_DASH_DOT,\
    "lgDashDotDot": MSO_LINE.DASH_DOT_DOT,\
    "sysDash": MSO_LINE.DASH,\
    "sysDot": MSO_LINE.SQUARE_DOT,\
    "sysDashDot": MSO_LINE.DASH_DOT,\
    "sysDashDotDot": MSO_LINE.DASH_DOT_DOT,\
    
    
}

# %%
def get_rgb_color(color_string):

    rcol = int(color_string[0:2],16)
    bcol = int(color_string[2:4],16)
    gcol = int(color_string[4:6],16)
    
    return RGBColor(rcol,bcol,gcol)

# %%
def get_textbox_properties(sph):
    #print(sph.element.xml)
    
    fillcolor_schemecolor = (sph.element.xpath("//p:spPr/a:solidFill//a:schemeClr/@val"))
    fillcolor_rbgcolor = (sph.element.xpath("//p:spPr/a:solidFill//a:srgbClr/@val"))
    fontsz = (sph.element.xpath("//a:rPr/@sz"))
    fontface = (sph.element.xpath("//a:rPr//@typeface"))
    fillbrightness = sph.element.xpath("//p:spPr/a:solidFill//a:schemeClr//a:lumOff//@val")
    filldarkness = sph.element.xpath("//p:spPr/a:solidFill//a:schemeClr//a:lumMod//@val")
    
    font_isbold = (sph.element.xpath("//a:rPr/@b"))
    font_isitalic = (sph.element.xpath("//a:rPr/@i"))
    font_isunderline = (sph.element.xpath("//a:rPr/@u"))
    font_iscentered = (sph.element.xpath("//a:rPr/a:cs"))
    font_alignment = (sph.element.xpath("//p:txBody//a:p//a:pPr/@algn"))
    
    box_border_schemecolor = (sph.element.xpath("//p:spPr//a:ln//a:solidFill//a:schemeClr/@val"))
    box_border_rbgcolor = (sph.element.xpath("//p:spPr//a:ln//a:solidFill//a:srgbClr/@val"))
    box_border_width = (sph.element.xpath("//p:spPr//a:ln/@w"))
    box_border_brightness = (sph.element.xpath("//p:spPr//a:ln//a:solidFill//a:schemeClr//a:lumOff/@val"))
    box_border_darkness = (sph.element.xpath("//p:spPr//a:ln//a:solidFill//a:schemeClr//a:lumMod/@val"))
    box_border_isdash = (sph.element.xpath("//p:spPr//a:ln//a:prstDash/@val"))
    
    
    if (len(fillbrightness)==0)&(len(filldarkness)!=0):
        fillbrightness = [100000-int(filldarkness[0])]
    
    if (len(box_border_brightness)==0)&(len(box_border_darkness)!=0):
        box_border_brightness = [100000-int(box_border_darkness[0])]
       
    if len(font_iscentered)!=0:
        palign = paragraph_align_map.get("ctr")
    else:
        try:
            palign = paragraph_align_map.get(font_alignment[0])
        except:
            palign = paragraph_align_map.get('r')
    
    #print(sph.fill.fore_color.type==MSO_COLOR_TYPE.SCHEME)
    
    outdict = {
        
        #"fillcolor_schemecolor": schemecolormap.get(fillcolor_schemecolor[0]) if len(fillcolor_schemecolor)!=0 else None,\
        "fillcolor_schemecolor": (sph.fill.fore_color.theme_color) if len(fillcolor_schemecolor)!=0 else None,\
        "fillcolor_rbgcolor": get_rgb_color(fillcolor_rbgcolor[0]) if len(fillcolor_rbgcolor)!=0 else None,\
        "fontsz": (int(fontsz[0])/100) if len(fontsz)!=0 else None,\
        "fontface": fontface[0] if len(fontface)!=0 else None,\
        "fillbrightness": (int(fillbrightness[0])/100000) if len(fillbrightness)!=0 else None,\
        "font_isbold": True if len(font_isbold)!=0 else False,\
        "font_isitalic": True if len(font_isitalic)!=0 else False,\
        "font_isunderline": True if len(font_isunderline)!=0 else False,\
        "font_alignment": palign,\
        
        "box_border_schemecolor": schemecolormap.get(box_border_schemecolor[0]) if len(box_border_schemecolor)!=0 else None,\
        "box_border_rbgcolor": get_rgb_color(box_border_rbgcolor[0]) if len(box_border_rbgcolor)!=0 else None,\
        "box_border_brightness": (int(box_border_brightness[0])/100000) if len(box_border_brightness)!=0 else None,\
        "box_border_width" : (int(box_border_width[0])/_EMUS_PER_PT) if len(box_border_width)!=0 else None,\
        "box_border_isdash":box_border_dashmap.get(box_border_isdash[0]) if len(box_border_isdash)!=0 else None
        
        
    }
    
    return outdict

# %%
def set_textbox_properties(tb,prop_dict):
    print(prop_dict)
    tf = tb.text_frame
    p = tf.paragraphs[0]
    run =p.add_run()
    #run.text = shape.text
    
    if prop_dict["fillcolor_schemecolor"]:
        tb.fill.solid()
        print(prop_dict["fillcolor_schemecolor"])
        tb.fill.fore_color.theme_color = prop_dict["fillcolor_schemecolor"]
    
    if prop_dict["fillcolor_rbgcolor"]:
        tb.fill.solid()
        tb.fill.fore_color.rgb = prop_dict["fillcolor_rbgcolor"]
        
    if prop_dict["fillbrightness"]:
        tb.fill.fore_color.brightness = prop_dict["fillbrightness"]
        #pass
    
    if prop_dict["fontsz"]:
        run.font.size=Pt(prop_dict["fontsz"])
        
    if prop_dict["fontface"]:
        run.font.name =prop_dict["fontface"]
    
    run.font.bold = prop_dict["font_isbold"]
    run.font.italic = prop_dict["font_isitalic"]
    run.font.underline = prop_dict["font_isunderline"]
    
    p.alignment = prop_dict["font_alignment"]
    
    if prop_dict["box_border_schemecolor"]:
        tb.line.color.theme_color = prop_dict["box_border_schemecolor"]
        
    if prop_dict["box_border_rbgcolor"]:
        tb.line.color.rgb = prop_dict["box_border_rbgcolor"]
    
    if prop_dict["box_border_brightness"]:
        #pass
        tb.line.color.brightness = prop_dict["box_border_brightness"]
    
    if prop_dict["box_border_width"]:
        tb.line.width = Pt(prop_dict["box_border_width"])
        
    if prop_dict["box_border_isdash"]:
        tb.line.dash_style = prop_dict["box_border_isdash"]
    
    
        
    return run

# %%
def set_text_holders(stext,text_replace_dict):
    otext = str(stext)
    sgr = (re.findall(r'{{(.*?)}}',otext))
       
    for sl in sgr:
        print(sl)
        print(str(text_replace_dict.get(sl)))
        otext = (otext).replace(sl,str(text_replace_dict.get(sl)))\
            .replace("{","").replace("}","")
    
    return otext

# %%
total_revenue = 7.17
rx_count = 234
active_provider = 100
patient_served = 678
new_provider = 897
rev_per_rx = 23

# %%
def get_variable_names(stext):
    otext = str(stext)
    sgr = (re.findall(r'{{(.*?)}}',otext))
    return sgr

# %%
def create_image_dict(df):
    xdf = df[['shape_name','replace_value']]
    return xdf.set_index('shape_name').to_dict()["replace_value"]

# %%
def create_variable_dict(df):
    xdf = df[['template_value']]
    
    hlist = []
    for i,r in xdf.iterrows():
        
        xlist = get_variable_names(r['template_value'])
        hlist = hlist + xlist
    
    vdict = {}
    for x in np.unique(np.array(hlist)):
        vdict[x] = eval(x)
    return vdict

# %%
variable_template_df = pd.ExcelFile('Final_excel1.xlsx')

# %%
for slide in wbr_template.slides:
    slide_no = (wbr_template.slides.index(slide))+1
    sheetname = "slide_{:02d}".format(slide_no)
    tslide = slide
    #print(tslide)
    oslide = ppt_output.slides.add_slide(ppt_output.slide_layouts[6])
    vtdf = variable_template_df.parse(sheetname)
    image_replace_dict = create_image_dict(vtdf[vtdf['shape_type']=='image'])
    text_replace_dict = create_variable_dict(vtdf[vtdf['shape_type']=='text box'])
    print(image_replace_dict)
    for shape in tslide.shapes:
        #print(shape._element.xml)
        #print(shape.name)
        sleft = Inches(shape.left/_EMUS_PER_INCH)
        swidth = Inches(shape.width/_EMUS_PER_INCH)
        sheight = Inches(shape.height/_EMUS_PER_INCH)
        stop = Inches(shape.top/_EMUS_PER_INCH)

        if shape.shape_type == MSO_SHAPE_TYPE.PICTURE:
            try:
                img_path = image_replace_path+image_replace_dict.get(shape.name)
                oslide.shapes.add_picture(img_path,left=sleft,top=stop,width=swidth,height=sheight)
            except:
                pass


        if shape.shape_type == MSO_SHAPE_TYPE.TEXT_BOX:
            #print(shape.shape_id)

            cshape = copy.deepcopy(shape)
            property_dict = (get_textbox_properties(cshape))

            tb = oslide.shapes.add_textbox(left=sleft,top=stop,width=swidth,height=sheight)
            run = set_textbox_properties(tb,property_dict)

            run.text = (set_text_holders(shape.text,text_replace_dict))
            print(run.text)

    ppt_output.save(output_ppt_path + 'A_overall_1_to_13.pptx')
    # ppt_output.save(output_ppt_path + 'A_Test.pptx')
# Out:
# {}
# {'Picture 6': 'Mode_of_transfer_by_billing_status.png', 'Picture 12': 'Mode_of_Rx_transfer_Overall.png', 'Picture 14': 'Overall_M-o-M_analysis_Rx_count.png', 'Picture 2': 'overall_pharmacy_wise_Rx_count.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Overview (Mode of Rx Transfer)
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 9.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 3, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# **All the Figures are Average Figs from Oct-20 to Feb-21, unless until month is specified
# {'Picture 6': 'billed_M-o-M_analysis_eRx.png', 'Picture 11': 'Mode_of_Rx_Transfer_Billed_pie.png', 'Picture 14': 'Billed_pharmacy_wise_Rx_count_table.png', 'Picture 16': 'Location_wise_mode_of_Rx_Transfer_billed.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Overview (Mode of Rx Transfer)- Billed
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 9.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 3, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# **All the Figures are Average Figs from Apr-21 to Sept-21
# {'Picture 6': 'Mode_of_Rx_Transfer_non_billed_pie.png', 'Picture 11': 'non_Billed_pharmacy_wise_Rx_count_table.png', 'Picture 14': 'Location_wise_mode_of_Rx_Transfer_non_billed.png', 'Picture 16': 'Non_billed_M-o-M_analysis_eRx.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Overview (Mode of Rx Transfer) Non-Billed
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 9.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 3, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# **All the Figures are Average Figs from Oct-20 to Feb-21, unless until month is specified
# {'Picture 15': 'NY-BK_billed_eRx_trend.png', 'Picture 17': 'NY-BK_billed_non_eRx_trend.png', 'Picture 19': 'NJ-SO_billed_eRx_trend.png', 'Picture 22': 'NJ-SO_billed_non_eRx_trend.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Location Wise (Mode of Transfer) - Billed
# {'Picture 2': 'FL-MI_billed_eRx_trend.png', 'Picture 13': 'FL-MI_billed_non_eRx_trend.png', 'Picture 15': 'NY-MA_billed_eRx_trend.png', 'Picture 17': 'NY-MA_billed_non_eRx_trend.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Location Wise (Mode of Transfer) Cont…
# {'Picture 6': 'MD-BA_billed_eRx_trend.png', 'Picture 13': 'MD-BA_billed_non_eRx_trend.png', 'Picture 15': 'PA-PH_billed_eRx_trend.png', 'Picture 17': 'PA-PH_billed_non_eRx_trend.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Location Wise (Mode of Transfer) Cont…
# {'Picture 8': 'NC-RA_billed_eRx_trend.png', 'Picture 10': 'NC-RA_billed_non_eRx_trend.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 27.0, 'fontface': 'Aldhabi', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Location Wise (Mode of Transfer) Cont…
# {'Picture 6': 'Mode_of_Rx_Transfer_Delivery.png', 'Picture 18': 'Delivery_M-o-M_analysis_eRx.png', 'Picture 22': 'Location_wise_mode_of_delivery.png', 'Picture 2': 'erx_delivery_data_pharmacy_wise_Rx_count_table.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 7.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': False, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 3, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# start_month
# Jul-21
# end_month
# Dec-21
# **All the Figures are Average Figs from Jul-21 to Dec-21
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 20.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Overall (Mode of Delivery) Rx Count Wise
# {'Picture 15': 'NY-BK_delivered_trend.png', 'Picture 17': 'NY-BK_pickedup_trend.png', 'Picture 19': 'FL-MI_pickedup_trend.png', 'Picture 21': 'FL-MI_delivered_trend.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 20.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Location Wise (Rx with Mode of Delivery)
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# NY-BK
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# FL-MI
# {'Picture 6': 'NJ-SO_pickedup_trend.png', 'Picture 12': 'NJ-SO_delivered_trend.png', 'Picture 15': 'PA-PH_pickedup_trend.png', 'Picture 17': 'PA-PH_delivered_trend.png'}
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 20.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# Location Wise (Rx with Mode of Delivery) Cont…
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# NJ-SO
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# PA-PH
# {'Picture 6': 'NY-MA_pickedup_trend.png', 'Picture 13': 'NY-MA_delivered_trend.png', 'Picture 15': 'NC-RA_pickedup_trend.png', 'Picture 17': 'NC-RA_delivered_trend.png'}
# {'fillcolor_schemecolor': None, 'fillcolor_rbgcolor': None, 'fontsz': 20.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# Location Wise (Rx with Mode Of Delivery) Cont…
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# NY-MA
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# NC-RA
# {'Picture 8': 'MD-BA_pickedup_trend.png', 'Picture 10': 'MD-BA_delivered_trend.png'}
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 20.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# Location Wise (Rx with Mode of Delivery) Cont…
# {'fillcolor_schemecolor': 14, 'fillcolor_rbgcolor': None, 'fontsz': 10.0, 'fontface': 'Nunito', 'fillbrightness': None, 'font_isbold': True, 'font_isitalic': False, 'font_isunderline': False, 'font_alignment': 2, 'box_border_schemecolor': None, 'box_border_rbgcolor': None, 'box_border_brightness': None, 'box_border_width': None, 'box_border_isdash': None}
# BACKGROUND_1 (14)
# MD-BA

# %%
oslide.shapes[0].element.xml
# Out:
# '<p:pic xmlns:p="http://schemas.openxmlformats.org/presentationml/2006/main" xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships">\n  <p:nvPicPr>\n    <p:cNvPr id="2" name="Picture 1" descr="MD-BA_pickedup_trend.png"/>\n    <p:cNvPicPr>\n      <a:picLocks noChangeAspect="1"/>\n    </p:cNvPicPr>\n    <p:nvPr/>\n  </p:nvPicPr>\n  <p:blipFill>\n    <a:blip r:embed="rId2"/>\n    <a:stretch>\n      <a:fillRect/>\n    </a:stretch>\n  </p:blipFill>\n  <p:spPr>\n    <a:xfrm>\n      <a:off x="5006451" y="870683"/>\n      <a:ext cx="3948344" cy="1686308"/>\n    </a:xfrm>\n    <a:prstGeom prst="rect">\n      <a:avLst/>\n    </a:prstGeom>\n  </p:spPr>\n</p:pic>\n'
